# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_df = pd.read_csv('data/delta_correlation_df.csv')

# %%
corr_df['Statistical_Significance'] = corr_df.FDR < 0.05

# %%
sns.boxplot(data = corr_df, y = 'Delta_Correlation', x = 'Cancer', showfliers = False)
# Out:
# <AxesSubplot:xlabel='Cancer', ylabel='Delta_Correlation'>

# %%
sns.histplot(data = corr_df, x = 'Delta_Correlation', hue = 'Cancer')
# Out:
# <AxesSubplot:xlabel='Delta_Correlation', ylabel='Count'>

# %%
colors = ['gray', 'orange']
sns.set_palette(sns.color_palette(colors))
g = sns.FacetGrid(data = corr_df, col= 'Cancer', col_wrap= 3, hue = 'Statistical_Significance', hue_order=[True, False])
g.map_dataframe(sns.histplot, x = 'Delta_Correlation')
g.add_legend()

# %%
sns.boxplot(data = corr_df, y = 'Delta_Correlation', x = 'Cancer', showfliers = False)
# Out:
# <AxesSubplot:xlabel='Cancer', ylabel='Delta_Correlation'>

# %%
sns.histplot(data = corr_df, x = 'Delta_Correlation', hue = 'Cancer')
# Out:
# <AxesSubplot:xlabel='Delta_Correlation', ylabel='Count'>

# %%
colors = ['gray', 'orange']
sns.set_palette(sns.color_palette(colors))
g = sns.FacetGrid(data = corr_df, col= 'Cancer', col_wrap= 3, hue = 'Statistical_Significance', hue_order=[True, False])
g.map_dataframe(sns.histplot, x = 'Delta_Correlation')
g.add_legend()

# %%
sns.kdeplot(data = corr_df, x = 'Delta_Correlation', hue = 'Cancer')
# Out:
# <AxesSubplot:xlabel='Delta_Correlation', ylabel='Density'>
