# %%
import cptac
import scipy
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statistics
import parse_correlations_dataframe as get_corr
import copy
# Out:
# cptac warning: Your version of cptac (0.8.5) is out-of-date. Latest is 0.8.6. Please run 'pip install --upgrade cptac' to update it. (<ipython-input-1-147bbc873c03>, line 1)

# %%
cptac.download("endometrial")

en = cptac.Endometrial()

# %% [markdown]
# # Beta-catenin in Endometrial Notebook
#
# The purpose of this notebook is to compare mutated CTNNB1 genes with non mutated genes in cancer cells.

# %%
beta_corr = get_corr.get_data(cancer_type=["endometrial"], tissue_type=["tumor"], genes = ["CTNNB1"], get_corr=True, get_r2=True, get_p=True)
corr = list(beta_corr["Correlation"])[0]
corr
# Out:
# 0.29272750009956416

# %%
beta_corr.head()
# Out:
#        Cancer_Type Tissue_Type    Gene  Correlation   P-value  R-squared
# 38134  Endometrial       tumor  CTNNB1     0.292728  0.003993   0.085689

# %%
trans_prot = en.join_omics_to_omics(df1_name='proteomics', df2_name='transcriptomics')
# Out:
# cptac warning: transcriptomics data was not found for the following samples, so transcriptomics data columns were filled with NaN for these samples: C3L-00563.N, C3L-00605.N, C3L-00769.N, C3L-00770.N, C3L-00771.N, C3L-00930.N, C3L-00947.N, C3L-00963.N, C3L-01246.N, C3L-01249.N, C3L-01252.N, C3L-01256.N, C3L-01257.N, C3L-01744.N, C3N-00200.N, C3N-00729.N, C3N-01211.N, NX1.N, NX10.N, NX11.N, NX12.N, NX13.N, NX14.N, NX15.N, NX16.N, NX17.N, NX18.N, NX2.N, NX3.N, NX4.N, NX5.N, NX6.N, NX7.N, NX8.N, NX9.N (<ipython-input-4-be6fcf8102c9>, line 1)

# %%
trans_prot.head()
# Out:
# Name        A1BG_proteomics  A2M_proteomics  A2ML1_proteomics  \
# Patient_ID
# C3L-00006            -1.180         -0.8630            -0.802
# C3L-00008            -0.685         -1.0700            -0.684
# C3L-00032            -0.528         -1.3200             0.435
# C3L-00090            -1.670         -1.1900            -0.443
# C3L-00098            -0.374         -0.0206            -0.537
#
# Name        A4GALT_proteomics  AAAS_proteomics  AACS_proteomics  \
# Patient_ID
# C3L-00006               0.222           0.2560           0.6650
# C3L-00008               0.984           0.1350           0.3340
# C3L-00032                 NaN          -0.2400           1.0400
# C3L-00090               0.243          -0.0993           0.7570
# C3L-00098               0.311           0.3750           0.0131
#
# Name        AADAT_proteomics  AAED1_proteomics  AAGAB_proteomics  \
# Patient_ID
# C3L-00006             1.2800           -0.3390             0.412
# C3L-00008             1.3000            0.1390             1.330
# C3L-00032            -0.0213           -0.0479             0.419
# C3L-00090             0.7400           -0.9290             0.229
# C3L-00098            -1.1000               NaN             0.565
#
# Name        AAK1_proteomics  ...  ZWILCH_transcriptomics  \
# Patient_ID                   ...
# C3L-00006            -0.664  ...                   11.06
# C3L-00008            -0.367  ...                   10.87
# C3L-00032            -0.500  ...                   10.06
# C3L-00090            -0.223  ...                   10.29
# C3L-00098            -0.101  ...                   10.36
#
# Name        ZWINT_transcriptomics  ZXDA_transcriptomics  ZXDB_transcriptomics  \
# Patient_ID
# C3L-00006                   10.73                  8.40                  9.78
# C3L-00008                   11.43                  8.39                  9.14
# C3L-00032                   10.13                  8.35                  9.27
# C3L-00090                   10.41                  9.10                  9.59
# C3L-00098                   11.24                  8.60                  9.44
#
# Name        ZXDC_transcriptomics  ZYG11A_transcriptomics  \
# Patient_ID
# C3L-00006                  10.88                    5.93
# C3L-00008                  10.38                    7.25
# C3L-00032                  10.46                    6.85
# C3L-00090                  10.15                    7.89
# C3L-00098                  11.80                    9.32
#
# Name        ZYG11B_transcriptomics  ZYX_transcriptomics  \
# Patient_ID
# C3L-00006                    11.52                10.23
# C3L-00008                    11.64                10.64
# C3L-00032                    11.60                10.21
# C3L-00090                    11.90                10.21
# C3L-00098                    11.97                 9.77
#
# Name        ZZEF1_transcriptomics  ZZZ3_transcriptomics
# Patient_ID
# C3L-00006                   11.50                 11.47
# C3L-00008                   11.26                 11.57
# C3L-00032                   11.51                 11.09
# C3L-00090                   11.34                 11.51
# C3L-00098                   11.37                 12.35
#
# [5 rows x 39056 columns]

# %%
beta_multi = en.multi_join({'proteomics': 'CTNNB1', 'transcriptomics':'CTNNB1', 'somatic_mutation' : 'CTNNB1'}, tissue_type = "tumor")

# %%
beta_multi.head()
# Out:
# Name        CTNNB1_proteomics  CTNNB1_transcriptomics CTNNB1_Mutation  \
# Patient_ID
# C3L-00006             0.80300                   14.38             NaN
# C3L-00008             0.42600                   14.60             NaN
# C3L-00032             0.00891                   15.07             NaN
# C3L-00090             0.78800                   14.56             NaN
# C3L-00098            -0.40200                   14.47             NaN
#
# Name       CTNNB1_Location CTNNB1_Mutation_Status
# Patient_ID
# C3L-00006              NaN                    NaN
# C3L-00008              NaN                    NaN
# C3L-00032              NaN                    NaN
# C3L-00090              NaN                    NaN
# C3L-00098              NaN                    NaN

# %%
catenin = []
for index, i in enumerate(beta_multi["CTNNB1_Location"]):
    
    if (type(i) == list):

        if(len(i) == 1):
            if (i[0][3] == '3') and (i[0][4] == '3'):
                catenin.append(index)
            if ((i[0][3] == '3') and (i[0][4] == '7')):
                catenin.append(index)
            if ((i[0][3] == '3') and (i[0][4] == '2')):
                catenin.append(index)
            if ((i[0][3] == '3') and (i[0][4] == '4')):
                catenin.append(index)
            if ((i[0][3] == '4') and (i[0][4] == '1')):
                catenin.append(index)
            if ((i[0][3] == '4') and (i[0][4] == '5')):
                catenin.append(index)
        if (len(i) > 1):
            for j in i:
                
                if (j[3] == '3') and (j[4] == '3'):
                    catenin.append(index)
                    break
                if ((j[3] == '3') and (j[4] == '7')):
                    catenin.append(index)
                    break
                if ((j[3] == '3') and (j[4] == '2')):
                    catenin.append(index)
                    break
                if ((j[3] == '3') and (j[4] == '4')):
                    catenin.append(index)
                    break
                if ((j[3] == '4') and (j[4] == '1')):
                    catenin.append(index)
                    break
                if ((j[3] == '4') and (j[4] == '5')):
                    catenin.append(index)
                    break

# %%
trans_col = list(beta_multi['CTNNB1_transcriptomics'])
prot_col = list(beta_multi['CTNNB1_proteomics'])
label_col = []
index_col = []
for i in range(len(trans_col)):
    if i in catenin:
        label_col.append("Mutation")
    else:
        label_col.append("Wild_type")
    index_col.append(i)

# %%
beta_df = pd.DataFrame({"Label" : label_col, "Proteomics" : prot_col, "Transcriptomics" : trans_col })

# %%
beta_df.head()
# Out:
#        Label  Proteomics  Transcriptomics
# 0  Wild_type     0.80300            14.38
# 1  Wild_type     0.42600            14.60
# 2  Wild_type     0.00891            15.07
# 3  Wild_type     0.78800            14.56
# 4  Wild_type    -0.40200            14.47

# %%
is_mutation = beta_df['Label'] == 'Mutation'
is_wild_type = beta_df['Label'] == 'Wild_type'

# %%
#beta-catenin and wild type statistical values
beta_correlation,beta_pval = scipy.stats.pearsonr(beta_df[is_mutation]['Proteomics'], beta_df[is_mutation]['Transcriptomics'])
wildT_correlation,wildT_pval = scipy.stats.pearsonr(beta_df[is_wild_type]['Proteomics'], beta_df[is_wild_type]['Transcriptomics'])
beta_slope, beta_intercept, beta_r_value, beta_p_value, beta_std_err = stats.linregress(beta_df[is_mutation]['Proteomics'], beta_df[is_mutation]['Transcriptomics'])
wildT_slope, wildT_intercept, wildT_r_value, wildT_p_value, wildT_std_err = stats.linregress(beta_df[is_wild_type]['Proteomics'], beta_df[is_wild_type]['Transcriptomics'])
beta_r_sqrd = beta_r_value ** 2
wildT_r_sqrd = wildT_r_value ** 2
r2_delta = beta_r_sqrd - wildT_r_sqrd
print("Beta catenin correlation: " + str(beta_correlation))
print("Wild type correlation: " + str(wildT_correlation))
print("Beta catenin R2: " + str(beta_r_sqrd))
print("Wild type R2: " + str(wildT_r_sqrd))
print("R2 Delta : " + str(r2_delta))
# Out:
# Beta catenin correlation: 0.34082338655621236
# Wild type correlation: 0.099528477948329
# Beta catenin R2: 0.11616058082364539
# Wild type R2: 0.009905917922710991
# R2 Delta : 0.1062546629009344

# %%
ax = sns.regplot( x = 'Proteomics', y= 'Transcriptomics',  data = beta_df[is_mutation], label = "Mutation")
ax = sns.regplot( x = 'Proteomics', y= 'Transcriptomics',  data = beta_df[is_wild_type], label = "Wild type")
ax.legend(loc="best")
plt.show()

# %%
beta_df['Label']
# Out:
# 0     Wild_type
# 1     Wild_type
# 2     Wild_type
# 3     Wild_type
# 4     Wild_type
#         ...
# 90    Wild_type
# 91    Wild_type
# 92    Wild_type
# 93    Wild_type
# 94    Wild_type
# Name: Label, Length: 95, dtype: object

# %%
counter = 0
for i in np.random.permutation(beta_df['Label']):
    if i == "Mutation":
        counter += 1
counter
# Out:
# 27

# %%
permu_df = copy.deepcopy(beta_df)

# %%
permu_df['Label'] = np.random.permutation(permu_df['Label'])

# %%
permutation_list = []
for i in range(10000):
    permu_df['Label'] = np.random.permutation(permu_df['Label'])
    permu_is_mutation = permu_df['Label'] == 'Mutation'
    permu_is_wild_type = permu_df['Label'] == 'Wild_type'
    beta_slope, beta_intercept, beta_r_value, beta_p_value, beta_std_err = stats.linregress(permu_df[permu_is_mutation]['Proteomics'], permu_df[permu_is_mutation]['Transcriptomics'])
    wildT_slope, wildT_intercept, wildT_r_value, wildT_p_value, wildT_std_err = stats.linregress(permu_df[permu_is_wild_type]['Proteomics'], permu_df[permu_is_wild_type]['Transcriptomics'])
    permu_beta_r2 = beta_r_value ** 2
    permu_wildT_r2 = wildT_r_value ** 2
    delta = permu_beta_r2 - permu_wildT_r2
    permutation_list.append(delta)

# %%
permutation_list
# Out:
# [0.302515860130643,
#  0.25956232596177153,
#  -0.14125454797621614,
#  -0.1125945351840015,
#  -0.01642098173071989,
#  0.14960903508935203,
#  0.14075248239653265,
#  -0.11907729796440063,
#  -0.10089518918736567,
#  0.32852545843549297,
#  0.26401691680196726,
#  0.15085963888558443,
#  -0.12689328414596443,
#  -0.16986807562243766,
#  0.05718114356407991,
#  -0.009996516016058152,
#  -0.14456438926402385,
#  -0.13035547695419702,
#  0.011767671242681951,
#  0.08160267025960914,
#  -0.12157899920320599,
#  0.06459897884880789,
#  -0.07237247051053501,
#  0.04942652431847806,
#  0.07149682484733515,
#  0.20071769396265032,
#  -0.054808560520392936,
#  -0.10238080312091083,
#  -0.05178030960353942,
#  -0.007974181715380904,
#  -0.01923122080567856,
#  -0.13860968761663411,
#  0.009238366748549165,
#  0.11295240214347711,
#  -0.07811693457254834,
#  0.18485786050622377,
#  0.12290081789121438,
#  0.006661137484002724,
#  0.16257885593080484,
#  0.024846259773363993,
#  -0.09746802707527519,
#  -0.13091002148841804,
#  0.01564075692081425,
#  0.07791338149109982,
#  0.05980595605269879,
#  0.1457536684025848,
#  -0.13099727760783067,
#  -0.1346854308694881,
#  0.18528973052674774,
#  -0.10345404423941817,
#  -0.002870078119533853,
#  -0.13317130819926892,
#  -0.14725869549971596,
#  -0.1566798868801923,
#  -0.0194380370472588,
#  0.002056369929195709,
#  0.40720417359068806,
#  0.21814066432895246,
#  0.17283549909333853,
#  -0.0677749933321351,
#  -0.13339412875109896,
#  0.21628509326337314,
#  -0.06281490002786105,
#  0.08902146332177509,
#  0.15606330667603513,
#  0.08269175913163024,
#  0.16237699927401886,
#  -0.10735388445356872,
#  -0.10565077136545754,
#  -0.11424682121918431,
#  -0.12313928735809938,
#  -0.06579044704263795,
#  0.0833597717244083,
#  -0.1039404552959759,
#  0.2820232849811316,
#  0.10326525943579712,
#  -0.08716161497619505,
#  -0.05535058674349674,
#  -0.10149466185682185,
#  0.11328593185209401,
#  -0.09702333639173151,
#  -0.014082477817922684,
#  -0.10722896672244696,
#  -0.025482644604807425,
#  0.30202608490970856,
#  0.1782299167755766,
#  -0.032781479790308904,
#  0.031964479774568066,
#  0.018775328914855643,
#  0.015355597728197362,
#  0.32622237092670386,
#  -0.14182181514402886,
#  -0.0030300951669715026,
#  -0.11460130032035788,
#  0.4162937744221755,
#  -0.12456048434067686,
#  -0.06322390299496362,
#  -0.08510729094172718,
#  -0.05955189576164383,
#  0.21294460616213473,
#  0.39433595933537285,
#  -0.1380258641315889,
#  -0.04241447630516172,
#  -0.10164750162910216,
#  -0.10014163005662145,
#  0.004690702216113812,
#  0.18487239774644842,
#  0.09583281751145281,
#  -0.05198261604393436,
#  0.049054937414303584,
#  -0.004219800232660428,
#  0.48326437214639456,
#  0.1295602662094316,
#  -0.036099860842355475,
#  -0.06523789663502552,
#  -0.11297267869662159,
#  0.2784329634057369,
#  -0.09766227058689332,
#  -0.13403510612296482,
#  -0.12177566655007696,
#  0.20002157256236863,
#  -0.02470572534508908,
#  -0.06334567521972034,
#  0.1264409063487022,
#  -0.12888899856189195,
#  -0.0716947700933071,
#  0.04789949669130385,
#  -0.14915136159586023,
#  -0.07232665260624002,
#  -0.08471488002174643,
#  0.135074060345703,
#  -0.040368574492264823,
#  -0.01709574347320375,
#  0.0654407129251682,
#  -0.1368902186742807,
#  -0.05952065403780123,
#  -0.13682471718063274,
#  -0.11223152130437251,
#  0.02851030189849478,
#  -0.0518940615432707,
#  -0.11644070429136785,
#  0.12870051974994068,
#  -0.08751206775162332,
#  0.15303036298774164,
#  0.06304284896246773,
#  -0.00817293777048854,
#  -0.04860148671668902,
#  -0.13894224698065527,
#  -0.042450735155018925,
#  -0.021720906179382507,
#  -0.09366698783025716,
#  0.16074002621628655,
#  -0.03173923427776249,
#  0.19855354217607707,
#  0.13937446884596638,
#  -0.047404327957905265,
#  -0.1288806644847327,
#  -0.12701478535811672,
#  -0.1322128086578011,
#  -0.14797304903311842,
#  0.23354377532990445,
#  -0.17889431172976875,
#  -0.12633735565746035,
#  0.22763532884583643,
#  0.1751413747049918,
#  0.0767965211113637,
#  0.15839562369864857,
#  0.131577657443616,
#  0.04989120680581832,
#  -0.1342206746558103,
#  0.08210149734352164,
#  0.12413746717433602,
#  -0.10828380325657042,
#  -0.0989784612538094,
#  0.14471176540526506,
#  0.3471262971749816,
#  0.039329076448062356,
#  0.2015841031782404,
#  0.24336165761586084,
#  0.45598819702313564,
#  0.012249511439981167,
#  -0.05300725217620311,
#  -0.12547612244129208,
#  -0.1175132662315304,
#  -0.12488780430188175,
#  -0.02934481890206808,
#  -0.10618005617927333,
#  0.029851069747176384,
#  0.391250515191888,
#  0.07710610612653636,
#  -0.19622365607210415,
#  0.25936544184121413,
#  -0.1538524174596184,
#  -0.0028506239529675903,
#  -0.1378005999874269,
#  0.26108321729417683,
#  -0.035326783771794656,
#  -0.07664378694729633,
#  0.08430901592033427,
#  0.20849219719051937,
#  0.11140641047135283,
#  0.029797843272249977,
#  -0.09031460379689597,
#  0.19472767263849666,
#  -0.08333478485344187,
#  0.2742617015106761,
#  -0.0522002784366549,
#  -0.006708919961350729,
#  0.035331929407460744,
#  -0.15719828277160738,
#  -0.069432270127056,
#  -0.10487405426791002,
#  0.08286250874940092,
#  -0.05487172218484409,
#  -0.12213239908497887,
#  -0.0596357160325465,
#  0.04838013922314463,
#  -0.15588845775088986,
#  0.02230276428222043,
#  0.23675261696945485,
#  0.005145657699068121,
#  -0.10433788291223718,
#  -0.12821237240361796,
#  -0.1168460632587707,
#  -0.13226392053078892,
#  0.11056056126977659,
#  -0.08208084942224811,
#  -0.19605806775392207,
#  -0.003796098396052827,
#  -0.0749316660926099,
#  0.18239286269277227,
#  -0.021383032175005492,
#  0.2500177405327804,
#  -0.05559173577652238,
#  -0.050301029268132944,
#  0.015111428684938408,
#  0.013576216550673398,
#  -0.09213102955678196,
#  -0.12611805999054865,
#  0.2895273732252696,
#  -0.11139097813924126,
#  0.23294407102466935,
#  0.25619540485062486,
#  0.1539667182982205,
#  -0.03216505481592545,
#  0.004948503548065447,
#  0.03337271432500867,
#  -0.03707045278129896,
#  -0.17121946631030727,
#  -0.049116635621117406,
#  0.11452652787350073,
#  -0.022547620691729914,
#  -0.14654444944706366,
#  0.10660865758279776,
#  -0.05986405349693432,
#  0.10747424192756835,
#  0.20285594789913025,
#  -0.07911328985320568,
#  -0.016342359987412305,
#  0.12532032405514137,
#  -0.12158504020566235,
#  -0.09843025744395931,
#  -0.16685416235152406,
#  -0.038611492484932765,
#  -0.12473623099312055,
#  -0.1279800571155752,
#  -0.07529939913617485,
#  0.18653967878618927,
#  -0.04576263605951298,
#  -0.13786685186177475,
#  0.046817090035771156,
#  0.28917042348979016,
#  -0.017385785281881116,
#  -0.0949175079481284,
#  0.04904719684964083,
#  -0.13314722528165723,
#  -0.04478695273744434,
#  -0.11958612160114376,
#  0.18966637069066294,
#  0.02610209469948517,
#  0.23714166526610825,
#  -0.01076373421181838,
#  -0.1217774632277362,
#  0.20400979860280294,
#  -0.00024515044810952125,
#  -0.0713407681349936,
#  0.1002306979686083,
#  -0.08579671410762693,
#  -0.00844906938384607,
#  0.10815788401555419,
#  0.21957086838965265,
#  0.1581286811007652,
#  -0.06770674050207957,
#  -0.16027973912907717,
#  0.13988800497138099,
#  0.04877285103460294,
#  -0.16065318219587005,
#  0.07946733181886345,
#  0.11036596025461604,
#  -0.07295367665965809,
#  -0.05788555822427506,
#  0.13912371165225537,
#  0.31912638968213525,
#  0.027081367377755947,
#  -0.05104328036806339,
#  -0.10071763312013268,
#  0.06037683104636518,
#  0.1966094010370289,
#  -0.11342373402489182,
#  0.044954878365872364,
#  0.044161714449603456,
#  0.02252014696689128,
#  -0.07477864249227537,
#  0.06378468647891253,
#  -0.08671194604196585,
#  0.012692825301514443,
#  -0.10760990080767807,
#  -0.15912332274178703,
#  -0.017820418536252866,
#  0.1627573939003092,
#  -0.14538835071483297,
#  0.22304732586197693,
#  -0.16092183653624162,
#  -0.09964707584681075,
#  -0.14308022801701253,
#  -0.04724739050663269,
#  -0.10945851541870388,
#  0.10318947319713509,
#  -0.14667215208285195,
#  0.18321026727674883,
#  0.16481482635517822,
#  0.12594880103920628,
#  -0.0587288271448852,
#  -0.1246845973678679,
#  0.4804742273687027,
#  -0.1301731071926501,
#  0.38670446601465996,
#  0.01758383174617617,
#  -0.13317785751131603,
#  0.1658446336171979,
#  0.2929467272371552,
#  -0.17017570589888056,
#  -0.024341200276284863,
#  -0.16055514084178574,
#  -0.06870096335250811,
#  0.1077680182351651,
#  0.1484295554662506,
#  0.13270981402268345,
#  0.07411119200812685,
#  0.08282754163657524,
#  -0.0016134811404664162,
#  -0.13510045784281308,
#  0.21509449557848667,
#  0.08976891504696288,
#  0.005448761359286888,
#  0.05111939479171616,
#  -0.024274966112176374,
#  0.021407680276079213,
#  -0.004340906543951112,
#  -0.008963956179402793,
#  -0.03137306547155501,
#  -0.13157122079667796,
#  0.14829525920192851,
#  -0.036790545543577594,
#  0.28531298107657943,
#  -0.09570764398459362,
#  0.0014086135456506804,
#  -0.14509534588598022,
#  -0.03345952535368898,
#  0.11467406888377253,
#  0.1510821045413575,
#  0.23574444336611994,
#  -0.11125695616784034,
#  -0.01673247925648029,
#  0.2485544053227382,
#  0.10353206656709779,
#  0.26190922026777685,
#  0.25458140536848123,
#  0.00278475403294004,
#  0.10200164068569798,
#  -0.13541653738409637,
#  -0.010535472426012646,
#  -0.04570131587015002,
#  0.19986954085977315,
#  0.0845554734462626,
#  -0.06677107457304002,
#  -0.06992782472543742,
#  0.009111050525510186,
#  0.32167551773754355,
#  0.06402711376920223,
#  0.4530030492829633,
#  0.26064493906020575,
#  -0.12804234090688144,
#  -0.11720028248815544,
#  0.07252898997546003,
#  0.03497982096441678,
#  0.013310422598229898,
#  0.18790150932233796,
#  -0.07315966034812134,
#  0.14418572306418342,
#  -0.12581458497094625,
#  -0.1231423823402432,
#  0.07386790905458669,
#  -0.10540269677823212,
#  -0.00016102396116512985,
#  0.03765366100842776,
#  -0.09638203467802041,
#  0.24735810657831114,
#  -0.11411455519392516,
#  0.33015416935959946,
#  -0.041456103561619655,
#  0.10344438967787682,
#  0.016737974303367098,
#  -0.06098049354318191,
#  0.04680335444501796,
#  -0.12024110220814749,
#  0.044024947548887264,
#  -0.10247156377095101,
#  0.39560724121525703,
#  -0.10125843711508506,
#  0.18055105971331706,
#  0.1051559684994,
#  0.11767538766019257,
#  0.3789979740430391,
#  0.014978679022232919,
#  -0.15693971791773584,
#  -0.07988205317207586,
#  0.18288798719396243,
#  -0.12689835846085992,
#  0.18102797830377096,
#  -0.03550173686286308,
#  0.17092028263925646,
#  0.15636837811776105,
#  0.04682043233918645,
#  -0.11983974453835607,
#  0.1292122307493393,
#  0.027139043115890285,
#  -0.07092816642636379,
#  -0.02126287352377805,
#  0.18264120571398215,
#  0.11737701668067049,
#  0.17962482435309263,
#  -0.05584752027639914,
#  0.23134960781473832,
#  0.0951629081143047,
#  0.1476343653007519,
#  -0.06599885386299775,
#  0.09588480667128371,
#  0.04166198283308212,
#  -0.1382237802585829,
#  -0.054938564397441436,
#  -0.1246875215616638,
#  0.0800715913546296,
#  0.1795906243998246,
#  0.2855823289136728,
#  -0.07210702181880023,
#  -0.10894064642901385,
#  -0.10111742898882813,
#  0.13090333889042274,
#  0.26209822583355313,
#  -0.09871037350288615,
#  -0.0081786311718101,
#  0.2108998167327239,
#  0.015618472061476693,
#  0.11405970281493356,
#  0.07641738450599009,
#  0.023650991959897005,
#  0.013013976496964091,
#  0.004336499425292364,
#  0.22458796486196822,
#  -0.12246851269829283,
#  0.041843544563476956,
#  0.29185906337593254,
#  -0.11414508399029784,
#  0.08817622735558586,
#  -0.07944494489789633,
#  0.2141137106638973,
#  -0.08482603032237307,
#  -0.1417427596759243,
#  -0.0543451114236024,
#  -0.027691784513788675,
#  0.012461981230435945,
#  -0.12244948521168106,
#  -0.067829867880486,
#  0.004378758338640154,
#  -0.15346668899714574,
#  -0.09393446916838802,
#  -0.1496624476942989,
#  -0.020063203738470217,
#  -0.10722003044579825,
#  -0.0806334182303339,
#  -0.04198381148170526,
#  -0.0831437420576097,
#  -0.13516483670960944,
#  0.302667836469392,
#  0.11273614740997376,
#  0.134489791787093,
#  -0.07041001635750921,
#  0.12352992047132866,
#  0.1640759291587978,
#  0.14244645820743213,
#  0.274139303679281,
#  -0.01678794630345687,
#  -0.08616985276990917,
#  0.2642937304744682,
#  -0.080596482002697,
#  -0.14941153851978553,
#  0.11112992748806615,
#  1.2471387612789098e-05,
#  0.2288348049397011,
#  0.026132118195941162,
#  -0.08871158143322724,
#  0.06098848280641399,
#  -0.06603213904319212,
#  -0.13733031384852248,
#  0.01670332724459736,
#  -0.11049486891983033,
#  -0.10839434041901781,
#  -0.0421745171245821,
#  -0.11730439070695665,
#  0.444037181799475,
#  -0.0590369615370656,
#  -0.011036517492218456,
#  0.14272189327986254,
#  -0.05612636048392949,
#  -0.12844086464580498,
#  -0.11307328732180685,
#  0.12697073080827687,
#  -0.12959363000815227,
#  0.035357367722126706,
#  0.10682667744360522,
#  0.0075523068073165694,
#  0.002454457729210477,
#  0.04082049720274589,
#  -0.01528033165682649,
#  -0.1009493644265196,
#  -0.09510448558908259,
#  -0.12084136718691948,
#  -0.013048828960324693,
#  -0.05202445572497153,
#  -0.14377428197254583,
#  0.03423736853341533,
#  0.24711905428915368,
#  0.03740079775511544,
#  -0.1399105341815989,
#  -0.05882211866146134,
#  0.05255444244807507,
#  -0.058026639331566016,
#  -0.11414621403210257,
#  -0.0775594692363718,
#  -0.14254207988881057,
#  -0.16907635269844298,
#  -0.008921697009883406,
#  0.22902746076751493,
#  -0.11651527300094018,
#  0.32155033509405384,
#  -0.053271864967731744,
#  -0.02721834464859972,
#  -0.08239570761493312,
#  -0.14051255311157176,
#  -0.15440773284443074,
#  0.19271707220826367,
#  0.1691400069754089,
#  -0.0721106938899535,
#  -0.05717707444166646,
#  -0.06944492660906343,
#  0.1320551649475809,
#  0.08971946240933275,
#  0.24044279881099528,
#  0.11871133388625357,
#  0.10564797895121883,
#  0.320241703912191,
#  -0.15787318877956452,
#  0.07547931152046933,
#  -0.0077029854378525275,
#  0.06739789542145444,
#  0.16977835839121158,
#  0.056828940592447905,
#  -0.0776499438308488,
#  -0.05390409509399088,
#  -0.12769678746698504,
#  -0.07133984676768348,
#  -0.05248574572597936,
#  0.09347037666900405,
#  -0.14470261201963566,
#  -0.004548702546417233,
#  -0.06895318838963632,
#  0.08327362260938102,
#  0.20168038082596818,
#  0.043133735917180685,
#  0.09140481962593304,
#  -0.03924702492348989,
#  -0.06458405344463777,
#  -0.05564816986669121,
#  0.08074585378629733,
#  0.06503190051569754,
#  0.22698322422142525,
#  0.40849710242883336,
#  0.01663945450424785,
#  -0.039913638643840475,
#  -0.13664214790070897,
#  -0.10302092438395181,
#  -0.08766330413336991,
#  0.25946691318557374,
#  -0.14309230997282416,
#  -0.008087829950378406,
#  -0.04009712172622498,
#  0.14904699139972022,
#  0.23639191814784713,
#  0.12137783300681804,
#  0.3326245844661409,
#  0.01919077061388859,
#  0.06908318838648266,
#  -0.09087918955623653,
#  -0.09473546967995673,
#  0.19957071551552505,
#  0.11200835793279218,
#  0.16695728503476578,
#  0.17973123163182572,
#  -0.026196392200004012,
#  -0.11720756947280664,
#  0.28492054955826607,
#  -0.07145544353175207,
#  -0.11137473481798323,
#  0.08517604207310883,
#  -0.14215334540247657,
#  0.05182673470884791,
#  -0.010770622583180067,
#  0.02236454407329065,
#  -0.06575444325599329,
#  -0.051149780574735224,
#  -0.045198045819877276,
#  -0.23064740873926265,
#  0.160518420743133,
#  -0.13141824906674146,
#  -0.14535179560324954,
#  0.19795068800219304,
#  -0.09637647154185927,
#  -0.12583215824269267,
#  0.017645067267456266,
#  -0.03540787051505487,
#  0.3108427618281021,
#  0.002341306390718431,
#  0.009515321731045703,
#  0.005343391652886512,
#  0.1040175034519988,
#  0.1685215251772282,
#  -0.09882741609249704,
#  -0.13143222580695932,
#  0.18646824916262475,
#  0.11506668225679756,
#  0.16842323177453103,
#  0.1582907731426098,
#  -0.018133184853474232,
#  0.10142417621908711,
#  -0.12487952073823544,
#  -0.10617414374906238,
#  0.10944380518087318,
#  0.191279365574421,
#  0.012294209815740434,
#  -0.06008543953784472,
#  -0.13535269569530012,
#  0.049961645058350365,
#  0.06837782831834435,
#  -0.14615993434297428,
#  -0.02597772412268945,
#  0.03543647831074247,
#  0.09424108318615942,
#  -0.14587647696836528,
#  -0.15149969130843177,
#  0.07123613876816695,
#  0.19588140441533924,
#  0.12536213350276806,
#  0.0884399616804837,
#  0.0853284032907688,
#  -0.07842720598992119,
#  -0.04778594433163812,
#  0.2354638548500415,
#  -0.11809192687263187,
#  -0.04272998436218368,
#  0.01086260938927143,
#  -0.10246799276200502,
#  -0.030892756085036756,
#  -0.01990670924551212,
#  -0.13324276331771803,
#  0.2867408784029224,
#  0.14474325055414516,
#  -0.04003794905280517,
#  -0.0832662504497195,
#  -0.1619942539440283,
#  -0.15770425186461112,
#  -0.1375531698955617,
#  0.5297760987770549,
#  -0.08394969290304088,
#  0.021919379836062458,
#  -0.13921519008225233,
#  -0.05100890961659063,
#  -0.05894703651656958,
#  0.05405231353419056,
#  0.04813890591800102,
#  0.08986549830290667,
#  0.3610741107473752,
#  0.008021345446770564,
#  0.29126407790265774,
#  0.14338045221292506,
#  0.1365208503106225,
#  -0.15123551944350364,
#  0.12859456005495123,
#  -0.13378310672292487,
#  -0.14783922503749278,
#  -0.09957788198810032,
#  0.2013384746184611,
#  0.006886786015596266,
#  0.06372239680128622,
#  0.3946081369291266,
#  0.11382475739609141,
#  0.13326224572377499,
#  -0.13388608039550262,
#  -0.08591250916575466,
#  -0.12446359525465091,
#  0.08996760653343423,
#  -0.06642850631996594,
#  0.3408173973099537,
#  -0.12380203666009043,
#  0.0720177682773405,
#  -0.14843205293305162,
#  -0.14673720313496016,
#  0.09479479201184557,
#  -0.13817889412436146,
#  -0.06540909096603384,
#  0.12401509516826059,
#  -0.06558732952386677,
#  -0.11572178279312129,
#  -0.06012618678060077,
#  0.018049108693777946,
#  -0.15512292176115508,
#  -0.09342406170989831,
#  -0.03226051180777344,
#  -0.08975497940596816,
#  0.10635519810659581,
#  0.03129217367367364,
#  0.02277690970874109,
#  -0.07113246163302758,
#  -0.1716600188069805,
#  0.3240811558917041,
#  -0.13368213786187583,
#  -0.12828672813820213,
#  -0.1363261161433783,
#  -0.021171077637728283,
#  -0.0687429859462983,
#  0.19338387781082675,
#  -0.0026089076861351285,
#  0.27425350945768323,
#  -0.04701821480959467,
#  0.20807040599111046,
#  -0.12358616541525833,
#  0.35374656203160737,
#  -0.1665109108644462,
#  -0.0693354193664,
#  -0.047850379942541536,
#  -0.08385493336446889,
#  -0.029286867568167924,
#  -0.01040304894806332,
#  -0.0858294822000196,
#  -0.14088222535386416,
#  -0.12801980754448042,
#  -0.13807978962010092,
#  -0.05973258386643089,
#  -0.19052231766951286,
#  0.22786405198775186,
#  -0.0631867479920967,
#  -0.0017519277419159457,
#  -0.08768768381756108,
#  -0.018075159252211634,
#  0.06560057720719271,
#  -0.12291856460823855,
#  -0.020328241273862416,
#  0.07393204165775846,
#  -0.023997295520276615,
#  0.06228283595805212,
#  0.2719950292466712,
#  0.20135100151453855,
#  0.0835283974346873,
#  -0.10908495371363812,
#  -0.12014040612559738,
#  -0.13965697663249982,
#  0.1344570187643391,
#  -0.1318370194469131,
#  -0.1164888433244868,
#  -0.00591135772412589,
#  -0.11328176532476746,
#  0.1745281541916378,
#  0.26854462351637853,
#  -0.06250598624277946,
#  -0.010307350085382666,
#  0.0330020005829402,
#  -0.1189628650675813,
#  0.0006209630044264891,
#  0.0709563745369964,
#  0.28610748194424207,
#  -0.07847581709835674,
#  -0.0616431316512894,
#  0.2658729528568162,
#  0.1542214343932835,
#  0.10018515726897925,
#  -0.1528319934913652,
#  -0.05131846591601586,
#  0.2992242337765115,
#  -0.13450709474558173,
#  -0.12360647980622277,
#  -0.06170757373065719,
#  0.06766710779527073,
#  0.17339698489480038,
#  -0.10745247587244428,
#  -0.13842581045220226,
#  -0.040609744842321695,
#  -0.11554182123339471,
#  0.29185935436399585,
#  0.1329487085541192,
#  0.14138572270906297,
#  -0.04595972452682381,
#  -0.09255225247757076,
#  -0.14117250962239236,
#  0.1003255719427762,
#  -0.01998478278010922,
#  -0.13958209230564966,
#  -0.0791606885864858,
#  -0.10498538965088619,
#  -0.15097885103844036,
#  -0.14851069230124603,
#  -0.11382255931082338,
#  -0.04918763606942167,
#  -0.028202839412760236,
#  0.1635597006146626,
#  -0.031132495353565534,
#  0.007404023639309268,
#  -0.04034196853103722,
#  0.29709260438567214,
#  0.01876834666422482,
#  0.2046714565310221,
#  0.15277479931087284,
#  -0.1250210801084985,
#  0.1202196330546656,
#  -0.01414958120995434,
#  -0.0291658377942636,
#  -0.06226405472974356,
#  0.15899655957476747,
#  -0.12657310616789555,
#  -0.018687018047358117,
#  0.15413969930160143,
#  0.14515782105759212,
#  -0.0707193804721217,
#  -0.16449531150700555,
#  0.05175953479847992,
#  -0.07056085246962243,
#  -0.09880661049357495,
#  -0.022338251493395883,
#  0.3749292211676895,
#  -0.09556692709240731,
#  -0.05130100426598516,
#  -0.13719177049019332,
#  -0.11260506806702236,
#  0.23480043842707962,
#  0.19245673084400727,
#  0.24315123172302172,
#  0.15620593065536353,
#  -0.06406345391684025,
#  -0.00695559169480317,
#  -0.014157320234002915,
#  0.020959972790953157,
#  0.014982813610347659,
#  -0.07682364635466586,
#  -0.07942880728493422,
#  0.09089263876786503,
#  -0.15770560916980392,
#  0.08059999452534551,
#  0.05655556512254374,
#  0.22518222402747046,
#  0.022869316667608774,
#  0.22116193957051714,
#  -0.1029135254992232,
#  0.005361001412205482,
#  -0.08027930951704904,
#  -0.04931290301438324,
#  0.17064673130719393,
#  -0.14142855456545253,
#  0.23894051310716485,
#  -0.04089172635350413,
#  0.07972861302438075,
#  0.008377191453550176,
#  -0.052542329188193536,
#  -0.06764503263391564,
#  -0.14437135600675013,
#  -0.16395797988890826,
#  -0.060144995981155386,
#  0.35484155878759044,
#  0.08654039916563383,
#  -0.15150651318005062,
#  -0.046307776417750524,
#  0.15420466868192645,
#  0.018373457987430786,
#  -0.06565692263344276,
#  0.21210073069768542,
#  0.027353299328014363,
#  -0.13428165754146382,
#  0.08406358851587277,
#  0.10474618996088671,
#  0.0435139215748816,
#  0.16547886094662412,
#  0.18950915011224717,
#  -0.1617259939443846,
#  0.004045521516157932,
#  -0.10141584821965122,
#  0.2377274339930698,
#  -0.034389943464763637,
#  0.04992686138817372,
#  0.10016695688564176,
#  -0.051376556393784516,
#  -0.1364431848392222,
#  0.10193709485126672,
#  -0.0015513306724639908,
#  -0.12371175735209824,
#  0.04010289961763211,
#  0.032743495551855906,
#  -0.1263618125909059,
#  0.11349123019335822,
#  0.4021069082011963,
#  -0.13171548071298217,
#  0.1703757660729442,
#  -0.09122859863441482,
#  0.3272601156904483,
#  0.161569652398453,
#  0.15078539652772802,
#  -0.07697642892240059,
#  0.02865178919256993,
#  -0.044590102540429374,
#  -0.10429838948471984,
#  0.04114800699642299,
#  -0.14092216240917532,
#  0.08200625693519115,
#  0.21168451687811995,
#  0.30789530455162273,
#  0.10056393870159344,
#  0.23959463165362826,
#  -0.05479965433340445,
#  0.16989990246219716,
#  0.1935741551677524,
#  0.03635247352127531,
#  -0.08913260186322725,
#  -0.13688583671951304,
#  0.1490199373797147,
#  -0.13803875139762123,
#  0.27461937754916843,
#  -0.12246015324876473,
#  0.0019323739092770853,
#  -0.04559831452768023,
#  -0.11256972625125983,
#  0.1870831534204657,
#  0.07789017961171169,
#  0.1280711346448139,
#  0.015472361165635842,
#  -0.1121923393872517,
#  0.26604626861789366,
#  0.07040103066891212,
#  0.17837690101037582,
#  0.3762547443916345,
#  0.06987109964696137,
#  -0.15603047901197567,
#  -0.1092647401784549,
#  -0.09980098924782013,
#  0.14201617254823193,
#  -0.00443407986382395,
#  0.020244589822146747,
#  0.01659752832660627,
#  0.14823039502550173,
#  -0.13221689753128932,
#  -0.042892809631470664,
#  0.12707214129900654,
#  -0.1448971035388276,
#  -0.1370082517408443,
#  0.09791963279596805,
#  0.17009623971491172,
#  -0.10671009333350923,
#  0.15521716217749393,
#  -0.050777682036939394,
#  -0.1410525104879041,
#  0.1861153786903753,
#  -0.14045280298683588,
#  -0.1661645788442239,
#  -0.04896876993130835,
#  0.14923296623624804,
#  0.21016581187279026,
#  0.1033829157603168,
#  -0.00936209850518914,
#  -0.007777143754832488,
#  -0.058753885316143985,
#  -0.12500799110981486,
#  -0.13045680076688826,
#  0.25929944961785906,
#  0.19324231554094684,
#  ...]

# %%
sns.distplot(permutation_list)
