# %%
import cptac
import cptac.utils as ut
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

# %%
perm_df = pd.read_csv("data/full_10k_permutation.csv", index_col=0)

# %%
significant_list = []
for i in perm_df:
    count = 0
    for j in perm_df[i]:
        if j <= 1/13669:
            count += 1
            if i not in significant_list and count >= 3:
                significant_list.append(i)
len(significant_list)
# Out:
# 1304

# %%
len(significant_list[:5])
# Out:
# 5

# %%
(len(significant_list)*100)/len(perm_df.columns)
# Out:
# 1.2949008705830711

# %%
from gprofiler import GProfiler

# %%
gp = GProfiler(return_dataframe=True)

# %%
returned_test = gp.profile(organism='hsapiens',query=significant_list)

# %%
returned_test[returned_test["source"]== "KEGG"] #Look at and read these pathways, why they are important in cancer
#Look at setting a background
# Out:
#      source      native                                         name  \
# 276    KEGG  KEGG:01100                           Metabolic pathways
# 353    KEGG  KEGG:01200                            Carbon metabolism
# 414    KEGG  KEGG:01230                  Biosynthesis of amino acids
# 451    KEGG  KEGG:00010                 Glycolysis / Gluconeogenesis
# 473    KEGG  KEGG:00240                        Pyrimidine metabolism
# 479    KEGG  KEGG:03030                              DNA replication
# 593    KEGG  KEGG:01240                    Biosynthesis of cofactors
# 642    KEGG  KEGG:00270           Cysteine and methionine metabolism
# 719    KEGG  KEGG:00920                            Sulfur metabolism
# 809    KEGG  KEGG:04110                                   Cell cycle
# 928    KEGG  KEGG:03430                              Mismatch repair
# 940    KEGG  KEGG:05230          Central carbon metabolism in cancer
# 979    KEGG  KEGG:00071                       Fatty acid degradation
# ...

# %%
returned_test["source"].value_counts()
# Out:
# TF       360
# GO:BP    221
# HPA      183
# GO:MF     90
# GO:CC     72
# REAC      27
# MIRNA     24
# WP        17
# KEGG      15
# CORUM      9
# Name: source, dtype: int64
