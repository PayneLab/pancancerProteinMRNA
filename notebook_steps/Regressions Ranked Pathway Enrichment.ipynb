# %%
import cptac
import numpy as np
import pandas as pd
import statsmodels.stats.multitest as ssm

# %%
df = pd.read_csv('data/regressions.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1    gene cancer  interaction_coeff  \
# 0               0             0    A1BG  ccrcc          -0.399310
# 1               1             1    A1CF  ccrcc           0.009264
# 2               2             2     A2M  ccrcc          -0.001738
# 3               3             3  A4GALT  ccrcc          -0.069014
# 4               4             4    AAAS  ccrcc          -0.005048
# ...           ...           ...     ...    ...                ...
# 54098       10066         10066    ZXDC   luad          -0.146323
# 54099       10067         10067  ZYG11B   luad           1.424677
# 54100       10068         10068     ZYX   luad           0.714921
# 54101       10069         10069   ZZEF1   luad           0.596868
# 54102       10070         10070    ZZZ3   luad           1.930651
#
#        condition_coeff  transcript_coeff  intercept  interaction_pval  \
# 0             0.683426          0.377849  -0.462140          0.030269
# 1            -0.282587          0.073218  -0.563416          0.483928
# 2             1.059763          0.001776  -0.899006          0.102154
# 3             1.186499          0.074956  -0.824329          0.787282
# 4             0.253459          0.008609  -0.148476          0.712627
# ...                ...               ...        ...               ...
# 54098         0.889409          0.886971  -3.806726          0.927943
# 54099        -5.791951         -0.529182   2.529373          0.000585
# 54100        -5.450918         -0.123800   2.023549          0.017024
# 54101        -2.881060          0.511473  -1.305858          0.077011
# 54102        -8.915487         -0.657206   3.464982          0.001024
#
#        condition_pval  transcript_pval  intercept_pval
# 0            0.000267     1.543240e-02    5.284138e-03
# 1            0.007715     1.334367e-20    3.375975e-10
# 2            0.000248     2.443435e-02    6.862382e-05
# 3            0.572700     5.662479e-01    5.581218e-01
# 4            0.094165     3.084530e-01    2.857311e-01
# ...               ...              ...             ...
# 54098        0.870375     4.851543e-01    4.178277e-01
# 54099        0.000112     2.167428e-01    8.937205e-02
# 54100        0.000068     7.126818e-01    1.239435e-01
# 54101        0.022896     1.157814e-01    3.362924e-01
# 54102        0.000210     2.770532e-01    1.394662e-01
#
# [54103 rows x 12 columns]

# %%
background_genes = list(pd.unique(df.gene))
len(background_genes)
# Out:
# 13457

# %%
sig_df = df[df.interaction_pval <= 0.05]
sig_df
# Out:
#        Unnamed: 0  Unnamed: 0.1    gene cancer  interaction_coeff  \
# 0               0             0    A1BG  ccrcc          -0.399310
# 10             10            10    AAK1  ccrcc           0.053062
# 11             11            11    AAMP  ccrcc           0.012601
# 14             14            14   AARS2  ccrcc          -0.083850
# 24             24            24   ABCA3  ccrcc          -0.363050
# ...           ...           ...     ...    ...                ...
# 54096       10064         10064  ZWILCH   luad           3.158582
# 54097       10065         10065   ZWINT   luad           0.875887
# 54099       10067         10067  ZYG11B   luad           1.424677
# 54100       10068         10068     ZYX   luad           0.714921
# 54102       10070         10070    ZZZ3   luad           1.930651
#
#        condition_coeff  transcript_coeff  intercept  interaction_pval  \
# 0             0.683426          0.377849  -0.462140          0.030269
# 10           -0.455378          0.032984  -0.009980          0.006332
# 11           -0.242299          0.006251  -0.403301          0.016747
# 14            0.458319          0.152507  -1.035045          0.025599
# 24            1.321452          0.382745  -1.437112          0.014050
# ...                ...               ...        ...               ...
# 54096        -4.319546         -0.801456  -0.265192          0.000018
# 54097        -2.358641          0.188274  -0.835616          0.007289
# 54099        -5.791951         -0.529182   2.529373          0.000585
# 54100        -5.450918         -0.123800   2.023549          0.017024
# 54102        -8.915487         -0.657206   3.464982          0.001024
#
#        condition_pval  transcript_pval  intercept_pval
# 0            0.000267     1.543240e-02        0.005284
# 10           0.000126     1.824412e-02        0.946774
# 11           0.330397     1.681417e-01        0.042514
# 14           0.094191     2.026622e-07        0.000002
# 24           0.021521     3.249287e-03        0.008090
# ...               ...              ...             ...
# 54096        0.000002     3.294543e-01        0.808117
# 54097        0.000877     5.507945e-01        0.001246
# 54099        0.000112     2.167428e-01        0.089372
# 54100        0.000068     7.126818e-01        0.123943
# 54102        0.000210     2.770532e-01        0.139466
#
# [12823 rows x 12 columns]

# %%
sig_genes = pd.DataFrame(sig_df.groupby('gene').size())
sig_genes = sig_genes[sig_genes[0] > 2]
sig_genes = list(sig_genes.index)
rows = []
for gene in sig_genes:
    row = dict()
    row['Gene'] = gene
    gene_df = sig_df[sig_df.gene == gene]
    avg_pval = np.mean(gene_df.interaction_pval)
    avg_interaction = np.mean(gene_df.interaction_coeff)
    abs_interaction = abs(avg_interaction)
    row['avg_pval'] = avg_pval
    row['avg_interaction_coeff'] = avg_interaction
    row['abs_interaction_coeff'] = abs_interaction
    rows.append(row)
sig_genes = pd.DataFrame(rows)
sig_genes
# Out:
#           Gene  avg_pval  avg_interaction_coeff  abs_interaction_coeff
# 0         AAK1  0.005286               0.453549               0.453549
# 1        AARS2  0.015897               0.719068               0.719068
# 2     AASDHPPT  0.001367               0.850032               0.850032
# 3         AASS  0.016457               1.079797               1.079797
# 4       ABCB10  0.013928               1.149501               1.149501
# ...        ...       ...                    ...                    ...
# 1334    ZNF638  0.002508               1.012607               1.012607
# 1335    ZNF687  0.014917               0.797145               0.797145
# 1336     ZNFX1  0.005884               0.388419               0.388419
# 1337    ZNHIT2  0.000316               0.756881               0.756881
# 1338     ZWINT  0.001955               0.988399               0.988399
#
# [1339 rows x 4 columns]

# %%
sig_genes = sig_genes.sort_values('avg_pval')
pval_gene_list = list(sig_genes.Gene)
sig_genes = sig_genes.sort_values('abs_interaction_coeff', ascending = False)
interaction_gene_list = list(sig_genes.Gene)
positive_interactions = sig_genes[sig_genes.avg_interaction_coeff >= 0].sort_values('avg_interaction_coeff', ascending = False)
positive_interactions_gene_list = list(positive_interactions.Gene)
negative_interactions = sig_genes[sig_genes.avg_interaction_coeff <= 0].sort_values('avg_interaction_coeff')
negative_interactions_gene_list = list(negative_interactions.Gene)

# %%
from gprofiler import GProfiler
gp = GProfiler(return_dataframe=True)

# %%
pval_results_df = gp.profile(organism='hsapiens', query = pval_gene_list, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)

# %%
interaction_results_df = gp.profile(organism='hsapiens', query = interaction_gene_list, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)

# %%
down_reg_results_df = gp.profile(organism='hsapiens', query = negative_interactions_gene_list, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)

# %%
up_reg_results_df = gp.profile(organism='hsapiens', query = positive_interactions_gene_list, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)

# %%
pval_results_df = pval_results_df[pval_results_df.term_size >= 5]
pval_results_df = pval_results_df[pval_results_df.term_size <= 500]
pval_results_df = pval_results_df[pval_results_df.source == 'KEGG']
pval_results_df
# Out:
#     source      native                                         name   p_value  \
# 51    KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism  0.000170
# 52    KEGG  KEGG:01230                  Biosynthesis of amino acids  0.000174
# 57    KEGG  KEGG:00051              Fructose and mannose metabolism  0.000360
# 74    KEGG  KEGG:04115                        p53 signaling pathway  0.001032
# 78    KEGG  KEGG:00270           Cysteine and methionine metabolism  0.001401
# 87    KEGG  KEGG:01200                            Carbon metabolism  0.002215
# 115   KEGG  KEGG:00250  Alanine, aspartate and glutamate metabolism  0.004399
# 164   KEGG  KEGG:04512                     ECM-receptor interaction  0.017954
# 167   KEGG  KEGG:00030                    Pentose phosphate pathway  0.021203
#
#      significant                                  description  term_size  \
# 51          True  Amino sugar and nucleotide sugar metabolism         44
# 52          True                  Biosynthesis of amino acids         73
# 57          True              Fructose and mannose metabolism         32
# 74          True                        p53 signaling pathway         63
# 78          True           Cysteine and methionine metabolism         47
# 87          True                            Carbon metabolism        114
# 115         True  Alanine, aspartate and glutamate metabolism         34
# 164         True                     ECM-receptor interaction         82
# 167         True                    Pentose phosphate pathway         29
#
#      query_size  intersection_size  effective_domain_size  precision  \
# 51         1309                 17                  13394   0.012987
# 52         1191                 21                  13394   0.017632
# 57         1223                 13                  13394   0.010630
# 74          936                 17                  13394   0.018162
# 78         1023                 14                  13394   0.013685
# 87         1223                 26                  13394   0.021259
# 115          68                  4                  13394   0.058824
# 164         687                 14                  13394   0.020378
# 167        1191                 10                  13394   0.008396
#
#        recall    query       parents  \
# 51   0.386364  query_1  [KEGG:00000]
# 52   0.287671  query_1  [KEGG:00000]
# 57   0.406250  query_1  [KEGG:00000]
# 74   0.269841  query_1  [KEGG:00000]
# 78   0.297872  query_1  [KEGG:00000]
# 87   0.228070  query_1  [KEGG:00000]
# 115  0.117647  query_1  [KEGG:00000]
# 164  0.170732  query_1  [KEGG:00000]
# 167  0.344828  query_1  [KEGG:00000]
#
#                                          intersections  \
# 51   [UGDH, GFPT2, GFPT1, NPL, GMDS, NANP, UAP1, FP...
# 52   [ALDOA, PYCR1, GOT1, BCAT1, PSPH, GPT2, SDS, S...
# 57   [ALDOA, AKR1B10, SORD, FBP1, PFKFB2, GMDS, FPG...
# 74   [RRM2, SERPINE1, IGFBP3, CDK1, CASP9, STEAP3, ...
# 78   [GOT1, BCAT1, AHCY, SDS, CTH, DNMT3A, MPST, IL...
# 87   [ALDOA, GOT1, PSPH, GCSH, FBP1, GPT2, DLD, SDS...
# 115                         [PPAT, GFPT2, GFPT1, GOT1]
# 164  [ITGAV, THBS2, CD36, ITGA11, ITGA2, COL1A1, CO...
# 167  [ALDOA, FBP1, RPE, RBKS, PFKP, G6PD, PGM1, TAL...
#
#                                              evidences
# 51   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 52   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 57   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 74   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 78   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 87   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 115                   [[KEGG], [KEGG], [KEGG], [KEGG]]
# 164  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 167  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %%
interaction_results_df = interaction_results_df[interaction_results_df.term_size >= 5]
interaction_results_df = interaction_results_df[interaction_results_df.term_size <= 500]
interaction_results_df = interaction_results_df[interaction_results_df.source == 'KEGG']
interaction_results_df
# Out:
#     source      native                                         name   p_value  \
# 112   KEGG  KEGG:04115                        p53 signaling pathway  0.000133
# 116   KEGG  KEGG:01230                  Biosynthesis of amino acids  0.000149
# 122   KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism  0.000193
# 137   KEGG  KEGG:00051              Fructose and mannose metabolism  0.000307
# 162   KEGG  KEGG:00270           Cysteine and methionine metabolism  0.001865
# 187   KEGG  KEGG:01200                            Carbon metabolism  0.007408
# 193   KEGG  KEGG:04110                                   Cell cycle  0.008634
# 198   KEGG  KEGG:00250  Alanine, aspartate and glutamate metabolism  0.010255
# 249   KEGG  KEGG:05230          Central carbon metabolism in cancer  0.035433
# 274   KEGG  KEGG:00030                    Pentose phosphate pathway  0.049612
#
#      significant                                  description  term_size  \
# 112         True                        p53 signaling pathway         63
# 116         True                  Biosynthesis of amino acids         73
# 122         True  Amino sugar and nucleotide sugar metabolism         44
# 137         True              Fructose and mannose metabolism         32
# 162         True           Cysteine and methionine metabolism         47
# 187         True                            Carbon metabolism        114
# 193         True                                   Cell cycle        113
# 198         True  Alanine, aspartate and glutamate metabolism         34
# 249         True          Central carbon metabolism in cancer         66
# 274         True                    Pentose phosphate pathway         29
#
#      query_size  intersection_size  effective_domain_size  precision  \
# 112         999                 19                  13394   0.019019
# 116        1077                 20                  13394   0.018570
# 122        1321                 17                  13394   0.012869
# 137        1206                 13                  13394   0.010779
# 162        1049                 14                  13394   0.013346
# 187        1234                 25                  13394   0.020259
# 193         896                 21                  13394   0.023438
# 198        1049                 11                  13394   0.010486
# 249         934                 14                  13394   0.014989
# 274        1321                 10                  13394   0.007570
#
#        recall    query       parents  \
# 112  0.301587  query_1  [KEGG:00000]
# 116  0.273973  query_1  [KEGG:00000]
# 122  0.386364  query_1  [KEGG:00000]
# 137  0.406250  query_1  [KEGG:00000]
# 162  0.297872  query_1  [KEGG:00000]
# 187  0.219298  query_1  [KEGG:00000]
# 193  0.185841  query_1  [KEGG:00000]
# 198  0.323529  query_1  [KEGG:00000]
# 249  0.212121  query_1  [KEGG:00000]
# 274  0.344828  query_1  [KEGG:00000]
#
#                                          intersections  \
# 112  [CDKN2A, CDK1, CCNB1, CHEK1, SERPINE1, GTSE1, ...
# 116  [RPIA, GPT2, PGK1, CTH, PSPH, TALDO1, PYCR1, R...
# 122  [UGDH, UAP1, GFPT1, UXS1, NANP, GFPT2, GNPNAT1...
# 137  [PMM2, TKFC, AKR1B10, GMDS, SORD, PFKP, PFKL, ...
# 162  [DNMT3A, AHCYL1, CTH, DNMT1, AHCY, PSAT1, GCLC...
# 187  [RPIA, GPT2, PGK1, PSPH, TALDO1, RPE, GCSH, GL...
# 193  [CDKN2A, MCM6, CCNA2, PLK1, CDK1, CCNB1, CHEK1...
# 198  [GPT2, ADSL, PPAT, GFPT1, GFPT2, GLUD1, GLS, A...
# 249  [SLC7A5, SLC1A5, MAP2K1, MET, GLS, PGAM1, SLC1...
# 274  [RPIA, RBKS, TALDO1, RPE, PFKP, PFKL, G6PD, AL...
#
#                                              evidences
# 112  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 116  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 122  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 137  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 162  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 187  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 193  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 198  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 249  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 274  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %%
down_reg_results_df = down_reg_results_df[down_reg_results_df.term_size >= 5]
down_reg_results_df = down_reg_results_df[down_reg_results_df.term_size <= 500]
down_reg_results_df = down_reg_results_df[down_reg_results_df.source == 'KEGG']
down_reg_results_df
# Out:
#    source      native                                             name  \
# 17   KEGG  KEGG:05412  Arrhythmogenic right ventricular cardiomyopathy
# 18   KEGG  KEGG:04979                           Cholesterol metabolism
# 24   KEGG  KEGG:05416                                Viral myocarditis
# 27   KEGG  KEGG:00010                     Glycolysis / Gluconeogenesis
# 28   KEGG  KEGG:05144                                          Malaria
# 36   KEGG  KEGG:04145                                        Phagosome
# 40   KEGG  KEGG:00520      Amino sugar and nucleotide sugar metabolism
#
#      p_value  significant                                      description  \
# 17  0.007987         True  Arrhythmogenic right ventricular cardiomyopathy
# 18  0.008074         True                           Cholesterol metabolism
# 24  0.013468         True                                Viral myocarditis
# 27  0.016691         True                     Glycolysis / Gluconeogenesis
# 28  0.018694         True                                          Malaria
# 36  0.032157         True                                        Phagosome
# 40  0.048213         True      Amino sugar and nucleotide sugar metabolism
#
#     term_size  query_size  intersection_size  effective_domain_size  \
# 17         64          43                  4                  13394
# 18         43          25                  3                  13394
# 24         55          26                  3                  13394
# 27         63         110                  5                  13394
# 28         37          84                  4                  13394
# 36        138          88                  6                  13394
# 40         44         110                  4                  13394
#
#     precision    recall    query       parents  \
# 17   0.093023  0.062500  query_1  [KEGG:00000]
# 18   0.120000  0.069767  query_1  [KEGG:00000]
# 24   0.115385  0.054545  query_1  [KEGG:00000]
# 27   0.045455  0.079365  query_1  [KEGG:00000]
# 28   0.047619  0.108108  query_1  [KEGG:00000]
# 36   0.068182  0.043478  query_1  [KEGG:00000]
# 40   0.036364  0.090909  query_1  [KEGG:00000]
#
#                                    intersections  \
# 17                     [DMD, ITGA2B, ACTN2, DES]
# 18                         [CD36, CYP27A1, LIPA]
# 24                             [CAV1, PRF1, DMD]
# 27           [ALDH3B1, HK3, FBP1, ALDH3A1, PGM1]
# 28                      [CD36, HGF, HBB, PECAM1]
# 36  [CD36, NCF4, NCF2, MRC1, HLA-DRB5, ATP6V0D1]
# 40                       [HK3, NPL, RENBP, PGM1]
#
#                                            evidences
# 17                  [[KEGG], [KEGG], [KEGG], [KEGG]]
# 18                          [[KEGG], [KEGG], [KEGG]]
# 24                          [[KEGG], [KEGG], [KEGG]]
# 27          [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 28                  [[KEGG], [KEGG], [KEGG], [KEGG]]
# 36  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 40                  [[KEGG], [KEGG], [KEGG], [KEGG]]

# %%
up_reg_results_df = up_reg_results_df[up_reg_results_df.term_size >= 5]
up_reg_results_df = up_reg_results_df[up_reg_results_df.term_size <= 500]
up_reg_results_df = up_reg_results_df[up_reg_results_df.source == 'KEGG']
up_reg_results_df
# Out:
#     source      native                                         name   p_value  \
# 130   KEGG  KEGG:01230                  Biosynthesis of amino acids  0.000056
# 154   KEGG  KEGG:04115                        p53 signaling pathway  0.000250
# 164   KEGG  KEGG:00270           Cysteine and methionine metabolism  0.000906
# 197   KEGG  KEGG:00250  Alanine, aspartate and glutamate metabolism  0.005803
# 202   KEGG  KEGG:01200                            Carbon metabolism  0.008034
# 205   KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism  0.008471
# 216   KEGG  KEGG:04110                                   Cell cycle  0.011806
# 219   KEGG  KEGG:00051              Fructose and mannose metabolism  0.013310
# 235   KEGG  KEGG:05230          Central carbon metabolism in cancer  0.019568
#
#      significant                                  description  term_size  \
# 130         True                  Biosynthesis of amino acids         73
# 154         True                        p53 signaling pathway         63
# 164         True           Cysteine and methionine metabolism         47
# 197         True  Alanine, aspartate and glutamate metabolism         34
# 202         True                            Carbon metabolism        114
# 205         True  Amino sugar and nucleotide sugar metabolism         44
# 216         True                                   Cell cycle        113
# 219         True              Fructose and mannose metabolism         32
# 235         True          Central carbon metabolism in cancer         66
#
#      query_size  intersection_size  effective_domain_size  precision  \
# 130        1014                 20                  13394   0.019724
# 154         942                 18                  13394   0.019108
# 164        1133                 15                  13394   0.013239
# 197         988                 11                  13394   0.011134
# 202        1014                 22                  13394   0.021696
# 205         918                 12                  13394   0.013072
# 216         848                 20                  13394   0.023585
# 219        1014                 10                  13394   0.009862
# 235         884                 14                  13394   0.015837
#
#        recall    query       parents  \
# 130  0.273973  query_1  [KEGG:00000]
# 154  0.285714  query_1  [KEGG:00000]
# 164  0.319149  query_1  [KEGG:00000]
# 197  0.323529  query_1  [KEGG:00000]
# 202  0.192982  query_1  [KEGG:00000]
# 205  0.272727  query_1  [KEGG:00000]
# 216  0.176991  query_1  [KEGG:00000]
# 219  0.312500  query_1  [KEGG:00000]
# 235  0.212121  query_1  [KEGG:00000]
#
#                                          intersections  \
# 130  [RPIA, GPT2, PGK1, CTH, PSPH, TALDO1, PYCR1, R...
# 154  [CDK1, CCNB1, CHEK1, SERPINE1, GTSE1, SERPINB5...
# 164  [DNMT3A, AHCYL1, CTH, DNMT1, AHCY, PSAT1, GCLC...
# 197  [GPT2, ADSL, PPAT, GFPT1, GFPT2, GLUD1, GLS, A...
# 202  [RPIA, GPT2, PGK1, PSPH, TALDO1, RPE, GCSH, GL...
# 205  [UGDH, UAP1, GFPT1, UXS1, NANP, GFPT2, GNPNAT1...
# 216  [MCM6, CCNA2, PLK1, CDK1, CCNB1, CHEK1, MAD2L1...
# 219  [PMM2, TKFC, AKR1B10, GMDS, SORD, PFKP, PFKL, ...
# 235  [SLC7A5, SLC1A5, MAP2K1, MET, GLS, PGAM1, SLC1...
#
#                                              evidences
# 130  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 154  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 164  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 197  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 202  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 205  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 216  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 219  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 235  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %% [markdown]
# Make KEGG Mapper scripts https://www.kegg.jp/kegg/tool/map_pathway2.html Search mode: organism-specific: hsa outside ID: UniProt

# %%
for index, row in pval_results_df.iterrows():
    pathway = row.description
    print('\n' + str(pathway))
    old_genes = (row.intersections)
    new_genes = list(gp.convert(query = old_genes, organism = 'hsapiens', target_namespace= 'uniprotswissprot_acc').converted)
    for gene, ID in zip(old_genes, new_genes):
        s = ID
        delta_corr = list(sig_genes[sig_genes.Gene == gene].avg_interaction_coeff)[0]
        if delta_corr > 0:
            s += ' green'
        else:
            s+= ' red'
        print(s)
# Out:
# Amino sugar and nucleotide sugar metabolism
# O60701 green
# O94808 green
# Q06210 green
# Q9BXD5 red
# O60547 green
# Q8TBE9 green
# Q16222 green
# O14772 green
# Q96EK6 green
# Q9UHQ9 green
# Q16851 green
# P36871 red
# O15305 green
# Q14376 green
# P52790 red
# Q8NBZ7 green
# P51606 red
#
# Biosynthesis of amino acids
# P04075 green
# P32322 green
# P17174 green
# P54687 green
# P78330 green
# Q8TD30 green
# P20132 green
# P34897 green
# P32929 green
# P18669 green
# Q96AT9 green
# P54886 green
# Q9Y617 green
# Q01813 green
# P00505 green
# P00558 green
# P04424 green
# P37837 green
# P14618 green
# P17858 green
# P49247 green
#
# Fructose and mannose metabolism
# P04075 green
# O60218 green
# Q00796 green
# P09467 red
# O60825 green
# O60547 green
# O14772 green
# Q01813 green
# Q3LXA3 green
# O15305 green
# P15121 red
# P17858 green
# P52790 red
#
# p53 signaling pathway
# P31350 green
# P05121 green
# P17936 green
# P06493 green
# P55211 green
# Q658P3 green
# Q9NYZ3 green
# P31947 green
# O96017 green
# P24941 green
# O14757 green
# Q53FA7 green
# P36952 green
# P99999 green
# P14635 green
# P60484 green
# P07996 green
#
# Cysteine and methionine metabolism
# P17174 green
# P54687 green
# P23526 green
# P20132 green
# P32929 green
# Q9Y6K1 green
# P25325 green
# Q96RQ9 green
# P26358 green
# Q9Y617 green
# O43865 green
# P48506 green
# P00505 green
# P48507 green
#
# Carbon metabolism
# P04075 green
# P17174 green
# P78330 green
# P23434 green
# P09467 red
# Q8TD30 green
# P09622 green
# P20132 green
# P34897 green
# P18669 green
# Q9NUB1 green
# P00367 green
# Q96AT9 green
# Q9Y617 green
# P07954 green
# Q01813 green
# P11413 green
# P00505 green
# P00558 green
# Q3LXA3 green
# P37837 green
# P14618 green
# P17858 green
# Q9P2R7 green
# P49247 green
# P52790 red
#
# Alanine, aspartate and glutamate metabolism
# Q06203 green
# O94808 green
# Q06210 green
# P17174 green
#
# ECM-receptor interaction
# P06756 green
# P35442 green
# P16671 red
# Q9UKX5 green
# P17301 green
# P02452 green
# P49747 green
# P18564 green
# Q13751 green
# P08648 green
# Q13753 green
# O75330 green
# P10451 green
# P08123 green
#
# Pentose phosphate pathway
# P04075 green
# P09467 red
# Q96AT9 green
# Q9H477 green
# Q01813 green
# P11413 green
# P36871 red
# P37837 green
# P17858 green
# P49247 green

# %%
for index, row in interaction_results_df.iterrows():
    pathway = row.description
    print('\n' + str(pathway))
    old_genes = (row.intersections)
    new_genes = list(gp.convert(query = old_genes, organism = 'hsapiens', target_namespace= 'uniprotswissprot_acc').converted)
    for gene, ID in zip(old_genes, new_genes):
        s = ID
        delta_corr = list(sig_genes[sig_genes.Gene == gene].avg_interaction_coeff)[0]
        if delta_corr > 0:
            s += ' green'
        else:
            s+= ' red'
        print(s)
# Out:
# p53 signaling pathway
# P42771 red
# Q8N726 green
# P06493 green
# P14635 green
# O14757 green
# P05121 green
# Q9NYZ3 green
# P36952 green
# P31947 green
# P31350 green
# O96017 green
# P24941 green
# P17936 green
# Q658P3 green
# P55211 green
# P07996 green
# P60484 green
# Q53FA7 green
# Q13315 green
#
# Biosynthesis of amino acids
# P49247 green
# Q8TD30 green
# P00558 green
# P32929 green
# P78330 green
# P37837 green
# P32322 green
# Q96AT9 green
# Q9Y617 green
# P34897 green
# P54886 green
# P18669 green
# Q01813 green
# P04424 green
# P17858 green
# P14618 green
# P17174 green
# P20132 green
# P00505 green
# P04075 green
#
# Amino sugar and nucleotide sugar metabolism
# O60701 green
# Q16222 green
# Q06210 green
# Q8NBZ7 green
# Q8TBE9 green
# O94808 green
# Q96EK6 green
# O15305 green
# O60547 green
# Q16851 green
# O14772 green
# Q14376 green
# P52790 red
# Q9BXD5 red
# Q9UHQ9 green
# P51606 red
# P36871 red
#
# Fructose and mannose metabolism
# O15305 green
# Q3LXA3 green
# O60218 green
# O60547 green
# Q00796 green
# Q01813 green
# P17858 green
# O14772 green
# O60825 green
# P04075 green
# P52790 red
# P09467 red
# P15121 red
#
# Cysteine and methionine metabolism
# Q9Y6K1 green
# O43865 green
# P32929 green
# P26358 green
# P23526 green
# Q9Y617 green
# P48506 green
# P48507 green
# P17174 green
# Q96RQ9 green
# Q16762 green
# P20132 green
# P25325 green
# P00505 green
#
# Carbon metabolism
# P49247 green
# Q8TD30 green
# P00558 green
# P78330 green
# P37837 green
# Q96AT9 green
# P23434 green
# P00367 green
# Q9Y617 green
# P34897 green
# Q3LXA3 green
# Q9NUB1 green
# P18669 green
# Q01813 green
# P17858 green
# P14618 green
# P17174 green
# P11413 green
# P20132 green
# P07954 green
# P00505 green
# P04075 green
# P52790 red
# P09467 red
# P09622 green
#
# Cell cycle
# P42771 red
# Q8N726 green
# Q14566 green
# P20248 green
# P53350 green
# P06493 green
# P14635 green
# O14757 green
# Q13257 green
# P63104 green
# P78527 green
# P06400 green
# P31947 green
# O96017 green
# P24941 green
# P33981 green
# O60566 green
# P31946 green
# Q09472 green
# P84022 green
# Q92793 green
#
# Alanine, aspartate and glutamate metabolism
# Q8TD30 green
# P30566 green
# Q06203 green
# Q06210 green
# O94808 green
# P00367 green
# O94925 green
# P04424 green
# P17174 green
# Q96RQ9 green
# P00505 green
#
# Central carbon metabolism in cancer
# Q01650 green
# Q15758 green
# Q02750 green
# P08581 green
# O94925 green
# P18669 green
# O15427 green
# Q01813 green
# P17858 green
# P14618 green
# P60484 green
# P11413 green
# P31751 green
# P31749 green
#
# Pentose phosphate pathway
# P49247 green
# Q9H477 green
# P37837 green
# Q96AT9 green
# Q01813 green
# P17858 green
# P11413 green
# P04075 green
# P09467 red
# P36871 red

# %%
for index, row in up_reg_results_df.iterrows():
    pathway = row.description
    print('\n' + str(pathway))
    old_genes = (row.intersections)
    new_genes = list(gp.convert(query = old_genes, organism = 'hsapiens', target_namespace= 'uniprotswissprot_acc').converted)
    for gene, ID in zip(old_genes, new_genes):
        s = ID
        delta_corr = list(sig_genes[sig_genes.Gene == gene].avg_interaction_coeff)[0]
        if delta_corr > 0:
            s += ' green'
        else:
            s+= ' red'
        print(s)
# Out:
# Biosynthesis of amino acids
# P49247 green
# Q8TD30 green
# P00558 green
# P32929 green
# P78330 green
# P37837 green
# P32322 green
# Q96AT9 green
# Q9Y617 green
# P34897 green
# P54886 green
# P18669 green
# Q01813 green
# P04424 green
# P17858 green
# P14618 green
# P17174 green
# P20132 green
# P00505 green
# P04075 green
#
# p53 signaling pathway
# P06493 green
# P14635 green
# O14757 green
# P05121 green
# Q9NYZ3 green
# P36952 green
# P31947 green
# P31350 green
# O96017 green
# P24941 green
# P17936 green
# Q658P3 green
# P55211 green
# P07996 green
# P60484 green
# Q53FA7 green
# Q13315 green
# P42574 green
#
# Cysteine and methionine metabolism
# Q9Y6K1 green
# O43865 green
# P32929 green
# P26358 green
# P23526 green
# Q9Y617 green
# P48506 green
# P48507 green
# P17174 green
# Q96RQ9 green
# Q16762 green
# P20132 green
# P25325 green
# P00505 green
# P54687 green
#
# Alanine, aspartate and glutamate metabolism
# Q8TD30 green
# P30566 green
# Q06203 green
# Q06210 green
# O94808 green
# P00367 green
# O94925 green
# P04424 green
# P17174 green
# Q96RQ9 green
# P00505 green
#
# Carbon metabolism
# P49247 green
# Q8TD30 green
# P00558 green
# P78330 green
# P37837 green
# Q96AT9 green
# P23434 green
# P00367 green
# Q9Y617 green
# P34897 green
# Q3LXA3 green
# Q9NUB1 green
# P18669 green
# Q01813 green
# P17858 green
# P14618 green
# P17174 green
# P11413 green
# P20132 green
# P07954 green
# P00505 green
# P04075 green
#
# Amino sugar and nucleotide sugar metabolism
# O60701 green
# Q16222 green
# Q06210 green
# Q8NBZ7 green
# Q8TBE9 green
# O94808 green
# Q96EK6 green
# O15305 green
# O60547 green
# Q16851 green
# O14772 green
# Q14376 green
#
# Cell cycle
# Q14566 green
# P20248 green
# P53350 green
# P06493 green
# P14635 green
# O14757 green
# Q13257 green
# P63104 green
# P78527 green
# P06400 green
# P31947 green
# O96017 green
# P24941 green
# P33981 green
# O60566 green
# P31946 green
# Q09472 green
# P84022 green
# Q92793 green
# Q04917 green
#
# Fructose and mannose metabolism
# O15305 green
# Q3LXA3 green
# O60218 green
# O60547 green
# Q00796 green
# Q01813 green
# P17858 green
# O14772 green
# O60825 green
# P04075 green
#
# Central carbon metabolism in cancer
# Q01650 green
# Q15758 green
# Q02750 green
# P08581 green
# O94925 green
# P18669 green
# O15427 green
# Q01813 green
# P17858 green
# P14618 green
# P60484 green
# P11413 green
# P31751 green
# P31749 green

# %%
for index, row in down_reg_results_df.iterrows():
    pathway = row.description
    print('\n' + str(pathway))
    old_genes = (row.intersections)
    new_genes = list(gp.convert(query = old_genes, organism = 'hsapiens', target_namespace= 'uniprotswissprot_acc').converted)
    for gene, ID in zip(old_genes, new_genes):
        s = ID
        delta_corr = list(sig_genes[sig_genes.Gene == gene].avg_interaction_coeff)[0]
        if delta_corr > 0:
            s += ' green'
        else:
            s+= ' red'
        print(s)
# Out:
# Arrhythmogenic right ventricular cardiomyopathy
# P11532 red
# P08514 red
# P35609 red
# P17661 red
#
# Cholesterol metabolism
# P16671 red
# Q02318 red
# P38571 red
#
# Viral myocarditis
# Q03135 red
# P14222 red
# P11532 red
#
# Glycolysis / Gluconeogenesis
# P43353 red
# P52790 red
# P09467 red
# P30838 red
# P36871 red
#
# Malaria
# P16671 red
# P14210 red
# P68871 red
# P16284 red
#
# Phagosome
# P16671 red
# Q15080 red
# P19878 red
# P22897 red
# Q30154 red
# P61421 red
#
# Amino sugar and nucleotide sugar metabolism
# P52790 red
# Q9BXD5 red
# P51606 red
# P36871 red

# %%
# look at differences between protein expression levels of tRNA synthase in tumor vs normal
# does it matter which way to do pathway analysis? 
# change cut off to 15 good sample points for each
