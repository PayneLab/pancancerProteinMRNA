# %%
import cptac
import scipy
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statistics
import parse_correlations_dataframe as get_corr
import copy
# Out:
# cptac warning: Your version of cptac (0.8.5) is out-of-date. Latest is 0.8.6. Please run 'pip install --upgrade cptac' to update it. (<ipython-input-1-147bbc873c03>, line 1)

# %%
def find_mutated_genes (cancer_type, min_patients = 10):
    mt = cancer_type.get_somatic_mutation()
    mt_genes = mt.groupby(by="Gene")
    genes = []
    for gene, patients in mt_genes:
        if len(patients) >= min_patients:
            genes.append(gene)
    return genes

# %%
def find_mutation_corr_effect(cancer_type, gene):
    gene_multi = cancer_type.multi_join({'proteomics': gene, 'transcriptomics': gene, 'somatic_mutation': gene}, tissue_type = 'tumor')
    if gene_multi[str(gene +"_transcriptomics")].isnull().values.any() or gene_multi[str(gene + '_proteomics')].isnull().values.any():
        return float("NaN"), float("NaN"), float("NaN")
    
    trans = list(gene_multi[str(gene +"_transcriptomics")])
    prot = list(gene_multi[str(gene + '_proteomics')])
    group = []
    for i in gene_multi[str(gene + '_Mutation_Status')]:
        if type(i) == str:
            group.append("mutation")
        else:
            group.append("wt")
            
    gene_df = pd.DataFrame({'Type': group, 'Proteomics': prot, 'Transcriptomics': trans})
    is_mut = gene_df['Type'] == 'mutation'
    is_wt = gene_df['Type'] == 'wt'
    gene_cor, gen_pval = scipy.stats.pearsonr(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
    wt_cor, wt_pval = scipy.stats.pearsonr(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
    gene_m, gene_b, gene_r, gene_p, gene_se = stats.linregress(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
    wt_m, wt_b, wt_r, wt_p, wt_se = stats.linregress(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
    gene_r2 = gene_r ** 2
    wt_r2 = wt_r ** 2
    r2_delta = gene_r2 - wt_r2
    corr_dif = gene_cor - wt_cor
    return corr_dif, r2_delta, gene_df

# %%
cptac.download("endometrial")
en = cptac.Endometrial()

# %%
genes = find_mutated_genes(en)

# %%
corr_diffs = []
r2_deltas = []
filtered_genes = []
gene_dfs = []
for gene in genes:
    cor, r2, gene_df = find_mutation_corr_effect(en, gene)
    if not np.isnan(cor):
        corr_diffs.append(cor)
        r2_deltas.append(r2)
        filtered_genes.append(gene)
        gene_dfs.append(gene_df)
en_mutation_effects = pd.DataFrame({'gene': filtered_genes, 'correlation_difference': corr_diffs, "r2_delta" : r2_deltas, "gene_dataframes": gene_dfs})
# Out:
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCA12 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCA13 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCA5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCA6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCB4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCC11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCC12 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABCC9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ACVR2A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADAM29 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADAM32 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADAM7 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADAMTS20 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADAMTS3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADCY1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADGRB3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADGRG4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ADGRV1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: AFF2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: AKAP6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ALK (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ALS2CR11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: ALS2CR11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANKRD18B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANKRD30A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANKRD30B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANKRD31 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANKRD36C (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANKS1B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANO2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ANO4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ARMCX4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ASPM (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ASTN1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ASXL1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ASXL3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ATP8B2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BAHCC1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRINP3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BSN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: C5orf42 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: C5orf42 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1C (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1D (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1E (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1F (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CACNA1H (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CASP8AP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CCDC102B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CCDC141 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CCDC168 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CCDC171 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CCDC73 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CCNB3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CDH10 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CDH23 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CDH7 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CDHR1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CELSR3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CEP295 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CFAP43 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CFAP47 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CFAP54 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CFAP61 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CFAP65 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CMYA5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CNTN6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CNTNAP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CNTNAP4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CNTNAP5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: COL11A1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: COL22A1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: COL4A3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: COL4A4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: COL6A5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: COL6A6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CR2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CRB1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CSMD1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CSMD2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CSMD3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CTAGE1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: CUBN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DCC (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DCHS2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DDIAS (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DGKI (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DISP1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DLGAP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH10 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH12 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH14 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH17 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH7 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNAH9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DNHD1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DOCK3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DOPEY1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: DOPEY1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DSCAM (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DSEL (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: DSPP (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ECT2L (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EFCAB5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EFCAB6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EFHB (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EGF (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EPHA3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EPHA5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EPHA6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ESPL1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: EYS (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: F8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAM135B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAM171B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAM184A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAM47A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAM47B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAM47C (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FANCM (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAT2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAT3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FAT4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FBXW7 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FER1L6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FHOD3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FLG (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FLG2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FMN2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FREM3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FRMPD1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FRY (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: FSIP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GABBR2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GPR158 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GPR179 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRID2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRIK2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRIK4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRIN3A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRM1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRM7 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: GRM8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HCN4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HECW1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HECW2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HFM1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HIVEP1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HMCN2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: HYDIN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ICE1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: IGFN1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: IGSF1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: IGSF10 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: IL1RAPL1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: IRX2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ITIH6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNH2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNH4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNH5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNH8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNJ3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNQ3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KCNU1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIAA0825 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIAA1024 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIAA1549L (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIAA2022 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: KIAA2022 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIAA2026 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIF4B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KIT (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KLHL34 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: L1TD1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LARGE1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LGSN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LOXHD1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LRP1B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LRP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LRRIQ1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: LRRN3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAGEC1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAGEE1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAGEL2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MALRD1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAP3K19 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MAP3K9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MCF2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MDGA2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MED12L (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MGAM (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MGAM2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MMP16 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MORC1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MOV10L1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MTUS2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MUC12 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MUC17 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MUC4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYH1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYH15 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYH2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYH4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYO15A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYO16 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYO18B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYO3A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYOM2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYPN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: MYT1L (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NALCN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NAV3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NCAM2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NDST4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NEB (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NLRC3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NLRP1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NLRP13 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NLRP5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NLRP8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NME8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NOS1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NPAP1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NR1H4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NRG1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NRG3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NRXN1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NUP210L (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: NUTM1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: OBSCN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: OTOGL (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: OVCH1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDH15 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDH17 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDH9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHA1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHA8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHA9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHB15 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHB5 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHB8 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: PCDHGB4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# ...
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SORCS3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SPATA31D1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SPEF2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SPHKAP (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: STAB2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: STARD9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: STXBP5L (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SYCP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SYDE2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TDRD15 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TDRD9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TECTA (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TENM1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TENM3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TENM4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TET1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TEX11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TEX13C (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TEX15 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TG (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: THSD7B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TLL1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TMEM132B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TMEM132D (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TNN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TOPAZ1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TRANK1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TRPM1 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TRPM2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TRPM3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TRPM6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: TTC6 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: UNC13C (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: UNC45B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: UNC79 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: UNC80 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: USH2A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: USP29 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: VWA3B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: WDR49 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: WDR87 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: WNK3 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: WNK4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: XIRP2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZAN (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZBED9 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZC3H12B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZCCHC11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: ZCCHC11 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZDBF2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZFHX4 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZFPM2 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZKSCAN7 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF107 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF117 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF180 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF208 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF23 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF236 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF334 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF469 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF471 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF479 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF484 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF518A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF521 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF536 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF540 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF546 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF559 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF624 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF709 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF711 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF716 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF729 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF782 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF804A (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF804B (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF831 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF835 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF862 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF91 (<ipython-input-22-b7e34fe7b4df>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ZNF99 (<ipython-input-22-b7e34fe7b4df>, line 2)

# %%
en_mutation_effects.head()
# Out:
#      gene  correlation_difference  r2_delta  \
# 0   ABCB1               -0.248630 -0.283049
# 1  ABI3BP               -0.097875 -0.122703
# 2    ADD3               -0.059687 -0.090649
# 3   AHNAK                0.070727  0.126240
# 4  AHNAK2                0.093237  0.155454
#
#                                      gene_dataframes
# 0     Type  Proteomics  Transcriptomics
# 0    wt  ...
# 1     Type  Proteomics  Transcriptomics
# 0    wt  ...
# 2          Type  Proteomics  Transcriptomics
# 0   ...
# 3     Type  Proteomics  Transcriptomics
# 0    wt  ...
# 4          Type  Proteomics  Transcriptomics
# 0   ...

# %%
en_mutation_effects=en_mutation_effects.sort_values(by='correlation_difference')

# %%
most_affected_genes = list(en_mutation_effects['correlation_difference'][0:4])
most_affected_genes.append(list(en_mutation_effects['correlation_difference'][-5:]))
print(most_affected_genes)
# Out:
# [-1.3344143936960622, -1.1702950078948477, -1.147348396454468, -1.100208714017844, [0.5308456843881129, 0.544458000745479, 0.5520101486608533, 0.5691648167902204, 0.706767846192286]]

# %%
for index, df in enumerate(en_mutation_effects['gene_dataframes'][0:4]):
    is_mt = df['Type'] =='mutation'
    is_wt = df['Type'] == 'wt'
    ax = sns.regplot( x = 'Proteomics', y= 'Transcriptomics',  data = df[is_mt], label = "Mutation")
    ax = sns.regplot( x = 'Proteomics', y= 'Transcriptomics',  data = df[is_wt], label = "Wild type")
    ax.legend(loc="best")
    plt.title(en_mutation_effects['gene'][index])
    plt.show()
for index, df in enumerate(en_mutation_effects['gene_dataframes'][-5:]):
    is_mt = df['Type'] =='mutation'
    is_wt = df['Type'] == 'wt'
    ax = sns.regplot( x = 'Proteomics', y= 'Transcriptomics',  data = df[is_mt], label = "Mutation")
    ax = sns.regplot( x = 'Proteomics', y= 'Transcriptomics',  data = df[is_wt], label = "Wild type")
    ax.legend(loc="best")
    plt.title(en_mutation_effects['gene'][index])
    plt.show()
