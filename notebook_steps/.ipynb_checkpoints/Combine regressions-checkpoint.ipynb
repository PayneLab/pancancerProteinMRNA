# %%
import pandas as pd
import glob

# %%
files = glob.glob('data/*regressions.csv')
files
# Out:
# ['data\\ccrcc_regressions.csv',
#  'data\\en_regressions.csv',
#  'data\\hnscc_regressions.csv',
#  'data\\lscc_regressions.csv',
#  'data\\luad_regressions.csv']

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
df = pd.concat(dfs)
df
# Out:
#        Unnamed: 0    gene cancer  interaction_coeff  condition_coeff  \
# 0               0    A1BG  ccrcc          -0.399310         0.683426
# 1               1    A1CF  ccrcc           0.009264        -0.282587
# 2               2     A2M  ccrcc          -0.001738         1.059763
# 3               3  A4GALT  ccrcc          -0.069014         1.186499
# 4               4    AAAS  ccrcc          -0.005048         0.253459
# ...           ...     ...    ...                ...              ...
# 10066       10066    ZXDC   luad          -0.146323         0.889409
# 10067       10067  ZYG11B   luad           1.424677        -5.791951
# 10068       10068     ZYX   luad           0.714921        -5.450918
# 10069       10069   ZZEF1   luad           0.596868        -2.881060
# 10070       10070    ZZZ3   luad           1.930651        -8.915487
#
#        transcript_coeff  intercept  interaction_pval  condition_pval  \
# ...

# %%
df.to_csv('data/regressions.csv')
