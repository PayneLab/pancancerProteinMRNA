# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Cancer_stages_correlations.csv')
df
# Out:
#        Cancer      Stage    Gene  PearsonR
# 0       CCRCC     Normal    A1BG  0.328964
# 1       CCRCC     Normal    A1CF  0.745763
# 2       CCRCC     Normal     A2M  0.287323
# 3       CCRCC     Normal    AAAS  0.156649
# 4       CCRCC     Normal    AACS  0.707274
# ...       ...        ...     ...       ...
# 235814   PDAC  Stage III  ZWILCH  0.385813
# 235815   PDAC  Stage III  ZYG11B  0.171495
# 235816   PDAC  Stage III     ZYX  0.480944
# 235817   PDAC  Stage III   ZZEF1  0.097533
# 235818   PDAC  Stage III    ZZZ3 -0.090946
#
# [235819 rows x 4 columns]

# %%
g = sns.FacetGrid(data = df, col = 'Cancer', hue = 'Stage', col_wrap = 3, legend_out = True, 
                  palette={"Normal" : "royalblue","Stage I" : "red", "Stage II" : "darkred",
                           "Stage III" : "purple","Stage IV" : "black"})

g.map_dataframe(sns.kdeplot, x = 'PearsonR')
g.add_legend()
plt.savefig('Figures/Figure 1) Correlation changes by cancer stage')
plt.show()
