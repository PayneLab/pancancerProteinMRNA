# %%
import pandas as pd
import scipy
import seaborn as sns
import matplotlib.pyplot as plt

# %%
permutations = pd.read_csv('full_10k_permutation.csv')

# %%
pval = pd.read_csv('p_val.csv')
pval = pval[pval.Cancer != 'gbm']

# %%
cor_diff = pd.read_csv('corr_diff.csv')
cor_diff = cor_diff[cor_diff.Cancer != 'gbm']

# %%
cor_diff = cor_diff.melt(id_vars = ['Cancer'], var_name = 'gene', value_name= 'cor_diff' )
pval = pval.melt(id_vars = ['Cancer'], var_name = 'gene', value_name= 'transformed_pval' )
permutations = permutations.melt(id_vars = ['Cancer'], var_name = 'gene', value_name= 'permutation_pval' )

# %%
both_pvals = pd.merge(permutations, pval)
both_pvals = both_pvals.dropna()
both_pvals
# Out:
#       Cancer   gene  permutation_pval  transformed_pval
# 0      ccrcc   A1BG          0.052810          0.008435
# 1       luad   A1BG          0.758399          0.778949
# 2      hnscc   A1BG          0.996778          0.988560
# 3       lscc   A1BG          0.137994          0.169387
# 4      ccrcc   A1CF          0.000838          0.001958
# ...      ...    ...               ...               ...
# 54671   lscc  ZZEF1          0.000002          0.011934
# 54672  ccrcc   ZZZ3          0.202787          0.191946
# 54673   luad   ZZZ3          0.000013          0.000002
# 54674  hnscc   ZZZ3          0.762835          0.795908
# 54675   lscc   ZZZ3          0.018557          0.000571
#
# [43001 rows x 4 columns]

# %%
sns.regplot(data = both_pvals, x = 'permutation_pval', y = 'transformed_pval')

# %%
perm_corr_diff = pd.merge(permutations, cor_diff)
perm_corr_diff = perm_corr_diff.dropna()
perm_corr_diff
# Out:
#       Cancer   gene  permutation_pval  cor_diff
# 0      ccrcc   A1BG          0.052810 -0.388745
# 1       luad   A1BG          0.758399 -0.039149
# 2      hnscc   A1BG          0.996778 -0.002651
# 3       lscc   A1BG          0.137994  0.196946
# 4      ccrcc   A1CF          0.000838  0.146993
# ...      ...    ...               ...       ...
# 54671   lscc  ZZEF1          0.000002  0.268239
# 54672  ccrcc   ZZZ3          0.202787 -0.220727
# 54673   luad   ZZZ3          0.000013  0.661323
# 54674  hnscc   ZZZ3          0.762835 -0.060708
# 54675   lscc   ZZZ3          0.018557  0.446553
#
# [43001 rows x 4 columns]

# %%
sns.regplot(data = perm_corr_diff, y = 'permutation_pval', x = 'cor_diff')

# %%
perm_corr_diff['cor_diff'] = abs(perm_corr_diff.cor_diff)

# %%
sns.regplot(data = perm_corr_diff, y = 'permutation_pval', x = 'cor_diff')

# %%
transform_corr_diff = pd.merge(pval, cor_diff)
transform_corr_diff = transform_corr_diff.dropna()
transform_corr_diff
# Out:
#             Cancer  gene  transformed_pval  cor_diff
# 0            ccrcc  A1BG          0.008435 -0.388745
# 1      endometrial  A1BG          0.824775  0.061654
# 2             luad  A1BG          0.778949 -0.039149
# 3            hnscc  A1BG          0.988560 -0.002651
# 4             lscc  A1BG          0.169387  0.196946
# ...            ...   ...               ...       ...
# 73175        ccrcc  ZZZ3          0.191946 -0.220727
# 73176  endometrial  ZZZ3          0.261292  0.342423
# 73177         luad  ZZZ3          0.000002  0.661323
# 73178        hnscc  ZZZ3          0.795908 -0.060708
# 73179         lscc  ZZZ3          0.000571  0.446553
#
# [53352 rows x 4 columns]

# %%
sns.regplot(data = transform_corr_diff, x = 'cor_diff', y = 'transformed_pval')

# %%
transform_corr_diff['cor_diff'] = abs(transform_corr_diff.cor_diff)

# %%
sns.regplot(data = transform_corr_diff, x = 'cor_diff', y = 'transformed_pval')

# %%
both_pvals.corr()
# Out:
#                   permutation_pval  transformed_pval
# permutation_pval          1.000000          0.961506
# transformed_pval          0.961506          1.000000

# %%
perm_corr_diff.corr()
# Out:
#                   permutation_pval  cor_diff
# permutation_pval          1.000000 -0.649468
# cor_diff                 -0.649468  1.000000

# %%
transform_corr_diff.corr()
# Out:
#                   transformed_pval  cor_diff
# transformed_pval          1.000000 -0.678293
# cor_diff                 -0.678293  1.000000
