# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy 
import dataframe_image as dfi

# %%
pd.set_option('display.max_rows',70)

# %%
df = pd.read_csv('data/Positive_delta_corr_individual_cancer_pathways.csv')
df = df[df.source.isin(['GO:BP', 'KEGG'])]
df = df[['source', 'name', 'p_value', 'term_size', 'intersection_size', 'Cancer']]
df = df.rename(columns = {'source': 'Database', 'name': 'Pathway', 'term_size' : 'Pathway size', 'intersection_size': '# upregulated genes'})
df = df.groupby(['Database', 'Pathway', 'Cancer', 'p_value', 'Pathway size', '# upregulated genes']).apply(lambda x: x['# upregulated genes'] / x['Pathway size'])

df = pd.DataFrame(df, columns = ['percent_pathway'])
df = df.droplevel(None)
#df['Cancer'] = df.index.get_level_values('Cancer')
df['Pathway size'] = df.index.get_level_values('Pathway size')
df['# upregulated genes'] = df.index.get_level_values('# upregulated genes')
df['p_value'] = df.index.get_level_values('p_value')
df = df.droplevel([ '# upregulated genes', 'Pathway size', 'p_value'])
#df = df.drop(columns = ['percent_pathway'])
df = df.style.hide_columns(['percent_pathway']).bar(subset=['p_value'], color = 'red')
#df = df.style.bar(subset=['p_value'], color = 'red')
df
# Out:
# <style  type="text/css" >
# #T_ee97f_row0_col3,#T_ee97f_row38_col3,#T_ee97f_row39_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 5.4%, transparent 5.4%);
#         }#T_ee97f_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 2.1%, transparent 2.1%);
#         }#T_ee97f_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.0%, transparent 9.0%);
#         }#T_ee97f_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 35.7%, transparent 35.7%);
#         }#T_ee97f_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 10.9%, transparent 10.9%);
#         }#T_ee97f_row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 36.7%, transparent 36.7%);
#         }#T_ee97f_row6_col3,#T_ee97f_row46_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 13.7%, transparent 13.7%);
#         }#T_ee97f_row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 91.5%, transparent 91.5%);
#         }#T_ee97f_row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 1.8%, transparent 1.8%);
#         }#T_ee97f_row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 2.6%, transparent 2.6%);
#         }#T_ee97f_row10_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 65.4%, transparent 65.4%);
#         }#T_ee97f_row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 1.2%, transparent 1.2%);
#         }#T_ee97f_row12_col3,#T_ee97f_row27_col3,#T_ee97f_row44_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 0.1%, transparent 0.1%);
#         }#T_ee97f_row13_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 19.5%, transparent 19.5%);
#         }#T_ee97f_row14_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 60.6%, transparent 60.6%);
#         }#T_ee97f_row15_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 0.3%, transparent 0.3%);
#         }#T_ee97f_row16_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 12.7%, transparent 12.7%);
#         }#T_ee97f_row17_col3,#T_ee97f_row49_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 1.1%, transparent 1.1%);
#         }#T_ee97f_row18_col3,#T_ee97f_row56_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 2.2%, transparent 2.2%);
#         }#T_ee97f_row19_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 15.2%, transparent 15.2%);
#         }#T_ee97f_row20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 11.4%, transparent 11.4%);
#         }#T_ee97f_row21_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 42.8%, transparent 42.8%);
#         }#T_ee97f_row22_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 16.4%, transparent 16.4%);
#         }#T_ee97f_row23_col3,#T_ee97f_row24_col3,#T_ee97f_row25_col3,#T_ee97f_row33_col3,#T_ee97f_row36_col3,#T_ee97f_row50_col3,#T_ee97f_row51_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 0.0%, transparent 0.0%);
#         }#T_ee97f_row26_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 2.8%, transparent 2.8%);
#         }#T_ee97f_row28_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 0.6%, transparent 0.6%);
#         }#T_ee97f_row29_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 44.7%, transparent 44.7%);
#         }#T_ee97f_row30_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 11.2%, transparent 11.2%);
#         }#T_ee97f_row31_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 56.4%, transparent 56.4%);
#         }#T_ee97f_row32_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 2.3%, transparent 2.3%);
#         }#T_ee97f_row34_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 22.9%, transparent 22.9%);
#         }#T_ee97f_row35_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.4%, transparent 7.4%);
#         }#T_ee97f_row37_col3{
#             width:  10em;
#              height:  80%;
#         }#T_ee97f_row40_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 100.0%, transparent 100.0%);
#         }#T_ee97f_row41_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 13.9%, transparent 13.9%);
#         }#T_ee97f_row42_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 20.5%, transparent 20.5%);
#         }#T_ee97f_row43_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 6.8%, transparent 6.8%);
#         }#T_ee97f_row45_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 6.7%, transparent 6.7%);
#         }#T_ee97f_row47_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 70.1%, transparent 70.1%);
#         }#T_ee97f_row48_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 3.4%, transparent 3.4%);
#         }#T_ee97f_row52_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 84.0%, transparent 84.0%);
#         }#T_ee97f_row53_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.6%, transparent 9.6%);
#         }#T_ee97f_row54_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 30.9%, transparent 30.9%);
#         }#T_ee97f_row55_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 75.1%, transparent 75.1%);
#         }#T_ee97f_row57_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 22.2%, transparent 22.2%);
#         }#T_ee97f_row58_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 66.4%, transparent 66.4%);
#         }#T_ee97f_row59_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 55.0%, transparent 55.0%);
#         }#T_ee97f_row60_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 5.2%, transparent 5.2%);
#         }</style><table id="T_ee97f_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>

# %%
df.index.get_level_values('Cancer')
# Out:
# Index(['LSCC', 'LUAD', 'LUAD', 'LSCC', 'LUAD', 'LUAD', 'HNSCC', 'LUAD', 'LSCC',
#        'LUAD', 'LSCC', 'LSCC', 'LUAD', 'LSCC', 'LSCC', 'LSCC', 'LSCC', 'LUAD',
#        'LSCC', 'LUAD', 'LSCC', 'LSCC', 'LSCC', 'LUAD', 'LSCC', 'LSCC', 'LSCC',
#        'LUAD', 'LSCC', 'LSCC', 'LUAD', 'LSCC', 'LUAD', 'LUAD', 'LSCC', 'LSCC',
#        'LSCC', 'LUAD', 'LUAD', 'LUAD', 'HNSCC', 'LSCC', 'LSCC', 'LSCC', 'LUAD',
#        'LSCC', 'HNSCC', 'Endometrial', 'LSCC', 'LUAD', 'LSCC', 'LUAD', 'LSCC',
#        'LSCC', 'LUAD', 'LSCC', 'LUAD', 'LSCC', 'HNSCC', 'LSCC', 'Endometrial'],
#       dtype='object', name='Cancer')

# %%
dfi.export(df, 'Figures/Positive_delta_corr_pathways.png', max_cols= -1, max_rows=-1)

# %%
g = sns.FacetGrid(data = df, col = 'Cancer', row = 'source', sharex = True, sharey=False)
g.map_dataframe(sns.barplot,y = 'name', x ='intersection_size', hue = 'p_value')
# Out:
# C:\Users\nanel\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(9,13))
g = sns.barplot(data = df, x = '-log10(p_value)', y = 'name', hue = 'Cancer Hallmark')
g.legend(bbox_to_anchor=(1.01, .5), ncol=1, title = 'Cancer Hallmark')
plt.ylabel('GO:BP Pathway')
#plt.tight_layout()
plt.savefig('Figures/Figure 5) Cancer Hallmarks Pathways.png', bbox_inches='tight')
