# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
trans_mutation_df = pd.read_csv('data (new)/transmutation_df.csv')
delta_correlation_df = pd.read_csv('data (new)/delta_correlation_df.csv')

# %%
delta_correlation_df = delta_correlation_df[delta_correlation_df.FDR < 0.05]
delta_correlation_df = delta_correlation_df[['Gene', 'Cancer']]
trans_df = pd.merge(trans_mutation_df, delta_correlation_df, how = 'inner')
trans_df
# Out:
#           Gene  Delta_Correlation   P_Value       FDR Cancer Mutated_Gene
# 0         A1CF          -0.065395  0.016782  0.583227  CCRCC        PBRM1
# 1         A1CF          -0.006303  0.754865  0.988557  CCRCC        SETD2
# 2        AAGAB          -0.165634  0.077515  0.729612  CCRCC        PBRM1
# 3        AAGAB          -0.073024  0.672998  0.983389  CCRCC        SETD2
# 4         AAK1          -0.148163  0.178295  0.800595  CCRCC        PBRM1
# ...        ...                ...       ...       ...    ...          ...
# 157355  ZNF185          -0.031223  0.373601  0.907771   PDAC         TP53
# 157356   ZNF24          -0.247906  0.240231  0.985551   PDAC        SMAD4
# 157357   ZNF24           0.069549  0.694942  0.961040   PDAC         TP53
# 157358    DSG3          -0.087929  0.422421  0.914512   PDAC         TP53
# 157359  METRNL           0.101221  0.577093  0.943065   PDAC         TP53
#
# [157360 rows x 6 columns]

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 2, sharex = True, sharey = True,
                        figsize=(12,15))
cancers = list(pd.unique(trans_df.Cancer))
for ax in axes.flatten():
    if len(cancers) == 0:
        break
    cancer = cancers[0]
    cancers.remove(cancer)
    df = trans_df[trans_df.Cancer == cancer]
    plt.subplot(ax)
    sns.scatterplot(data = df, x = 'Delta_Correlation', y= 'FDR', hue = 'Mutated_Gene')
    ax.invert_yaxis()
    ax.set_yscale('log')
    plt.axhline(y = 0.05, color = 'r')
    plt.title(cancer)

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 2, sharex = True, sharey = True,
                        figsize=(12,15))
cancers = list(pd.unique(trans_mutation_df.Cancer))
for ax in axes.flatten():
    if len(cancers) == 0:
        break
    cancer = cancers[0]
    cancers.remove(cancer)
    df = trans_mutation_df[trans_mutation_df.Cancer == cancer]
    plt.subplot(ax)
    sns.scatterplot(data = df, x = 'Delta_Correlation', y= 'FDR', hue = 'Mutated_Gene')
    plt.axhline(y = 0.05, color = 'r')
    plt.title(cancer)
    plt.legend(bbox_to_anchor=(1.01, 1))
ax.invert_yaxis()
ax.set_yscale('log')
