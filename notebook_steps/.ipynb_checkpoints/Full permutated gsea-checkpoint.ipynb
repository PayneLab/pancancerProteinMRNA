# %%
import cptac
import cptac.utils as ut
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd

# %%
perm_df = pd.read_csv("full_10k_permutation.csv", index_col=0)

# %%
aList = []
for i in perm_df:
    count = 0
    for j in perm_df[i]:
        if j <= 0.05/13669:
            count += 1
            if i not in aList and count >= 4:
                aList.append(i)
#     print(perm_df[i])
len(aList)
# Out:
# 177

# %%
len(perm_df.columns)
# Out:
# 13669

# %%
(len(aList)*100)/len(perm_df.columns)
# Out:
# 1.2949008705830711

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot
# Out:
# Creating directory C:\Users\nanel\AppData\Local\bioservices\bioservices

# %%
tumor_enr = gp.enrichr(gene_list = aList, description='', gene_sets='MSigDB_Hallmark_2020')

# %%
tumor_enr

# %%
barplot(tumor_enr.res2d)
plt.show()

# %%
perm_df
# Out:
#             A1BG      A1CF       A2M         A2ML1    A4GALT      AAAS  \
# Cancer
# ccrcc   0.052810  0.000838  0.029716           NaN  0.337474  0.728086
# en      0.781720       NaN  0.911887  1.389663e-02  0.332572  0.005615
# luad    0.758399       NaN  0.010615           NaN       NaN  0.139531
# hnscc   0.996778  0.776459  0.228337  5.558182e-04  0.040184  0.014557
# lscc    0.137994       NaN  0.097044  2.033188e-22  0.154022  0.008081
#
#                 AACS     AADAC     AADAT     AAED1  ...    ZSWIM9  \
# Cancer                                              ...
# ccrcc   6.413643e-02  0.350422  0.057700  0.652970  ...       NaN
# en      6.073417e-09       NaN  0.309108  0.020057  ...  0.601641
# luad    1.567981e-36  0.022448  0.017033  0.834506  ...       NaN
# hnscc   8.203827e-01  0.000280       NaN  0.133325  ...       NaN
# lscc    7.086254e-02  0.456664       NaN       NaN  ...  0.001427
#
#                 ZW10        ZWILCH         ZWINT  ZXDA      ZXDC  \
# ...

# %%
ccrcc_list = []
perm_cols = perm_df.columns
for index, value in enumerate(perm_df.loc['ccrcc']):
    if(value <= 0.05/13669):
        ccrcc_list.append(perm_cols[index])
tumor_enr = gp.enrichr(gene_list = ccrcc_list, description='', gene_sets='KEGG_2016')
barplot(tumor_enr.res2d)
plt.show()

# %%
tumor_enr.res2d.head(20)
# Out:
#      Gene_set                                               Term   Overlap  \
# 0   KEGG_2016           Metabolic pathways Homo sapiens hsa01100  134/1239
# 1   KEGG_2016            Carbon metabolism Homo sapiens hsa01200    29/113
# 2   KEGG_2016        Propanoate metabolism Homo sapiens hsa00640     12/32
# 3   KEGG_2016  Glycine, serine and threonine metabolism Homo ...     13/40
# 4   KEGG_2016  Biosynthesis of amino acids Homo sapiens hsa01230     17/74
# 5   KEGG_2016  Valine, leucine and isoleucine degradation Hom...     13/48
# 6   KEGG_2016  Glycolysis / Gluconeogenesis Homo sapiens hsa0...     14/67
# 7   KEGG_2016  Antigen processing and presentation Homo sapie...     15/77
# 8   KEGG_2016       Rap1 signaling pathway Homo sapiens hsa04015    26/211
# 9   KEGG_2016               Tight junction Homo sapiens hsa04530    20/139
# 10  KEGG_2016       ErbB signaling pathway Homo sapiens hsa04012     15/87
# ...

# %%
en_list = []
perm_cols = perm_df.columns
for index, value in enumerate(perm_df.loc['en']):
    if(value <= 0.05/13669):
        en_list.append(perm_cols[index])
tumor_enr = gp.enrichr(gene_list = ccrcc_list, description='', gene_sets='KEGG_2016')
barplot(tumor_enr.res2d)
plt.show()

# %%
luad_list = []
perm_cols = perm_df.columns
for index, value in enumerate(perm_df.loc['luad']):
    if(value <= 0.05/13669):
        luad_list.append(perm_cols[index])
tumor_enr = gp.enrichr(gene_list = ccrcc_list, description='', gene_sets='KEGG_2016')
barplot(tumor_enr.res2d)
plt.show()

# %%
hnscc_list = []
perm_cols = perm_df.columns
for index, value in enumerate(perm_df.loc['hnscc']):
    if(value <= 0.05/13669):
        hnscc_list.append(perm_cols[index])
tumor_enr = gp.enrichr(gene_list = ccrcc_list, description='', gene_sets='KEGG_2016')
barplot(tumor_enr.res2d)
plt.show()

# %%
lscc_list = []
perm_cols = perm_df.columns
for index, value in enumerate(perm_df.loc['lscc']):
    if(value <= 0.05/13669):
        lscc_list.append(perm_cols[index])
tumor_enr = gp.enrichr(gene_list = ccrcc_list, description='', gene_sets='KEGG_2016')
barplot(tumor_enr.res2d)
plt.show()
