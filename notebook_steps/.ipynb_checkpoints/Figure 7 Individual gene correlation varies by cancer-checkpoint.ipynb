# %%
import cptac
import scipy
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statistics
import parse_correlations_dataframe as get_corr
import copy
# Out:
# cptac warning: Your version of cptac (0.8.5) is out-of-date. Latest is 0.8.6. Please run 'pip install --upgrade cptac' to update it. (<ipython-input-1-147bbc873c03>, line 1)

# %%
def find_mutation_corr_effect(cancer_type, gene, corr_dif = True):
    gene_multi = cancer_type.multi_join({'proteomics': gene, 'transcriptomics': gene, 'somatic_mutation': gene})
    print(gene_multi)
    if gene_multi[str(gene + '_proteomics')].isnull().values.any():
        return float("NaN"), float("NaN"), float("NaN")    
    trans = list(gene_multi[str(gene +"_transcriptomics")])
    prot = list(gene_multi[str(gene + '_proteomics')])
    group = []
    for i in gene_multi[str(gene + '_Mutation_Status')]:
        if type(i) == str:
            group.append("mutation")
        else:
            group.append("wt")           
    gene_df = pd.DataFrame({'Type': group, 'Proteomics': prot, 'Transcriptomics': trans})
    is_mut = gene_df['Type'] == 'mutation'
    is_wt = gene_df['Type'] == 'wt'
    gene_df = gene_df.dropna()
    gene_cor, gen_pval = scipy.stats.pearsonr(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
    wt_cor, wt_pval = scipy.stats.pearsonr(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
    gene_m, gene_b, gene_r, gene_p, gene_se = stats.linregress(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
    wt_m, wt_b, wt_r, wt_p, wt_se = stats.linregress(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
    gene_r2 = gene_r ** 2
    wt_r2 = wt_r ** 2
    r2_delta = gene_r2 - wt_r2
    corr_dif = gene_cor - wt_cor
    if corr_dif:
        return abs(corr_dif), r2_delta, gene_df
    else: 
        return gene_cor, wt_cor, gene_df

# %%
def find_norm_tumor_corr_effect(cancer_type, gene):
    tumor = cancer_type.multi_join({'proteomics': gene, 'transcriptomics': gene}, tissue_type= 'tumor', flatten = True)
    normal = cancer_type.multi_join({'proteomics': gene, 'transcriptomics': gene}, tissue_type= 'normal', flatten = True)
    tumor = tumor.dropna()
    normal = normal.dropna()
    if len(normal) < 2 or len(tumor) < 2:
        return float("NaN"), float("NaN"), float("NaN")
    tumor.columns = ['proteomics', 'transcriptomics']
    normal.columns = ['proteomics', 'transcriptomics']
    groups = ['tumor'] * len(tumor)
    groups.extend(['normal']*len(normal))
    prot_list = list(tumor['proteomics'])
    prot_list.extend(list(normal['proteomics']))
    trans_list = list(tumor['transcriptomics'])
    trans_list.extend(list(normal['transcriptomics']))
    gene_df = pd.DataFrame({'Type': groups, 'Proteomics': prot_list, 'Transcriptomics': trans_list})
    is_tum = gene_df['Type'] == 'tumor'
    is_norm = gene_df['Type'] == 'normal'
    tum_cor, tum_pval = scipy.stats.pearsonr(gene_df[is_tum]['Proteomics'], gene_df[is_tum]['Transcriptomics'])
    norm_cor, norm_pval = scipy.stats.pearsonr(gene_df[is_norm]['Proteomics'], gene_df[is_norm]['Transcriptomics'])
    return tum_cor, norm_cor, gene_df

# %%
def get_cancer_string(cancer):
    if cancer == brca:
        return "brca"
    if cancer == ccrcc:
        return "ccrcc"
    if cancer == colon:
        return 'colon'
    if cancer == en:
        return 'en'
    if cancer == gbm:
        return 'gbm'
    if cancer == luad:
        return 'luad'
    if cancer == ovarian:
        return 'ovarian'
    if cancer == hnscc:
        return 'hnscc'
    if cancer == lscc:
        return 'lscc'

# %%
gene = 'KRAS'
tumor = ccrcc.multi_join({'proteomics': gene, 'transcriptomics': gene}, tissue_type= 'tumor', flatten = False)
tumor = tumor.dropna()
print(tumor)

tumor = ccrcc.join_omics_to_omics('proteomics', 'transcriptomics', genes1 = gene, genes2 = gene)
print(tumor)
# Out:
# Name        KRAS_proteomics             KRAS_transcriptomics
# Database_ID     NP_004976.2 NP_203524.1
# Patient_ID
# C3L-00079         -0.222096   -0.088909             6.352764
# C3L-00910          0.490832    0.450157            10.446762
# C3L-01281         -0.306274   -0.097409             6.565567
# C3N-00495          0.047788    0.654244             5.817948
# C3N-00831          0.093145    0.619984             4.848198
# C3N-01220          0.102117    0.402413             6.450097
# C3N-01522         -0.187688   -0.180526             6.034788
# C3N-01646         -0.178977   -0.079340             5.296055
# Name        KRAS_proteomics             KRAS_transcriptomics
# Database_ID     NP_004976.2 NP_203524.1
# Patient_ID
# C3L-00004         -0.393854         NaN             8.363200
# C3L-00010         -0.085605         NaN             7.786690
# C3L-00011         -0.206344         NaN             8.061561
# C3L-00026         -0.375411         NaN             6.527772
# C3L-00079         -0.222096   -0.088909             6.352764
# ...                     ...         ...                  ...
# C3N-01646.N        0.365730    0.055344             7.138401
# C3N-01648.N       -0.020032         NaN             7.175792
# C3N-01649.N        0.197927         NaN             6.609927
# C3N-01651.N             NaN         NaN             7.620171
# C3N-01808.N        0.400278         NaN             6.097377
#
# [194 rows x 3 columns]
# cptac warning: transcriptomics data was not found for the following samples, so transcriptomics data columns were filled with NaN for these samples: C3L-00183.N, C3L-00791.N, C3N-00246.N, C3N-00312.N, C3N-00317.N, C3N-00320.N, C3N-00437.N, C3N-00492.N, C3N-00953.N (<ipython-input-93-7d73838dd191>, line 6)

# %%
cancer_genes = ['ABL1','BRAF','FAT1','IDH1','TP53','BRCA2','KMT2D','KRAS','PIK3CA','PTEN','SETD2','SPTA1']

# %%
brca = cptac.Brca()
ccrcc = cptac.Ccrcc()
colon = cptac.Colon()
en = cptac.Endometrial()
gbm = cptac.Gbm()
luad = cptac.Luad()
ovarian = cptac.Ovarian()
hnscc  = cptac.Hnscc()
lscc = cptac.Lscc()
# Out:
# Checking that luad index is up-to-date...
# cptac warning: The GBM dataset is under publication embargo until March 01, 2021. CPTAC is a community resource project and data are made available rapidly after generation for community research use. The embargo allows exploring and utilizing the data, but analysis may not be published until after the embargo date. Please see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details. (<ipython-input-4-0467c23f8dc0>, line 5)
# Checking that lscc index is up-to-date...
# cptac warning: The HNSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (<ipython-input-4-0467c23f8dc0>, line 8)
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (<ipython-input-4-0467c23f8dc0>, line 9)

# %%
cancer_list = [brca,ccrcc,colon,en,gbm,luad,ovarian,hnscc,lscc]

# %%
tum_corr = []
norm_corr = []
gene_dfs = []
genes = []
cancer_type = []
for cancer in cancer_list:
    for gene in cancer_genes:
        if gene == "KRAS" and cancer == ccrcc:
            continue
        tum_cor, norm_cor, gene_df = find_norm_tumor_corr_effect(cancer, gene)
        if not np.isnan(tum_cor):
            tum_corr.append(tum_cor)
            norm_corr.append(norm_cor)
            gene_dfs.append(gene_df)
            cancer_type.append(get_cancer_string(cancer))
            genes.append(gene)
norm_tumor_effects = pd.DataFrame({'cancer': cancer_type, 'gene': genes, 'tumor_correlation': tum_corr, 'normal_correlation': norm_corr, 'gene_df': gene_dfs})
norm_tumor_effects.head()
# Out:
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KMT2D (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KMT2D (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: SPTA1 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: SPTA1 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABL1 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABL1 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
#   cancer  gene  tumor_correlation  normal_correlation  \
# 0  ccrcc  ABL1           0.549188            0.289991
# 1  ccrcc  BRAF           0.546805            0.081654
# 2  ccrcc  FAT1           0.600361            0.409362
# 3  ccrcc  IDH1           0.699513            0.741719
# 4  ccrcc  TP53           0.146573           -0.278706
#
#                                              gene_df
# 0         Type  Proteomics  Transcriptomics
# 0    ...
# 1         Type  Proteomics  Transcriptomics
# 0    ...
# 2         Type  Proteomics  Transcriptomics
# 0    ...
# 3         Type  Proteomics  Transcriptomics
# 0    ...
# 4        Type  Proteomics  Transcriptomics
# 0    t...

# %%
norm_tumor_effects = norm_tumor_effects.assign(cor_dif = abs(norm_tumor_effects['tumor_correlation'] - norm_tumor_effects['normal_correlation']))

# %%
norm_tumor_effects.head()
# Out:
#   cancer  gene  tumor_correlation  normal_correlation  \
# 0  ccrcc  ABL1           0.549188            0.289991
# 1  ccrcc  BRAF           0.546805            0.081654
# 2  ccrcc  FAT1           0.600361            0.409362
# 3  ccrcc  IDH1           0.699513            0.741719
# 4  ccrcc  TP53           0.146573           -0.278706
#
#                                              gene_df   cor_dif
# 0         Type  Proteomics  Transcriptomics
# 0    ...  0.259198
# 1         Type  Proteomics  Transcriptomics
# 0    ...  0.465151
# 2         Type  Proteomics  Transcriptomics
# 0    ...  0.191000
# 3         Type  Proteomics  Transcriptomics
# 0    ...  0.042206
# 4        Type  Proteomics  Transcriptomics
# 0    t...  0.425279

# %%
norm_tumor_effects = norm_tumor_effects.sort_values(by = 'cor_dif', ascending=False, ignore_index=True)
norm_tumor_effects.head()
# Out:
#   cancer   gene  tumor_correlation  normal_correlation  \
# 0    gbm   IDH1           0.748630           -0.320068
# 1   lscc   TP53           0.723227           -0.344411
# 2    gbm  KMT2D           0.163472           -0.814371
# 3    gbm   ABL1           0.454675           -0.446110
# 4     en  SETD2           0.526095           -0.355628
#
#                                              gene_df   cor_dif
# 0         Type  Proteomics  Transcriptomics
# 0    ...  1.068698
# 1         Type  Proteomics  Transcriptomics
# 0    ...  1.067638
# 2         Type  Proteomics  Transcriptomics
# 0    ...  0.977843
# 3         Type  Proteomics  Transcriptomics
# 0    ...  0.900785
# 4         Type  Proteomics  Transcriptomics
# 0    ...  0.881722

# %%
for index, df in enumerate(norm_tumor_effects['gene_df']):
    is_norm = df['Type']=='normal'
    is_tum = df['Type'] == 'tumor'
    ax = sns.regplot(x = 'Proteomics', y = 'Transcriptomics', data = df[is_norm], label = "Normal")
    ax = sns.regplot(x = 'Proteomics', y = 'Transcriptomics', data = df[is_tum], label = 'Tumor')
    ax.legend(loc = 'best')
    plt.title(str(norm_tumor_effects['cancer'][index] + ' | ' + norm_tumor_effects['gene'][index]))
    plt.show()

# %%
dfs = []
for cancer in cancer_list:
    for gene in cancer_genes:
        if gene == "KRAS" and cancer == ccrcc:
            continue
        tum_cor, norm_cor, gene_df = find_norm_tumor_corr_effect(cancer, gene)
        if not np.isnan(tum_cor):
            gene_df['cancer'] = [get_cancer_string(cancer)]*len(gene_df)
            gene_df['gene'] = [gene]*len(gene_df)
            dfs.append(gene_df)
print(dfs)
# Out:
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KMT2D (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: KMT2D (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: SPTA1 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the transcriptomics dataframe, so they were inserted into joined table, but filled with NaN: SPTA1 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABL1 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: ABL1 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: SETD2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 2)
# cptac warning: The following columns were not found in the proteomics dataframe, so they were inserted into joined table, but filled with NaN: BRCA2 (<ipython-input-95-4eb76cdc6c64>, line 3)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# cptac warning: You tried to flatten a column index that didn't have multiple levels, so we didn't actually change anything. (C:\Users\nanel\anaconda3\lib\site-packages\cptac\dataset.py, line 697)
# [       Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.009639         7.661943  ccrcc  ABL1
# 1     tumor    0.237193         9.920884  ccrcc  ABL1
# 2     tumor    0.191196        11.183207  ccrcc  ABL1
# 3     tumor    0.293282        10.196784  ccrcc  ABL1
# 4     tumor    0.016505        13.882935  ccrcc  ABL1
# ..      ...         ...              ...    ...   ...
# 180  normal    0.042291        12.240661  ccrcc  ABL1
# 181  normal    0.083964        14.393607  ccrcc  ABL1
# 182  normal   -0.082013        12.459424  ccrcc  ABL1
# 183  normal    0.217424        13.749119  ccrcc  ABL1
# 184  normal    0.066026        14.471453  ccrcc  ABL1
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor    0.235538        21.616591  ccrcc  BRAF
# 1     tumor    0.232718        19.209432  ccrcc  BRAF
# 2     tumor    0.034752        14.278585  ccrcc  BRAF
# 3     tumor    0.328557        22.972120  ccrcc  BRAF
# 4     tumor    0.136153        15.809168  ccrcc  BRAF
# ..      ...         ...              ...    ...   ...
# 180  normal   -0.006068        20.481532  ccrcc  BRAF
# 181  normal    0.009571        19.272746  ccrcc  BRAF
# 182  normal   -0.069232        19.506177  ccrcc  BRAF
# 183  normal   -0.015187        19.897661  ccrcc  BRAF
# 184  normal   -0.104049        20.944983  ccrcc  BRAF
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor    0.172885        67.268992  ccrcc  FAT1
# 1     tumor    0.154061        96.241549  ccrcc  FAT1
# 2     tumor    0.247759       128.428837  ccrcc  FAT1
# 3     tumor    0.028126        72.644416  ccrcc  FAT1
# 4     tumor    0.122807        54.528526  ccrcc  FAT1
# ..      ...         ...              ...    ...   ...
# 180  normal   -0.374394        74.741854  ccrcc  FAT1
# 181  normal   -0.443165        61.907787  ccrcc  FAT1
# 182  normal   -0.348866        82.913480  ccrcc  FAT1
# 183  normal   -0.159362        81.852728  ccrcc  FAT1
# 184  normal   -0.395701        76.884517  ccrcc  FAT1
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.506355        21.774438  ccrcc  IDH1
# 1     tumor   -0.869648        29.495557  ccrcc  IDH1
# 2     tumor   -0.031566       111.739501  ccrcc  IDH1
# 3     tumor   -0.083857        55.378346  ccrcc  IDH1
# 4     tumor   -0.660680        27.710801  ccrcc  IDH1
# ..      ...         ...              ...    ...   ...
# 180  normal    0.354283        57.661908  ccrcc  IDH1
# 181  normal    0.584737        59.090186  ccrcc  IDH1
# 182  normal    0.028456        47.251980  ccrcc  IDH1
# 183  normal    0.541883        61.815468  ccrcc  IDH1
# 184  normal    0.716593        88.677864  ccrcc  IDH1
#
# [185 rows x 5 columns],       Type  Proteomics  Transcriptomics cancer  gene
# 0    tumor    0.402191         9.780815  ccrcc  TP53
# 1    tumor    0.092737         5.350098  ccrcc  TP53
# 2    tumor    0.288820         8.795810  ccrcc  TP53
# 3    tumor    0.346025         6.911960  ccrcc  TP53
# 4    tumor   -0.265361         6.610207  ccrcc  TP53
# 5    tumor    0.551421         9.690823  ccrcc  TP53
# 6    tumor   -0.003795         4.390354  ccrcc  TP53
# 7    tumor    0.054547         6.977388  ccrcc  TP53
# 8    tumor    0.262081         5.636842  ccrcc  TP53
# 9    tumor    0.399628         9.280067  ccrcc  TP53
# 10   tumor    0.710508         5.940013  ccrcc  TP53
# 11   tumor    0.029765         7.044392  ccrcc  TP53
# 12   tumor    0.624368         9.831388  ccrcc  TP53
# 13   tumor   -0.051828        10.938879  ccrcc  TP53
# 14   tumor   -0.008935         8.247615  ccrcc  TP53
# 15   tumor    0.735526         6.956272  ccrcc  TP53
# 16   tumor    0.227797        13.520885  ccrcc  TP53
# 17   tumor    0.640209         8.193786  ccrcc  TP53
# 18   tumor   -0.109999         4.890864  ccrcc  TP53
# 19   tumor   -0.187418        12.057045  ccrcc  TP53
# 20   tumor   -0.061055         2.128300  ccrcc  TP53
# 21   tumor    0.547632         6.536379  ccrcc  TP53
# 22   tumor   -0.471908         6.370292  ccrcc  TP53
# 23   tumor    0.026815         8.095986  ccrcc  TP53
# 24   tumor    0.011089         7.590293  ccrcc  TP53
# 25   tumor    0.805374         6.771211  ccrcc  TP53
# 26   tumor   -0.451155         5.949959  ccrcc  TP53
# 27   tumor    0.000696         7.956202  ccrcc  TP53
# 28   tumor    0.436299         6.826602  ccrcc  TP53
# 29  normal    0.051564         3.627219  ccrcc  TP53
# 30  normal    0.604208         4.350773  ccrcc  TP53
# 31  normal   -0.322980         5.594442  ccrcc  TP53
# 32  normal    0.002399         4.813755  ccrcc  TP53
# 33  normal    0.307002         5.291857  ccrcc  TP53
# 34  normal    0.164409         3.724864  ccrcc  TP53
# 35  normal   -0.444407         4.851568  ccrcc  TP53
# 36  normal   -0.377543         3.951312  ccrcc  TP53
# 37  normal   -0.140340         3.256600  ccrcc  TP53
# 38  normal   -0.515526         5.366418  ccrcc  TP53
# 39  normal   -0.316560         3.957752  ccrcc  TP53
# 40  normal   -0.155393         4.694116  ccrcc  TP53
# 41  normal   -0.305210         4.874896  ccrcc  TP53
# 42  normal   -0.082998         3.412232  ccrcc  TP53
# 43  normal   -0.954862         5.817625  ccrcc  TP53
# 44  normal   -0.061503         5.344095  ccrcc  TP53
# 45  normal   -0.084015         4.608044  ccrcc  TP53
# 46  normal   -0.194078         6.113324  ccrcc  TP53
# 47  normal    0.863807         4.506557  ccrcc  TP53
# 48  normal   -0.306764         3.201349  ccrcc  TP53
# 49  normal   -0.436675         5.134231  ccrcc  TP53
# 50  normal   -0.277512         5.508301  ccrcc  TP53
# 51  normal   -0.332409         5.233893  ccrcc  TP53
# 52  normal   -0.024319         4.652722  ccrcc  TP53,       Type  Proteomics  Transcriptomics cancer   gene
# 0    tumor    0.066001         5.460886  ccrcc  BRCA2
# 1    tumor    0.585466         2.765732  ccrcc  BRCA2
# 2    tumor   -0.154169         2.777555  ccrcc  BRCA2
# 3    tumor    0.414185         1.676496  ccrcc  BRCA2
# 4    tumor    0.411763         2.318683  ccrcc  BRCA2
# 5    tumor   -0.096594         2.800698  ccrcc  BRCA2
# 6    tumor   -0.126821         2.127726  ccrcc  BRCA2
# 7    tumor    0.777474         1.725240  ccrcc  BRCA2
# 8    tumor    0.346350         3.498166  ccrcc  BRCA2
# 9    tumor    0.413760         2.342496  ccrcc  BRCA2
# 10   tumor    0.514473         1.846619  ccrcc  BRCA2
# 11   tumor    0.136451         0.403023  ccrcc  BRCA2
# 12   tumor   -0.012119         2.035669  ccrcc  BRCA2
# 13   tumor   -0.235233         4.755568  ccrcc  BRCA2
# 14   tumor    0.198962         1.939146  ccrcc  BRCA2
# 15   tumor    0.021285         2.432468  ccrcc  BRCA2
# 16  normal   -0.121518         0.315505  ccrcc  BRCA2
# 17  normal    0.033994         0.401199  ccrcc  BRCA2
# 18  normal   -0.324818         0.620120  ccrcc  BRCA2
# 19  normal   -0.155980         0.438438  ccrcc  BRCA2
# 20  normal    0.026256         0.255049  ccrcc  BRCA2
# 21  normal   -0.196469         0.339364  ccrcc  BRCA2
# 22  normal    0.177099         0.259218  ccrcc  BRCA2
# 23  normal   -0.009722         0.233096  ccrcc  BRCA2
# 24  normal   -0.228266         0.394745  ccrcc  BRCA2
# 25  normal   -0.068468         0.394951  ccrcc  BRCA2
# 26  normal    0.038673         0.382210  ccrcc  BRCA2
# 27  normal    0.174801         0.256225  ccrcc  BRCA2
# 28  normal   -0.230973         0.796520  ccrcc  BRCA2
# 29  normal    0.266208         0.301841  ccrcc  BRCA2
# 30  normal    0.032701         0.250691  ccrcc  BRCA2,        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   -0.127784         3.081014  ccrcc  KMT2D
# 1     tumor    0.174338         2.638795  ccrcc  KMT2D
# 2     tumor    0.108432         2.375027  ccrcc  KMT2D
# 3     tumor   -0.167009         2.255719  ccrcc  KMT2D
# 4     tumor    0.074220         2.851038  ccrcc  KMT2D
# ..      ...         ...              ...    ...    ...
# 180  normal    0.126618         3.592410  ccrcc  KMT2D
# 181  normal   -0.067437         6.926195  ccrcc  KMT2D
# 182  normal    0.075319         3.942060  ccrcc  KMT2D
# 183  normal   -0.042631         5.254142  ccrcc  KMT2D
# 184  normal    0.083409         6.124783  ccrcc  KMT2D
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer    gene
# 0     tumor    0.236571        10.349676  ccrcc  PIK3CA
# 1     tumor    0.081964         9.129876  ccrcc  PIK3CA
# 2     tumor    0.082787        10.172186  ccrcc  PIK3CA
# 3     tumor   -0.181069         7.733350  ccrcc  PIK3CA
# 4     tumor    0.026469        10.273045  ccrcc  PIK3CA
# ..      ...         ...              ...    ...     ...
# 180  normal    0.121420         6.415172  ccrcc  PIK3CA
# 181  normal    0.107406         7.390624  ccrcc  PIK3CA
# 182  normal    0.074386         6.950743  ccrcc  PIK3CA
# 183  normal    0.203580         8.104795  ccrcc  PIK3CA
# 184  normal    0.235716         6.833134  ccrcc  PIK3CA
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor    0.097356        23.498344  ccrcc  PTEN
# 1     tumor   -0.025882        26.708583  ccrcc  PTEN
# 2     tumor    0.365576       101.921700  ccrcc  PTEN
# 3     tumor   -0.259137        24.133446  ccrcc  PTEN
# 4     tumor   -0.254395        41.350921  ccrcc  PTEN
# ..      ...         ...              ...    ...   ...
# 180  normal    0.378444        23.724512  ccrcc  PTEN
# 181  normal    0.392962        23.762577  ccrcc  PTEN
# 182  normal    0.103449        22.550134  ccrcc  PTEN
# 183  normal    0.381277        21.933274  ccrcc  PTEN
# 184  normal    0.174256        18.788127  ccrcc  PTEN
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   -0.364051        12.225871  ccrcc  SETD2
# 1     tumor   -0.003857        13.412459  ccrcc  SETD2
# 2     tumor    0.071931        13.189717  ccrcc  SETD2
# 3     tumor   -0.485209        11.515884  ccrcc  SETD2
# 4     tumor    0.198854        21.194186  ccrcc  SETD2
# ..      ...         ...              ...    ...    ...
# 180  normal    0.138492        26.715319  ccrcc  SETD2
# 181  normal    0.339053        27.908853  ccrcc  SETD2
# 182  normal    0.129132        27.978143  ccrcc  SETD2
# 183  normal    0.411475        27.485234  ccrcc  SETD2
# 184  normal   -0.113968        28.934620  ccrcc  SETD2
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   -0.643136         0.039680  ccrcc  SPTA1
# 1     tumor   -0.171893         0.134558  ccrcc  SPTA1
# 2     tumor   -0.345668         0.063605  ccrcc  SPTA1
# 3     tumor    0.734517         0.048605  ccrcc  SPTA1
# 4     tumor   -0.977896         0.206339  ccrcc  SPTA1
# ..      ...         ...              ...    ...    ...
# 180  normal   -1.720077         0.021323  ccrcc  SPTA1
# 181  normal   -2.937450         0.058696  ccrcc  SPTA1
# 182  normal   -0.454376         0.027412  ccrcc  SPTA1
# 183  normal   -0.934899         0.004742  ccrcc  SPTA1
# 184  normal   -0.859433         0.016332  ccrcc  SPTA1
#
# [185 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.2960            11.36     en  ABL1
# 1     tumor     -0.0897            11.77     en  ABL1
# 2     tumor     -0.1770            11.04     en  ABL1
# 3     tumor     -0.5130            10.93     en  ABL1
# 4     tumor     -0.5260            10.57     en  ABL1
# ..      ...         ...              ...    ...   ...
# 104  normal      1.1000            12.92     en  ABL1
# 105  normal      0.2630            12.06     en  ABL1
# 106  normal      0.7850            12.39     en  ABL1
# 107  normal      0.7980            14.01     en  ABL1
# 108  normal      0.9680            12.70     en  ABL1
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor    -0.11600            11.86     en  BRAF
# 1     tumor    -0.12200            11.17     en  BRAF
# 2     tumor    -0.10700            11.26     en  BRAF
# 3     tumor     0.19100            12.07     en  BRAF
# 4     tumor     0.50300            12.02     en  BRAF
# ..      ...         ...              ...    ...   ...
# 104  normal     0.00719            12.12     en  BRAF
# 105  normal     0.32100            12.10     en  BRAF
# 106  normal    -0.15500            12.08     en  BRAF
# 107  normal    -0.09200            12.77     en  BRAF
# 108  normal    -0.02970            11.79     en  BRAF
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      0.1720            14.39     en  FAT1
# 1     tumor      0.8780            14.65     en  FAT1
# 2     tumor      0.3500            14.78     en  FAT1
# 3     tumor      0.0190            14.31     en  FAT1
# 4     tumor     -1.0600            11.55     en  FAT1
# ..      ...         ...              ...    ...   ...
# 104  normal     -0.0617            13.14     en  FAT1
# 105  normal     -0.1940            13.82     en  FAT1
# 106  normal     -0.1990            13.23     en  FAT1
# 107  normal     -0.1150            13.84     en  FAT1
# 108  normal      0.1570            13.88     en  FAT1
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.2580            12.45     en  IDH1
# 1     tumor      2.2100            15.74     en  IDH1
# 2     tumor      0.1080            12.98     en  IDH1
# 3     tumor     -0.1220            12.44     en  IDH1
# 4     tumor      0.3160            13.34     en  IDH1
# ..      ...         ...              ...    ...   ...
# 104  normal     -0.3460            10.63     en  IDH1
# 105  normal      0.0674            11.36     en  IDH1
# 106  normal     -0.2880            12.20     en  IDH1
# 107  normal     -0.6880             9.49     en  IDH1
# 108  normal     -0.7810            10.89     en  IDH1
#
# [109 rows x 5 columns],       Type  Proteomics  Transcriptomics cancer  gene
# 0    tumor      0.2950            11.62     en  TP53
# 1    tumor      0.2770            11.83     en  TP53
# 2    tumor     -0.8710            10.73     en  TP53
# 3    tumor     -0.3430            10.95     en  TP53
# 4    tumor      3.0100            10.69     en  TP53
# ..     ...         ...              ...    ...   ...
# 89  normal      0.7950             9.83     en  TP53
# 90  normal      0.6270            10.64     en  TP53
# 91  normal     -0.2370             9.62     en  TP53
# 92  normal     -0.7290            10.45     en  TP53
# 93  normal     -0.0788            10.28     en  TP53
#
# [94 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor      0.0929            11.71     en  KMT2D
# 1     tumor     -0.1410            11.12     en  KMT2D
# 2     tumor     -0.2600            10.65     en  KMT2D
# 3     tumor     -0.2260            12.13     en  KMT2D
# 4     tumor     -0.4930            11.11     en  KMT2D
# ..      ...         ...              ...    ...    ...
# 104  normal     -0.1230            11.50     en  KMT2D
# 105  normal     -0.2330            12.22     en  KMT2D
# 106  normal      0.0338            11.31     en  KMT2D
# 107  normal      0.2220            11.65     en  KMT2D
# 108  normal      0.1750            12.16     en  KMT2D
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.0603            11.59     en  KRAS
# 1     tumor      0.2680            11.55     en  KRAS
# 2     tumor      0.1040            11.58     en  KRAS
# 3     tumor      0.0285            11.40     en  KRAS
# 4     tumor     -0.2560            10.53     en  KRAS
# ..      ...         ...              ...    ...   ...
# 104  normal      0.4410            11.05     en  KRAS
# 105  normal      0.6560            10.97     en  KRAS
# 106  normal     -0.2160            10.85     en  KRAS
# 107  normal     -0.1070            11.54     en  KRAS
# 108  normal     -0.0826            10.66     en  KRAS
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer    gene
# 0     tumor      -0.450            11.12     en  PIK3CA
# 1     tumor      -0.215            10.96     en  PIK3CA
# 2     tumor      -0.178            11.08     en  PIK3CA
# 3     tumor      -0.392            11.02     en  PIK3CA
# 4     tumor       0.287            11.71     en  PIK3CA
# ..      ...         ...              ...    ...     ...
# 104  normal       0.790            12.15     en  PIK3CA
# 105  normal       0.345            12.14     en  PIK3CA
# 106  normal       0.232            11.78     en  PIK3CA
# 107  normal       0.279            11.95     en  PIK3CA
# 108  normal       0.668            11.58     en  PIK3CA
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      -0.526            12.87     en  PTEN
# 1     tumor      -0.830            13.29     en  PTEN
# 2     tumor      -0.941            12.60     en  PTEN
# 3     tumor       0.730            14.31     en  PTEN
# 4     tumor      -0.379            12.58     en  PTEN
# ..      ...         ...              ...    ...   ...
# 104  normal       0.450            13.72     en  PTEN
# 105  normal       0.031            13.33     en  PTEN
# 106  normal       1.080            14.28     en  PTEN
# 107  normal       0.248            13.18     en  PTEN
# 108  normal       0.703            13.18     en  PTEN
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor     0.07920            13.00     en  SETD2
# 1     tumor     0.03640            12.57     en  SETD2
# 2     tumor    -0.11800            12.45     en  SETD2
# 3     tumor     0.23600            12.98     en  SETD2
# 4     tumor     0.22500            13.11     en  SETD2
# ..      ...         ...              ...    ...    ...
# 104  normal    -0.06790            13.21     en  SETD2
# 105  normal    -0.37500            13.23     en  SETD2
# 106  normal    -0.00181            13.17     en  SETD2
# 107  normal    -0.02240            13.22     en  SETD2
# 108  normal     0.09320            13.00     en  SETD2
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor      -1.070             1.55     en  SPTA1
# 1     tumor      -0.472             0.00     en  SPTA1
# 2     tumor      -0.878             1.82     en  SPTA1
# 3     tumor      -0.479             0.00     en  SPTA1
# 4     tumor      -0.409             1.16     en  SPTA1
# ..      ...         ...              ...    ...    ...
# 104  normal       1.220             5.22     en  SPTA1
# 105  normal       0.395             3.66     en  SPTA1
# 106  normal       0.940             2.76     en  SPTA1
# 107  normal       0.855             1.96     en  SPTA1
# 108  normal       1.270             3.41     en  SPTA1
#
# [109 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.168016    423349.716986    gbm  ABL1
# 1     tumor    0.264811    528069.561616    gbm  ABL1
# 2     tumor   -0.351114    278819.439298    gbm  ABL1
# 3     tumor   -0.342637    335949.724874    gbm  ABL1
# 4     tumor    0.014418    397555.209875    gbm  ABL1
# ..      ...         ...              ...    ...   ...
# 103  normal   -0.352599    312563.502287    gbm  ABL1
# 104  normal   -0.253407    172369.510003    gbm  ABL1
# 105  normal   -0.484621    274765.372995    gbm  ABL1
# 106  normal    0.004712    164770.852020    gbm  ABL1
# 107  normal   -0.310516    167114.467783    gbm  ABL1
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.112509    203638.628275    gbm  BRAF
# 1     tumor   -0.551587    251219.525272    gbm  BRAF
# 2     tumor    0.577739    208062.612956    gbm  BRAF
# 3     tumor    0.197062    254447.664585    gbm  BRAF
# 4     tumor   -0.254450    248059.610507    gbm  BRAF
# ..      ...         ...              ...    ...   ...
# 103  normal    1.757210    221078.137804    gbm  BRAF
# 104  normal    1.879307    407039.944785    gbm  BRAF
# 105  normal    1.952212    385356.454721    gbm  BRAF
# 106  normal    1.814127    466231.650004    gbm  BRAF
# 107  normal    1.796517    478521.284792    gbm  BRAF
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.085396     6.878761e+05    gbm  FAT1
# 1     tumor    0.231562     9.046275e+05    gbm  FAT1
# 2     tumor    0.608554     8.821661e+05    gbm  FAT1
# 3     tumor   -0.431371     4.629238e+05    gbm  FAT1
# 4     tumor    0.769462     1.199216e+06    gbm  FAT1
# ..      ...         ...              ...    ...   ...
# 103  normal   -0.510117     3.711093e+05    gbm  FAT1
# 104  normal   -0.129882     3.238429e+05    gbm  FAT1
# 105  normal   -0.208901     2.149881e+05    gbm  FAT1
# 106  normal   -0.664837     2.603790e+05    gbm  FAT1
# 107  normal   -0.403974     2.499332e+05    gbm  FAT1
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.741522    280283.951865    gbm  IDH1
# 1     tumor   -0.460861    322430.470106    gbm  IDH1
# 2     tumor    0.271150    962109.481688    gbm  IDH1
# 3     tumor   -0.167075    402771.863139    gbm  IDH1
# 4     tumor   -0.234281    456399.283404    gbm  IDH1
# ..      ...         ...              ...    ...   ...
# 103  normal   -1.456926    123308.793226    gbm  IDH1
# 104  normal   -1.250708    123171.475813    gbm  IDH1
# 105  normal   -1.334004     90063.723723    gbm  IDH1
# 106  normal   -1.490393    117729.097807    gbm  IDH1
# 107  normal   -1.491538    111183.172354    gbm  IDH1
#
# [108 rows x 5 columns],       Type  Proteomics  Transcriptomics cancer  gene
# 0    tumor    0.044573    121103.347848    gbm  TP53
# 1    tumor    0.117856     97896.003473    gbm  TP53
# 2    tumor   -0.120887    161630.007773    gbm  TP53
# 3    tumor    1.832557    288742.052253    gbm  TP53
# 4    tumor   -0.288708    193060.722980    gbm  TP53
# ..     ...         ...              ...    ...   ...
# 75  normal   -0.265672     52436.028046    gbm  TP53
# 76  normal   -0.329402    117070.611175    gbm  TP53
# 77  normal   -0.315356     26182.275182    gbm  TP53
# 78  normal    0.438055     22629.094530    gbm  TP53
# 79  normal   -0.742282     27336.243438    gbm  TP53
#
# [80 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor    0.179768    117620.697413    gbm  KMT2D
# 1     tumor   -0.093923     98904.843058    gbm  KMT2D
# 2     tumor    0.327555     93510.875277    gbm  KMT2D
# 3     tumor   -0.287677    139040.855165    gbm  KMT2D
# 4     tumor    0.055089    133786.226786    gbm  KMT2D
# ..      ...         ...              ...    ...    ...
# 103  normal   -0.329863    421368.118796    gbm  KMT2D
# 104  normal   -0.231092    269408.962222    gbm  KMT2D
# 105  normal   -0.171991    286576.427588    gbm  KMT2D
# 106  normal   -0.030411    165620.774870    gbm  KMT2D
# 107  normal   -0.119448    230153.129774    gbm  KMT2D
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.023009    147895.095636    gbm  KRAS
# 1     tumor    0.088499    122740.367794    gbm  KRAS
# 2     tumor   -0.071808    128101.960668    gbm  KRAS
# 3     tumor   -0.438601     93082.963526    gbm  KRAS
# 4     tumor    0.108811    106386.765022    gbm  KRAS
# ..      ...         ...              ...    ...   ...
# 103  normal    1.095820    121976.132501    gbm  KRAS
# 104  normal    1.182354    241438.657166    gbm  KRAS
# 105  normal    1.638740    217654.475089    gbm  KRAS
# 106  normal    1.521527    329723.969989    gbm  KRAS
# 107  normal    1.458192    282474.356226    gbm  KRAS
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer    gene
# 0     tumor    0.124542    200986.283461    gbm  PIK3CA
# 1     tumor   -0.211025    218120.942149    gbm  PIK3CA
# 2     tumor   -0.573919    166938.628363    gbm  PIK3CA
# 3     tumor   -0.360962    138130.375542    gbm  PIK3CA
# 4     tumor    0.137414    221822.401601    gbm  PIK3CA
# ..      ...         ...              ...    ...     ...
# 103  normal    0.762257    174015.999132    gbm  PIK3CA
# 104  normal    0.794670    241762.180491    gbm  PIK3CA
# 105  normal    0.773608    226793.236111    gbm  PIK3CA
# 106  normal    0.695154    224198.544001    gbm  PIK3CA
# 107  normal    0.675153    246937.731911    gbm  PIK3CA
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   -0.431991    177100.345056    gbm  PTEN
# 1     tumor   -0.265044    175155.715999    gbm  PTEN
# 2     tumor    0.390190    349109.743565    gbm  PTEN
# 3     tumor   -0.915526    207316.199536    gbm  PTEN
# 4     tumor    0.680291    213887.007588    gbm  PTEN
# ..      ...         ...              ...    ...   ...
# 103  normal    1.064378    275161.172491    gbm  PTEN
# 104  normal    1.269154    341202.579113    gbm  PTEN
# 105  normal    1.419910    257442.126251    gbm  PTEN
# 106  normal    1.543902    387796.792376    gbm  PTEN
# 107  normal    1.196431    342265.221727    gbm  PTEN
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   -0.041108    427425.930406    gbm  SETD2
# 1     tumor    0.151423    444154.119628    gbm  SETD2
# 2     tumor   -0.148277    369633.613447    gbm  SETD2
# 3     tumor   -0.001687    418851.952342    gbm  SETD2
# 4     tumor   -0.032488    398325.103208    gbm  SETD2
# ..      ...         ...              ...    ...    ...
# 103  normal    0.187526    388157.749275    gbm  SETD2
# 104  normal   -0.415590    378445.133351    gbm  SETD2
# 105  normal   -0.306193    410670.108473    gbm  SETD2
# 106  normal   -0.290512    316467.179091    gbm  SETD2
# 107  normal   -0.216042    323577.827424    gbm  SETD2
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   -0.002554       407.382943    gbm  SPTA1
# 1     tumor    1.640146       528.690200    gbm  SPTA1
# 2     tumor    2.619612      3556.998975    gbm  SPTA1
# 3     tumor    1.943402       439.188215    gbm  SPTA1
# 4     tumor   -0.149263       845.344266    gbm  SPTA1
# ..      ...         ...              ...    ...    ...
# 103  normal   -0.776487       228.392956    gbm  SPTA1
# 104  normal   -1.190681       119.105222    gbm  SPTA1
# 105  normal   -1.241818       152.291028    gbm  SPTA1
# 106  normal   -1.223680       104.936222    gbm  SPTA1
# 107  normal   -0.355014        65.244460    gbm  SPTA1
#
# [108 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.0100           4.7548   luad  BRAF
# 1     tumor     -0.3133           4.2448   luad  BRAF
# 2     tumor     -0.2816           4.5552   luad  BRAF
# 3     tumor     -0.4243           4.0457   luad  BRAF
# 4     tumor      0.2698           4.3303   luad  BRAF
# ..      ...         ...              ...    ...   ...
# 206  normal     -0.5087           4.3610   luad  BRAF
# 207  normal     -0.4379           4.2574   luad  BRAF
# 208  normal      0.4244           4.5175   luad  BRAF
# 209  normal      0.2347           4.6164   luad  BRAF
# 210  normal      1.4437           4.4203   luad  BRAF
#
# [211 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -1.4901           4.8255   luad  FAT1
# 1     tumor      2.9552           5.9278   luad  FAT1
# 2     tumor      0.7198           6.1585   luad  FAT1
# 3     tumor      1.0433           4.5623   luad  FAT1
# 4     tumor     -0.1589           5.1819   luad  FAT1
# ..      ...         ...              ...    ...   ...
# 206  normal      0.1379           4.5792   luad  FAT1
# 207  normal     -0.1197           4.2691   luad  FAT1
# 208  normal      0.1739           4.0864   luad  FAT1
# 209  normal      0.0595           4.5919   luad  FAT1
# 210  normal     -0.1328           4.1781   luad  FAT1
#
# [211 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.1647           5.8576   luad  IDH1
# 1     tumor      0.1288           5.8447   luad  IDH1
# 2     tumor     -0.0083           5.9687   luad  IDH1
# 3     tumor     -0.5525           4.1446   luad  IDH1
# 4     tumor      1.1840           6.3215   luad  IDH1
# ..      ...         ...              ...    ...   ...
# 206  normal     -1.2544           4.7722   luad  IDH1
# 207  normal     -0.4026           5.3240   luad  IDH1
# 208  normal     -0.8281           4.7136   luad  IDH1
# 209  normal     -0.8540           5.0229   luad  IDH1
# 210  normal     -1.0491           4.8840   luad  IDH1
#
# [211 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      4.8596           2.9596   luad  TP53
# 1     tumor      3.2419           3.5986   luad  TP53
# 2     tumor     -0.6443           2.3355   luad  TP53
# 3     tumor      0.6554           3.7229   luad  TP53
# 4     tumor      2.5045           3.2606   luad  TP53
# ..      ...         ...              ...    ...   ...
# 155  normal     -1.1333           2.7355   luad  TP53
# 156  normal     -1.5409           2.6740   luad  TP53
# 157  normal     -2.0448           3.0952   luad  TP53
# 158  normal     -0.4540           2.7063   luad  TP53
# 159  normal     -1.1202           2.7867   luad  TP53
#
# [160 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor      0.5801           1.9277   luad  BRCA2
# 1     tumor      0.1892           1.8259   luad  BRCA2
# 2     tumor     -1.2162           1.9974   luad  BRCA2
# 3     tumor      2.3207          -0.1094   luad  BRCA2
# 4     tumor     -2.8482           2.3880   luad  BRCA2
# ..      ...         ...              ...    ...    ...
# 206  normal     -0.5491           0.9140   luad  BRCA2
# 207  normal     -0.2415           0.4605   luad  BRCA2
# 208  normal     -0.8014           0.2588   luad  BRCA2
# 209  normal     -0.4461           0.1210   luad  BRCA2
# 210  normal     -0.4370           0.6333   luad  BRCA2
#
# [211 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor     -0.1994           2.3944   luad  KMT2D
# 1     tumor     -0.0866           2.1775   luad  KMT2D
# 2     tumor      0.8700           3.7825   luad  KMT2D
# 3     tumor     -0.0688           3.6309   luad  KMT2D
# 4     tumor     -1.1971           2.0124   luad  KMT2D
# ..      ...         ...              ...    ...    ...
# 206  normal      0.1746           2.5785   luad  KMT2D
# 207  normal      0.1160           3.1205   luad  KMT2D
# 208  normal      0.7183           2.9788   luad  KMT2D
# 209  normal      0.0696           2.4997   luad  KMT2D
# 210  normal     -0.4853           2.5246   luad  KMT2D
#
# [211 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      0.6464           4.5117   luad  KRAS
# 1     tumor      0.8679           3.1879   luad  KRAS
# 2     tumor     -0.3416           2.4528   luad  KRAS
# 3     tumor     -1.0057           3.1081   luad  KRAS
# 4     tumor      0.5142           4.0837   luad  KRAS
# ..      ...         ...              ...    ...   ...
# 198  normal      0.2885           3.0443   luad  KRAS
# 199  normal     -0.1394           2.8286   luad  KRAS
# 200  normal      0.3976           2.8466   luad  KRAS
# 201  normal      1.3908           3.1094   luad  KRAS
# 202  normal      1.2063           2.9375   luad  KRAS
#
# [203 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer    gene
# ...
# 1     tumor   24.169637            10.75  hnscc  TP53
# 2     tumor   20.330993             9.86  hnscc  TP53
# 3     tumor   21.811121            10.97  hnscc  TP53
# 4     tumor   21.870247             8.93  hnscc  TP53
# ..      ...         ...              ...    ...   ...
# 130  normal   22.061391            10.64  hnscc  TP53
# 131  normal   20.745262            10.32  hnscc  TP53
# 132  normal   20.623211            10.18  hnscc  TP53
# 133  normal   21.570320            10.46  hnscc  TP53
# 134  normal   20.518137            10.33  hnscc  TP53
#
# [135 rows x 5 columns],       Type  Proteomics  Transcriptomics cancer   gene
# 0    tumor   19.138350            11.15  hnscc  BRCA2
# 1    tumor   18.484527            11.86  hnscc  BRCA2
# 2    tumor   18.897915            10.80  hnscc  BRCA2
# 3    tumor   17.499995            10.81  hnscc  BRCA2
# 4    tumor   19.591433            10.81  hnscc  BRCA2
# 5    tumor   18.894398            10.51  hnscc  BRCA2
# 6    tumor   17.001744            11.16  hnscc  BRCA2
# 7    tumor   18.637560            10.96  hnscc  BRCA2
# 8    tumor   19.245470             9.67  hnscc  BRCA2
# 9    tumor   19.439359            11.48  hnscc  BRCA2
# 10   tumor   19.666633            11.42  hnscc  BRCA2
# 11   tumor   17.967123             9.58  hnscc  BRCA2
# 12   tumor   15.788684            10.38  hnscc  BRCA2
# 13   tumor   18.469749            11.90  hnscc  BRCA2
# 14   tumor   17.937861            10.57  hnscc  BRCA2
# 15   tumor   15.856573            11.72  hnscc  BRCA2
# 16   tumor   17.370911            10.13  hnscc  BRCA2
# 17   tumor   19.096287            10.83  hnscc  BRCA2
# 18   tumor   15.190936            11.41  hnscc  BRCA2
# 19   tumor   21.344191            10.94  hnscc  BRCA2
# 20   tumor   19.375829            10.99  hnscc  BRCA2
# 21   tumor   18.338268            10.98  hnscc  BRCA2
# 22   tumor   17.827830            10.45  hnscc  BRCA2
# 23   tumor   18.754611            10.86  hnscc  BRCA2
# 24   tumor   17.948393            10.72  hnscc  BRCA2
# 25   tumor   18.611587            10.15  hnscc  BRCA2
# 26   tumor   18.769162            10.95  hnscc  BRCA2
# 27   tumor   16.800048            10.82  hnscc  BRCA2
# 28   tumor   19.235741            10.47  hnscc  BRCA2
# 29   tumor   18.965899            10.35  hnscc  BRCA2
# 30   tumor   18.430914            10.60  hnscc  BRCA2
# 31   tumor   16.798063            10.31  hnscc  BRCA2
# 32   tumor   18.187790            11.08  hnscc  BRCA2
# 33   tumor   19.867675            12.67  hnscc  BRCA2
# 34   tumor   18.665905            10.46  hnscc  BRCA2
# 35   tumor   19.045864             9.37  hnscc  BRCA2
# 36   tumor   19.347949            10.13  hnscc  BRCA2
# 37   tumor   18.706569            11.19  hnscc  BRCA2
# 38   tumor   18.097860            10.29  hnscc  BRCA2
# 39   tumor   17.595577            10.71  hnscc  BRCA2
# 40   tumor   18.536473            11.99  hnscc  BRCA2
# 41  normal   18.482273             9.79  hnscc  BRCA2
# 42  normal   20.350451             8.57  hnscc  BRCA2
# 43  normal   16.644731             9.12  hnscc  BRCA2
# 44  normal   18.556927             9.61  hnscc  BRCA2
# 45  normal   19.843358             9.18  hnscc  BRCA2
# 46  normal   18.554932             9.27  hnscc  BRCA2
# 47  normal   15.498160             8.59  hnscc  BRCA2
# 48  normal   19.491311            10.49  hnscc  BRCA2
# 49  normal   16.113268             9.95  hnscc  BRCA2
# 50  normal   19.711916             9.59  hnscc  BRCA2
# 51  normal   18.516167            10.04  hnscc  BRCA2
# 52  normal   20.375069             8.74  hnscc  BRCA2
# 53  normal   18.849064             9.09  hnscc  BRCA2
# 54  normal   19.613472             9.42  hnscc  BRCA2
# 55  normal   18.968964            10.24  hnscc  BRCA2
# 56  normal   19.112038             8.79  hnscc  BRCA2
# 57  normal   18.862646             9.41  hnscc  BRCA2,        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   23.282877            11.02  hnscc  KMT2D
# 1     tumor   22.557801            11.49  hnscc  KMT2D
# 2     tumor   23.080289            11.57  hnscc  KMT2D
# 3     tumor   23.255262            12.35  hnscc  KMT2D
# 4     tumor   23.094487            11.09  hnscc  KMT2D
# ..      ...         ...              ...    ...    ...
# 146  normal   23.279029            12.04  hnscc  KMT2D
# 147  normal   23.183071            11.07  hnscc  KMT2D
# 148  normal   23.039394            11.76  hnscc  KMT2D
# 149  normal   23.490891            11.66  hnscc  KMT2D
# 150  normal   23.137151            12.63  hnscc  KMT2D
#
# [151 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   25.521839            11.01  hnscc  KRAS
# 1     tumor   25.643428            11.83  hnscc  KRAS
# 2     tumor   25.427323            10.94  hnscc  KRAS
# 3     tumor   25.917623            11.26  hnscc  KRAS
# 4     tumor   25.785704            11.94  hnscc  KRAS
# ..      ...         ...              ...    ...   ...
# 146  normal   25.756290            11.06  hnscc  KRAS
# 147  normal   26.120086            11.60  hnscc  KRAS
# 148  normal   26.170356            11.22  hnscc  KRAS
# 149  normal   25.999816            11.19  hnscc  KRAS
# 150  normal   25.805414             9.88  hnscc  KRAS
#
# [151 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer    gene
# 0     tumor   22.682087            11.05  hnscc  PIK3CA
# 1     tumor   23.113374            11.96  hnscc  PIK3CA
# 2     tumor   22.865592            11.36  hnscc  PIK3CA
# 3     tumor   22.712703            11.43  hnscc  PIK3CA
# 4     tumor   22.856271            11.75  hnscc  PIK3CA
# ..      ...         ...              ...    ...     ...
# 146  normal   22.872629            11.37  hnscc  PIK3CA
# 147  normal   22.658420            11.50  hnscc  PIK3CA
# 148  normal   22.690716            10.91  hnscc  PIK3CA
# 149  normal   22.869182            11.26  hnscc  PIK3CA
# 150  normal   22.823915            10.77  hnscc  PIK3CA
#
# [151 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor   23.604974            12.97  hnscc  PTEN
# 1     tumor   23.370790            12.03  hnscc  PTEN
# 2     tumor   23.924803            13.00  hnscc  PTEN
# 3     tumor   23.961489            12.93  hnscc  PTEN
# 4     tumor   23.319454            12.34  hnscc  PTEN
# ..      ...         ...              ...    ...   ...
# 146  normal   24.061332            13.09  hnscc  PTEN
# 147  normal   23.546297            13.05  hnscc  PTEN
# 148  normal   23.740096            12.44  hnscc  PTEN
# 149  normal   23.367411            12.56  hnscc  PTEN
# 150  normal   23.937504            12.29  hnscc  PTEN
#
# [151 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   23.260432            11.97  hnscc  SETD2
# 1     tumor   22.997403            12.91  hnscc  SETD2
# 2     tumor   21.954315            12.34  hnscc  SETD2
# 3     tumor   22.536703            12.45  hnscc  SETD2
# 4     tumor   22.645612            12.07  hnscc  SETD2
# ..      ...         ...              ...    ...    ...
# 146  normal   22.626832            12.83  hnscc  SETD2
# 147  normal   22.816488            12.64  hnscc  SETD2
# 148  normal   22.560949            12.71  hnscc  SETD2
# 149  normal   22.633375            12.73  hnscc  SETD2
# 150  normal   22.671068            12.82  hnscc  SETD2
#
# [151 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor   25.604550             3.69  hnscc  SPTA1
# 1     tumor   24.800777             2.88  hnscc  SPTA1
# 2     tumor   25.546178             4.18  hnscc  SPTA1
# 3     tumor   24.756450             3.70  hnscc  SPTA1
# 4     tumor   25.248062             3.75  hnscc  SPTA1
# ..      ...         ...              ...    ...    ...
# 146  normal   27.129772             4.82  hnscc  SPTA1
# 147  normal   27.226168             3.79  hnscc  SPTA1
# 148  normal   24.409524             3.45  hnscc  SPTA1
# 149  normal   27.128554             1.73  hnscc  SPTA1
# 150  normal   26.554217             3.02  hnscc  SPTA1
#
# [151 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      0.0748          17.6779   lscc  ABL1
# 1     tumor     -0.6798          16.9762   lscc  ABL1
# 2     tumor      0.1030          18.5037   lscc  ABL1
# 3     tumor     -0.0385          18.1960   lscc  ABL1
# 4     tumor     -0.7618          17.1842   lscc  ABL1
# ..      ...         ...              ...    ...   ...
# 197  normal      0.9853          18.4111   lscc  ABL1
# 198  normal      1.0417          18.0078   lscc  ABL1
# 199  normal      0.5496          17.7507   lscc  ABL1
# 200  normal      0.7537          18.1407   lscc  ABL1
# 201  normal      1.0101          18.4407   lscc  ABL1
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.5338          17.9463   lscc  BRAF
# 1     tumor      1.1060          17.6762   lscc  BRAF
# 2     tumor     -0.5905          17.7026   lscc  BRAF
# 3     tumor      0.0954          17.5568   lscc  BRAF
# 4     tumor      0.1381          18.2785   lscc  BRAF
# ..      ...         ...              ...    ...   ...
# 197  normal     -0.1813          17.8257   lscc  BRAF
# 198  normal      0.1663          18.1415   lscc  BRAF
# 199  normal      0.2906          17.8991   lscc  BRAF
# 200  normal      0.9503          18.0041   lscc  BRAF
# 201  normal      0.3508          18.1940   lscc  BRAF
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      0.4631          20.3357   lscc  FAT1
# 1     tumor     -2.0272          17.7414   lscc  FAT1
# 2     tumor     -0.8749          19.2270   lscc  FAT1
# 3     tumor      2.0274          19.5603   lscc  FAT1
# 4     tumor     -0.4015          19.9581   lscc  FAT1
# ..      ...         ...              ...    ...   ...
# 197  normal      0.1524          18.8929   lscc  FAT1
# 198  normal     -0.6410          18.2292   lscc  FAT1
# 199  normal     -1.3830          18.5863   lscc  FAT1
# 200  normal     -0.4547          18.5724   lscc  FAT1
# 201  normal     -0.8500          18.6211   lscc  FAT1
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.5744          19.7071   lscc  IDH1
# 1     tumor     -0.2604          19.7475   lscc  IDH1
# 2     tumor     -0.7826          18.8346   lscc  IDH1
# 3     tumor      0.9640          19.7571   lscc  IDH1
# 4     tumor     -0.4377          19.2258   lscc  IDH1
# ..      ...         ...              ...    ...   ...
# 197  normal      0.4779          18.6746   lscc  IDH1
# 198  normal     -0.1208          18.5929   lscc  IDH1
# 199  normal      1.2470          19.2531   lscc  IDH1
# 200  normal      0.2740          18.9689   lscc  IDH1
# 201  normal      0.3615          19.0758   lscc  IDH1
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor      3.9436          17.7702   lscc  TP53
# 1     tumor     -0.4092          17.5280   lscc  TP53
# 2     tumor      4.1522          18.0818   lscc  TP53
# 3     tumor     -1.0329          17.6878   lscc  TP53
# 4     tumor     -2.7917          16.1104   lscc  TP53
# ..      ...         ...              ...    ...   ...
# 197  normal     -4.7566          17.0759   lscc  TP53
# 198  normal     -1.4965          16.9600   lscc  TP53
# 199  normal     -4.8158          16.6879   lscc  TP53
# 200  normal     -2.5726          16.8299   lscc  TP53
# 201  normal     -4.1949          16.8497   lscc  TP53
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor     -2.7769          17.7044   lscc  BRCA2
# 1     tumor      0.1320          16.2483   lscc  BRCA2
# 2     tumor     -1.6134          16.6971   lscc  BRCA2
# 3     tumor     -0.6920          16.3828   lscc  BRCA2
# 4     tumor     -2.2140          16.3383   lscc  BRCA2
# ..      ...         ...              ...    ...    ...
# 197  normal      1.0846          15.1941   lscc  BRCA2
# 198  normal     -0.1606          14.7874   lscc  BRCA2
# 199  normal     -0.6544          14.5889   lscc  BRCA2
# 200  normal      0.8219          15.0141   lscc  BRCA2
# 201  normal      0.5679          15.7848   lscc  BRCA2
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor     -0.5802          15.8447   lscc  KMT2D
# 1     tumor     -0.0439          16.2687   lscc  KMT2D
# 2     tumor     -1.5785          17.1773   lscc  KMT2D
# 3     tumor     -1.1101          16.9756   lscc  KMT2D
# 4     tumor      0.4387          17.2008   lscc  KMT2D
# ..      ...         ...              ...    ...    ...
# 197  normal      0.2848          16.8827   lscc  KMT2D
# 198  normal      0.5727          16.9238   lscc  KMT2D
# 199  normal      0.1170          16.6481   lscc  KMT2D
# 200  normal      0.6908          16.9231   lscc  KMT2D
# 201  normal      0.0667          17.9873   lscc  KMT2D
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -0.1716          18.6650   lscc  KRAS
# 1     tumor     -1.3697          17.2589   lscc  KRAS
# 2     tumor     -1.0421          17.2083   lscc  KRAS
# 3     tumor     -1.0248          17.6283   lscc  KRAS
# 4     tumor     -1.3648          17.0803   lscc  KRAS
# ..      ...         ...              ...    ...   ...
# 197  normal     -0.0847          17.0766   lscc  KRAS
# 198  normal      0.9934          17.2511   lscc  KRAS
# 199  normal      0.1483          17.2709   lscc  KRAS
# 200  normal      0.0250          17.2024   lscc  KRAS
# 201  normal     -0.1611          17.2442   lscc  KRAS
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer    gene
# 0     tumor      0.4776          18.7916   lscc  PIK3CA
# 1     tumor      0.0346          17.9383   lscc  PIK3CA
# 2     tumor     -0.1390          18.3283   lscc  PIK3CA
# 3     tumor      2.7904          18.7687   lscc  PIK3CA
# 4     tumor     -0.7600          18.1785   lscc  PIK3CA
# ..      ...         ...              ...    ...     ...
# 197  normal      0.6737          17.7090   lscc  PIK3CA
# 198  normal      0.6466          17.7485   lscc  PIK3CA
# 199  normal      0.2109          17.4930   lscc  PIK3CA
# 200  normal      0.4392          17.6445   lscc  PIK3CA
# 201  normal      0.0050          17.3802   lscc  PIK3CA
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer  gene
# 0     tumor     -1.3685          17.8496   lscc  PTEN
# 1     tumor     -0.4444          17.6464   lscc  PTEN
# 2     tumor     -0.5731          17.5784   lscc  PTEN
# 3     tumor     -0.4809          17.9602   lscc  PTEN
# 4     tumor     -0.0756          18.0824   lscc  PTEN
# ..      ...         ...              ...    ...   ...
# 197  normal      1.2749          18.7356   lscc  PTEN
# 198  normal      1.0019          18.5623   lscc  PTEN
# 199  normal      0.3333          18.6130   lscc  PTEN
# 200  normal      1.3828          18.8701   lscc  PTEN
# 201  normal      1.1361          18.3423   lscc  PTEN
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor      0.2631          18.3409   lscc  SETD2
# 1     tumor      0.0481          18.2221   lscc  SETD2
# 2     tumor      0.0806          18.5454   lscc  SETD2
# 3     tumor     -0.6555          18.4174   lscc  SETD2
# 4     tumor     -0.2132          18.0603   lscc  SETD2
# ..      ...         ...              ...    ...    ...
# 197  normal      0.3620          18.6228   lscc  SETD2
# 198  normal      0.1350          18.8650   lscc  SETD2
# 199  normal     -0.4580          18.7699   lscc  SETD2
# 200  normal      0.5702          18.7989   lscc  SETD2
# 201  normal      0.2034          18.8341   lscc  SETD2
#
# [202 rows x 5 columns],        Type  Proteomics  Transcriptomics cancer   gene
# 0     tumor     -5.7532          10.8853   lscc  SPTA1
# 1     tumor     -4.7518           9.3463   lscc  SPTA1
# 2     tumor     -4.6072          10.8670   lscc  SPTA1
# 3     tumor     -4.4626           8.0982   lscc  SPTA1
# 4     tumor     -0.8433          10.3982   lscc  SPTA1
# ..      ...         ...              ...    ...    ...
# 195  normal     -0.7880          10.2935   lscc  SPTA1
# 196  normal     -0.3226           9.8418   lscc  SPTA1
# 197  normal      0.6607          10.9359   lscc  SPTA1
# 198  normal      1.1285          10.5726   lscc  SPTA1
# 199  normal     -1.9596          10.1512   lscc  SPTA1
#
# [200 rows x 5 columns]]

# %%
norm_tumor_effects_facet_graph = pd.concat(dfs)
norm_tumor_effects_facet_graph.head()
# Out:
#     Type  Proteomics  Transcriptomics cancer  gene
# 0  tumor   -0.009639         7.661943  ccrcc  ABL1
# 1  tumor    0.237193         9.920884  ccrcc  ABL1
# 2  tumor    0.191196        11.183207  ccrcc  ABL1
# 3  tumor    0.293282        10.196784  ccrcc  ABL1
# 4  tumor    0.016505        13.882935  ccrcc  ABL1

# %%
g = sns.FacetGrid(norm_tumor_effects_facet_graph, col = 'gene', row = 'cancer')
g.map(sns.regplot, 'Proteomics', 'Transcriptomics')

# %%
corr_diffs = []
r2_deltas = []
filtered_genes = []
gene_dfs = []
for gene in cancer_genes:
    print(gene)
    cor, r2, gene_df = find_mutation_corr_effect(en, gene)
    if not np.isnan(cor):
        corr_diffs.append(cor)
        r2_deltas.append(r2)
        filtered_genes.append(gene)
        gene_dfs.append(gene_df)
en_mutation_effects = pd.DataFrame({'gene': filtered_genes, 'correlation_difference': corr_diffs, "r2_delta" : r2_deltas, "gene_dataframes": gene_dfs})
# Out:
# ABL1
# Name         ABL1_proteomics  ABL1_transcriptomics        ABL1_Mutation  \
# Patient_ID
# C3L-00006            -0.2960                 11.36  [Missense_Mutation]
# C3L-00006.N           0.8840                 12.10                  NaN
# C3L-00008            -0.0897                 11.77                  NaN
# C3L-00032            -0.1770                 11.04                  NaN
# C3L-00090            -0.5130                 10.93                  NaN
# ...                      ...                   ...                  ...
# NX5.N                 0.4080                   NaN                  NaN
# NX6.N                 0.6630                   NaN                  NaN
# NX7.N                 0.6640                   NaN                  NaN
# NX8.N                 0.5840                   NaN                  NaN
# NX9.N                 0.8610                   NaN                  NaN
#
# Name        ABL1_Location ABL1_Mutation_Status
# Patient_ID
# C3L-00006       [p.G273R]      Single_mutation
# C3L-00006.N           NaN                  NaN
# C3L-00008             NaN                  NaN
# C3L-00032             NaN                  NaN
# C3L-00090             NaN                  NaN
# ...                   ...                  ...
# NX5.N                 NaN                  NaN
# NX6.N                 NaN                  NaN
# NX7.N                 NaN                  NaN
# NX8.N                 NaN                  NaN
# NX9.N                 NaN                  NaN
#
# [144 rows x 5 columns]
#          Type  Proteomics  Transcriptomics
# 0    mutation     -0.2960            11.36
# 1          wt      0.8840            12.10
# 2          wt     -0.0897            11.77
# 3          wt     -0.1770            11.04
# 4          wt     -0.5130            10.93
# ..        ...         ...              ...
# 121        wt     -0.1810            11.98
# 122        wt     -0.6250            11.29
# 123        wt     -0.2450            11.40
# 124        wt      0.1190            10.58
# 125        wt      0.1480            11.22
#
# [109 rows x 3 columns]
# wt
#     Type  Proteomics  Transcriptomics
# 1     wt      0.8840            12.10
# 2     wt     -0.0897            11.77
# 3     wt     -0.1770            11.04
# 4     wt     -0.5130            10.93
# 5     wt     -0.5260            10.57
# ..   ...         ...              ...
# 121   wt     -0.1810            11.98
# 122   wt     -0.6250            11.29
# 123   wt     -0.2450            11.40
# 124   wt      0.1190            10.58
# 125   wt      0.1480            11.22
#
# [104 rows x 3 columns]
# mt
#         Type  Proteomics  Transcriptomics
# 0   mutation     -0.2960            11.36
# 9   mutation     -0.5720            11.27
# 47  mutation      0.1270            11.40
# 74  mutation     -0.0543            11.36
# 87  mutation     -0.0398            11.96
# BRAF
# Name         BRAF_proteomics  BRAF_transcriptomics BRAF_Mutation  \
# Patient_ID
# C3L-00006            -0.1160                 11.86           NaN
# C3L-00006.N           0.1070                 12.24           NaN
# C3L-00008            -0.1220                 11.17           NaN
# C3L-00032            -0.1070                 11.26           NaN
# C3L-00090             0.1910                 12.07           NaN
# ...                      ...                   ...           ...
# NX5.N                -0.0575                   NaN           NaN
# NX6.N                 0.0902                   NaN           NaN
# NX7.N                -0.1010                   NaN           NaN
# NX8.N                 0.0988                   NaN           NaN
# NX9.N                 0.0121                   NaN           NaN
#
# Name        BRAF_Location BRAF_Mutation_Status
# Patient_ID
# C3L-00006             NaN                  NaN
# C3L-00006.N           NaN                  NaN
# C3L-00008             NaN                  NaN
# C3L-00032             NaN                  NaN
# C3L-00090             NaN                  NaN
# ...                   ...                  ...
# NX5.N                 NaN                  NaN
# NX6.N                 NaN                  NaN
# NX7.N                 NaN                  NaN
# NX8.N                 NaN                  NaN
# NX9.N                 NaN                  NaN
#
# [144 rows x 5 columns]
# <ipython-input-2-58de92ccf073>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(gene_df[is_wt])
# <ipython-input-2-58de92ccf073>:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(gene_df[is_mut])
# <ipython-input-2-58de92ccf073>:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gene_cor, gen_pval = scipy.stats.pearsonr(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
# <ipython-input-2-58de92ccf073>:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   wt_cor, wt_pval = scipy.stats.pearsonr(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
# <ipython-input-2-58de92ccf073>:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gene_m, gene_b, gene_r, gene_p, gene_se = stats.linregress(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
# <ipython-input-2-58de92ccf073>:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   wt_m, wt_b, wt_r, wt_p, wt_se = stats.linregress(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
#     Type  Proteomics  Transcriptomics
# 0     wt     -0.1160            11.86
# 1     wt      0.1070            12.24
# 2     wt     -0.1220            11.17
# 3     wt     -0.1070            11.26
# 4     wt      0.1910            12.07
# ..   ...         ...              ...
# 121   wt     -0.0436            11.60
# 122   wt      0.3580            11.87
# 123   wt     -0.0918            11.94
# 124   wt     -0.4540            11.81
# 125   wt     -0.1350            11.12
#
# [109 rows x 3 columns]
# wt
#     Type  Proteomics  Transcriptomics
# 0     wt     -0.1160            11.86
# 1     wt      0.1070            12.24
# 2     wt     -0.1220            11.17
# 3     wt     -0.1070            11.26
# 4     wt      0.1910            12.07
# ..   ...         ...              ...
# 121   wt     -0.0436            11.60
# 122   wt      0.3580            11.87
# 123   wt     -0.0918            11.94
# 124   wt     -0.4540            11.81
# 125   wt     -0.1350            11.12
#
# [108 rows x 3 columns]
# mt
#         Type  Proteomics  Transcriptomics
# 55  mutation      -0.371            11.87
# <ipython-input-2-58de92ccf073>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(gene_df[is_wt])
# <ipython-input-2-58de92ccf073>:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(gene_df[is_mut])
# <ipython-input-2-58de92ccf073>:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gene_cor, gen_pval = scipy.stats.pearsonr(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-142f05902cc6> in <module>
#       5 for gene in cancer_genes:
#       6     print(gene)
# ----> 7     cor, r2, gene_df = find_mutation_corr_effect(en, gene)
#       8     if not np.isnan(cor):
#       9         corr_diffs.append(cor)
#
# <ipython-input-2-58de92ccf073> in find_mutation_corr_effect(cancer_type, gene, corr_dif)
#      21     print("mt")
#      22     print(gene_df[is_mut])
# ---> 23     gene_cor, gen_pval = scipy.stats.pearsonr(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
#      24     wt_cor, wt_pval = scipy.stats.pearsonr(gene_df[is_wt]['Proteomics'], gene_df[is_wt]['Transcriptomics'])
#      25     gene_m, gene_b, gene_r, gene_p, gene_se = stats.linregress(gene_df[is_mut]['Proteomics'], gene_df[is_mut]['Transcriptomics'])
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3836
#    3837     if n < 2:
# -> 3838         raise ValueError('x and y must have length at least 2.')
#    3839
#    3840     x = np.asarray(x)
#
# ValueError: x and y must have length at least 2.
