# %%
import pandas as pd
import glob
import statsmodels.stats.multitest as ssm

# %%
files = glob.glob('Scripts_to_make_transmutation_effects_dataframes/*effects.csv')
files
# Out:
# ['Scripts_to_make_transmutation_effects_dataframes_With_Pancan/Endometrial_CTNNB1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/HNSCC_NOTCH1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/LUAD_PCLO_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/LUAD_COL11A1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/LSCC_NAV3_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/LUAD_KRAS_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/HNSCC_MUC16_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/HNSCC_CDKN2A_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes_With_Pancan/Endometrial_PIK3CA_transmutation_effects.csv',
# ...

# %%
# files = glob.glob('Scripts_to_make_transmutation_effects_dataframes/*effects.csv')
# files

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
transmutation_df = pd.concat(dfs)
dfs = []
for cancer in pd.unique(transmutation_df.Cancer):
    df = transmutation_df[transmutation_df.Cancer == cancer]
    df['FDR'] = ssm.fdrcorrection(df['P_Value'])[1]
    dfs.append(df)
transmutation_df = pd.concat(dfs)
transmutation_df = transmutation_df[transmutation_df.Cancer != 'PDAC']
transmutation_df.to_csv('transmutation_df.csv', index = False)
transmutation_df
# Out:
# /var/folders/16/01vxw5fs66d9b01nlwf3w5yc0000gn/T/ipykernel_16313/1879016018.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FDR'] = ssm.fdrcorrection(df['P_Value'])[1]
#         Gene  Delta_Correlation   P_Value       FDR       Cancer Mutated_Gene
# 0       A1BG          -0.501626  0.022048  0.715592  Endometrial       CTNNB1
# 1        A2M          -0.193069  0.404778  0.932070  Endometrial       CTNNB1
# 2      A2ML1           0.111895  0.266785  0.902925  Endometrial       CTNNB1
# 3     A4GALT          -0.204002  0.380381  0.926176  Endometrial       CTNNB1
# 4       AAAS          -0.068426  0.773817  0.981924  Endometrial       CTNNB1
# ...      ...                ...       ...       ...          ...          ...
# ...
