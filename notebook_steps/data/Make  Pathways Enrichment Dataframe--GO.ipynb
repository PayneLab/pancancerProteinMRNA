# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation   P_Value       FDR Cancer
# 0        A1BG          -0.388745  0.054892  0.142871  CCRCC
# 1        A1CF           0.146993  0.001086  0.005807  CCRCC
# 2         A2M          -0.277035  0.029705  0.089411  CCRCC
# 3        AAAS          -0.044291  0.708329  0.829294  CCRCC
# 4        AACS          -0.128218  0.065429  0.162756  CCRCC
# ...       ...                ...       ...       ...    ...
# 58209  ZSWIM8          -0.301055  0.297288  0.635725   PDAC
# 58210    ZW10          -0.190323  0.365786  0.694767   PDAC
# 58211  ZYG11B          -0.231357  0.398680  0.720323   PDAC
# 58212     ZYX          -0.232389  0.246493  0.581496   PDAC
# 58213   ZZEF1          -0.019623  0.928292  0.977865   PDAC
#
# [58214 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
pathway_enrichments = []
for cancer in pd.unique(delta_correlation_df.Cancer):
    cancer_df = delta_correlation_df[delta_correlation_df.Cancer == cancer]
    sig_cancer_df = cancer_df[cancer_df.FDR < 0.05]
    sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
    sig_cancer_df = sig_cancer_df.sort_values('Delta_Correlation', ascending = False)
    sig_genes = list(sig_cancer_df.Gene)
    pathway_enrichment = gp.profile(organism='hsapiens', query = sig_genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])
    pathway_enrichment['Cancer'] = [cancer] * len(pathway_enrichment)
    pathway_enrichments.append(pathway_enrichment)
pathway_enrichments = pd.concat(pathway_enrichments)
pathway_enrichments.to_csv('go_bp_pathway_enrichment_df.csv', index = False)
pathway_enrichments
# Out:
# <ipython-input-5-610e4806653d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-610e4806653d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-610e4806653d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-610e4806653d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-610e4806653d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-610e4806653d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
#    source      native                                               name  \
# 0   GO:BP  GO:0016054                     organic acid catabolic process
# 1   GO:BP  GO:0046395                  carboxylic acid catabolic process
# 2   GO:BP  GO:0044282                   small molecule catabolic process
# 3   GO:BP  GO:0055086  nucleobase-containing small molecule metabolic...
# 4   GO:BP  GO:0044281                   small molecule metabolic process
# ..    ...         ...                                                ...
# 1   GO:BP  GO:0071357             cellular response to type I interferon
# 2   GO:BP  GO:0034340                      response to type I interferon
# 3   GO:BP  GO:0030198                  extracellular matrix organization
# 4   GO:BP  GO:0043062               extracellular structure organization
# 5   GO:BP  GO:0045229      external encapsulating structure organization
#
#          p_value significant  \
# 0   3.560568e-07        True
# 1   7.038918e-07        True
# 2   5.195967e-06        True
# 3   2.774041e-03        True
# 4   4.099417e-03        True
# ..           ...         ...
# 1   3.416397e-04        True
# 2   8.300346e-04        True
# 3   8.217828e-03        True
# 4   8.787008e-03        True
# 5   1.003743e-02        True
#
#                                           description term_size query_size  \
# 0   "The chemical reactions and pathways resulting...       211       2107
# 1   "The chemical reactions and pathways resulting...       196       2191
# 2   "The chemical reactions and pathways resulting...       327       2267
# 3   "The cellular chemical reactions and pathways ...       444       2073
# 4   "The chemical reactions and pathways involving...      1341       2151
# ..                                                ...       ...        ...
# 1   "Any process that results in a change in state...        72        473
# 2   "Any process that results in a change in state...        76        473
# 3   "A process that is carried out at the cellular...       296        433
# 4   "A process that is carried out at the cellular...       296        433
# 5   "A process that is carried out at the cellular...       299        433
#
#    intersection_size effective_domain_size  precision    recall    query  \
# 0                 82                 12487   0.038918  0.388626  query_1
# 1                 79                 12487   0.036057  0.403061  query_1
# 2                117                 12487   0.051610  0.357798  query_1
# 3                133                 12487   0.064158  0.299550  query_1
# 4                360                 12487   0.167364  0.268456  query_1
# ..               ...                   ...        ...       ...      ...
# 1                 18                 12487   0.038055  0.250000  query_1
# 2                 18                 12487   0.038055  0.236842  query_1
# 3                 33                 12487   0.076212  0.111486  query_1
# 4                 33                 12487   0.076212  0.111486  query_1
# 5                 33                 12487   0.076212  0.110368  query_1
#
#                                              parents  \
# 0   [GO:0006082, GO:0044248, GO:0044282, GO:1901575]
# 1                           [GO:0016054, GO:0019752]
# 2                           [GO:0009056, GO:0044281]
# 3                           [GO:0006139, GO:0044281]
# 4                                       [GO:0008152]
# ..                                               ...
# 1                           [GO:0034340, GO:0071345]
# 2                           [GO:0034097, GO:0045087]
# 3                           [GO:0043062, GO:0045229]
# 4                                       [GO:0016043]
# 5                                       [GO:0016043]
#
#                                         intersections  \
# 0   [GOT1, ACAA2, EHHADH, IDNK, RIDA, AKR1A1, HADH...
# 1   [GOT1, ACAA2, EHHADH, IDNK, RIDA, AKR1A1, HADH...
# 2   [GOT1, GLYCTK, ACAA2, ENTPD2, EHHADH, NUDT1, P...
# 3   [IMPDH2, ENTPD2, CAD, EIF6, TYMS, DBI, RFK, IM...
# 4   [GOT1, TALDO1, IMPDH2, MTHFD1L, FPGT, MTHFD2, ...
# ..                                                ...
# 1   [WNT5A, OASL, CDC37, TTLL12, BST2, IRAK1, ISG1...
# 2   [WNT5A, OASL, CDC37, TTLL12, BST2, IRAK1, ISG1...
# 3   [MMP12, LAMB3, LOXL2, LAMC2, ADAMTSL3, THSD4, ...
# 4   [MMP12, LAMB3, LOXL2, LAMC2, ADAMTSL3, THSD4, ...
# 5   [MMP12, LAMB3, LOXL2, LAMC2, ADAMTSL3, THSD4, ...
#
#                                             evidences       Cancer
# 0   [[IDA], [IBA, TAS], [IDA, ISS, IBA, TAS, NAS],...  Endometrial
# 1   [[IDA], [IBA, TAS], [IDA, ISS, IBA, TAS, NAS],...  Endometrial
# 2   [[IDA], [TAS], [IBA, TAS], [TAS], [IDA, ISS, I...  Endometrial
# 3   [[IDA, IBA, TAS], [IBA, TAS], [IDA, ISS, IBA, ...  Endometrial
# 4   [[IDA, ISS, IBA, TAS], [TAS], [IDA, IBA, TAS],...  Endometrial
# ..                                                ...          ...
# 1   [[IDA], [TAS], [IMP], [IMP], [TAS], [IMP], [IM...         PDAC
# 2   [[IDA], [TAS], [IMP], [IMP], [TAS], [IMP], [ID...         PDAC
# 3   [[IBA, TAS], [IBA, TAS], [IMP, IBA], [TAS], [I...         PDAC
# 4   [[IBA, TAS], [IBA, TAS], [IMP, IBA], [TAS], [I...         PDAC
# 5   [[IBA, TAS], [IBA, TAS], [IMP, IBA], [TAS], [I...         PDAC
#
# [115 rows x 17 columns]
