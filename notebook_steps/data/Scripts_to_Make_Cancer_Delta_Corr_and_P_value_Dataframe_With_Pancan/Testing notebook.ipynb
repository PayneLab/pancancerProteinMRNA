# %%
import cptac.pancan as pc

# %%
# !pip install --upgrade cptac

import cptac
cptac.version()
# Out:
# Requirement already satisfied: cptac in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: requests>=2.21.0 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (2.27.1)
# Requirement already satisfied: xlrd>=2.0.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (2.0.1)
# Requirement already satisfied: numpy>=1.16.3 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (1.21.5)
# Requirement already satisfied: pandas>=1.2.0 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (1.4.2)
# Requirement already satisfied: packaging>=19.2 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (21.3)
# Requirement already satisfied: statsmodels>=0.10.0 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (0.13.2)
# Requirement already satisfied: scipy>=1.2.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (1.7.3)
# Requirement already satisfied: beautifulsoup4>=4.7.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (4.11.1)
# Requirement already satisfied: gtfparse>=1.2.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (1.2.1)
# Requirement already satisfied: flask>=1.1.0 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (1.1.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (1.26.9)
# Requirement already satisfied: mygene>=3.2.2 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (3.2.2)
# Requirement already satisfied: openpyxl>=2.6.0 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from cptac) (3.0.9)
# Requirement already satisfied: soupsieve>1.2 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.7.1->cptac) (2.3.1)
# Requirement already satisfied: click>=5.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from flask>=1.1.0->cptac) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from flask>=1.1.0->cptac) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from flask>=1.1.0->cptac) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from flask>=1.1.0->cptac) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->flask>=1.1.0->cptac) (2.0.1)
# Requirement already satisfied: biothings-client>=0.2.6 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from mygene>=3.2.2->cptac) (0.2.6)
# Requirement already satisfied: et-xmlfile in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from openpyxl>=2.6.0->cptac) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from packaging>=19.2->cptac) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->cptac) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->cptac) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->cptac) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->cptac) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->cptac) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->cptac) (2021.10.8)
# Requirement already satisfied: patsy>=0.5.2 in /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.10.0->cptac) (0.5.2)
# '1.1.2'

# %%
# import cptac
import scipy.stats as stats
import numpy as np
import pandas as pd
import copy
import cptac.utils as ut

# %%
import cptac.utils

# %%
cptac.utils.reduce_multiindex()

# %%
# ccrcc = pc.PancanCcrcc()
# hnscc = pc.PancanHnscc()
luad = pc.PancanLuad()
# Out:
# Loading broadluad v1.0...
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/gtfparse/read_gtf.py:82: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunk_iterator = pd.read_csv(
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/gtfparse/read_gtf.py:82: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunk_iterator = pd.read_csv(
# Loading washuluad v1.0.........
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/cptac/pancan/washuluad.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = tumor.append(normal)
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/cptac/pancan/washuluad.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = tumor.append(normal)
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/cptac/pancan/washuluad.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = tumor.append(normal)
# Loading washuluad v1.0..........
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/gtfparse/read_gtf.py:82: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunk_iterator = pd.read_csv(
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/gtfparse/read_gtf.py:82: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunk_iterator = pd.read_csv(
# Formatting washuluad dataframes...
# /Users/humbertogiraldez/opt/anaconda3/lib/python3.9/site-packages/cptac/pancan/washuluad.py:215: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rna_combined = rna_tumor.append(rna_normal)

# %%
luad.list_data_sources()
# Out:
#                   Data type  Available sources
# 0                       CNV              washu
# 1          cancer_diagnosis               mssm
# 2              circular_RNA                bcm
# 3                  clinical               mssm
# 4   deconvolution_cibersort              washu
# 5       deconvolution_xcell              washu
# 6               demographic               mssm
# 7                  followup               mssm
# 8              mature_miRNA              washu
# 9        medical_conditions               mssm
# 10        phosphoproteomics              umich
# 11          precursor_miRNA              washu
# 12          previous_cancer               mssm
# 13               proteomics              umich
# 14         somatic_mutation  harmonized, washu
# 15              total_miRNA              washu
# 16          transcriptomics  bcm, broad, washu
# 17             tumor_purity              washu

# %%
ccrcc.get_transcriptomics("washu", "normal")
# Out:
# Name                  5S_rRNA                                      \
# Database_ID ENSG00000201285.1 ENSG00000212595.1 ENSG00000252830.2
# Patient_ID
# C3L-00004.N               0.0               0.0               0.0
# C3L-00010.N               0.0               0.0               0.0
# C3L-00011.N               0.0               0.0               0.0
# C3L-00026.N               0.0               0.0               0.0
# C3L-00079.N               0.0               0.0               0.0
# ...                       ...               ...               ...
# C3N-01646.N               0.0               0.0               0.0
# C3N-01648.N               0.0               0.0               0.0
# C3N-01649.N               0.0               0.0               0.0
# C3N-01651.N               0.0               0.0               0.0
# C3N-01808.N               0.0               0.0               0.0
#
# Name                                                               \
# Database_ID ENSG00000271924.1 ENSG00000272253.1 ENSG00000272351.1
# Patient_ID
# C3L-00004.N          0.710629          1.554085          0.465790
# C3L-00010.N          0.391454          0.428039          0.000000
# C3L-00011.N          1.557894          1.703492          1.094079
# C3L-00026.N          1.564504          2.443884          0.219744
# C3L-00079.N          2.206354          1.608370          0.000000
# ...                       ...               ...               ...
# C3N-01646.N          2.043907          0.957825          0.287079
# C3N-01648.N          0.570147          1.870295          0.000000
# C3N-01649.N          0.704438          1.797306          0.000000
# C3N-01651.N          1.584157          3.117976          0.623013
# C3N-01808.N          0.204842          2.015876          0.604198
#
# Name                                                               \
# Database_ID ENSG00000272435.1 ENSG00000274059.1 ENSG00000274097.1
# Patient_ID
# C3L-00004.N               0.0               0.0          0.000000
# C3L-00010.N               0.0               0.0          0.000000
# C3L-00011.N               0.0               0.0          0.000000
# C3L-00026.N               0.0               0.0          0.488777
# C3L-00079.N               0.0               0.0          0.000000
# ...                       ...               ...               ...
# C3N-01646.N               0.0               0.0          0.000000
# C3N-01648.N               0.0               0.0          0.000000
# C3N-01649.N               0.0               0.0          0.256758
# C3N-01651.N               0.0               0.0          0.000000
# C3N-01808.N               0.0               0.0          0.000000
#
# Name                           ...            uc_338                    \
# Database_ID ENSG00000274164.1  ... ENSG00000278040.1 ENSG00000278113.1
# Patient_ID                     ...
# C3L-00004.N          0.000000  ...          0.824837          0.000000
# C3L-00010.N          0.184678  ...          1.090479          0.000000
# C3L-00011.N          0.000000  ...          2.789902          0.000000
# C3L-00026.N          0.421767  ...          2.179130          0.000000
# C3L-00079.N          0.000000  ...          1.195109          0.000000
# ...                       ...  ...               ...               ...
# C3N-01646.N          0.000000  ...          0.813391          0.203348
# C3N-01648.N          0.000000  ...          2.580933          0.000000
# C3N-01649.N          0.000000  ...          0.981182          0.000000
# C3N-01651.N          0.000000  ...          0.661951          0.000000
# C3N-01808.N          0.000000  ...          1.283921          0.000000
#
# Name                                                               \
# Database_ID ENSG00000278218.1 ENSG00000278236.1 ENSG00000278333.1
# Patient_ID
# C3L-00004.N          0.894017          4.350535               0.0
# C3L-00010.N          0.492475          6.390716               0.0
# C3L-00011.N          1.679941          7.872282               0.0
# C3L-00026.N          0.843534          4.713003               0.0
# C3L-00079.N          0.462623          6.003336               0.0
# ...                       ...               ...               ...
# C3N-01646.N          2.571366          4.568233               0.0
# C3N-01648.N          0.896602          6.011403               0.0
# C3N-01649.N          1.329344          7.347457               0.0
# C3N-01651.N          2.590863          3.448304               0.0
# C3N-01808.N          0.901966          3.344166               0.0
#
# Name                                                               \
# Database_ID ENSG00000278413.1 ENSG00000278498.1 ENSG00000278587.1
# Patient_ID
# C3L-00004.N               0.0          2.040333               0.0
# C3L-00010.N               0.0          1.826386               0.0
# C3L-00011.N               0.0          4.792470               0.0
# C3L-00026.N               0.0          2.566828               0.0
# C3L-00079.N               0.0          2.639504               0.0
# ...                       ...               ...               ...
# C3N-01646.N               0.0          2.724612               0.0
# C3N-01648.N               0.0          3.887842               0.0
# C3N-01649.N               0.0          2.865293               0.0
# C3N-01651.N               0.0          5.458052               0.0
# C3N-01808.N               0.0          2.940677               0.0
#
# Name                                 yR211F11.2
# Database_ID ENSG00000278643.1 ENSG00000213076.3
# Patient_ID
# C3L-00004.N          0.149003          0.095567
# C3L-00010.N          0.246237          0.276380
# C3L-00011.N          0.000000          0.089790
# C3L-00026.N          0.140589          0.225427
# C3L-00079.N          0.154208          0.049453
# ...                       ...               ...
# C3N-01646.N          0.000000          0.294504
# C3N-01648.N          1.613883          0.632568
# C3N-01649.N          0.443115          0.426307
# C3N-01651.N          0.000000          0.447388
# C3N-01808.N          0.128852          0.371894
#
# [75 rows x 60483 columns]

# %%
def get_prot_trans_df(cancer):

    prot_normal_df = cancer.get_proteomics("umich", 'normal')
    if isinstance(prot_normal_df.columns, pd.MultiIndex):
        prot_normal_df = ut.reduce_multiindex(df= prot_normal_df, levels_to_drop = 'Database_ID', quiet=True)

    trans_normal_df = cancer.get_transcriptomics("washu", 'normal')
    if isinstance(trans_normal_df.columns, pd.MultiIndex):
        trans_normal_df = ut.reduce_multiindex(df = trans_normal_df, levels_to_drop='Database_ID', quiet=True)

    prot_normal_df['Name'] = prot_normal_df.index
    trans_normal_df['Name'] = trans_normal_df.index

    prot_normal_df = prot_normal_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Proteomics')
    trans_normal_df = trans_normal_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Transcriptomics')

    prot_tumor_df = cancer.get_proteomics("umich", 'tumor')
    if isinstance(prot_tumor_df.columns, pd.MultiIndex):
        prot_tumor_df = ut.reduce_multiindex(df= prot_tumor_df, levels_to_drop = 'Database_ID', quiet=True)

    trans_tumor_df = cancer.get_transcriptomics("washu", 'tumor')
    if isinstance(trans_tumor_df.columns, pd.MultiIndex):
        trans_tumor_df = ut.reduce_multiindex(df = trans_tumor_df, levels_to_drop='Database_ID', quiet=True)

    prot_tumor_df['Name'] = prot_tumor_df.index
    trans_tumor_df['Name'] = trans_tumor_df.index

    prot_tumor_df = prot_tumor_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Proteomics')
    trans_tumor_df = trans_tumor_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Transcriptomics')

    prot_tumor_df['Tissue'] = ['Tumor'] * len(prot_tumor_df)
    prot_normal_df['Tissue'] = ['Normal'] * len(prot_normal_df)
    trans_tumor_df['Tissue'] = ['Tumor'] * len(trans_tumor_df)
    trans_normal_df['Tissue'] = ['Normal'] * len(trans_normal_df)

    prot_df = pd.concat([prot_tumor_df, prot_normal_df])
    trans_df = pd.concat([trans_tumor_df, trans_normal_df])

    return(pd.merge(prot_df, trans_df).dropna())

# %%
cancer = luad

# %%
prot_normal_df = cancer.get_proteomics("umich", 'normal')
if isinstance(prot_normal_df.columns, pd.MultiIndex):
    prot_normal_df = ut.reduce_multiindex(df= prot_normal_df, levels_to_drop = 'Database_ID', quiet=True)

trans_normal_df = cancer.get_transcriptomics("washu", 'normal')
if isinstance(trans_normal_df.columns, pd.MultiIndex):
    trans_normal_df = ut.reduce_multiindex(df = trans_normal_df, levels_to_drop='Database_ID', quiet=True)

prot_normal_df['Name'] = prot_normal_df.index
trans_normal_df['Name'] = trans_normal_df.index

prot_normal_df = prot_normal_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Proteomics')
trans_normal_df = trans_normal_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Transcriptomics')

prot_tumor_df = cancer.get_proteomics("umich", 'tumor')
if isinstance(prot_tumor_df.columns, pd.MultiIndex):
    prot_tumor_df = ut.reduce_multiindex(df= prot_tumor_df, levels_to_drop = 'Database_ID', quiet=True)

trans_tumor_df = cancer.get_transcriptomics("washu", 'tumor')
if isinstance(trans_tumor_df.columns, pd.MultiIndex):
    trans_tumor_df = ut.reduce_multiindex(df = trans_tumor_df, levels_to_drop='Database_ID', quiet=True)

prot_tumor_df['Name'] = prot_tumor_df.index
trans_tumor_df['Name'] = trans_tumor_df.index

prot_tumor_df = prot_tumor_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Proteomics')
# trans_tumor_df = trans_tumor_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Transcriptomics')

# %%
prot_tumor_df
# Out:
#               Name   Gene  Proteomics
# 0          11LU013   A1BG   -0.522000
# 1          11LU016   A1BG   -0.416894
# 2          11LU022   A1BG   -0.114286
# 3          11LU035   A1BG   -0.138902
# 4        C3L-00001   A1BG   -0.779792
# ...            ...    ...         ...
# 1476517  C3N-02582  ZZEF1   -0.292263
# 1476518  C3N-02586  ZZEF1   -0.164234
# 1476519  C3N-02587  ZZEF1    0.098843
# 1476520  C3N-02588  ZZEF1   -0.224152
# 1476521  C3N-02729  ZZEF1   -0.255202
#
# [1476522 rows x 3 columns]

# %%
df = df[df.Gene == 'ARID1B']

# %%
# df = get_prot_trans_df(luad)
# delta_correlation(get_prot_trans_df(luad))
# column = 'Tissue'
# label1 = 'Tumor'
# label2 ='Normal'
# cutoff = 15
normal_corr = df[df[column] == label2].corr(method = 'spearman',min_periods = cutoff ).iloc[0][1]
tumor_corr = df[df[column] == label1].corr(method = 'spearman',min_periods = cutoff).iloc[0][1]
# Out:
# /var/folders/16/01vxw5fs66d9b01nlwf3w5yc0000gn/T/ipykernel_88445/2063825305.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   normal_corr = df[df[column] == label2].corr(method = 'spearman',min_periods = cutoff ).iloc[0][1]
# /var/folders/16/01vxw5fs66d9b01nlwf3w5yc0000gn/T/ipykernel_88445/2063825305.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tumor_corr = df[df[column] == label1].corr(method = 'spearman',min_periods = cutoff).iloc[0][1]

# %%
print(normal_corr)
print(tumor_corr)
#
# Out:
# 0.02675596971461852
# 0.5646011315736086

# %%
print(normal_corr)
print(tumor_corr)
#
# Out:
# 0.02675596971461852
# 0.5646011315736086

# %%
def delta_correlation(df, column = 'Tissue', label1 = 'Tumor', label2 ='Normal', cutoff = 15):
    normal_corr = df[df[column] == label2].corr(method = 'spearman',min_periods = cutoff ).iloc[0][1]
    tumor_corr = df[df[column] == label1].corr(method = 'spearman',min_periods = cutoff).iloc[0][1]
    delta_corr = tumor_corr - normal_corr
    return delta_corr

# %%
import cptac.pancan as pc
pc.get_box_token()
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.
# 'pDsRMupmWmnAwVcP1UOuWwQnTbmnaQaB'

# %%
import cptac.pancan as pc
import scipy.stats as stats
import numpy as np
import copy
import cptac.utils as ut
import statsmodels.stats.multitest as ssm
import pandas as pd
import warnings
import sys, os

def get_prot_trans_df(cancer):

    prot_normal_df = cancer.get_proteomics("pdc", 'normal')
    if isinstance(prot_normal_df.columns, pd.MultiIndex):
        prot_normal_df = ut.reduce_multiindex(df= prot_normal_df, levels_to_drop = 'Database_ID', quiet=True)

    trans_normal_df = cancer.get_transcriptomics("washu", 'normal')
    if isinstance(trans_normal_df.columns, pd.MultiIndex):
        trans_normal_df = ut.reduce_multiindex(df = trans_normal_df, levels_to_drop='Database_ID', quiet=True)

    prot_normal_df['Name'] = prot_normal_df.index
    trans_normal_df['Name'] = trans_normal_df.index

    prot_normal_df = prot_normal_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Proteomics')
    trans_normal_df = trans_normal_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Transcriptomics')

    prot_tumor_df = cancer.get_proteomics("pdc", 'tumor')
    if isinstance(prot_tumor_df.columns, pd.MultiIndex):
        prot_tumor_df = ut.reduce_multiindex(df= prot_tumor_df, levels_to_drop = 'Database_ID', quiet=True)

    trans_tumor_df = cancer.get_transcriptomics("washu", 'tumor')
    if isinstance(trans_tumor_df.columns, pd.MultiIndex):
        trans_tumor_df = ut.reduce_multiindex(df = trans_tumor_df, levels_to_drop='Database_ID', quiet=True)

    prot_tumor_df['Name'] = prot_tumor_df.index
    trans_tumor_df['Name'] = trans_tumor_df.index

    prot_tumor_df = prot_tumor_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Proteomics')
    trans_tumor_df = trans_tumor_df.melt(id_vars = 'Name', var_name = 'Gene', value_name = 'Transcriptomics')

    prot_tumor_df['Tissue'] = ['Tumor'] * len(prot_tumor_df)
    prot_normal_df['Tissue'] = ['Normal'] * len(prot_normal_df)
    trans_tumor_df['Tissue'] = ['Tumor'] * len(trans_tumor_df)
    trans_normal_df['Tissue'] = ['Normal'] * len(trans_normal_df)

    prot_df = pd.concat([prot_tumor_df, prot_normal_df])
    trans_df = pd.concat([trans_tumor_df, trans_normal_df])

    return(pd.merge(prot_df, trans_df).dropna())

def permutate(df, column = 'Tissue', label1 = 'Tumor', label2 ='Normal', cutoff = 15, num_permutations = 10000, return_perm_list = False):
    delta_corr = delta_correlation(df, column = column, label1 = label1, label2 = label2, cutoff= cutoff)
    perm_delta_corrs = []
    for i in range(0, num_permutations):
        df[column] = np.random.permutation(df[column])
        perm_delta_corr = delta_correlation(df, column = column, label1 = label1, label2 = label2, cutoff = cutoff)
        perm_delta_corrs.append(perm_delta_corr)
    if return_perm_list:
        return perm_delta_corrs
    z_score = (delta_corr - np.mean(perm_delta_corrs)) / np.std(perm_delta_corrs)
    p_val = stats.norm.sf(abs(z_score)) * 2  
    return(delta_corr, p_val)


warnings.filterwarnings('ignore')
# currentdir = os.path.dirname(os.path.realpath('Make_Cancer_Delta_Corr_and_P_Value_Dataframe'))
# parentdir = os.path.dirname(currentdir)
# parentdir = os.path.dirname(parentdir)
# sys.path.append(parentdir)


# input_cancer_type = sys.argv[1]
# input_permutation_number = int(sys.argv[2])
# token = sys.argv[3]
cutoff = 15
input_cancer_type = "CCRCC"
token ="pDsRMupmWmnAwVcP1UOuWwQnTbmnaQaB"
if input_cancer_type == "CCRCC":
    pc.download("pancanccrcc", box_token=token)
    cancer = pc.PancanCcrcc()
elif input_cancer_type == "Endometrial":
    pc.download("pancanucec", box_token=token)
    cancer = pc.PancanUcec()
    cutoff = 10
elif input_cancer_type == "LUAD":
    pc.download("pancanluad", box_token=token)
    cancer = pc.PancanLuad()
elif input_cancer_type == "HNSCC":
    pc.download("pancanhnscc", box_token=token)
    cancer = pc.PancanHnscc()
elif input_cancer_type == "LSCC":
    pc.download("pancanlscc", box_token=token)
    cancer = pc.PancanLscc()


prot_trans_df = get_prot_trans_df(cancer)
perm_results = prot_trans_df.groupby('Gene').apply(lambda x: permutate(df = x, cutoff = cutoff, num_permutations = input_permutation_number))
df = pd.DataFrame.from_records(perm_results, columns = ['Delta_Correlation', 'P_Value'])
df.index = perm_results.index
df = df.dropna()
df.reset_index(inplace = True)
df['FDR'] = ssm.fdrcorrection(df.P_Value)[1]
df['Cancer'] = [input_cancer_type] * len(df)
file_name = input_cancer_type + '_delta_corr_pval_df.csv'
df.to_csv(file_name, index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-40a3db8e56dd> in <module>
#      95
#      96 prot_trans_df = get_prot_trans_df(cancer)
# ---> 97 perm_results = prot_trans_df.groupby('Gene').apply(lambda x: permutate(df = x, cutoff = cutoff, num_permutations = input_permutation_number))
#      98 df = pd.DataFrame.from_records(perm_results, columns = ['Delta_Correlation', 'P_Value'])
#      99 df.index = perm_results.index
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1412         with option_context("mode.chained_assignment", None):
#    1413             try:
# -> 1414                 result = self._python_apply_general(f, self._selected_obj)
#    1415             except TypeError:
#    1416                 # gh-20949
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same)
#    1453             data after applying f
#    1454         """
# -> 1455         values, mutated = self.grouper.apply(f, data, self.axis)
#    1456
#    1457         if not_indexed_same is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     759             # group might be modified
#     760             group_axes = group.axes
# --> 761             res = f(group)
#     762             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763                 mutated = True
#
# <ipython-input-4-40a3db8e56dd> in <lambda>(x)
#      95
#      96 prot_trans_df = get_prot_trans_df(cancer)
# ---> 97 perm_results = prot_trans_df.groupby('Gene').apply(lambda x: permutate(df = x, cutoff = cutoff, num_permutations = input_permutation_number))
#      98 df = pd.DataFrame.from_records(perm_results, columns = ['Delta_Correlation', 'P_Value'])
#      99 df.index = perm_results.index
#
# NameError: name 'input_permutation_number' is not defined

# %%
def permutate(df, column = 'Tissue', label1 = 'Tumor', label2 ='Normal', cutoff = 15, num_permutations = 10000, return_perm_list = False):
    delta_corr = delta_correlation(df, column = column, label1 = label1, label2 = label2, cutoff= cutoff)
    perm_delta_corrs = []
    for i in range(0, num_permutations):
        df[column] = np.random.permutation(df[column])
        perm_delta_corr = delta_correlation(df, column = column, label1 = label1, label2 = label2, cutoff = cutoff)
        perm_delta_corrs.append(perm_delta_corr)
    if return_perm_list:
        return perm_delta_corrs
    z_score = (delta_corr - np.mean(perm_delta_corrs)) / np.std(perm_delta_corrs)
    p_val = stats.norm.sf(abs(z_score)) * 2  
    return(delta_corr, p_val)

# %%
permutate(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 permutate(0)
#
# Input In [29], in permutate(df, column, label1, label2, cutoff, num_permutations, return_perm_list)
#       1 def permutate(df, column = 'Tissue', label1 = 'Tumor', label2 ='Normal', cutoff = 15, num_permutations = 10000, return_perm_list = False):
# ----> 2     delta_corr = delta_correlation(df, column = column, label1 = label1, label2 = label2, cutoff= cutoff)
#       3     perm_delta_corrs = []
#       4     for i in range(0, num_permutations):
#
# NameError: name 'delta_correlation' is not defined
