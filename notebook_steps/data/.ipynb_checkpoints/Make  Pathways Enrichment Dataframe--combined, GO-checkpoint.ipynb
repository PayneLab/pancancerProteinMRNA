# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.388745  5.489179e-02  1.428712e-01  CCRCC
# 1        A1CF           0.146993  1.086323e-03  5.807113e-03  CCRCC
# 2         A2M          -0.277035  2.970512e-02  8.941116e-02  CCRCC
# 3        AAAS          -0.044291  7.083291e-01  8.292938e-01  CCRCC
# 4        AACS          -0.128218  6.542873e-02  1.627560e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50299    ZXDC           0.087794  5.862270e-01  6.491477e-01   LUAD
# 50300  ZYG11B           0.707991  8.084098e-11  5.520566e-10   LUAD
# 50301     ZYX           0.472139  3.818601e-08  1.866439e-07   LUAD
# 50302   ZZEF1           0.418589  2.609770e-15  2.744540e-14   LUAD
# 50303    ZZZ3           0.661323  1.156770e-05  3.867049e-05   LUAD
#
# [50304 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
sig_delta_corr = delta_correlation_df[delta_correlation_df.FDR < 0.05]
num_genes = pd.DataFrame(sig_delta_corr.groupby('Gene').size())
sig_genes = num_genes[num_genes[0] >=3].index
sig_delta_corr = sig_delta_corr[sig_delta_corr.Gene.isin(sig_genes)]
sig_delta_corr = sig_delta_corr.groupby('Gene').mean()
sig_delta_corr['Delta_Correlation'] = abs(sig_delta_corr.Delta_Correlation)
sig_delta_corr = sig_delta_corr.sort_values('Delta_Correlation', ascending = False)
sig_delta_corr.reset_index(inplace = True)
genes = list(sig_delta_corr.Gene)
pathway_enrichment = gp.profile(organism='hsapiens', query = genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])
pathway_enrichment.to_csv('combinded_GO_pathway_enrichment_df.csv', index = False)

# %%
pathway_enrichment
# Out:
#    source      native                                               name  \
# 0   GO:BP  GO:0000278                                 mitotic cell cycle
# 1   GO:BP  GO:1903047                         mitotic cell cycle process
# 2   GO:BP  GO:0007049                                         cell cycle
# 3   GO:BP  GO:0022402                                 cell cycle process
# 4   GO:BP  GO:0006271  DNA strand elongation involved in DNA replication
# 5   GO:BP  GO:0007052                       mitotic spindle organization
# 6   GO:BP  GO:0140014                           mitotic nuclear division
# 7   GO:BP  GO:0051276                            chromosome organization
# 8   GO:BP  GO:1902850  microtubule cytoskeleton organization involved...
# 9   GO:BP  GO:0000075                    cell cycle checkpoint signaling
# 10  GO:BP  GO:0044786                         cell cycle DNA replication
# 11  GO:BP  GO:0000819                       sister chromatid segregation
# 12  GO:BP  GO:0000070               mitotic sister chromatid segregation
# 13  GO:BP  GO:0007093            mitotic cell cycle checkpoint signaling
# 14  GO:BP  GO:0033260                            nuclear DNA replication
# 15  GO:BP  GO:0007051                               spindle organization
# 16  GO:BP  GO:0007059                             chromosome segregation
# 17  GO:BP  GO:0022616                              DNA strand elongation
# 18  GO:BP  GO:0044770                        cell cycle phase transition
# 19  GO:BP  GO:0044772                mitotic cell cycle phase transition
# 20  GO:BP  GO:0044282                   small molecule catabolic process
# 21  GO:BP  GO:0000280                                   nuclear division
# 22  GO:BP  GO:0006974           cellular response to DNA damage stimulus
# 23  GO:BP  GO:0098813                     nuclear chromosome segregation
# 24  GO:BP  GO:0048285                                  organelle fission
# 25  GO:BP  GO:0051983               regulation of chromosome segregation
# 26  GO:BP  GO:0006259                              DNA metabolic process
# 27  GO:BP  GO:0006399                             tRNA metabolic process
# 28  GO:BP  GO:0000959                mitochondrial RNA metabolic process
# 29  GO:BP  GO:0006281                                         DNA repair
# 30  GO:BP  GO:1901988  negative regulation of cell cycle phase transi...
# 31  GO:BP  GO:0006396                                     RNA processing
# 32  GO:BP  GO:0000281                                mitotic cytokinesis
# 33  GO:BP  GO:0033047  regulation of mitotic sister chromatid segrega...
# 34  GO:BP  GO:1901987          regulation of cell cycle phase transition
# 35  GO:BP  GO:0046112                    nucleobase biosynthetic process
# 36  GO:BP  GO:0009123         nucleoside monophosphate metabolic process
# 37  GO:BP  GO:0051304                              chromosome separation
# 38  GO:BP  GO:1902299  pre-replicative complex assembly involved in c...
# 39  GO:BP  GO:0006267  pre-replicative complex assembly involved in n...
# 40  GO:BP  GO:1901991  negative regulation of mitotic cell cycle phas...
# 41  GO:BP  GO:1901990  regulation of mitotic cell cycle phase transition
# 42  GO:BP  GO:0000077                    DNA damage checkpoint signaling
# 43  GO:BP  GO:0051726                           regulation of cell cycle
# 44  GO:BP  GO:0045071    negative regulation of viral genome replication
# 45  GO:BP  GO:1905818                regulation of chromosome separation
# 46  GO:BP  GO:0033045         regulation of sister chromatid segregation
# 47  GO:BP  GO:0009112                       nucleobase metabolic process
# 48  GO:BP  GO:1902969                            mitotic DNA replication
# 49  GO:BP  GO:0009124      nucleoside monophosphate biosynthetic process
# 50  GO:BP  GO:0042770      signal transduction in response to DNA damage
#
#          p_value  significant  \
# 0   2.537652e-10         True
# 1   5.174290e-08         True
# 2   1.032820e-06         True
# 3   1.700306e-06         True
# 4   3.932273e-06         True
# 5   8.815392e-06         True
# 6   2.101378e-05         True
# 7   2.257688e-05         True
# 8   3.176894e-05         True
# 9   3.743448e-05         True
# 10  5.013074e-05         True
# 11  5.349614e-05         True
# 12  5.379025e-05         True
# 13  6.082066e-05         True
# 14  7.089759e-05         True
# 15  8.201839e-05         True
# 16  2.703005e-04         True
# 17  3.185260e-04         True
# 18  3.221188e-04         True
# 19  3.226356e-04         True
# 20  8.269675e-04         True
# 21  1.045542e-03         True
# 22  1.631001e-03         True
# 23  1.747793e-03         True
# 24  2.002050e-03         True
# 25  2.368213e-03         True
# 26  3.665462e-03         True
# 27  4.899831e-03         True
# 28  5.497330e-03         True
# 29  7.230989e-03         True
# 30  8.324002e-03         True
# 31  8.415000e-03         True
# 32  1.178473e-02         True
# 33  1.183307e-02         True
# 34  1.239420e-02         True
# 35  1.664536e-02         True
# 36  1.724910e-02         True
# 37  1.729514e-02         True
# 38  1.752219e-02         True
# 39  1.752219e-02         True
# 40  1.923104e-02         True
# 41  1.969868e-02         True
# 42  2.643815e-02         True
# 43  2.695320e-02         True
# 44  2.877452e-02         True
# 45  2.880118e-02         True
# 46  3.444063e-02         True
# 47  3.767709e-02         True
# 48  4.153575e-02         True
# 49  4.290250e-02         True
# 50  4.356042e-02         True
#
#                                           description  term_size  query_size  \
# 0   "Progression through the phases of the mitotic...        792         223
# 1   "A process that is part of the mitotic cell cy...        702         743
# 2   "The progression of biochemical and morphologi...       1143         223
# 3   "The cellular process that ensures successive ...        969         746
# 4   "The process in which an existing DNA strand i...         18        1575
# 5   "A process that is carried out at the cellular...        172         223
# 6   "A mitotic cell cycle process comprising the s...        269         487
# 7   "A process that is carried out at the cellular...        823         770
# 8   "Any microtubule cytoskeleton organization tha...        183         223
# 9   "A signaling process that controls cell cycle ...        146         230
# 10  "The DNA-dependent DNA replication that takes ...         57        1119
# 11  "The cell cycle process in which sister chroma...        164         708
# 12  "The cell cycle process in which replicated ho...        142         708
# 13  "A signaling process that ensures accurate chr...        122         223
# 14  "The DNA-dependent DNA replication that occurs...         56        1119
# 15  "A process that is carried out at the cellular...        213         223
# 16  "The process in which genetic material, in the...        231         708
# 17  "The DNA metabolic process in which an existin...         23        1575
# 18  "The cell cycle process by which a cell commit...        473         239
# 19  "The cell cycle process by which a cell commit...        418         223
# 20  "The chemical reactions and pathways resulting...        326        3747
# 21  "The division of a cell nucleus into two nucle...        316         223
# 22  "Any process that results in a change in state...        628        1050
# 23  "The process in which genetic material, in the...        192         708
# 24  "The creation of two or more organelles by div...        355         223
# 25  "Any process that modulates the frequency, rat...         67         418
# 26  "Any cellular metabolic process involving deox...        639        1126
# 27  "The chemical reactions and pathways involving...        139        1726
# 28  "The chemical reactions and pathways involving...         36        1767
# 29  "The process of restoring DNA after damage. Ge...        399        1050
# 30  "Any process that stops, prevents or reduces t...        224         230
# 31  "Any process involved in the conversion of one...        815         867
# 32  "A cell cycle process that results in the divi...         63        2509
# 33  "Any process that modulates the frequency, rat...         35         584
# 34  "Any process that modulates the frequency, rat...        377         239
# 35  "The chemical reactions and pathways resulting...         14        3292
# 36  "The chemical reactions and pathways involving...         33        3356
# 37  "The cell cycle process in which paired chromo...         67         584
# 38  "Any pre-replicative complex assembly that is ...          7        1119
# 39  "The aggregation, arrangement and bonding toge...          7        1119
# 40  "Any process that stops, prevents or reduces t...        185         223
# 41  "Any process that modulates the frequency, rat...        327         239
# 42  "A signal transduction process that contribute...        101         230
# 43  "Any process that modulates the rate or extent...        736         239
# 44  "Any process that stops, prevents, or reduces ...         42        3538
# 45  "Any process that modulates the frequency, rat...         54         396
# 46  "Any process that modulates the frequency, rat...         55         396
# 47  "The chemical reactions and pathways involving...         21        3497
# 48  "Any nuclear DNA replication that is involved ...         11        1035
# 49  "The chemical reactions and pathways resulting...         23        2477
# 50  "A cascade of processes induced by the detecti...        141         230
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                  56                  12414   0.251121  0.070707  query_1
# 1                 106                  12414   0.142665  0.150997  query_1
# 2                  64                  12414   0.286996  0.055993  query_1
# 3                 134                  12414   0.179625  0.138287  query_1
# 4                  15                  12414   0.009524  0.833333  query_1
# 5                  20                  12414   0.089686  0.116279  query_1
# 6                  39                  12414   0.080082  0.144981  query_1
# 7                 116                  12414   0.150649  0.140948  query_1
# 8                  20                  12414   0.089686  0.109290  query_1
# 9                  19                  12414   0.082609  0.130137  query_1
# 10                 24                  12414   0.021448  0.421053  query_1
# 11                 36                  12414   0.050847  0.219512  query_1
# 12                 33                  12414   0.046610  0.232394  query_1
# 13                 17                  12414   0.076233  0.139344  query_1
# 14                 23                  12414   0.020554  0.410714  query_1
# 15                 21                  12414   0.094170  0.098592  query_1
# 16                 45                  12414   0.063559  0.194805  query_1
# 17                 16                  12414   0.010159  0.695652  query_1
# 18                 35                  12414   0.146444  0.073996  query_1
# 19                 31                  12414   0.139013  0.074163  query_1
# 20                161                  12414   0.042968  0.493865  query_1
# 21                 27                  12414   0.121076  0.085443  query_1
# 22                111                  12414   0.105714  0.176752  query_1
# 23                 39                  12414   0.055085  0.203125  query_1
# 24                 28                  12414   0.125561  0.078873  query_1
# 25                 15                  12414   0.035885  0.223881  query_1
# 26                120                  12414   0.106572  0.187793  query_1
# 27                 49                  12414   0.028389  0.352518  query_1
# 28                 21                  12414   0.011885  0.583333  query_1
# 29                 78                  12414   0.074286  0.195489  query_1
# 30                 21                  12414   0.091304  0.093750  query_1
# 31                104                  12414   0.119954  0.127607  query_1
# 32                 33                  12414   0.013153  0.523810  query_1
# 33                 12                  12414   0.020548  0.342857  query_1
# 34                 28                  12414   0.117155  0.074271  query_1
# 35                 13                  12414   0.003949  0.928571  query_1
# 36                 24                  12414   0.007151  0.727273  query_1
# 37                 17                  12414   0.029110  0.253731  query_1
# 38                  7                  12414   0.006256  1.000000  query_1
# 39                  7                  12414   0.006256  1.000000  query_1
# 40                 18                  12414   0.080717  0.097297  query_1
# 41                 25                  12414   0.104603  0.076453  query_1
# 42                 13                  12414   0.056522  0.128713  query_1
# 43                 42                  12414   0.175732  0.057065  query_1
# 44                 33                  12414   0.009327  0.785714  query_1
# 45                 12                  12414   0.030303  0.222222  query_1
# 46                 12                  12414   0.030303  0.218182  query_1
# 47                 17                  12414   0.004861  0.809524  query_1
# 48                  8                  12414   0.007729  0.727273  query_1
# 49                 16                  12414   0.006459  0.695652  query_1
# 50                 15                  12414   0.065217  0.106383  query_1
#
#                                              parents  \
# 0                                       [GO:0007049]
# 1                           [GO:0000278, GO:0022402]
# 2                                       [GO:0009987]
# 3                           [GO:0007049, GO:0009987]
# 4                           [GO:0006261, GO:0022616]
# 5                           [GO:0007051, GO:1902850]
# 6                           [GO:0000280, GO:1903047]
# 7                                       [GO:0006996]
# 8                           [GO:0000226, GO:1903047]
# 9                           [GO:0035556, GO:1901988]
# 10                          [GO:0006261, GO:0022402]
# 11                          [GO:0051276, GO:0098813]
# 12              [GO:0000819, GO:0140014, GO:1903047]
# 13              [GO:0000075, GO:0045930, GO:1903047]
# 14                                      [GO:0044786]
# 15                          [GO:0000226, GO:0022402]
# 16                                      [GO:0009987]
# 17                                      [GO:0006259]
# 18                                      [GO:0022402]
# 19                          [GO:0044770, GO:1903047]
# 20                          [GO:0009056, GO:0044281]
# 21                                      [GO:0048285]
# 22                                      [GO:0033554]
# 23                          [GO:0007059, GO:0022402]
# 24                                      [GO:0006996]
# 25                          [GO:0007059, GO:0050794]
# 26                          [GO:0044260, GO:0090304]
# 27                                      [GO:0034660]
# 28                                      [GO:0016070]
# 29                          [GO:0006259, GO:0006974]
# 30              [GO:0010948, GO:0044770, GO:1901987]
# 31                          [GO:0010467, GO:0016070]
# 32                          [GO:0061640, GO:1903047]
# 33                          [GO:0000070, GO:0033045]
# 34                          [GO:0010564, GO:0044770]
# 35  [GO:0009112, GO:0018130, GO:1901362, GO:1901566]
# 36                                      [GO:0006753]
# 37                          [GO:0007059, GO:0022402]
# 38              [GO:0022402, GO:0036388, GO:0044786]
# 39                          [GO:0033260, GO:1902299]
# 40  [GO:0044772, GO:0045930, GO:1901988, GO:1901990]
# 41              [GO:0007346, GO:0044772, GO:1901987]
# 42                          [GO:0031570, GO:0042770]
# 43                          [GO:0007049, GO:0050794]
# 44              [GO:0019079, GO:0045069, GO:0048525]
# 45              [GO:0010564, GO:0051304, GO:0051983]
# 46  [GO:0000819, GO:0010564, GO:0033044, GO:0051983]
# 47                          [GO:0055086, GO:1901564]
# 48                          [GO:0033260, GO:1903047]
# 49                          [GO:0009123, GO:1901293]
# 50                          [GO:0006974, GO:0035556]
#
#                                         intersections  \
# 0   [TRIP13, ZWINT, PBK, MAPRE1, KIF11, CHEK1, NCA...
# 1   [TRIP13, ZWINT, MAPRE1, KIF11, CHEK1, NCAPD3, ...
# 2   [TRIP13, ZWINT, PBK, MAPRE1, KIF11, CHEK1, NCA...
# 3   [TRIP13, ZWINT, MAPRE1, KIF11, CHEK1, NCAPD3, ...
# 4   [GINS3, PCNA, GINS1, MCM3, MCM7, MCM4, GINS2, ...
# 5   [ZWINT, MAPRE1, KIF11, TPX2, KIFC1, PRC1, NDC8...
# 6   [TRIP13, ZWINT, KIF11, CHEK1, NCAPD3, TPX2, KI...
# 7   [DHX36, TRIP13, ZWINT, NSD3, RIOX1, CHEK1, NCA...
# 8   [ZWINT, MAPRE1, KIF11, TPX2, KIFC1, PRC1, NDC8...
# 9   [TRIP13, ZWINT, CHEK1, NDC80, USP28, BLM, TP53...
# 10  [BLM, GINS3, PCNA, RFC1, WRN, ATRX, PRIM1, DSC...
# 11  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 12  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 13  [TRIP13, ZWINT, CHEK1, NDC80, BLM, TP53, TOPBP...
# 14  [BLM, GINS3, PCNA, RFC1, WRN, ATRX, PRIM1, DSC...
# 15  [ZWINT, MAPRE1, KIF11, TPX2, KIFC1, EZR, PRC1,...
# 16  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 17  [GINS3, PCNA, GINS1, MCM3, MCM7, MCM4, GINS2, ...
# 18  [TRIP13, ZWINT, MAPRE1, CHEK1, TPX2, PSMD10, T...
# 19  [TRIP13, ZWINT, MAPRE1, CHEK1, TPX2, PSMD10, T...
# 20  [XDH, ENTPD5, PGK1, AMACR, KHK, ACAD10, GCSH, ...
# 21  [TRIP13, ZWINT, KIF11, CHEK1, NCAPD3, TPX2, KI...
# 22  [UBE2T, TRIP13, CHEK1, WDR70, PSMD10, HSF1, GN...
# 23  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 24  [TRIP13, ZWINT, KIF11, CHEK1, NCAPD3, TPX2, KI...
# 25  [TRIP13, ZWINT, NDC80, KIF2C, CENPF, DLGAP5, U...
# 26  [UBE2T, DHX36, TRIP13, CHEK1, WDR70, TYMS, HSF...
# 27  [NSUN2, SARS2, TRMT5, C9orf64, TRMT1L, ZBTB8OS...
# 28  [SARS2, TFB1M, TFB2M, TRMT5, TRIT1, DARS2, TAR...
# 29  [UBE2T, TRIP13, CHEK1, WDR70, HSF1, PPIE, BLM,...
# 30  [TRIP13, ZWINT, CHEK1, PSMD10, NDC80, USP28, B...
# 31  [DHX36, NSUN2, ZC3H7A, WBP11, EIF6, HSF1, PPIE...
# 32  [INCENP, ANLN, KIF23, PLK1, CHMP1B, USP8, CKAP...
# 33  [TRIP13, ZWINT, NDC80, CENPF, MAD2L1, CCNB1, A...
# 34  [TRIP13, ZWINT, MAPRE1, CHEK1, TPX2, PSMD10, N...
# 35  [PAICS, CAD, GMPS, SHMT2, HPRT1, UMPS, GART, C...
# 36  [XDH, PAICS, TYMS, IMPDH2, PPAT, GMPS, RFK, HP...
# 37  [TRIP13, ZWINT, NDC80, CENPF, DLGAP5, UBE2C, C...
# 38         [MCM3, MCM7, MCM5, MCM4, MCM2, MCM6, ORC3]
# 39         [MCM3, MCM7, MCM5, MCM4, MCM2, MCM6, ORC3]
# 40  [TRIP13, ZWINT, CHEK1, PSMD10, NDC80, BLM, TP5...
# 41  [TRIP13, ZWINT, MAPRE1, CHEK1, TPX2, PSMD10, N...
# 42  [CHEK1, USP28, BLM, TP53, TOPBP1, CHEK2, CARM1...
# 43  [TRIP13, ZWINT, MAPRE1, KIF11, CHEK1, TPX2, PS...
# 44  [APOBEC3B, SRPK1, ZC3HAV1, HMGA2, SRPK2, INPP5...
# 45  [TRIP13, ZWINT, NDC80, CENPF, DLGAP5, UBE2C, C...
# 46  [TRIP13, ZWINT, NDC80, CENPF, DLGAP5, UBE2C, M...
# 47  [XDH, PAICS, CAD, GMPS, SHMT2, HPRT1, GDA, UMP...
# 48  [GINS3, GINS1, MCM3, MCM4, MCM2, POLA1, LIG1, ...
# 49  [PAICS, TYMS, IMPDH2, PPAT, GMPS, RFK, HPRT1, ...
# 50  [CHEK1, PSMD10, USP28, BLM, TP53, TOPBP1, CHEK...
#
#                                             evidences
# 0   [[IMP], [IDA, IBA, TAS], [NAS], [TAS], [IDA, I...
# 1   [[IMP], [IDA, IBA, TAS], [TAS], [IDA, IMP, IBA...
# 2   [[IMP, ISS, IBA], [IDA, IBA, TAS], [NAS], [IBA...
# 3   [[IMP, ISS, IBA], [IDA, IBA, TAS], [IBA, TAS],...
# 4   [[TAS], [IBA], [IBA, TAS], [IBA], [IBA], [IBA]...
# 5   [[TAS], [TAS], [IDA, IMP, IBA, TAS], [IDA, ISS...
# 6   [[IMP], [IDA, IBA], [IDA, IMP, IBA], [IDA], [I...
# 7   [[IDA, IMP], [IMP, ISS], [IDA, IBA], [IDA, IMP...
# 8   [[TAS], [TAS], [IDA, IMP, IBA, TAS], [IDA, ISS...
# 9   [[IMP, IBA], [IDA], [IDA, IMP], [IMP], [IMP, I...
# 10  [[TAS], [IBA], [ISS, TAS], [TAS], [TAS], [ISS]...
# 11  [[IMP], [IDA, IBA], [IDA, IMP, IBA, TAS], [IMP...
# 12  [[IMP], [IDA, IBA], [IDA, IMP, IBA, TAS], [IMP...
# 13  [[IMP], [IDA], [IMP], [IMP], [IDA], [IMP, TAS]...
# 14  [[TAS], [IBA], [ISS, TAS], [TAS], [TAS], [ISS]...
# 15  [[TAS], [IBA, TAS], [IDA, IMP, IBA, TAS], [IDA...
# 16  [[IMP, ISS], [IDA, IBA], [IDA, IMP, IBA, TAS],...
# 17  [[TAS], [IBA], [IBA, TAS], [IBA], [IBA], [IBA]...
# 18  [[IMP, IBA], [IDA], [TAS], [IDA, IMP], [TAS], ...
# 19  [[IMP], [IDA], [TAS], [IMP], [TAS], [TAS], [TA...
# 20  [[IDA], [TAS], [TAS], [TAS], [TAS], [TAS], [IB...
# 21  [[IMP, ISS, IBA], [IDA, IBA], [IDA, IMP, IBA],...
# 22  [[IMP, IBA, TAS], [ISS], [IDA, IMP, ISS], [IBA...
# 23  [[IMP, ISS], [IDA, IBA], [IDA, IMP, IBA, TAS],...
# 24  [[IMP, ISS, IBA], [IDA, IBA], [IDA, IMP, IBA],...
# 25  [[IMP], [IDA], [IMP], [IMP], [NAS], [NAS], [IB...
# 26  [[IMP, TAS], [IMP], [ISS, IBA], [IDA, IMP], [I...
# 27  [[IDA, ISS, IBA, TAS], [ISS, IBA, TAS], [IMP, ...
# 28  [[IBA], [IBA], [IDA, IBA, TAS], [IMP, IBA], [T...
# 29  [[IMP, TAS], [ISS], [IDA, IMP], [IBA], [IMP], ...
# 30  [[IMP, IBA], [IDA], [IDA, IMP], [TAS], [IMP], ...
# 31  [[IMP], [IDA, IBA, TAS], [IMP, IBA], [IBA, TAS...
# 32  [[IMP, IBA], [IDA, IBA], [IMP], [IDA], [IMP], ...
# 33  [[IMP], [IDA], [IMP], [NAS], [IDA, IMP, IBA, T...
# 34  [[IMP, IBA], [IDA], [TAS], [IDA, IMP], [TAS], ...
# 35  [[TAS], [IDA, ISS, IBA], [TAS], [IBA], [IDA, I...
# 36  [[IDA], [TAS], [IDA, IBA], [TAS], [TAS], [IDA,...
# 37  [[IMP], [IDA], [IMP], [NAS], [NAS], [IBA], [IM...
# 38  [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IBA]]
# 39  [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IBA]]
# 40  [[IMP], [IDA], [IMP], [TAS], [IMP], [IDA], [IM...
# 41  [[IMP], [IDA], [TAS], [IMP], [TAS], [TAS], [IM...
# 42  [[IDA, IMP], [IMP, IBA], [IDA], [IMP, TAS], [I...
# 43  [[IMP, IBA], [IDA], [TAS], [IMP], [IDA, IMP, T...
# 44  [[IBA], [IDA], [IDA], [IDA], [IDA], [IDA], [TA...
# 45  [[IMP], [IDA], [IMP], [NAS], [NAS], [IBA], [IM...
# 46  [[IMP], [IDA], [IMP], [NAS], [NAS], [IBA], [ID...
# 47  [[IDA, IBA], [TAS], [IDA, ISS, IBA], [TAS], [I...
# 48  [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IB...
# 49  [[TAS], [IDA, IBA], [TAS], [TAS], [IDA, IBA, T...
# 50  [[IDA, IMP], [IDA], [IMP, IBA], [IDA], [IDA, I...
