# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation   P_Value       FDR Cancer
# 0        A1BG          -0.388745  0.054892  0.142871  CCRCC
# 1        A1CF           0.146993  0.001086  0.005807  CCRCC
# 2         A2M          -0.277035  0.029705  0.089411  CCRCC
# 3        AAAS          -0.044291  0.708329  0.829294  CCRCC
# 4        AACS          -0.128218  0.065429  0.162756  CCRCC
# ...       ...                ...       ...       ...    ...
# 58209  ZSWIM8          -0.301055  0.297288  0.635725   PDAC
# 58210    ZW10          -0.190323  0.365786  0.694767   PDAC
# 58211  ZYG11B          -0.231357  0.398680  0.720323   PDAC
# 58212     ZYX          -0.232389  0.246493  0.581496   PDAC
# 58213   ZZEF1          -0.019623  0.928292  0.977865   PDAC
#
# [58214 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
sig_delta_corr = delta_correlation_df[delta_correlation_df.FDR < 0.05]
num_genes = pd.DataFrame(sig_delta_corr.groupby('Gene').size())
sig_genes = num_genes[num_genes[0] >=3].index
sig_delta_corr = sig_delta_corr[sig_delta_corr.Gene.isin(sig_genes)]
sig_delta_corr = sig_delta_corr.groupby('Gene').mean()
sig_delta_corr['Delta_Correlation'] = abs(sig_delta_corr.Delta_Correlation)
sig_delta_corr = sig_delta_corr.sort_values('Delta_Correlation', ascending = False)
sig_delta_corr.reset_index(inplace = True)
genes = list(sig_delta_corr.Gene)
pathway_enrichment = gp.profile(organism='hsapiens', query = genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])
pathway_enrichment.to_csv('combinded_GO_pathway_enrichment_df.csv', index = False)

# %%
pathway_enrichment
# Out:
#    source      native                                               name  \
# 0   GO:BP  GO:0000278                                 mitotic cell cycle
# 1   GO:BP  GO:1903047                         mitotic cell cycle process
# 2   GO:BP  GO:0022402                                 cell cycle process
# 3   GO:BP  GO:0007049                                         cell cycle
# 4   GO:BP  GO:0000075                    cell cycle checkpoint signaling
# 5   GO:BP  GO:0006271  DNA strand elongation involved in DNA replication
# 6   GO:BP  GO:0007093            mitotic cell cycle checkpoint signaling
# 7   GO:BP  GO:0007052                       mitotic spindle organization
# 8   GO:BP  GO:0033260                            nuclear DNA replication
# 9   GO:BP  GO:0140014                           mitotic nuclear division
# 10  GO:BP  GO:0044786                         cell cycle DNA replication
# 11  GO:BP  GO:0051276                            chromosome organization
# 12  GO:BP  GO:1902850  microtubule cytoskeleton organization involved...
# 13  GO:BP  GO:0007051                               spindle organization
# 14  GO:BP  GO:0000819                       sister chromatid segregation
# 15  GO:BP  GO:0000070               mitotic sister chromatid segregation
# 16  GO:BP  GO:0006281                                         DNA repair
# 17  GO:BP  GO:0007059                             chromosome segregation
# 18  GO:BP  GO:0006974           cellular response to DNA damage stimulus
# 19  GO:BP  GO:0022616                              DNA strand elongation
# 20  GO:BP  GO:0044282                   small molecule catabolic process
# 21  GO:BP  GO:0044770                        cell cycle phase transition
# 22  GO:BP  GO:0044772                mitotic cell cycle phase transition
# 23  GO:BP  GO:0048285                                  organelle fission
# 24  GO:BP  GO:1901988  negative regulation of cell cycle phase transi...
# 25  GO:BP  GO:0000280                                   nuclear division
# 26  GO:BP  GO:0051983               regulation of chromosome segregation
# 27  GO:BP  GO:0000077                    DNA damage checkpoint signaling
# 28  GO:BP  GO:1901991  negative regulation of mitotic cell cycle phas...
# 29  GO:BP  GO:0098813                     nuclear chromosome segregation
# 30  GO:BP  GO:0000281                                mitotic cytokinesis
# 31  GO:BP  GO:0006396                                     RNA processing
# 32  GO:BP  GO:0006399                             tRNA metabolic process
# 33  GO:BP  GO:0042770      signal transduction in response to DNA damage
# 34  GO:BP  GO:0031570                 DNA integrity checkpoint signaling
# 35  GO:BP  GO:0045071    negative regulation of viral genome replication
# 36  GO:BP  GO:0000959                mitochondrial RNA metabolic process
# 37  GO:BP  GO:0006261                      DNA-dependent DNA replication
# 38  GO:BP  GO:0006259                              DNA metabolic process
# 39  GO:BP  GO:0046112                    nucleobase biosynthetic process
# 40  GO:BP  GO:0033047  regulation of mitotic sister chromatid segrega...
# 41  GO:BP  GO:0045930          negative regulation of mitotic cell cycle
# 42  GO:BP  GO:0010948          negative regulation of cell cycle process
# 43  GO:BP  GO:1902969                            mitotic DNA replication
# 44  GO:BP  GO:0006260                                    DNA replication
# 45  GO:BP  GO:1902299  pre-replicative complex assembly involved in c...
# 46  GO:BP  GO:0006267  pre-replicative complex assembly involved in n...
# 47  GO:BP  GO:0051304                              chromosome separation
# 48  GO:BP  GO:0009123         nucleoside monophosphate metabolic process
# 49  GO:BP  GO:0009112                       nucleobase metabolic process
# 50  GO:BP  GO:0051726                           regulation of cell cycle
# 51  GO:BP  GO:1905818                regulation of chromosome separation
# 52  GO:BP  GO:0044839                   cell cycle G2/M phase transition
# 53  GO:BP  GO:0033045         regulation of sister chromatid segregation
#
#          p_value  significant  \
# 0   2.188050e-09         True
# 1   1.342106e-07         True
# 2   1.277708e-06         True
# 3   1.745237e-06         True
# 4   6.374500e-06         True
# 5   8.450717e-06         True
# 6   9.830076e-06         True
# 7   1.185427e-05         True
# 8   1.307086e-05         True
# 9   1.523851e-05         True
# 10  2.296368e-05         True
# 11  3.795553e-05         True
# 12  4.254541e-05         True
# 13  4.417909e-05         True
# 14  9.434288e-05         True
# 15  2.147492e-04         True
# 16  3.855479e-04         True
# 17  4.185177e-04         True
# 18  6.108937e-04         True
# 19  6.908457e-04         True
# 20  1.162688e-03         True
# 21  1.478687e-03         True
# 22  1.793018e-03         True
# 23  2.161535e-03         True
# 24  2.243535e-03         True
# 25  2.955275e-03         True
# 26  3.706343e-03         True
# 27  4.332099e-03         True
# 28  4.998286e-03         True
# 29  6.453873e-03         True
# 30  7.840775e-03         True
# 31  8.101647e-03         True
# 32  8.248848e-03         True
# 33  8.993000e-03         True
# 34  9.478352e-03         True
# 35  9.895047e-03         True
# 36  1.225662e-02         True
# 37  1.488808e-02         True
# 38  1.660163e-02         True
# 39  1.663021e-02         True
# 40  1.715667e-02         True
# 41  1.862841e-02         True
# 42  2.009578e-02         True
# 43  2.150296e-02         True
# 44  2.243666e-02         True
# 45  2.459450e-02         True
# 46  2.459450e-02         True
# 47  2.806321e-02         True
# 48  3.025641e-02         True
# 49  3.613591e-02         True
# 50  3.657024e-02         True
# 51  3.815505e-02         True
# 52  3.946021e-02         True
# 53  4.558942e-02         True
#
#                                           description  term_size  query_size  \
# 0   "Progression through the phases of the mitotic...        794         228
# 1   "A process that is part of the mitotic cell cy...        704         789
# 2   "The cellular process that ensures successive ...        972         792
# 3   "The progression of biochemical and morphologi...       1146         673
# 4   "A signaling process that controls cell cycle ...        146         234
# 5   "The process in which an existing DNA strand i...         18        1670
# 6   "A signaling process that ensures accurate chr...        122         228
# 7   "A process that is carried out at the cellular...        172         228
# 8   "The DNA-dependent DNA replication that occurs...         56         753
# 9   "A mitotic cell cycle process comprising the s...        271         506
# 10  "The DNA-dependent DNA replication that takes ...         57        1182
# 11  "A process that is carried out at the cellular...        824         817
# 12  "Any microtubule cytoskeleton organization tha...        183         228
# 13  "A process that is carried out at the cellular...        213         409
# 14  "The cell cycle process in which sister chroma...        165         493
# 15  "The cell cycle process in which replicated ho...        143         486
# 16  "The process of restoring DNA after damage. Ge...        401         249
# 17  "The process in which genetic material, in the...        232         748
# 18  "Any process that results in a change in state...        630         249
# 19  "The DNA metabolic process in which an existin...         23        1670
# 20  "The chemical reactions and pathways resulting...        327        3848
# 21  "The cell cycle process by which a cell commit...        473         243
# 22  "The cell cycle process by which a cell commit...        418         228
# 23  "The creation of two or more organelles by div...        359         486
# 24  "Any process that stops, prevents or reduces t...        224         234
# 25  "The division of a cell nucleus into two nucle...        319         486
# 26  "Any process that modulates the frequency, rat...         67         435
# 27  "A signal transduction process that contribute...        101         234
# 28  "Any process that stops, prevents or reduces t...        185         228
# 29  "The process in which genetic material, in the...        193         748
# 30  "A cell cycle process that results in the divi...         63        2618
# 31  "Any process involved in the conversion of one...        816         915
# 32  "The chemical reactions and pathways involving...        139        1821
# 33  "A cascade of processes induced by the detecti...        141         234
# 34  "A signaling process that controls cell cycle ...        107         234
# 35  "Any process that stops, prevents, or reduces ...         42        3608
# 36  "The chemical reactions and pathways involving...         36        1861
# 37  "A DNA replication process that uses parental ...        180         956
# 38  "Any cellular metabolic process involving deox...        641        1189
# 39  "The chemical reactions and pathways resulting...         14        2566
# 40  "Any process that modulates the frequency, rat...         35         608
# 41  "Any process that stops, prevents or reduces t...        216         228
# 42  "Any process that decreases the rate, frequenc...        275         234
# 43  "Any nuclear DNA replication that is involved ...         11         956
# 44  "The cellular metabolic process in which a cel...        247        1025
# 45  "Any pre-replicative complex assembly that is ...          7        1182
# 46  "The aggregation, arrangement and bonding toge...          7        1182
# 47  "The cell cycle process in which paired chromo...         67         608
# 48  "The chemical reactions and pathways involving...         33        3471
# 49  "The chemical reactions and pathways involving...         21        2566
# 50  "Any process that modulates the rate or extent...        738         243
# 51  "Any process that modulates the frequency, rat...         54         409
# 52  "The cell cycle process by which a cell in G2 ...        219         228
# 53  "Any process that modulates the frequency, rat...         55         409
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                  55                  12487   0.241228  0.069270  query_1
# 1                 109                  12487   0.138150  0.154830  query_1
# 2                 140                  12487   0.176768  0.144033  query_1
# 3                 140                  12487   0.208024  0.122164  query_1
# 4                  20                  12487   0.085470  0.136986  query_1
# 5                  15                  12487   0.008982  0.833333  query_1
# 6                  18                  12487   0.078947  0.147541  query_1
# 7                  20                  12487   0.087719  0.116279  query_1
# 8                  20                  12487   0.026560  0.357143  query_1
# 9                  40                  12487   0.079051  0.147601  query_1
# 10                 25                  12487   0.021151  0.438596  query_1
# 11                120                  12487   0.146879  0.145631  query_1
# 12                 20                  12487   0.087719  0.109290  query_1
# 13                 29                  12487   0.070905  0.136150  query_1
# 14                 29                  12487   0.058824  0.175758  query_1
# 15                 26                  12487   0.053498  0.181818  query_1
# 16                 32                  12487   0.128514  0.079800  query_1
# 17                 46                  12487   0.061497  0.198276  query_1
# 18                 41                  12487   0.164659  0.065079  query_1
# 19                 16                  12487   0.009581  0.695652  query_1
# 20                163                  12487   0.042360  0.498471  query_1
# 21                 34                  12487   0.139918  0.071882  query_1
# 22                 30                  12487   0.131579  0.071770  query_1
# 23                 45                  12487   0.092593  0.125348  query_1
# 24                 22                  12487   0.094017  0.098214  query_1
# 25                 42                  12487   0.086420  0.131661  query_1
# 26                 15                  12487   0.034483  0.223881  query_1
# 27                 14                  12487   0.059829  0.138614  query_1
# 28                 19                  12487   0.083333  0.102703  query_1
# 29                 39                  12487   0.052139  0.202073  query_1
# 30                 34                  12487   0.012987  0.539683  query_1
# 31                108                  12487   0.118033  0.132353  query_1
# 32                 50                  12487   0.027457  0.359712  query_1
# 33                 16                  12487   0.068376  0.113475  query_1
# 34                 14                  12487   0.059829  0.130841  query_1
# 35                 34                  12487   0.009424  0.809524  query_1
# 36                 21                  12487   0.011284  0.583333  query_1
# 37                 38                  12487   0.039749  0.211111  query_1
# 38                122                  12487   0.102607  0.190328  query_1
# 39                 12                  12487   0.004677  0.857143  query_1
# 40                 12                  12487   0.019737  0.342857  query_1
# 41                 20                  12487   0.087719  0.092593  query_1
# 42                 23                  12487   0.098291  0.083636  query_1
# 43                  8                  12487   0.008368  0.727273  query_1
# 44                 49                  12487   0.047805  0.198381  query_1
# 45                  7                  12487   0.005922  1.000000  query_1
# 46                  7                  12487   0.005922  1.000000  query_1
# 47                 17                  12487   0.027961  0.253731  query_1
# 48                 24                  12487   0.006914  0.727273  query_1
# 49                 15                  12487   0.005846  0.714286  query_1
# 50                 42                  12487   0.172840  0.056911  query_1
# 51                 12                  12487   0.029340  0.222222  query_1
# 52                 18                  12487   0.078947  0.082192  query_1
# 53                 12                  12487   0.029340  0.218182  query_1
#
#                                              parents  \
# 0                                       [GO:0007049]
# 1                           [GO:0000278, GO:0022402]
# 2                           [GO:0007049, GO:0009987]
# 3                                       [GO:0009987]
# 4                           [GO:0035556, GO:1901988]
# 5                           [GO:0006261, GO:0022616]
# 6               [GO:0000075, GO:0045930, GO:1903047]
# 7                           [GO:0007051, GO:1902850]
# 8                                       [GO:0044786]
# 9                           [GO:0000280, GO:1903047]
# 10                          [GO:0006261, GO:0022402]
# 11                                      [GO:0006996]
# 12                          [GO:0000226, GO:1903047]
# 13                          [GO:0000226, GO:0022402]
# 14                          [GO:0051276, GO:0098813]
# 15              [GO:0000819, GO:0140014, GO:1903047]
# 16                          [GO:0006259, GO:0006974]
# 17                                      [GO:0009987]
# 18                                      [GO:0033554]
# 19                                      [GO:0006259]
# 20                          [GO:0009056, GO:0044281]
# 21                                      [GO:0022402]
# 22                          [GO:0044770, GO:1903047]
# 23                                      [GO:0006996]
# 24              [GO:0010948, GO:0044770, GO:1901987]
# 25                                      [GO:0048285]
# 26                          [GO:0007059, GO:0050794]
# 27                          [GO:0031570, GO:0042770]
# 28  [GO:0044772, GO:0045930, GO:1901988, GO:1901990]
# 29                          [GO:0007059, GO:0022402]
# 30                          [GO:0061640, GO:1903047]
# 31                          [GO:0010467, GO:0016070]
# 32                                      [GO:0034660]
# 33                          [GO:0006974, GO:0035556]
# 34                                      [GO:0000075]
# 35              [GO:0019079, GO:0045069, GO:0048525]
# 36                                      [GO:0016070]
# 37                                      [GO:0006260]
# 38                          [GO:0044260, GO:0090304]
# 39  [GO:0009112, GO:0018130, GO:1901362, GO:1901566]
# 40                          [GO:0000070, GO:0033045]
# 41              [GO:0000278, GO:0007346, GO:0045786]
# 42              [GO:0010564, GO:0022402, GO:0045786]
# 43                          [GO:0033260, GO:1903047]
# 44                                      [GO:0034645]
# 45              [GO:0022402, GO:0036388, GO:0044786]
# 46                          [GO:0033260, GO:1902299]
# 47                          [GO:0007059, GO:0022402]
# 48                                      [GO:0006753]
# 49                          [GO:0055086, GO:1901564]
# 50                          [GO:0007049, GO:0050794]
# 51              [GO:0010564, GO:0051304, GO:0051983]
# 52                                      [GO:0044770]
# 53  [GO:0000819, GO:0010564, GO:0033044, GO:0051983]
#
#                                         intersections  \
# 0   [TRIP13, ZWINT, PBK, MAPRE1, KIF11, CHEK1, NCA...
# 1   [TRIP13, ZWINT, MAPRE1, KIF11, CHEK1, NCAPD3, ...
# 2   [TRIP13, ZWINT, MAPRE1, KIF11, CHEK1, NCAPD3, ...
# 3   [TRIP13, ZWINT, PBK, MAPRE1, KIF11, CHEK1, NCA...
# 4   [TRIP13, ZWINT, CHEK1, NDC80, PCNA, USP28, BLM...
# 5   [PCNA, GINS3, GINS1, MCM3, MCM7, MCM4, GINS2, ...
# 6   [TRIP13, ZWINT, CHEK1, NDC80, PCNA, BLM, TP53,...
# 7   [ZWINT, MAPRE1, KIF11, TPX2, KIFC1, PRC1, NDC8...
# 8   [PCNA, BLM, FEN1, GINS3, RFC1, WRN, ATRX, PRIM...
# 9   [TRIP13, ZWINT, KIF11, CHEK1, NCAPD3, TPX2, KI...
# 10  [PCNA, BLM, FEN1, GINS3, RFC1, WRN, ATRX, PRIM...
# 11  [DHX36, TRIP13, ZWINT, NSD3, RIOX1, CHEK1, NCA...
# 12  [ZWINT, MAPRE1, KIF11, TPX2, KIFC1, PRC1, NDC8...
# 13  [ZWINT, MAPRE1, KIF11, TPX2, KIFC1, EZR, PRC1,...
# 14  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 15  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 16  [UBE2T, TRIP13, CHEK1, WDR70, HSF1, PCNA, PPIE...
# 17  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 18  [UBE2T, TRIP13, CHEK1, WDR70, PSMD10, HSF1, PC...
# 19  [PCNA, GINS3, GINS1, MCM3, MCM7, MCM4, GINS2, ...
# 20  [XDH, PGK1, ENTPD5, AMACR, KHK, ACAD10, GCSH, ...
# 21  [TRIP13, ZWINT, MAPRE1, CHEK1, TPX2, PSMD10, T...
# 22  [TRIP13, ZWINT, MAPRE1, CHEK1, TPX2, PSMD10, T...
# 23  [TRIP13, ZWINT, KIF11, CHEK1, NCAPD3, TPX2, KI...
# 24  [TRIP13, ZWINT, CHEK1, PSMD10, NDC80, PCNA, US...
# 25  [TRIP13, ZWINT, KIF11, CHEK1, NCAPD3, TPX2, KI...
# 26  [TRIP13, ZWINT, NDC80, KIF2C, CENPF, DLGAP5, C...
# 27  [CHEK1, PCNA, USP28, BLM, TP53, TOPBP1, CHEK2,...
# 28  [TRIP13, ZWINT, CHEK1, PSMD10, NDC80, PCNA, BL...
# 29  [TRIP13, ZWINT, NCAPD3, KIFC1, PRC1, NDC80, KI...
# 30  [INCENP, KIF23, RAB35, PLK1, CHMP1B, USP8, ANL...
# 31  [DHX36, NSUN2, ZC3H7A, WBP11, EIF6, HSF1, PPIE...
# 32  [NSUN2, SARS2, TRMT5, C9orf64, TRMT1L, ZBTB8OS...
# 33  [CHEK1, PSMD10, PCNA, USP28, BLM, TP53, TOPBP1...
# 34  [CHEK1, PCNA, USP28, BLM, TP53, TOPBP1, CHEK2,...
# 35  [HMGA2, APOBEC3B, SRPK1, ZC3HAV1, SRPK2, BST2,...
# 36  [SARS2, TFB1M, TFB2M, TRMT5, TRIT1, DARS2, TAR...
# 37  [PSMD10, STOML2, PCNA, POLB, BLM, TOPBP1, FEN1...
# 38  [UBE2T, DHX36, TRIP13, CHEK1, WDR70, TYMS, HSF...
# 39  [PAICS, CAD, GMPS, SHMT2, HPRT1, UMPS, GART, C...
# 40  [TRIP13, ZWINT, NDC80, CENPF, MAD2L1, CCNB1, A...
# 41  [TRIP13, ZWINT, CHEK1, PSMD10, NDC80, PCNA, BL...
# 42  [TRIP13, ZWINT, CHEK1, PSMD10, NDC80, PCNA, US...
# 43  [GINS3, GINS1, MCM3, MCM4, MCM6, MCM2, POLA1, ...
# 44  [CHEK1, PSMD10, STOML2, PCNA, POLB, BLM, TOPBP...
# 45         [MCM3, MCM7, MCM5, MCM4, MCM6, MCM2, ORC3]
# 46         [MCM3, MCM7, MCM5, MCM4, MCM6, MCM2, ORC3]
# 47  [TRIP13, ZWINT, NDC80, CENPF, DLGAP5, CSNK2A2,...
# 48  [PAICS, XDH, TYMS, IMPDH2, PPAT, GMPS, RFK, HP...
# 49  [PAICS, XDH, CAD, GMPS, SHMT2, HPRT1, UMPS, GA...
# 50  [TRIP13, ZWINT, MAPRE1, KIF11, CHEK1, TPX2, PS...
# 51  [TRIP13, ZWINT, NDC80, CENPF, DLGAP5, CSNK2A2,...
# 52  [MAPRE1, CHEK1, TPX2, PSMD10, PPP2R2A, BLM, TP...
# 53  [TRIP13, ZWINT, NDC80, CENPF, DLGAP5, MAD2L1, ...
#
#                                             evidences
# 0   [[IMP], [IDA, IBA, TAS], [NAS], [TAS], [IDA, I...
# 1   [[IMP], [IDA, IBA, TAS], [TAS], [IDA, IMP, IBA...
# 2   [[IMP, ISS, IBA], [IDA, IBA, TAS], [IBA, TAS],...
# 3   [[IMP, ISS, IBA], [IDA, IBA, TAS], [NAS], [IBA...
# 4   [[IMP, IBA], [IDA], [IDA, IMP], [IMP], [TAS], ...
# 5   [[IBA], [TAS], [IBA, TAS], [IBA], [IBA], [IBA]...
# 6   [[IMP], [IDA], [IMP], [IMP], [TAS], [IDA], [IM...
# 7   [[TAS], [TAS], [IDA, IMP, IBA, TAS], [IDA, ISS...
# 8   [[ISS, TAS], [TAS], [TAS], [IBA], [TAS], [TAS]...
# 9   [[IMP], [IDA, IBA], [IDA, IMP, IBA], [IDA], [I...
# 10  [[ISS, TAS], [TAS], [TAS], [IBA], [TAS], [TAS]...
# 11  [[IDA, IMP], [IMP, ISS], [IDA, IBA], [IDA, IMP...
# 12  [[TAS], [TAS], [IDA, IMP, IBA, TAS], [IDA, ISS...
# 13  [[TAS], [IBA, TAS], [IDA, IMP, IBA, TAS], [IDA...
# 14  [[IMP], [IDA, IBA], [IDA, IMP, IBA, TAS], [IMP...
# 15  [[IMP], [IDA, IBA], [IDA, IMP, IBA, TAS], [IMP...
# 16  [[IMP, TAS], [ISS], [IDA, IMP], [IBA], [IMP], ...
# 17  [[IMP, ISS], [IDA, IBA], [IDA, IMP, IBA, TAS],...
# 18  [[IMP, IBA, TAS], [ISS], [IDA, IMP, ISS], [IBA...
# 19  [[IBA], [TAS], [IBA, TAS], [IBA], [IBA], [IBA]...
# 20  [[IDA], [TAS], [TAS], [TAS], [TAS], [TAS], [IB...
# 21  [[IMP, IBA], [IDA], [TAS], [IDA, IMP], [TAS], ...
# 22  [[IMP], [IDA], [TAS], [IMP], [TAS], [TAS], [TA...
# 23  [[IMP, ISS, IBA], [IDA, IBA], [IDA, IMP, IBA],...
# 24  [[IMP, IBA], [IDA], [IDA, IMP], [TAS], [IMP], ...
# 25  [[IMP, ISS, IBA], [IDA, IBA], [IDA, IMP, IBA],...
# 26  [[IMP], [IDA], [IMP], [IMP], [NAS], [NAS], [IM...
# 27  [[IDA, IMP], [TAS], [IMP, IBA], [IDA], [IMP, T...
# 28  [[IMP], [IDA], [IMP], [TAS], [IMP], [TAS], [ID...
# 29  [[IMP, ISS], [IDA, IBA], [IDA, IMP, IBA, TAS],...
# 30  [[IMP, IBA], [IMP], [IMP], [IDA], [IMP], [IMP]...
# 31  [[IMP], [IDA, IBA, TAS], [IMP, IBA], [IBA, TAS...
# 32  [[IDA, ISS, IBA, TAS], [ISS, IBA, TAS], [IMP, ...
# 33  [[IDA, IMP], [IDA], [TAS], [IMP, IBA], [IDA], ...
# 34  [[IDA, IMP], [TAS], [IMP, IBA], [IDA], [IMP, T...
# 35  [[IDA], [IBA], [IDA], [IDA], [IDA], [IDA], [ID...
# 36  [[IBA], [IBA], [IDA, IBA, TAS], [IMP, IBA], [T...
# 37  [[TAS], [IMP], [IMP, ISS, IBA, TAS], [TAS], [I...
# 38  [[IMP, TAS], [IMP], [ISS, IBA], [IDA, IMP], [I...
# 39  [[TAS], [IDA, ISS, IBA], [TAS], [IBA], [IDA, I...
# 40  [[IMP], [IDA], [IMP], [NAS], [IDA, IMP, IBA, T...
# 41  [[IMP], [IDA], [IDA, IMP], [TAS], [IMP], [TAS]...
# 42  [[IMP, IBA], [IDA], [IDA, IMP, TAS], [TAS], [I...
# 43  [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IB...
# 44  [[TAS], [TAS], [IMP], [IMP, ISS, IBA, TAS], [T...
# 45  [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IBA]]
# 46  [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IBA]]
# 47  [[IMP], [IDA], [IMP], [NAS], [NAS], [IMP, IBA]...
# 48  [[TAS], [IDA], [IDA, IBA], [TAS], [TAS], [IDA,...
# 49  [[TAS], [IDA, IBA], [IDA, ISS, IBA], [TAS], [I...
# 50  [[IMP, IBA], [IDA], [TAS], [IMP], [IDA, IMP, T...
# 51  [[IMP], [IDA], [IMP], [NAS], [NAS], [IMP, IBA]...
# 52  [[TAS], [IMP], [TAS], [TAS], [TAS], [IDA], [TA...
# 53  [[IMP], [IDA], [IMP], [NAS], [NAS], [IDA, IMP,...
