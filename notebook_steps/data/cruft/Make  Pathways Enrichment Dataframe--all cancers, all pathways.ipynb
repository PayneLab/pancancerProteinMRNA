# %%
import pandas as pd
from gprofiler import GProfiler
gp = GProfiler(return_dataframe=True)

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR       Cancer
# 0        A1BG          -0.198013  2.451044e-01  4.045115e-01        HNSCC
# 1         A2M          -0.118384  4.480278e-01  6.091130e-01        HNSCC
# 2       A2ML1          -0.023469  2.918125e-01  4.561968e-01        HNSCC
# 3        AAAS           0.275905  1.051756e-01  2.209072e-01        HNSCC
# 4        AACS          -0.136836  1.800586e-01  3.266475e-01        HNSCC
# ...       ...                ...           ...           ...          ...
# 50684   ZWINT           1.219024  2.267627e-09  1.049863e-07  Endometrial
# 50685    ZXDC          -0.346532  2.983295e-01  5.386144e-01  Endometrial
# 50686  ZYG11B           0.768196  5.463938e-04  5.319699e-03  Endometrial
# 50687     ZYX           0.253630  2.456049e-01  4.795301e-01  Endometrial
# 50688   ZZEF1           0.176244  5.839048e-01  7.795750e-01  Endometrial
#
# [50689 rows x 5 columns]

# %%
all_pathways = []
positive_pathways = []
negative_pathways = []
for cancer in pd.unique(delta_correlation_df.Cancer):
    cancer_df = delta_correlation_df[delta_correlation_df.Cancer == cancer]
    background_genes  = list(pd.unique(cancer_df.Gene))
    cancer_df = cancer_df[cancer_df.FDR < 0.05]
    positive_cancer_df = cancer_df[cancer_df.Delta_Correlation > 0]
    negative_cancer_df = cancer_df[cancer_df.Delta_Correlation < 0]
    cancer_df['Delta_Correlation'] = abs(cancer_df['Delta_Correlation'])
    cancer_df = cancer_df.sort_values('Delta_Correlation', ascending = False)
    positive_cancer_df = positive_cancer_df.sort_values('Delta_Correlation', ascending = False)
    negative_cancer_df = negative_cancer_df.sort_values('Delta_Correlation')
    all_genes = list(cancer_df.Gene)
    positive_genes = list(positive_cancer_df.Gene)
    negative_genes = list(negative_cancer_df.Gene)
    all_cancer_pathways = gp.profile(organism='hsapiens', query = all_genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)
    all_cancer_pathways['Cancer'] = [cancer] * len(all_cancer_pathways)
    positive_cancer_pathways = gp.profile(organism='hsapiens', query = positive_genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)
    positive_cancer_pathways['Cancer'] = [cancer] * len(positive_cancer_pathways)
    negative_cancer_pathways = gp.profile(organism='hsapiens', query = negative_genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)
    negative_cancer_pathways['Cancer'] = [cancer] * len(negative_cancer_pathways)
    all_pathways.append(all_cancer_pathways)
    positive_pathways.append(positive_cancer_pathways)
    negative_pathways.append(negative_cancer_pathways)
all_pathways = pd.concat(all_pathways)    
all_pathways.to_csv('Individual_cancer_pathway_enrichment.csv', index = False)
positive_pathways = pd.concat(positive_pathways)
positive_pathways.to_csv('Positive_delta_corr_individual_cancer_pathways.csv', index = False)
negative_pathways = pd.concat(negative_pathways)
negative_pathways.to_csv('Negative_delta_corr_individual_cancer_pathways', index = False)

# %%
pd.set_option('display.max_rows', 500)

# %%
pd.unique(all_pathways.source)
# Out:
# array(['HP', 'CORUM', 'HPA', 'REAC', 'WP', 'MIRNA', 'GO:BP', 'GO:MF',
#        'KEGG', 'GO:CC'], dtype=object)

# %%
all_pathways[all_pathways.source == 'GO:BP']
# Out:
#     source      native                                               name  \
# 22   GO:BP  GO:0006261                      DNA-templated DNA replication
# 122  GO:BP  GO:0006260                                    DNA replication
# 125  GO:BP  GO:0090329        regulation of DNA-templated DNA replication
# 9    GO:BP  GO:0000727  double-strand break repair via break-induced r...
# 12   GO:BP  GO:0007059                             chromosome segregation
# 19   GO:BP  GO:0032392                               DNA geometric change
# 30   GO:BP  GO:0000278                                 mitotic cell cycle
# 31   GO:BP  GO:0032508                               DNA duplex unwinding
# 32   GO:BP  GO:0071103                            DNA conformation change
# 35   GO:BP  GO:0006268          DNA unwinding involved in DNA replication
# 44   GO:BP  GO:0000070               mitotic sister chromatid segregation
# 50   GO:BP  GO:0000819                       sister chromatid segregation
# 59   GO:BP  GO:0009123         nucleoside monophosphate metabolic process
# 60   GO:BP  GO:0098813                     nuclear chromosome segregation
# 68   GO:BP  GO:0009161     ribonucleoside monophosphate metabolic process
# 81   GO:BP  GO:1902969                            mitotic DNA replication
# 89   GO:BP  GO:1903047                         mitotic cell cycle process
# 123  GO:BP  GO:0051276                            chromosome organization
# 124  GO:BP  GO:0140014                           mitotic nuclear division
#
#       p_value  significant                                        description  \
# 22   0.001152         True  "A DNA replication process that uses parental ...
# 122  0.037516         True  "The cellular metabolic process in which a cel...
# 125  0.040067         True  "Any process that modulates the rate, frequenc...
# 9    0.000018         True  "The error-free repair of a double-strand brea...
# 12   0.000139         True  "The process in which genetic material, in the...
# 19   0.000398         True  "The process in which a transformation is indu...
# 30   0.001097         True  "Progression through the phases of the mitotic...
# 31   0.001244         True  "The process in which interchain hydrogen bond...
# 32   0.001471         True  "A cellular process that results in a change i...
# 35   0.001688         True  "The process in which interchain hydrogen bond...
# 44   0.002570         True  "The cell cycle process in which replicated ho...
# 50   0.003813         True  "The cell cycle process in which sister chroma...
# 59   0.005901         True  "The chemical reactions and pathways involving...
# 60   0.005918         True  "The process in which genetic material, in the...
# 68   0.007725         True  "The chemical reactions and pathways involving...
# 81   0.009928         True  "Any nuclear DNA replication that is involved ...
# 89   0.016599         True  "A process that is part of the mitotic cell cy...
# 123  0.043746         True  "A process that is carried out at the cellular...
# 124  0.044070         True  "A mitotic cell cycle process comprising the s...
#
#      term_size  query_size  intersection_size  effective_domain_size  \
# 22         122        3150                 71                  11402
# 122        187        1917                 68                  11402
# 125         38        1889                 22                  11402
# 9            9         554                  9                  11081
# 12         212         282                 28                  11081
# 19          44         182                 10                  11081
# 30         579          13                  9                  11081
# 31          38         182                  9                  11081
# 32          49         182                 10                  11081
# 35          20         554                 10                  11081
# 44         134         803                 33                  11081
# 50         150         803                 36                  11081
# 59          31         486                 11                  11081
# 60         173         282                 23                  11081
# 68          26         486                 10                  11081
# 81          10         877                  8                  11081
# 89         485         282                 39                  11081
# 123        542         166                 30                  11081
# 124        207         483                 31                  11081
#
#      precision    recall    query                               parents  \
# 22    0.022540  0.581967  query_1                          [GO:0006260]
# 122   0.035472  0.363636  query_1                          [GO:0006259]
# 125   0.011646  0.578947  query_1              [GO:0006261, GO:0006275]
# 9     0.016245  1.000000  query_1                          [GO:0000724]
# 12    0.099291  0.132075  query_1                          [GO:0009987]
# 19    0.054945  0.227273  query_1                          [GO:0071103]
# 30    0.692308  0.015544  query_1                          [GO:0007049]
# 31    0.049451  0.236842  query_1                          [GO:0032392]
# 32    0.054945  0.204082  query_1                          [GO:0051276]
# 35    0.018051  0.500000  query_1              [GO:0006261, GO:0032508]
# 44    0.041096  0.246269  query_1  [GO:0000819, GO:0140014, GO:1903047]
# 50    0.044832  0.240000  query_1              [GO:0051276, GO:0098813]
# 59    0.022634  0.354839  query_1                          [GO:0006753]
# 60    0.081560  0.132948  query_1              [GO:0007059, GO:0022402]
# 68    0.020576  0.384615  query_1                          [GO:0009123]
# 81    0.009122  0.800000  query_1              [GO:0033260, GO:1903047]
# 89    0.138298  0.080412  query_1              [GO:0000278, GO:0022402]
# 123   0.180723  0.055351  query_1                          [GO:0006996]
# 124   0.064182  0.149758  query_1              [GO:0000280, GO:1903047]
#
#                                          intersections  \
# 22   [MMS22L, RFC5, ZPR1, MCM10, STOML2, TIMELESS, ...
# 122  [MMS22L, RFC5, ZPR1, MCM10, STOML2, TIMELESS, ...
# 125  [RFC5, STOML2, TIMELESS, TIPIN, LIG3, GINS2, G...
# 9    [CDC45, MCM2, MCM7, GINS4, GINS2, MCM5, MCM6, ...
# 12   [CENPH, SMC2, TRIP13, ESCO2, MIS18A, KNTC1, KI...
# 19   [CDC45, ANXA1, MCM2, MCM7, RECQL5, HMGB3, TOP2...
# 30   [CDC45, CENPH, SMC2, TRIP13, MELK, WDHD1, AURK...
# 31   [CDC45, ANXA1, MCM2, MCM7, RECQL5, TOP2A, GINS...
# 32   [CDC45, ANXA1, MCM2, MCM7, RECQL5, HMGB3, TOP2...
# 35   [CDC45, MCM2, MCM7, RECQL5, GINS4, GINS2, MCM5...
# 44   [SMC2, TRIP13, KNTC1, KIFC1, KIF2C, KIF22, KIF...
# 50   [SMC2, TRIP13, ESCO2, KNTC1, KIFC1, KIF2C, KIF...
# 59   [XDH, ADSL, TYMS, PAICS, CAD, GMPR2, PFAS, GMP...
# 60   [SMC2, TRIP13, ESCO2, KNTC1, KIFC1, KIF2C, PSM...
# 68   [XDH, ADSL, PAICS, CAD, GMPR2, PFAS, GMPS, UMP...
# 81   [CDC45, MCM2, LIG1, MCM6, MCM3, MCM4, POLA1, G...
# 89   [CDC45, CENPH, SMC2, TRIP13, MELK, AURKA, ANXA...
# 123  [CDC45, CENPH, SMC2, TRIP13, ANXA1, ESCO2, MCM...
# 124  [SMC2, TRIP13, AURKA, TPX2, KNTC1, KIFC1, KIF2...
#
#                                              evidences Cancer
# 22   [[IMP, IBA], [IDA, IBA], [ISS], [IMP, IBA], [I...   LSCC
# 122  [[IMP, IBA], [IDA, IBA, NAS], [ISS], [IMP, IBA...   LSCC
# 125  [[IDA], [IMP], [IBA], [IBA, TAS], [IMP], [IDA]...   LSCC
# 9    [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IB...   LUAD
# 12   [[IBA], [IDA, IBA, TAS], [IMP, ISS], [IBA], [I...   LUAD
# 19   [[IDA], [IBA], [IDA, IBA], [IDA, IBA], [IBA], ...   LUAD
# 30   [[IBA], [IBA], [IDA, IBA, TAS], [IMP], [TAS], ...   LUAD
# 31   [[IDA], [IBA], [IDA, IBA], [IDA, IBA], [IBA], ...   LUAD
# 32   [[IDA], [IBA], [IDA, IBA], [IDA, IBA], [IBA], ...   LUAD
# 35   [[IDA], [IDA, IBA], [IDA, IBA], [IBA], [IDA], ...   LUAD
# 44   [[IDA, IBA, TAS], [IMP], [IDA, IBA], [IMP, NAS...   LUAD
# 50   [[IDA, IBA, TAS], [IMP], [IBA], [IDA, IBA], [I...   LUAD
# 59   [[IDA], [IDA, IBA], [IDA, IBA], [IDA, IBA], [I...   LUAD
# 60   [[IDA, IBA, TAS], [IMP, ISS], [IBA], [IDA, IBA...   LUAD
# 68   [[IDA], [IDA, IBA], [IDA, IBA], [IDA], [IDA], ...   LUAD
# 81   [[IBA], [IBA], [IBA], [IBA], [IBA], [IBA], [IB...   LUAD
# 89   [[IBA], [IBA], [IDA, IBA, TAS], [IMP], [TAS], ...   LUAD
# 123  [[IDA], [TAS], [IDA, IBA, TAS], [IMP, ISS], [I...   LUAD
# 124  [[IDA, IBA, TAS], [IMP], [TAS], [IDA, IBA], [I...   LUAD

# %%
pd.unique(positive_pathways.source)
# Out:
# array(['HP', 'CORUM', 'KEGG', 'HPA', 'REAC', 'WP', 'MIRNA', 'GO:BP',
#        'GO:CC', 'GO:MF'], dtype=object)

# %%
positive_pathways[positive_pathways.source == 'WP']
# Out:
#     source     native                                               name  \
# 9       WP  WP:WP2446                      Retinoblastoma gene in cancer
# 17      WP  WP:WP5213  Amino acid metabolism in triple-negative breas...
# 18      WP   WP:WP466                                    DNA replication
# 24      WP  WP:WP4752                               Base excision repair
# 44      WP  WP:WP4290            Metabolic reprogramming in colon cancer
# 49      WP   WP:WP384                      Apoptosis modulation by HSP70
# 61      WP  WP:WP4629                                 Aerobic glycolysis
# 68      WP  WP:WP4016        DNA IR-damage and cellular response via ATR
# 76      WP  WP:WP4674              Head and neck squamous cell carcinoma
# 84      WP  WP:WP5046  NAD metabolism in oncogene-induced senescence ...
# 99      WP   WP:WP531                                DNA mismatch repair
# 104     WP  WP:WP1772                 Apoptosis modulation and signaling
# 107     WP   WP:WP368  Mitochondrial long chain fatty acid beta-oxida...
# 118     WP  WP:WP2513          Nanoparticle triggered regulated necrosis
# 129     WP  WP:WP4595                 Urea cycle and associated pathways
# 1       WP   WP:WP313        Hepatocyte growth factor receptor signaling
# 3       WP  WP:WP4786  Type I collagen synthesis in the context of os...
# 3       WP  WP:WP2446                      Retinoblastoma gene in cancer
# 23      WP  WP:WP4225         Pyrimidine metabolism and related diseases
# 38      WP   WP:WP466                                    DNA replication
# 49      WP  WP:WP4584     Biomarkers for pyrimidine metabolism disorders
# 56      WP   WP:WP179                                         Cell cycle
# 57      WP  WP:WP4016        DNA IR-damage and cellular response via ATR
# 108     WP  WP:WP4224            Purine metabolism and related disorders
# 110     WP  WP:WP4022                              Pyrimidine metabolism
# 114     WP  WP:WP4753                         Nucleotide excision repair
# 119     WP  WP:WP4946                  DNA repair pathways, full network
# 120     WP   WP:WP531                                DNA mismatch repair
# 0       WP   WP:WP357                            Fatty acid biosynthesis
# 1       WP   WP:WP368  Mitochondrial long chain fatty acid beta-oxida...
# 11      WP  WP:WP5220       Metabolic reprogramming in pancreatic cancer
# 12      WP  WP:WP2446                      Retinoblastoma gene in cancer
#
#           p_value  significant  \
# 9    1.116740e-04         True
# 17   4.878876e-04         True
# 18   5.321233e-04         True
# 24   1.121120e-03         True
# 44   5.439309e-03         True
# 49   6.615788e-03         True
# 61   1.310997e-02         True
# 68   1.578617e-02         True
# 76   1.819447e-02         True
# 84   2.264450e-02         True
# 99   2.494196e-02         True
# 104  2.734874e-02         True
# 107  3.116818e-02         True
# 118  3.736875e-02         True
# 129  4.167006e-02         True
# 1    1.682010e-02         True
# 3    2.993333e-02         True
# 3    2.398374e-07         True
# 23   5.371688e-04         True
# 38   1.968507e-03         True
# 49   3.296489e-03         True
# 56   4.847358e-03         True
# 57   4.926331e-03         True
# 108  3.248401e-02         True
# 110  3.314245e-02         True
# 114  3.474171e-02         True
# 119  3.878812e-02         True
# 120  4.114045e-02         True
# 0    2.463258e-03         True
# 1    2.547657e-03         True
# 11   3.687875e-02         True
# 12   4.210725e-02         True
#
#                                            description  term_size  query_size  \
# 9                        Retinoblastoma gene in cancer         80        4703
# 17   Amino acid metabolism in triple-negative breas...          7         508
# 18                                     DNA replication         37        3130
# 24                                Base excision repair         29        5375
# 44             Metabolic reprogramming in colon cancer         39         712
# 49                       Apoptosis modulation by HSP70         14         124
# 61                                  Aerobic glycolysis         12        5250
# 68         DNA IR-damage and cellular response via ATR         70         647
# 76               Head and neck squamous cell carcinoma         65          40
# 84   NAD metabolism in oncogene-induced senescence ...         22        1300
# 99                                 DNA mismatch repair         22        3130
# 104                 Apoptosis modulation and signaling         71          37
# 107  Mitochondrial long chain fatty acid beta-oxida...         16        6728
# 118          Nanoparticle triggered regulated necrosis         11         124
# 129                 Urea cycle and associated pathways         23         877
# 1          Hepatocyte growth factor receptor signaling         32        1933
# 3    Type I collagen synthesis in the context of os...         23        2025
# 3                        Retinoblastoma gene in cancer         75        1326
# 23          Pyrimidine metabolism and related diseases         15         502
# 38                                     DNA replication         33         773
# 49      Biomarkers for pyrimidine metabolism disorders         13         502
# 56                                          Cell cycle         93          57
# 57         DNA IR-damage and cellular response via ATR         66        1143
# 108            Purine metabolism and related disorders         18         163
# 110                              Pyrimidine metabolism         68         502
# 114                         Nucleotide excision repair         42        1302
# 119                  DNA repair pathways, full network        100        1337
# 120                                DNA mismatch repair         22        3116
# 0                              Fatty acid biosynthesis         20        1492
# 1    Mitochondrial long chain fatty acid beta-oxida...         16        1239
# 11        Metabolic reprogramming in pancreatic cancer         36         174
# 12                       Retinoblastoma gene in cancer         63        1520
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 9                   58                  11402   0.012333  0.725000  query_1
# 17                   5                  11402   0.009843  0.714286  query_1
# 18                  25                  11402   0.007987  0.675676  query_1
# 24                  26                  11402   0.004837  0.896552  query_1
# 44                  11                  11402   0.015449  0.282051  query_1
# 49                   4                  11402   0.032258  0.285714  query_1
# 61                  12                  11402   0.002286  1.000000  query_1
# 68                  14                  11402   0.021638  0.200000  query_1
# 76                   4                  11402   0.100000  0.061538  query_1
# 84                  10                  11402   0.007692  0.454545  query_1
# 99                  15                  11402   0.004792  0.681818  query_1
# 104                  4                  11402   0.108108  0.056338  query_1
# 107                 16                  11402   0.002378  1.000000  query_1
# 118                  3                  11402   0.024194  0.272727  query_1
# 129                  8                  11402   0.009122  0.347826  query_1
# 1                   17                   9719   0.008795  0.531250  query_1
# 3                   16                   9719   0.007901  0.695652  query_1
# 3                   32                  11081   0.024133  0.426667  query_1
# 23                   7                  11081   0.013944  0.466667  query_1
# 38                  12                  11081   0.015524  0.363636  query_1
# 49                   6                  11081   0.011952  0.461538  query_1
# 56                   6                  11081   0.105263  0.064516  query_1
# 57                  21                  11081   0.018373  0.318182  query_1
# 108                  4                  11081   0.024540  0.222222  query_1
# 110                 12                  11081   0.023904  0.176471  query_1
# 114                 14                  11081   0.010753  0.333333  query_1
# 119                 28                  11081   0.020942  0.280000  query_1
# 120                 15                  11081   0.004814  0.681818  query_1
# 0                   13                   8698   0.008713  0.650000  query_1
# 1                   10                   8698   0.008071  0.625000  query_1
# 11                   6                   8698   0.034483  0.166667  query_1
# 12                  29                   8698   0.019079  0.460317  query_1
#
#          parents                                      intersections  \
# 9    [WP:000000]  [TP53, RFC5, SKP2, SMC2, PRIM1, CDC45, TFDP1, ...
# 17   [WP:000000]             [SLC2A1, PSPH, SLC7A11, SLC1A5, PSAT1]
# 18   [WP:000000]  [RFC5, MCM10, PRIM1, CDC45, ORC5, POLA1, POLE,...
# 24   [WP:000000]  [UNG, LIG3, POLE, PARP2, TDG, APEX2, POLE3, LI...
# 44   [WP:000000]  [IDH3A, SLC2A1, PGK1, PSPH, GLUD1, GOT2, SLC1A...
# 49   [WP:000000]                     [RIPK1, NFKB1, FADD, TNFRSF1A]
# 61   [WP:000000]  [SLC2A1, PGK1, TPI1, GAPDH, HK1, LDHA, PFKM, P...
# 68   [WP:000000]  [FANCI, TP53, FANCD2, CHEK2, BRCA1, CDC45, TOP...
# 76   [WP:000000]                        [FGFR3, TP53, NFKB1, KEAP1]
# 84   [WP:000000]  [TP53, SLC2A1, RELA, GOT1, GOT2, ELAVL1, SIRT1...
# 99   [WP:000000]  [RFC5, MSH2, POLE, RFC1, RFC4, POLE3, RFC2, EX...
# 104  [WP:000000]                         [RIPK1, BAG3, TP53, NFKB1]
# 107  [WP:000000]  [ECI1, ACADM, ACSF2, ACADL, HADHA, CPT1A, EHHA...
# 118  [WP:000000]                            [RIPK1, FADD, TNFRSF1A]
# 129  [WP:000000]  [GLUD1, CPS1, GOT1, GOT2, SLC25A12, PYCR1, FH,...
# 1    [WP:000000]  [RAP1A, SRC, RAP1B, PAK1, ITGA1, PTK2, CRKL, P...
# 3    [WP:000000]  [PLOD1, LOX, ITPR1, PLOD2, P4HA2, BMP1, P4HA1,...
# 3    [WP:000000]  [CDC45, SMC2, CCNB2, DHFR, MCM7, TYMS, KIF4A, ...
# 23   [WP:000000]           [TYMS, CAD, DPYD, RRM2, UMPS, TK2, RRM1]
# 38   [WP:000000]  [CDC45, MCM2, MCM7, MCM5, GMNN, PRIM1, MCM6, M...
# 49   [WP:000000]                [TYMS, DPYD, RRM2, UMPS, TK2, RRM1]
# 56   [WP:000000]           [CDC45, YWHAZ, CCNB2, MCM2, CDC20, MCM7]
# 57   [WP:000000]  [CDC45, MCM2, RECQL5, BRCA1, CDK1, FANCI, TOPB...
# 108  [WP:000000]                           [XDH, ADSL, PAICS, PFAS]
# 110  [WP:000000]  [DCTPP1, TYMS, CAD, DTYMK, TK1, DPYD, ENPP3, R...
# 114  [WP:000000]  [LIG1, XPA, CUL4A, POLE2, RFC1, PCNA, GTF2H1, ...
# 119  [WP:000000]  [BRCA1, FANCI, PMS2, LIG1, XPA, RAD54B, CHEK1,...
# 120  [WP:000000]  [PMS2, LIG1, POLE2, RFC1, PCNA, RFC3, RFC5, MS...
# 0    [WP:000000]  [ACAA2, MECR, PECR, ECH1, ECHS1, DECR1, ACSL4,...
# 1    [WP:000000]  [ACADS, PECR, CPT1A, EHHADH, ACADL, ECI1, ACSL...
# 11   [WP:000000]        [GOT1, SLC16A1, SLC7A5, HK2, SLC1A5, BCAT2]
# 12   [WP:000000]  [CDK1, CHEK1, CCNB1, TYMS, CCNA2, PRIM1, ANLN,...
#
#                                              evidences       Cancer
# 9    [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 17                      [[WP], [WP], [WP], [WP], [WP]]         LSCC
# 18   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 24   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 44   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 49                            [[WP], [WP], [WP], [WP]]         LSCC
# 61   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 68   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 76                            [[WP], [WP], [WP], [WP]]         LSCC
# 84   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 99   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 104                           [[WP], [WP], [WP], [WP]]         LSCC
# 107  [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LSCC
# 118                                 [[WP], [WP], [WP]]         LSCC
# 129   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP]]         LSCC
# 1    [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...        CCRCC
# 3    [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...        CCRCC
# 3    [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 23          [[WP], [WP], [WP], [WP], [WP], [WP], [WP]]         LUAD
# 38   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 49                [[WP], [WP], [WP], [WP], [WP], [WP]]         LUAD
# 56                [[WP], [WP], [WP], [WP], [WP], [WP]]         LUAD
# 57   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 108                           [[WP], [WP], [WP], [WP]]         LUAD
# 110  [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 114  [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 119  [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 120  [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...         LUAD
# 0    [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...  Endometrial
# 1    [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...  Endometrial
# 11                [[WP], [WP], [WP], [WP], [WP], [WP]]  Endometrial
# 12   [[WP], [WP], [WP], [WP], [WP], [WP], [WP], [WP...  Endometrial

# %%
pd.unique(negative_pathways.source)
# Out:
# array(['KEGG', 'GO:CC', 'REAC', 'WP', 'GO:BP', 'HP', 'GO:MF', 'CORUM',
#        'HPA'], dtype=object)

# %%
negative_pathways[negative_pathways.source == 'KEGG']
# Out:
#     source      native                                               name  \
# 0     KEGG  KEGG:05415                            Diabetic cardiomyopathy
# 10    KEGG  KEGG:00190                          Oxidative phosphorylation
# 16    KEGG  KEGG:05208  Chemical carcinogenesis - reactive oxygen species
# 17    KEGG  KEGG:04714                                      Thermogenesis
# 30    KEGG  KEGG:05020                                      Prion disease
# 35    KEGG  KEGG:05014                      Amyotrophic lateral sclerosis
# 36    KEGG  KEGG:05012                                  Parkinson disease
# 37    KEGG  KEGG:05016                                 Huntington disease
# 43    KEGG  KEGG:05010                                  Alzheimer disease
# 74    KEGG  KEGG:05022  Pathways of neurodegeneration - multiple diseases
# 77    KEGG  KEGG:04260                         Cardiac muscle contraction
# 92    KEGG  KEGG:04932                  Non-alcoholic fatty liver disease
# 127   KEGG  KEGG:04723               Retrograde endocannabinoid signaling
# 161   KEGG  KEGG:05171                     Coronavirus disease - COVID-19
# 176   KEGG  KEGG:00620                                Pyruvate metabolism
# 185   KEGG  KEGG:05410                        Hypertrophic cardiomyopathy
# 191   KEGG  KEGG:03010                                           Ribosome
# 194   KEGG  KEGG:05414                             Dilated cardiomyopathy
# 199   KEGG  KEGG:00010                       Glycolysis / Gluconeogenesis
# 216   KEGG  KEGG:00071                             Fatty acid degradation
# 30    KEGG  KEGG:03010                                           Ribosome
# 35    KEGG  KEGG:05171                     Coronavirus disease - COVID-19
# 15    KEGG  KEGG:01200                                  Carbon metabolism
# 19    KEGG  KEGG:00280         Valine, leucine and isoleucine degradation
# 25    KEGG  KEGG:01100                                 Metabolic pathways
# 48    KEGG  KEGG:00190                          Oxidative phosphorylation
# 52    KEGG  KEGG:00020                          Citrate cycle (TCA cycle)
# 78    KEGG  KEGG:00630            Glyoxylate and dicarboxylate metabolism
# 81    KEGG  KEGG:00640                              Propanoate metabolism
# 96    KEGG  KEGG:00071                             Fatty acid degradation
# 113   KEGG  KEGG:00260           Glycine, serine and threonine metabolism
# 117   KEGG  KEGG:00620                                Pyruvate metabolism
# 139   KEGG  KEGG:05415                            Diabetic cardiomyopathy
# 146   KEGG  KEGG:04978                                 Mineral absorption
# 156   KEGG  KEGG:04146                                         Peroxisome
# 166   KEGG  KEGG:00010                       Glycolysis / Gluconeogenesis
# 180   KEGG  KEGG:00650                               Butanoate metabolism
# 206   KEGG  KEGG:04714                                      Thermogenesis
# 217   KEGG  KEGG:04964            Proximal tubule bicarbonate reclamation
# 233   KEGG  KEGG:05012                                  Parkinson disease
# 244   KEGG  KEGG:04966                     Collecting duct acid secretion
# 10    KEGG  KEGG:04721                             Synaptic vesicle cycle
# 17    KEGG  KEGG:04145                                          Phagosome
# 18    KEGG  KEGG:04150                             mTOR signaling pathway
# 20    KEGG  KEGG:05110                          Vibrio cholerae infection
# 21    KEGG  KEGG:04966                     Collecting duct acid secretion
# 30    KEGG  KEGG:00190                          Oxidative phosphorylation
# 33    KEGG  KEGG:05120  Epithelial cell signaling in Helicobacter pylo...
# 34    KEGG  KEGG:05165                     Human papillomavirus infection
# 42    KEGG  KEGG:05323                               Rheumatoid arthritis
# 45    KEGG  KEGG:04142                                           Lysosome
#
#       p_value significant                                        description  \
# 0         0.0        True                            Diabetic cardiomyopathy
# 10        0.0        True                          Oxidative phosphorylation
# 16        0.0        True  Chemical carcinogenesis - reactive oxygen species
# 17        0.0        True                                      Thermogenesis
# 30        0.0        True                                      Prion disease
# 35        0.0        True                      Amyotrophic lateral sclerosis
# 36        0.0        True                                  Parkinson disease
# 37        0.0        True                                 Huntington disease
# 43   0.000001        True                                  Alzheimer disease
# 74   0.000011        True  Pathways of neurodegeneration - multiple diseases
# 77   0.000014        True                         Cardiac muscle contraction
# 92   0.000047        True                  Non-alcoholic fatty liver disease
# 127  0.001368        True               Retrograde endocannabinoid signaling
# 161  0.007178        True                     Coronavirus disease - COVID-19
# 176  0.014813        True                                Pyruvate metabolism
# 185  0.017688        True                        Hypertrophic cardiomyopathy
# 191  0.023149        True                                           Ribosome
# 194  0.026357        True                             Dilated cardiomyopathy
# 199  0.030874        True                       Glycolysis / Gluconeogenesis
# 216  0.043713        True                             Fatty acid degradation
# 30        0.0        True                                           Ribosome
# 35        0.0        True                     Coronavirus disease - COVID-19
# 15        0.0        True                                  Carbon metabolism
# 19        0.0        True         Valine, leucine and isoleucine degradation
# 25        0.0        True                                 Metabolic pathways
# 48        0.0        True                          Oxidative phosphorylation
# 52        0.0        True                          Citrate cycle (TCA cycle)
# 78   0.000004        True            Glyoxylate and dicarboxylate metabolism
# 81   0.000005        True                              Propanoate metabolism
# 96   0.000022        True                             Fatty acid degradation
# 113  0.000061        True           Glycine, serine and threonine metabolism
# 117  0.000069        True                                Pyruvate metabolism
# 139  0.000459        True                            Diabetic cardiomyopathy
# 146  0.000625        True                                 Mineral absorption
# 156  0.000984        True                                         Peroxisome
# 166  0.001433        True                       Glycolysis / Gluconeogenesis
# 180  0.003232        True                               Butanoate metabolism
# 206  0.009413        True                                      Thermogenesis
# 217  0.012279        True            Proximal tubule bicarbonate reclamation
# 233  0.022872        True                                  Parkinson disease
# 244  0.030259        True                     Collecting duct acid secretion
# 10   0.000332        True                             Synaptic vesicle cycle
# 17   0.001626        True                                          Phagosome
# 18   0.001691        True                             mTOR signaling pathway
# 20   0.002683        True                          Vibrio cholerae infection
# 21   0.002831        True                     Collecting duct acid secretion
# 30   0.007763        True                          Oxidative phosphorylation
# 33   0.011269        True  Epithelial cell signaling in Helicobacter pylo...
# 34   0.013208        True                     Human papillomavirus infection
# 42   0.023681        True                               Rheumatoid arthritis
# 45   0.033426        True                                           Lysosome
#
#     term_size query_size intersection_size effective_domain_size precision  \
# 0         149        242                31                  9747  0.128099
# 10         83        132                17                  9747  0.128788
# 16        156        132                20                  9747  0.151515
# 17        143        132                20                  9747  0.151515
# 30        179        132                19                  9747  0.143939
# 35        243        132                21                  9747  0.159091
# 36        168        132                18                  9747  0.136364
# 37        192        132                19                  9747  0.143939
# 43        237        132                21                  9747  0.159091
# 74        293        132                22                  9747  0.166667
# 77         49        314                14                  9747  0.044586
# 92        110        132                12                  9747  0.090909
# 127        80        131                10                  9747  0.076336
# 161       157        125                11                  9747     0.088
# 176        40        332                 8                  9747  0.024096
# 185        63        328                11                  9747  0.033537
# 191        97        125                 8                  9747     0.064
# 194        62        328                11                  9747  0.033537
# 199        52        332                 9                  9747  0.027108
# 216        36        332                 7                  9747  0.021084
# 30         97        131                16                 11402  0.122137
# 35        163        153                18                 11402  0.117647
# 15         99        708                36                  9719  0.050847
# 19         44        724                23                  9719  0.031768
# 25       1023        763               188                  9719  0.246396
# 48         88        489                26                  9719   0.05317
# 52         28        700                15                  9719  0.021429
# 78         28        673                13                  9719  0.019316
# 81         28        666                13                  9719   0.01952
# 96         36        753                15                  9719   0.01992
# 113        32        763                14                  9719  0.018349
# 117        42        719                15                  9719  0.020862
# 139       151        634                30                  9719  0.047319
# 146        36        674                15                  9719  0.022255
# 156        67        753                19                  9719  0.025232
# 166        55        719                16                  9719  0.022253
# 180        21        751                10                  9719  0.013316
# 206       149        358                20                  9719  0.055866
# 217        15        674                 8                  9719  0.011869
# 233       176        358                21                  9719  0.058659
# 244        21        496                 7                  9719  0.014113
# 10         44         98                 7                 11081  0.071429
# 17        124        184                11                 11081  0.059783
# 18        119         41                 6                 11081  0.146341
# 20         39         41                 4                 11081  0.097561
# 21         18        159                 5                 11081  0.031447
# 30         84         98                 7                 11081  0.071429
# 33         57         41                 4                 11081  0.097561
# 34        240         41                 7                 11081  0.170732
# 42         62        161                 7                 11081  0.043478
# 45        111        116                 7                 11081  0.060345
#
#        recall    query       parents  \
# 0    0.208054  query_1  [KEGG:00000]
# 10   0.204819  query_1  [KEGG:00000]
# 16   0.128205  query_1  [KEGG:00000]
# 17    0.13986  query_1  [KEGG:00000]
# 30   0.106145  query_1  [KEGG:00000]
# 35    0.08642  query_1  [KEGG:00000]
# 36   0.107143  query_1  [KEGG:00000]
# 37   0.098958  query_1  [KEGG:00000]
# 43   0.088608  query_1  [KEGG:00000]
# 74   0.075085  query_1  [KEGG:00000]
# 77   0.285714  query_1  [KEGG:00000]
# 92   0.109091  query_1  [KEGG:00000]
# 127     0.125  query_1  [KEGG:00000]
# 161  0.070064  query_1  [KEGG:00000]
# 176       0.2  query_1  [KEGG:00000]
# 185  0.174603  query_1  [KEGG:00000]
# 191  0.082474  query_1  [KEGG:00000]
# 194  0.177419  query_1  [KEGG:00000]
# 199  0.173077  query_1  [KEGG:00000]
# 216  0.194444  query_1  [KEGG:00000]
# 30   0.164948  query_1  [KEGG:00000]
# 35   0.110429  query_1  [KEGG:00000]
# 15   0.363636  query_1  [KEGG:00000]
# 19   0.522727  query_1  [KEGG:00000]
# 25   0.183773  query_1  [KEGG:00000]
# 48   0.295455  query_1  [KEGG:00000]
# 52   0.535714  query_1  [KEGG:00000]
# 78   0.464286  query_1  [KEGG:00000]
# 81   0.464286  query_1  [KEGG:00000]
# 96   0.416667  query_1  [KEGG:00000]
# 113    0.4375  query_1  [KEGG:00000]
# 117  0.357143  query_1  [KEGG:00000]
# 139  0.198675  query_1  [KEGG:00000]
# 146  0.416667  query_1  [KEGG:00000]
# 156  0.283582  query_1  [KEGG:00000]
# 166  0.290909  query_1  [KEGG:00000]
# 180   0.47619  query_1  [KEGG:00000]
# 206  0.134228  query_1  [KEGG:00000]
# 217  0.533333  query_1  [KEGG:00000]
# 233  0.119318  query_1  [KEGG:00000]
# 244  0.333333  query_1  [KEGG:00000]
# 10   0.159091  query_1  [KEGG:00000]
# 17    0.08871  query_1  [KEGG:00000]
# 18    0.05042  query_1  [KEGG:00000]
# 20   0.102564  query_1  [KEGG:00000]
# 21   0.277778  query_1  [KEGG:00000]
# 30   0.083333  query_1  [KEGG:00000]
# 33   0.070175  query_1  [KEGG:00000]
# 34   0.029167  query_1  [KEGG:00000]
# 42   0.112903  query_1  [KEGG:00000]
# 45   0.063063  query_1  [KEGG:00000]
#
#                                          intersections  \
# 0    [MT-ND4, PDHA1, MT-CO1, MT-CO3, NDUFB9, UQCRFS...
# 10   [MT-ND4, MT-CO1, MT-CO3, ATP6V1B1, NDUFB9, UQC...
# 16   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, UQCRFS1, NDUF...
# 17   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, UQCRFS1, CPT1...
# 30   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, UQCRFS1, NDUF...
# 35   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, PRPH, UQCRFS1...
# 36   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, UQCRFS1, NDUF...
# 37   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, UQCRFS1, NDUF...
# 43   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, UQCRFS1, NDUF...
# 74   [MT-ND4, MT-CO1, MT-CO3, NDUFB9, PRPH, UQCRFS1...
# 77   [MT-CO1, MT-CO3, UQCRFS1, MT-CO2, ATP2A2, UQCR...
# 92   [MT-CO1, MT-CO3, NDUFB9, UQCRFS1, NDUFB3, MT-C...
# 127  [MT-ND4, NDUFB9, NDUFB3, MT-ND1, MT-ND2, NDUFS...
# 161  [RPL18, RPLP0, RPL31, RPL3, NFKBIB, RPL37A, RP...
# 176  [PDHA1, ACACB, ADH4, ACYP2, MDH1, ACAT1, ADH1B...
# 185  [ITGA2B, ATP2A2, SGCB, TGFB1, CACNB1, SGCG, DM...
# 191  [RPL18, RPLP0, RPL31, RPL3, RPL37A, RPL37, RPL...
# 194  [ITGA2B, ATP2A2, SGCB, TGFB1, CACNB1, SGCG, DM...
# 199  [PDHA1, PGM1, ADH4, PFKM, ENO3, PGAM2, ALDH3A1...
# 216    [ACADL, CPT1B, ADH4, ACADS, ACAT1, ADH1B, ADH7]
# 30   [RPL35A, RPL37A, RPS11, RPL21, RPS19, RPL31, R...
# 35   [RPL35A, RPL37A, RPS11, RPL21, RPS19, RPL31, R...
# 15   [AGXT, GLYCTK, ALDH6A1, HAO1, GLUD1, ENO3, SUC...
# 19   [ACAA1, ABAT, HADH, DBT, ALDH6A1, HMGCL, ACADS...
# 25   [INPP5E, NT5C1A, AGXT, CYP4F2, GCDH, HPD, CYP1...
# 48   [MT-ND6, NDUFV1, NDUFC1, MT-ND2, NDUFS2, NDUFS...
# 52   [PCK2, SUCLG2, SDHD, SDHC, OGDHL, IDH3G, IDH2,...
# 78   [AGXT, GLYCTK, HAO1, HOGA1, HAO2, AFMID, PCCB,...
# 81   [LDHC, ABAT, DBT, ALDH6A1, SUCLG2, ACOX1, HIBC...
# 96   [GCDH, ACAA1, HADH, ADH4, ADH6, ACADSB, ACOX1,...
# 113  [AGXT, DAO, GLYCTK, SARDH, GATM, PIPOX, PGAM2,...
# 117  [PCK2, LDHC, LDHD, ADH4, ADH6, ALDH2, ACSS1, P...
# 139  [MT-ND6, NDUFV1, NDUFC1, MT-ND2, NDUFS2, NDUFS...
# 146  [SLC34A3, MT1F, SLC34A1, MT1M, MT1H, MT1X, MT1...
# 156  [AGXT, ACAA1, DAO, ACOX2, PIPOX, HAO1, HMGCL, ...
# 166  [PCK2, LDHC, ADH4, ADH6, ENO3, ALDOB, PGAM2, A...
# 180  [ACSM3, ABAT, HADH, HMGCL, BDH1, OXCT1, ECHS1,...
# 206  [MT-ND6, NDUFV1, NDUFC1, MT-ND2, NDUFS2, NDUFS...
# 217  [PCK2, GLUD1, ATP1B1, FXYD2, SLC4A4, SLC9A3, P...
# 233  [CALML3, MT-ND6, NDUFV1, NDUFC1, MT-ND2, TUBAL...
# 244  [ATP6V1G3, ATP6V1B1, ATP6V1C2, ATP6V0A4, ATP6V...
# 10   [ATP6V1H, SLC6A4, ATP6V1G1, ATP6V1E1, ATP6V1F,...
# 17   [ATP6V1H, ATP6V1G1, ATP6V1E1, ATP6V1F, NCF4, A...
# 18   [ATP6V1H, LAMTOR2, ATP6V1G1, ATP6V1E1, LAMTOR5...
# 20              [ATP6V1H, ATP6V1G1, ATP6V1E1, ATP6V1F]
# 21     [ATP6V1G1, ATP6V1E1, ATP6V1F, ATP6V0D1, SLC4A1]
# 30   [ATP6V1H, ATP6V1G1, ATP6V1E1, ATP6V1F, MT-CO2,...
# 33              [ATP6V1H, ATP6V1G1, ATP6V1E1, ATP6V1F]
# 34   [TCF7, ATP6V1H, TNR, ATP6V1G1, ITGA2B, ATP6V1E...
# 42   [ATP6V1H, ATP6V1G1, ATP6V1E1, ATP6V1F, ATP6V0D...
# 45   [ATP6V1H, PSAP, HEXB, LIPA, ATP6V0D1, GM2A, AS...
#
#                                              evidences Cancer
# 0    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 10   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 16   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 17   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 30   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 35   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 36   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 37   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 43   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 74   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 77   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 92   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 127  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 161  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 176  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 185  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 191  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 194  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 199  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 216  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  HNSCC
# 30   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LSCC
# 35   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LSCC
# 15   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 19   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 25   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 48   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 52   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 78   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 81   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 96   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 113  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 117  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 139  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 146  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 156  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 166  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 180  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 206  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 217  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 233  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 244  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  CCRCC
# 10   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LUAD
# 17   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LUAD
# 18    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]   LUAD
# 20                    [[KEGG], [KEGG], [KEGG], [KEGG]]   LUAD
# 21            [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]   LUAD
# 30   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LUAD
# 33                    [[KEGG], [KEGG], [KEGG], [KEGG]]   LUAD
# 34   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LUAD
# 42   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LUAD
# 45   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...   LUAD
