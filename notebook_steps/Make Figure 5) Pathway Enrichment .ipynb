# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/go_bp_pathway_enrichment_df.csv')
df
# Out:
#     source      native                                               name  \
# 0    GO:BP  GO:0016054                     organic acid catabolic process
# 1    GO:BP  GO:0046395                  carboxylic acid catabolic process
# 2    GO:BP  GO:0044282                   small molecule catabolic process
# 3    GO:BP  GO:0055086  nucleobase-containing small molecule metabolic...
# 4    GO:BP  GO:0044281                   small molecule metabolic process
# ..     ...         ...                                                ...
# 110  GO:BP  GO:0071357             cellular response to type I interferon
# 111  GO:BP  GO:0034340                      response to type I interferon
# 112  GO:BP  GO:0030198                  extracellular matrix organization
# 113  GO:BP  GO:0043062               extracellular structure organization
# 114  GO:BP  GO:0045229      external encapsulating structure organization
#
#           p_value  significant  \
# 0    3.560568e-07         True
# ...

# %%
g = sns.FacetGrid(data = df, col = 'Cancer', col_wrap = 1, sharey = False)
g.map_dataframe(sns.barplot, y = 'name', x = 'p_value')
# Out:
# C:\Users\nanel\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
