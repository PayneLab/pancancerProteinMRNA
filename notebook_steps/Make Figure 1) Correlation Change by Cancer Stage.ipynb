# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Cancer_stages_correlations.csv')
df
# Out:
#         Unnamed: 0 Cancer      Stage    Gene  PearsonR
# 0                1  CCRCC     Normal    A1BG  0.328964
# 1                3  CCRCC     Normal    A1CF  0.745763
# 2                5  CCRCC     Normal     A2M  0.287323
# 3                9  CCRCC     Normal    AAAS  0.156649
# 4               11  CCRCC     Normal    AACS  0.707274
# ...            ...    ...        ...     ...       ...
# 197542      519669   LUAD  Stage III    ZXDC  0.267841
# 197543      519671   LUAD  Stage III  ZYG11B  0.668127
# 197544      519673   LUAD  Stage III     ZYX  0.609019
# 197545      519675   LUAD  Stage III   ZZEF1  0.701179
# 197546      519677   LUAD  Stage III    ZZZ3  0.372303
#
# [197547 rows x 5 columns]

# %%
g = sns.FacetGrid(data = df, col = 'Cancer', hue = 'Stage', col_wrap = 2, legend_out = True)
g.map_dataframe(sns.kdeplot, x = 'PearsonR')
g.add_legend()
plt.savefig('Figures/Figure 1) Correlation changes by cancer stage')
plt.show()
