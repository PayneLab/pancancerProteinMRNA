# %%
import pandas as pd

# %%
p_val = pd.read_csv("p_val.csv")

# %%
p_val
# Out:
#         Cancer      A1BG      A1CF       A2M         A2ML1    A4GALT  \
# 0        ccrcc  0.008435  0.001958  0.061198           NaN  0.347296
# 1  endometrial  0.824775       NaN  0.936116  3.499895e-02  0.264571
# 2         luad  0.778949       NaN  0.433724           NaN       NaN
# 3        hnscc  0.988560  0.446635  0.252807  6.755440e-02  0.118225
# 4         lscc  0.169387       NaN  0.610199  2.377650e-12  0.156933
#
#        AAAS          AACS     AADAC     AADAT  ...    ZSWIM9      ZW10  \
# 0  0.767248  1.477092e-01  0.081185  0.370717  ...       NaN  0.069946
# 1  0.030133  3.175433e-03       NaN  0.287843  ...  0.654079  0.781930
# 2  0.131262  7.607273e-12  0.065583  0.003088  ...       NaN  0.000012
# 3  0.011762  7.665152e-01  0.000098       NaN  ...       NaN  0.005881
# 4  0.030961  1.035001e-01  0.300931       NaN  ...  0.000682  0.000139
#
#          ZWILCH         ZWINT  ZXDA      ZXDC        ZYG11B       ZYX  \
# ...

# %%
perm_df = pd.read_csv("full_10k_permutation.csv")

# %%
perm_df
# Out:
#   Cancer      A1BG      A1CF       A2M         A2ML1    A4GALT      AAAS  \
# 0  ccrcc  0.052810  0.000838  0.029716           NaN  0.337474  0.728086
# 1     en  0.781720       NaN  0.911887  1.389663e-02  0.332572  0.005615
# 2   luad  0.758399       NaN  0.010615           NaN       NaN  0.139531
# 3  hnscc  0.996778  0.776459  0.228337  5.558182e-04  0.040184  0.014557
# 4   lscc  0.137994       NaN  0.097044  2.033188e-22  0.154022  0.008081
#
#            AACS     AADAC     AADAT  ...    ZSWIM9          ZW10  \
# 0  6.413643e-02  0.350422  0.057700  ...       NaN  1.506673e-01
# 1  6.073417e-09       NaN  0.309108  ...  0.601641  7.465966e-01
# 2  1.567981e-36  0.022448  0.017033  ...       NaN  4.054898e-10
# 3  8.203827e-01  0.000280       NaN  ...       NaN  6.634511e-04
# 4  7.086254e-02  0.456664       NaN  ...  0.001427  1.917384e-13
#
#          ZWILCH         ZWINT  ZXDA      ZXDC        ZYG11B           ZYX  \
# ...

# %%
p_val.corrwith(perm_df, axis = 1)
# Out:
# 0    0.942944
# 1    0.967711
# 2    0.967378
# 3    0.971085
# 4    0.961925
# dtype: float64

# %%
#use permutations from now on
#add 2d scatterplot zooming in on bottom portion
#look at gene sets
