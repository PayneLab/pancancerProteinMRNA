# %%
import pandas as pd
from gprofiler import GProfiler

# %%
proteomics_t_test = pd.read_csv('data/proteomics_t_tests.csv')
proteomics_t_test['Cancer'] = [cancer.lower() for cancer in proteomics_t_test.Cancer]
transcriptomics_t_test = pd.read_csv('data/transcriptomics_t_tests.csv')
transcriptomics_t_test.Cancer = [cancer.lower() for cancer in transcriptomics_t_test.Cancer]
delta_corr_pvals = pd.read_csv('data/full_10k_permutation_corrected.csv')
delta_corr_pvals = delta_corr_pvals.replace('en', 'endometrial')
delta_corr_pvals = delta_corr_pvals.melt(id_vars='Cancer', var_name = 'Gene', value_name = 'perm_pval')
delta_corr_pvals = delta_corr_pvals.dropna()

# %%
exp_background = list(set(transcriptomics_t_test.Gene) & set(proteomics_t_test.Gene))
print(len(exp_background))
corr_background = list(pd.unique(delta_corr_pvals.Gene))
print(len(corr_background))
trans_background = list(pd.unique(transcriptomics_t_test.Gene))
print(len(trans_background))
prot_background = list(pd.unique(proteomics_t_test.Gene))
print(len(prot_background))
# Out:
# 13700
# 13026
# 37921
# 13709

# %%
dfs = []
for cancer in pd.unique(delta_corr_pvals.Cancer):
    sig_prot = proteomics_t_test[proteomics_t_test.Cancer == cancer]
    sig_trans = transcriptomics_t_test[transcriptomics_t_test.Cancer == cancer]   
    sig_corr = delta_corr_pvals[delta_corr_pvals.Cancer == cancer]
    sig_prot = set(sig_prot[sig_prot.qval < 0.05].Gene)
    sig_trans = set(sig_trans[sig_trans.qval < 0.05].Gene)
    sig_corr = set(sig_corr[sig_corr.perm_pval < 0.05].Gene)
    sig_exp = set(sig_prot) & set(sig_trans)
    df = pd.DataFrame({'Cancer': [cancer] * len(sig_exp), 'Gene': list(sig_exp), 'Group': ['expression'] * len(sig_exp)})
    dfs.append(df)
    df = pd.DataFrame({'Cancer': [cancer] * len(sig_corr), 'Gene': list(sig_corr), 'Group': ['correlation'] * len(sig_corr)})
    dfs.append(df)
    df = pd.DataFrame({'Cancer': [cancer] * len(sig_trans), 'Gene': list(sig_trans), 'Group': ['transcriptomics'] * len(sig_trans)})
    dfs.append(df)
    df = pd.DataFrame({'Cancer': [cancer] * len(sig_prot), 'Gene': list(sig_prot), 'Group': ['proteomics'] * len(sig_prot)})
    dfs.append(df)
df = pd.concat(dfs)
df = pd.DataFrame(df.groupby(['Group', 'Gene']).size())
df.reset_index(inplace=True)
df = df[df[0] >2]
df
# Out:
#                  Group    Gene  0
# 3          correlation    AAAS  3
# 7          correlation   AAGAB  4
# 8          correlation    AAK1  4
# 10         correlation    AAMP  3
# 12         correlation    AARS  4
# ...                ...     ... ..
# 64040  transcriptomics    ZXDC  3
# 64041  transcriptomics  ZYG11A  3
# 64042  transcriptomics  ZYG11B  5
# 64043  transcriptomics     ZYX  5
# 64044  transcriptomics   ZZEF1  5
#
# [35383 rows x 3 columns]

# %%
corr = df[df.Group == 'correlation'].Gene
exp = df[df.Group == 'expression'].Gene
prot = df[df.Group == 'proteomics'].Gene
trans = df[df.Group == 'transcriptomics'].Gene

# %%
gp = GProfiler(return_dataframe=True)

# %%
corr_pathways = gp.profile(organism='hsapiens', query = list(corr), no_iea=True,
                       ordered=False, no_evidences=False, background= corr_background, sources = ['KEGG'])

# %%
exp_pathways = gp.profile(organism='hsapiens', query = list(exp), no_iea=True,
                       ordered=False, no_evidences=False, background= exp_background, sources = ['KEGG'])

# %%
prot_pathways = gp.profile(organism='hsapiens', query = list(prot), no_iea=True,
                       ordered=False, no_evidences=False, background= prot_background, sources = ['KEGG'])

# %%
trans_pathways = gp.profile(organism='hsapiens', query = list(trans), no_iea=True,
                       ordered=False, no_evidences=False, background= trans_background, sources = ['KEGG'])

# %%
corr_pathways = corr_pathways[corr_pathways.term_size < 500]
corr_pathways = corr_pathways[corr_pathways.term_size > 15]
corr_pathways
# Out:
#    source      native                                         name  \
# 1    KEGG  KEGG:01240                    Biosynthesis of cofactors
# 2    KEGG  KEGG:00240                        Pyrimidine metabolism
# 3    KEGG  KEGG:01200                            Carbon metabolism
# 4    KEGG  KEGG:00970                  Aminoacyl-tRNA biosynthesis
# 5    KEGG  KEGG:00280   Valine, leucine and isoleucine degradation
# 7    KEGG  KEGG:05164                                  Influenza A
# 8    KEGG  KEGG:04621          NOD-like receptor signaling pathway
# 9    KEGG  KEGG:00760       Nicotinate and nicotinamide metabolism
# 10   KEGG  KEGG:05160                                  Hepatitis C
# 11   KEGG  KEGG:05162                                      Measles
# 12   KEGG  KEGG:01230                  Biosynthesis of amino acids
# 13   KEGG  KEGG:00640                        Propanoate metabolism
# 14   KEGG  KEGG:00051              Fructose and mannose metabolism
# 15   KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism
# 16   KEGG  KEGG:05161                                  Hepatitis B
# 17   KEGG  KEGG:00230                            Purine metabolism
# 18   KEGG  KEGG:04217                                  Necroptosis
# 19   KEGG  KEGG:04066                      HIF-1 signaling pathway
# 20   KEGG  KEGG:05230          Central carbon metabolism in cancer
# 21   KEGG  KEGG:04218                          Cellular senescence
# 22   KEGG  KEGG:05170     Human immunodeficiency virus 1 infection
#
#          p_value  significant                                  description  \
# 1   1.783777e-07         True                    Biosynthesis of cofactors
# 2   6.378181e-07         True                        Pyrimidine metabolism
# 3   6.398922e-07         True                            Carbon metabolism
# 4   7.770558e-05         True                  Aminoacyl-tRNA biosynthesis
# 5   1.777308e-04         True   Valine, leucine and isoleucine degradation
# 7   1.425699e-03         True                                  Influenza A
# 8   2.627233e-03         True          NOD-like receptor signaling pathway
# 9   2.648745e-03         True       Nicotinate and nicotinamide metabolism
# 10  4.404378e-03         True                                  Hepatitis C
# 11  6.026793e-03         True                                      Measles
# 12  6.461696e-03         True                  Biosynthesis of amino acids
# 13  8.994816e-03         True                        Propanoate metabolism
# 14  1.055358e-02         True              Fructose and mannose metabolism
# 15  1.321890e-02         True  Amino sugar and nucleotide sugar metabolism
# 16  1.657271e-02         True                                  Hepatitis B
# 17  2.438409e-02         True                            Purine metabolism
# 18  3.690708e-02         True                                  Necroptosis
# 19  3.802983e-02         True                      HIF-1 signaling pathway
# 20  3.939898e-02         True          Central carbon metabolism in cancer
# 21  4.575047e-02         True                          Cellular senescence
# 22  4.653282e-02         True     Human immunodeficiency virus 1 infection
#
#     term_size  query_size  intersection_size  effective_domain_size  \
# 1         134        3746                 72                  12945
# 2          51        3746                 35                  12945
# 3         110        3746                 61                  12945
# 4          28        3746                 21                  12945
# 5          48        3746                 30                  12945
# 7         133        3746                 62                  12945
# 8         146        3746                 66                  12945
# 9          30        3746                 20                  12945
# 10        118        3746                 55                  12945
# 11        111        3746                 52                  12945
# 12         72        3746                 37                  12945
# 13         34        3746                 21                  12945
# 14         32        3746                 20                  12945
# 15         44        3746                 25                  12945
# 16        131        3746                 58                  12945
# 17        105        3746                 48                  12945
# 18        112        3746                 50                  12945
# 19         93        3746                 43                  12945
# 20         64        3746                 32                  12945
# 21        138        3746                 59                  12945
# 22        181        3746                 74                  12945
#
#     precision    recall    query       parents  \
# 1    0.019221  0.537313  query_1  [KEGG:00000]
# 2    0.009343  0.686275  query_1  [KEGG:00000]
# 3    0.016284  0.554545  query_1  [KEGG:00000]
# 4    0.005606  0.750000  query_1  [KEGG:00000]
# 5    0.008009  0.625000  query_1  [KEGG:00000]
# 7    0.016551  0.466165  query_1  [KEGG:00000]
# 8    0.017619  0.452055  query_1  [KEGG:00000]
# 9    0.005339  0.666667  query_1  [KEGG:00000]
# 10   0.014682  0.466102  query_1  [KEGG:00000]
# 11   0.013881  0.468468  query_1  [KEGG:00000]
# 12   0.009877  0.513889  query_1  [KEGG:00000]
# 13   0.005606  0.617647  query_1  [KEGG:00000]
# 14   0.005339  0.625000  query_1  [KEGG:00000]
# 15   0.006674  0.568182  query_1  [KEGG:00000]
# 16   0.015483  0.442748  query_1  [KEGG:00000]
# 17   0.012814  0.457143  query_1  [KEGG:00000]
# 18   0.013348  0.446429  query_1  [KEGG:00000]
# 19   0.011479  0.462366  query_1  [KEGG:00000]
# 20   0.008542  0.500000  query_1  [KEGG:00000]
# 21   0.015750  0.427536  query_1  [KEGG:00000]
# 22   0.019754  0.408840  query_1  [KEGG:00000]
#
#                                         intersections  \
# 1   [ADSL, ADSS, AK1, AK2, AK3, AK4, AK6, ALAD, AL...
# 2   [CAD, CANT1, CMPK1, CMPK2, CTPS1, CTPS2, DCK, ...
# 3   [ACADS, ACAT1, ACOX3, ACSS1, ACSS2, ALDH6A1, A...
# 4   [AARS2, CARS, DARS2, EARS2, FARS2, HARS2, IARS...
# 5   [ABAT, ACAA2, ACAD8, ACADM, ACADS, ACADSB, ACA...
# 7   [ADAR, AKT2, AKT3, APAF1, BAK1, BID, CASP1, CA...
# 8   [ANTXR1, ATG16L1, CARD16, CARD6, CARD8, CARD9,...
# 9   [AOX1, ENPP1, NADK2, NADSYN1, NAMPT, NAPRT, NM...
# 10  [AKT2, AKT3, APAF1, BAK1, BID, BRAF, CASP8, CA...
# 11  [ADAR, AKT2, AKT3, APAF1, BAK1, BID, CASP8, CA...
# 12  [ACY1, ALDH18A1, ALDOA, ALDOC, ARG1, ARG2, ASN...
# 13  [ABAT, ACACA, ACADS, ACAT1, ACOX3, ACSS1, ACSS...
# 14  [AKR1B10, ALDOA, ALDOC, FBP1, FPGT, GMDS, HK1,...
# 15  [CMAS, CYB5R1, CYB5R3, CYB5R4, FPGT, GALE, GAL...
# 16  [AKT2, AKT3, APAF1, BID, BRAF, CASP10, CASP8, ...
# 17  [ADA, ADSL, ADSS, AK1, AK2, AK3, AK4, AK6, AMP...
# 18  [BID, CAMK2D, CASP1, CASP8, CHMP1B, CHMP2A, CH...
# 19  [AKT2, AKT3, ALDOA, ALDOC, ARNT, CAMK2D, CDKN1...
# 20  [AKT2, AKT3, EGFR, ERBB2, G6PD, GLS, HK1, HK2,...
# 21  [AKT2, AKT3, ATR, CALML3, CALML5, CCNA2, CCNB1...
# 22  [AKT2, AKT3, AP1G1, AP1S3, APOBEC3B, APOBEC3C,...
#
#                                             evidences
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 9   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 10  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 11  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 12  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 13  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 14  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 15  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 16  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 17  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 18  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 19  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 20  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 21  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 22  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %%
exp_pathways = exp_pathways[exp_pathways.term_size < 500]
exp_pathways = exp_pathways[exp_pathways.term_size > 15]
exp_pathways
# Out:
#    source      native                                         name  \
# 1    KEGG  KEGG:03010                                     Ribosome
# 2    KEGG  KEGG:03013                                RNA transport
# 3    KEGG  KEGG:05171               Coronavirus disease - COVID-19
# 4    KEGG  KEGG:03008            Ribosome biogenesis in eukaryotes
# 5    KEGG  KEGG:04144                                  Endocytosis
# 7    KEGG  KEGG:01200                            Carbon metabolism
# 8    KEGG  KEGG:03040                                  Spliceosome
# 9    KEGG  KEGG:05169                 Epstein-Barr virus infection
# 10   KEGG  KEGG:03030                              DNA replication
# 11   KEGG  KEGG:05014                Amyotrophic lateral sclerosis
# 12   KEGG  KEGG:04062                  Chemokine signaling pathway
# 13   KEGG  KEGG:00280   Valine, leucine and isoleucine degradation
# 14   KEGG  KEGG:05100       Bacterial invasion of epithelial cells
# 15   KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism
# 16   KEGG  KEGG:04512                     ECM-receptor interaction
# 17   KEGG  KEGG:05203                         Viral carcinogenesis
# 18   KEGG  KEGG:00071                       Fatty acid degradation
# 19   KEGG  KEGG:04932            Non-alcoholic fatty liver disease
# 20   KEGG  KEGG:05415                      Diabetic cardiomyopathy
# 21   KEGG  KEGG:05163              Human cytomegalovirus infection
# 22   KEGG  KEGG:04666             Fc gamma R-mediated phagocytosis
# 23   KEGG  KEGG:04810             Regulation of actin cytoskeleton
# 24   KEGG  KEGG:04530                               Tight junction
# 25   KEGG  KEGG:04670         Leukocyte transendothelial migration
# 26   KEGG  KEGG:05222                       Small cell lung cancer
#
#          p_value  significant                                  description  \
# 1   2.454217e-13         True                                     Ribosome
# 2   6.860733e-09         True                                RNA transport
# 3   1.503773e-06         True               Coronavirus disease - COVID-19
# 4   2.672239e-05         True            Ribosome biogenesis in eukaryotes
# 5   2.864860e-05         True                                  Endocytosis
# 7   1.583017e-04         True                            Carbon metabolism
# 8   1.595670e-04         True                                  Spliceosome
# 9   3.142469e-04         True                 Epstein-Barr virus infection
# 10  6.764488e-04         True                              DNA replication
# 11  1.090329e-03         True                Amyotrophic lateral sclerosis
# 12  2.167432e-03         True                  Chemokine signaling pathway
# 13  6.399593e-03         True   Valine, leucine and isoleucine degradation
# 14  7.146343e-03         True       Bacterial invasion of epithelial cells
# 15  1.193684e-02         True  Amino sugar and nucleotide sugar metabolism
# 16  1.226751e-02         True                     ECM-receptor interaction
# 17  1.279536e-02         True                         Viral carcinogenesis
# 18  1.371391e-02         True                       Fatty acid degradation
# 19  1.451505e-02         True            Non-alcoholic fatty liver disease
# 20  2.172028e-02         True                      Diabetic cardiomyopathy
# 21  2.506995e-02         True              Human cytomegalovirus infection
# 22  2.517172e-02         True             Fc gamma R-mediated phagocytosis
# 23  3.129137e-02         True             Regulation of actin cytoskeleton
# 24  3.698156e-02         True                               Tight junction
# 25  4.016040e-02         True         Leukocyte transendothelial migration
# 26  4.846822e-02         True                       Small cell lung cancer
#
#     term_size  query_size  intersection_size  effective_domain_size  \
# 1         132        6597                108                  13598
# 2         155        6597                115                  13598
# 3         201        6597                137                  13598
# 4          73        6597                 57                  13598
# 5         232        6597                151                  13598
# 7         113        6597                 80                  13598
# 8         135        6597                 93                  13598
# 9         171        6597                113                  13598
# 10         35        6597                 30                  13598
# 11        326        6597                197                  13598
# 12        144        6597                 95                  13598
# 13         48        6597                 37                  13598
# 14         66        6597                 48                  13598
# 15         44        6597                 34                  13598
# 16         82        6597                 57                  13598
# 17        152        6597                 97                  13598
# 18         41        6597                 32                  13598
# 19        131        6597                 85                  13598
# 20        186        6597                115                  13598
# 21        181        6597                112                  13598
# 22         92        6597                 62                  13598
# 23        189        6597                116                  13598
# 24        146        6597                 92                  13598
# 25        100        6597                 66                  13598
# 26         83        6597                 56                  13598
#
#     precision    recall    query       parents  \
# 1    0.016371  0.818182  query_1  [KEGG:00000]
# 2    0.017432  0.741935  query_1  [KEGG:00000]
# 3    0.020767  0.681592  query_1  [KEGG:00000]
# 4    0.008640  0.780822  query_1  [KEGG:00000]
# 5    0.022889  0.650862  query_1  [KEGG:00000]
# 7    0.012127  0.707965  query_1  [KEGG:00000]
# 8    0.014097  0.688889  query_1  [KEGG:00000]
# 9    0.017129  0.660819  query_1  [KEGG:00000]
# 10   0.004548  0.857143  query_1  [KEGG:00000]
# 11   0.029862  0.604294  query_1  [KEGG:00000]
# 12   0.014400  0.659722  query_1  [KEGG:00000]
# 13   0.005609  0.770833  query_1  [KEGG:00000]
# 14   0.007276  0.727273  query_1  [KEGG:00000]
# 15   0.005154  0.772727  query_1  [KEGG:00000]
# 16   0.008640  0.695122  query_1  [KEGG:00000]
# 17   0.014704  0.638158  query_1  [KEGG:00000]
# 18   0.004851  0.780488  query_1  [KEGG:00000]
# 19   0.012885  0.648855  query_1  [KEGG:00000]
# 20   0.017432  0.618280  query_1  [KEGG:00000]
# 21   0.016977  0.618785  query_1  [KEGG:00000]
# 22   0.009398  0.673913  query_1  [KEGG:00000]
# 23   0.017584  0.613757  query_1  [KEGG:00000]
# 24   0.013946  0.630137  query_1  [KEGG:00000]
# 25   0.010005  0.660000  query_1  [KEGG:00000]
# 26   0.008489  0.674699  query_1  [KEGG:00000]
#
#                                         intersections  \
# 1   [FAU, MRPL1, MRPL10, MRPL11, MRPL12, MRPL13, M...
# 2   [AAAS, ACIN1, ALYREF, CLNS1A, CYFIP1, DDX19A, ...
# 3   [ACE, ADAM17, ADAR, C1QA, C1QB, C1QC, C2, C3, ...
# 4   [BMS1, CSNK2A1, DKC1, DROSHA, EIF6, EMG1, FBL,...
# 5   [ACAP1, ACAP2, ACAP3, ACTR2, ACTR3, ACTR3B, AG...
# 7   [ACAT1, ACAT2, ACO1, ACO2, ACOX1, ACOX3, ACSS1...
# 8   [ACIN1, ALYREF, BCAS2, BUD31, CCDC12, CDC5L, C...
# 9   [ADRM1, AKT1, AKT3, APAF1, B2M, BAK1, BAX, BID...
# 10  [FEN1, LIG1, MCM2, MCM3, MCM4, MCM5, MCM6, MCM...
# 11  [ACTB, ACTG1, ACTR10, ACTR1A, ADRM1, ALYREF, A...
# 12  [ADCY3, ADCY5, ADCY6, ADCY9, AKT1, AKT3, ARRB1...
# 13  [AACS, ABAT, ACAA1, ACAA2, ACAD8, ACADM, ACADS...
# 14  [ACTB, ACTG1, ACTR2, ACTR3, ACTR3B, ARHGAP10, ...
# 15  [CHIT1, CMAS, CYB5R3, CYB5R4, FPGT, GALE, GALT...
# 16  [AGRN, CD36, CD44, CD47, COL1A1, COL1A2, COL4A...
# 17  [ACTN1, ATF2, ATP6V0D1, ATP6V0D2, BAK1, BAX, C...
# 18  [ACAA1, ACAA2, ACADL, ACADM, ACADSB, ACADVL, A...
# 19  [ADIPOR1, AKT1, AKT3, BAX, BID, CASP3, CASP7, ...
# 20  [ACE, AKT1, AKT3, ATP2A2, ATP5PB, CAMK2D, CAMK...
# 21  [ADCY3, ADCY5, ADCY6, ADCY9, AKAP13, AKT1, AKT...
# 22  [ACTR2, ACTR3, ACTR3B, AKT1, AKT3, AMPH, ARPC1...
# 23  [ABI2, ACTB, ACTG1, ACTN1, ACTR2, ACTR3, ACTR3...
# 24  [ACTB, ACTG1, ACTN1, ACTR2, ACTR3, ACTR3B, AFD...
# 25  [ACTB, ACTG1, ACTN1, AFDN, CD99, CD99L2, CDC42...
# 26  [AKT1, AKT3, APAF1, BAK1, BAX, CASP3, CASP9, C...
#
#                                             evidences
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 9   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 10  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 11  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 12  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 13  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 14  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 15  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 16  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 17  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 18  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 19  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 20  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 21  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 22  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 23  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 24  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 25  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 26  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %%
prot_pathways = prot_pathways[prot_pathways.term_size < 500]
prot_pathways = prot_pathways[prot_pathways.term_size > 15]
prot_pathways
# Out:
#    source      native                                         name  \
# 1    KEGG  KEGG:05171               Coronavirus disease - COVID-19
# 2    KEGG  KEGG:03010                                     Ribosome
# 3    KEGG  KEGG:04144                                  Endocytosis
# 5    KEGG  KEGG:03013                                RNA transport
# 6    KEGG  KEGG:04610          Complement and coagulation cascades
# 7    KEGG  KEGG:03040                                  Spliceosome
# 8    KEGG  KEGG:05415                      Diabetic cardiomyopathy
# 9    KEGG  KEGG:05014                Amyotrophic lateral sclerosis
# 10   KEGG  KEGG:05132                         Salmonella infection
# 11   KEGG  KEGG:04141  Protein processing in endoplasmic reticulum
# 12   KEGG  KEGG:05135                           Yersinia infection
# 13   KEGG  KEGG:05169                 Epstein-Barr virus infection
# 14   KEGG  KEGG:03008            Ribosome biogenesis in eukaryotes
# 15   KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism
# 16   KEGG  KEGG:04611                          Platelet activation
# 17   KEGG  KEGG:00280   Valine, leucine and isoleucine degradation
# 18   KEGG  KEGG:05020                                Prion disease
# 19   KEGG  KEGG:05131                                  Shigellosis
# 20   KEGG  KEGG:04932            Non-alcoholic fatty liver disease
# 21   KEGG  KEGG:04145                                    Phagosome
# 22   KEGG  KEGG:05130        Pathogenic Escherichia coli infection
# 23   KEGG  KEGG:05145                                Toxoplasmosis
# 24   KEGG  KEGG:05012                            Parkinson disease
# 25   KEGG  KEGG:01200                            Carbon metabolism
# 26   KEGG  KEGG:04140                           Autophagy - animal
# 27   KEGG  KEGG:04666             Fc gamma R-mediated phagocytosis
# 28   KEGG  KEGG:05220                     Chronic myeloid leukemia
# 29   KEGG  KEGG:04613      Neutrophil extracellular trap formation
# 30   KEGG  KEGG:05161                                  Hepatitis B
# 31   KEGG  KEGG:04530                               Tight junction
# 32   KEGG  KEGG:00190                    Oxidative phosphorylation
# 33   KEGG  KEGG:05170     Human immunodeficiency virus 1 infection
# 34   KEGG  KEGG:05140                                Leishmaniasis
# 35   KEGG  KEGG:05134                                Legionellosis
# 36   KEGG  KEGG:05203                         Viral carcinogenesis
# 37   KEGG  KEGG:04512                     ECM-receptor interaction
# 38   KEGG  KEGG:04714                                Thermogenesis
# 39   KEGG  KEGG:05016                           Huntington disease
# 40   KEGG  KEGG:04810             Regulation of actin cytoskeleton
# 41   KEGG  KEGG:05164                                  Influenza A
# 42   KEGG  KEGG:04979                       Cholesterol metabolism
# 43   KEGG  KEGG:04660            T cell receptor signaling pathway
# 44   KEGG  KEGG:00900              Terpenoid backbone biosynthesis
# 45   KEGG  KEGG:05142                               Chagas disease
# 46   KEGG  KEGG:04380                   Osteoclast differentiation
# 47   KEGG  KEGG:00010                 Glycolysis / Gluconeogenesis
# 48   KEGG  KEGG:04062                  Chemokine signaling pathway
# 49   KEGG  KEGG:00071                       Fatty acid degradation
# 50   KEGG  KEGG:04910                    Insulin signaling pathway
# 51   KEGG  KEGG:05166      Human T-cell leukemia virus 1 infection
# 52   KEGG  KEGG:04625     C-type lectin receptor signaling pathway
# 53   KEGG  KEGG:04612          Antigen processing and presentation
# 54   KEGG  KEGG:05010                            Alzheimer disease
# 55   KEGG  KEGG:05205                      Proteoglycans in cancer
# 56   KEGG  KEGG:04510                               Focal adhesion
# 57   KEGG  KEGG:03030                              DNA replication
# 58   KEGG  KEGG:04210                                    Apoptosis
# 59   KEGG  KEGG:04670         Leukocyte transendothelial migration
# 60   KEGG  KEGG:05212                            Pancreatic cancer
#
#          p_value  significant                                  description  \
# 1   1.745898e-13         True               Coronavirus disease - COVID-19
# 2   3.565362e-13         True                                     Ribosome
# 3   2.427947e-11         True                                  Endocytosis
# 5   7.783271e-09         True                                RNA transport
# 6   8.030456e-09         True          Complement and coagulation cascades
# 7   1.864217e-08         True                                  Spliceosome
# 8   1.035857e-07         True                      Diabetic cardiomyopathy
# 9   4.908653e-07         True                Amyotrophic lateral sclerosis
# 10  4.175610e-06         True                         Salmonella infection
# 11  7.239206e-06         True  Protein processing in endoplasmic reticulum
# 12  1.507063e-05         True                           Yersinia infection
# 13  2.164748e-05         True                 Epstein-Barr virus infection
# 14  2.618512e-05         True            Ribosome biogenesis in eukaryotes
# 15  1.047005e-04         True  Amino sugar and nucleotide sugar metabolism
# 16  1.138383e-04         True                          Platelet activation
# 17  1.865596e-04         True   Valine, leucine and isoleucine degradation
# 18  1.965711e-04         True                                Prion disease
# 19  2.083969e-04         True                                  Shigellosis
# 20  2.166182e-04         True            Non-alcoholic fatty liver disease
# 21  2.495208e-04         True                                    Phagosome
# 22  2.927543e-04         True        Pathogenic Escherichia coli infection
# 23  4.925088e-04         True                                Toxoplasmosis
# 24  5.743979e-04         True                            Parkinson disease
# 25  5.877300e-04         True                            Carbon metabolism
# 26  7.424805e-04         True                           Autophagy - animal
# 27  8.835438e-04         True             Fc gamma R-mediated phagocytosis
# 28  9.341482e-04         True                     Chronic myeloid leukemia
# 29  1.384773e-03         True      Neutrophil extracellular trap formation
# 30  1.456552e-03         True                                  Hepatitis B
# 31  1.658448e-03         True                               Tight junction
# 32  1.704009e-03         True                    Oxidative phosphorylation
# 33  3.055989e-03         True     Human immunodeficiency virus 1 infection
# 34  3.407933e-03         True                                Leishmaniasis
# 35  4.607097e-03         True                                Legionellosis
# 36  4.813431e-03         True                         Viral carcinogenesis
# 37  5.018112e-03         True                     ECM-receptor interaction
# 38  5.250057e-03         True                                Thermogenesis
# 39  5.865264e-03         True                           Huntington disease
# 40  5.983218e-03         True             Regulation of actin cytoskeleton
# 41  7.316655e-03         True                                  Influenza A
# 42  7.586865e-03         True                       Cholesterol metabolism
# 43  8.092913e-03         True            T cell receptor signaling pathway
# 44  9.576899e-03         True              Terpenoid backbone biosynthesis
# 45  1.114755e-02         True                               Chagas disease
# 46  1.133757e-02         True                   Osteoclast differentiation
# 47  1.235373e-02         True                 Glycolysis / Gluconeogenesis
# 48  1.283703e-02         True                  Chemokine signaling pathway
# 49  1.541632e-02         True                       Fatty acid degradation
# 50  1.568258e-02         True                    Insulin signaling pathway
# 51  1.820937e-02         True      Human T-cell leukemia virus 1 infection
# 52  1.913113e-02         True     C-type lectin receptor signaling pathway
# 53  2.150643e-02         True          Antigen processing and presentation
# 54  2.194113e-02         True                            Alzheimer disease
# 55  2.324779e-02         True                      Proteoglycans in cancer
# 56  2.336158e-02         True                               Focal adhesion
# 57  2.517981e-02         True                              DNA replication
# 58  3.848697e-02         True                                    Apoptosis
# 59  4.120538e-02         True         Leukocyte transendothelial migration
# 60  4.800798e-02         True                            Pancreatic cancer
#
#     term_size  query_size  intersection_size  effective_domain_size  \
# 1         201        8699                178                  13603
# 2         132        8699                123                  13603
# 3         232        8699                198                  13603
# 5         155        8699                135                  13603
# 6          79        8699                 75                  13603
# 7         135        8699                119                  13603
# 8         191        8699                160                  13603
# 9         331        8699                260                  13603
# 10        240        8699                192                  13603
# 11        160        8699                133                  13603
# 12        126        8699                107                  13603
# 13        171        8699                140                  13603
# 14         73        8699                 66                  13603
# 15         44        8699                 42                  13603
# 16        115        8699                 97                  13603
# 17         48        8699                 45                  13603
# 18        247        8699                192                  13603
# 19        212        8699                167                  13603
# 20        132        8699                109                  13603
# 21        139        8699                114                  13603
# 22        175        8699                140                  13603
# 23         94        8699                 80                  13603
# 24        228        8699                177                  13603
# 25        113        8699                 94                  13603
# 26        131        8699                107                  13603
# 27         92        8699                 78                  13603
# 28         67        8699                 59                  13603
# 29        106        8699                 88                  13603
# 30        132        8699                107                  13603
# 31        146        8699                117                  13603
# 32        124        8699                101                  13603
# 33        182        8699                142                  13603
# 34         63        8699                 55                  13603
# 35         49        8699                 44                  13603
# 36        152        8699                120                  13603
# 37         82        8699                 69                  13603
# 38        210        8699                161                  13603
# 39        279        8699                209                  13603
# 40        189        8699                146                  13603
# 41        136        8699                108                  13603
# 42         43        8699                 39                  13603
# 43         88        8699                 73                  13603
# 44         21        8699                 21                  13603
# 45         83        8699                 69                  13603
# 46        109        8699                 88                  13603
# 47         63        8699                 54                  13603
# 48        144        8699                113                  13603
# 49         41        8699                 37                  13603
# 50        122        8699                 97                  13603
# 51        190        8699                145                  13603
# 52         81        8699                 67                  13603
# 53         53        8699                 46                  13603
# 54        319        8699                234                  13603
# 55        182        8699                139                  13603
# 56        192        8699                146                  13603
# 57         35        8699                 32                  13603
# 58        118        8699                 93                  13603
# 59        100        8699                 80                  13603
# 60         70        8699                 58                  13603
#
#     precision    recall    query       parents  \
# 1    0.020462  0.885572  query_1  [KEGG:00000]
# 2    0.014140  0.931818  query_1  [KEGG:00000]
# 3    0.022761  0.853448  query_1  [KEGG:00000]
# 5    0.015519  0.870968  query_1  [KEGG:00000]
# 6    0.008622  0.949367  query_1  [KEGG:00000]
# 7    0.013680  0.881481  query_1  [KEGG:00000]
# 8    0.018393  0.837696  query_1  [KEGG:00000]
# 9    0.029888  0.785498  query_1  [KEGG:00000]
# 10   0.022072  0.800000  query_1  [KEGG:00000]
# 11   0.015289  0.831250  query_1  [KEGG:00000]
# 12   0.012300  0.849206  query_1  [KEGG:00000]
# 13   0.016094  0.818713  query_1  [KEGG:00000]
# 14   0.007587  0.904110  query_1  [KEGG:00000]
# 15   0.004828  0.954545  query_1  [KEGG:00000]
# 16   0.011151  0.843478  query_1  [KEGG:00000]
# 17   0.005173  0.937500  query_1  [KEGG:00000]
# 18   0.022072  0.777328  query_1  [KEGG:00000]
# 19   0.019198  0.787736  query_1  [KEGG:00000]
# 20   0.012530  0.825758  query_1  [KEGG:00000]
# 21   0.013105  0.820144  query_1  [KEGG:00000]
# 22   0.016094  0.800000  query_1  [KEGG:00000]
# 23   0.009196  0.851064  query_1  [KEGG:00000]
# 24   0.020347  0.776316  query_1  [KEGG:00000]
# 25   0.010806  0.831858  query_1  [KEGG:00000]
# 26   0.012300  0.816794  query_1  [KEGG:00000]
# 27   0.008967  0.847826  query_1  [KEGG:00000]
# 28   0.006782  0.880597  query_1  [KEGG:00000]
# 29   0.010116  0.830189  query_1  [KEGG:00000]
# 30   0.012300  0.810606  query_1  [KEGG:00000]
# 31   0.013450  0.801370  query_1  [KEGG:00000]
# 32   0.011611  0.814516  query_1  [KEGG:00000]
# 33   0.016324  0.780220  query_1  [KEGG:00000]
# 34   0.006323  0.873016  query_1  [KEGG:00000]
# 35   0.005058  0.897959  query_1  [KEGG:00000]
# 36   0.013795  0.789474  query_1  [KEGG:00000]
# 37   0.007932  0.841463  query_1  [KEGG:00000]
# 38   0.018508  0.766667  query_1  [KEGG:00000]
# 39   0.024026  0.749104  query_1  [KEGG:00000]
# 40   0.016784  0.772487  query_1  [KEGG:00000]
# 41   0.012415  0.794118  query_1  [KEGG:00000]
# 42   0.004483  0.906977  query_1  [KEGG:00000]
# 43   0.008392  0.829545  query_1  [KEGG:00000]
# 44   0.002414  1.000000  query_1  [KEGG:00000]
# 45   0.007932  0.831325  query_1  [KEGG:00000]
# 46   0.010116  0.807339  query_1  [KEGG:00000]
# 47   0.006208  0.857143  query_1  [KEGG:00000]
# 48   0.012990  0.784722  query_1  [KEGG:00000]
# 49   0.004253  0.902439  query_1  [KEGG:00000]
# 50   0.011151  0.795082  query_1  [KEGG:00000]
# 51   0.016669  0.763158  query_1  [KEGG:00000]
# 52   0.007702  0.827160  query_1  [KEGG:00000]
# 53   0.005288  0.867925  query_1  [KEGG:00000]
# 54   0.026900  0.733542  query_1  [KEGG:00000]
# 55   0.015979  0.763736  query_1  [KEGG:00000]
# 56   0.016784  0.760417  query_1  [KEGG:00000]
# 57   0.003679  0.914286  query_1  [KEGG:00000]
# 58   0.010691  0.788136  query_1  [KEGG:00000]
# 59   0.009196  0.800000  query_1  [KEGG:00000]
# 60   0.006667  0.828571  query_1  [KEGG:00000]
#
#                                         intersections  \
# 1   [ACE, ADAM17, ADAR, C1QA, C1QB, C1QC, C1R, C1S...
# 2   [FAU, MRPL1, MRPL10, MRPL11, MRPL12, MRPL13, M...
# 3   [ACAP1, ACAP2, ACAP3, ACTR2, ACTR3, ACTR3B, AG...
# 5   [AAAS, ACIN1, ALYREF, CASC3, CLNS1A, CYFIP1, C...
# 6   [A2M, C1QA, C1QB, C1QC, C1R, C1S, C2, C3, C4A,...
# 7   [ACIN1, ALYREF, AQR, BCAS2, BUD31, CCDC12, CDC...
# 8   [ACE, AGT, AKT1, AKT3, ATP2A2, ATP5F1A, ATP5F1...
# 9   [ACTB, ACTG1, ACTR10, ACTR1A, ACTR1B, ADRM1, A...
# 10  [ABI1, ACBD3, ACTB, ACTG1, ACTR10, ACTR1A, ACT...
# 11  [AMFR, ATF6, ATXN3, BAG1, BAG2, BAK1, BAX, BCA...
# 12  [ACTB, ACTG1, ACTR2, ACTR3, ACTR3B, AKT1, AKT3...
# 13  [ADRM1, AKT1, AKT3, APAF1, B2M, BAK1, BAX, BID...
# 14  [AK6, BMS1, CSNK2A1, CSNK2A2, DKC1, DROSHA, EI...
# 15  [AMDHD2, CHIT1, CMAS, CYB5R1, CYB5R2, CYB5R3, ...
# 16  [ACTB, ACTG1, ADCY3, ADCY5, ADCY6, ADCY9, AKT1...
# 17  [AACS, ABAT, ACAA1, ACAA2, ACAD8, ACADM, ACADS...
# 18  [ADRM1, APAF1, ATF2, ATP5F1A, ATP5F1B, ATP5F1C...
# 19  [ACTB, ACTG1, ACTN1, ACTN4, ACTR2, ACTR3, ACTR...
# 20  [ADIPOQ, ADIPOR1, AKT1, AKT3, BAX, BID, CASP3,...
# 21  [ACTB, ACTG1, ATP6V0A1, ATP6V0A2, ATP6V0D1, AT...
# 22  [ABI1, ABL1, ACTB, ACTG1, ACTR2, ACTR3, ACTR3B...
# 23  [AKT1, AKT3, ALOX5, BAD, BCL2L1, BIRC2, BIRC3,...
# 24  [ADCY5, ADRM1, APAF1, ATF6, ATP5F1A, ATP5F1B, ...
# 25  [ACADS, ACAT1, ACAT2, ACO1, ACO2, ACOX1, ACOX3...
# 26  [AKT1, AKT3, ATG101, ATG13, ATG14, ATG16L1, AT...
# 27  [ACTR2, ACTR3, ACTR3B, AKT1, AKT3, AMPH, ARF6,...
# 28  [ABL1, AKT1, AKT3, ARAF, BAD, BAK1, BAX, BCL2L...
# 29  [ACTB, ACTG1, AKT1, AKT3, ATG7, AZU1, C3, C5, ...
# 30  [AKT1, AKT3, APAF1, ARAF, ATF2, BAD, BAX, BID,...
# 31  [ACTB, ACTG1, ACTN1, ACTN4, ACTR2, ACTR3, ACTR...
# 32  [ATP12A, ATP5F1A, ATP5F1B, ATP5F1C, ATP5F1D, A...
# 33  [AKT1, AKT3, AP1B1, AP1G1, AP1M2, AP1S1, AP1S2...
# 34  [C3, CR1, CYBA, CYBB, EEF1A1, EEF1A2, FCGR1A, ...
# 35  [APAF1, ARF1, BCL2L13, BNIP3, C3, CASP1, CASP3...
# 36  [ACTN1, ACTN4, ATF2, ATP6V0D1, ATP6V0D2, BAD, ...
# 37  [AGRN, CD36, CD44, CD47, CHAD, COL1A1, COL1A2,...
# 38  [ACSL1, ACSL3, ACSL4, ACSL5, ACTB, ACTG1, ACTL...
# 39  [ACTR10, ACTR1A, ACTR1B, ADRM1, AP2A1, AP2A2, ...
# 40  [ABI2, ACTB, ACTG1, ACTN1, ACTN4, ACTR2, ACTR3...
# 41  [ACTB, ACTG1, ADAR, AKT1, AKT3, APAF1, BAK1, B...
# 42  [ABCA1, ANGPTL4, APOA1, APOA2, APOA4, APOB, AP...
# 43  [AKT1, AKT3, BCL10, CARD11, CBLB, CD247, CD3D,...
# 44  [ACAT1, ACAT2, DHDDS, FDPS, FNTA, FNTB, GGPS1,...
# 45  [ACE, AKT1, AKT3, C1QA, C1QB, C1QC, C3, CALR, ...
# 46  [ACP5, AKT1, AKT3, BLNK, BTK, CAMK4, CHUK, CRE...
# 47  [ACSS1, ACSS2, ADH1A, ADH1B, ADH1C, ADH4, ADH5...
# 48  [ADCY3, ADCY5, ADCY6, ADCY9, AKT1, AKT3, ARRB1...
# 49  [ACAA1, ACAA2, ACADL, ACADM, ACADS, ACADSB, AC...
# 50  [ACACB, AKT1, AKT3, ARAF, BAD, BRAF, CALML3, C...
# 51  [ADCY3, ADCY5, ADCY6, ADCY9, AKT1, AKT3, ANAPC...
# 52  [AKT1, AKT3, ARHGEF12, BCL10, BCL3, CALML3, CA...
# 53  [B2M, CALR, CANX, CD4, CD74, CD8A, CREB1, CTSB...
# 54  [ADAM10, ADAM17, ADRM1, AKT1, AKT3, APAF1, APB...
# 55  [ACTB, ACTG1, AKT1, AKT3, ANK1, ANK2, ANK3, AR...
# 56  [ACTB, ACTG1, ACTN1, ACTN4, AKT1, AKT3, ARHGAP...
# 57  [FEN1, LIG1, MCM2, MCM3, MCM4, MCM5, MCM6, MCM...
# 58  [ACTB, ACTG1, AIFM1, AKT1, AKT3, APAF1, ATM, B...
# 59  [ACTB, ACTG1, ACTN1, ACTN4, AFDN, ARHGAP35, BC...
# 60  [AKT1, AKT3, ARAF, ARHGEF6, BAD, BAK1, BAX, BC...
#
#                                             evidences
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 6   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 9   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 10  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 11  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 12  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 13  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 14  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 15  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 16  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 17  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 18  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 19  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 20  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 21  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 22  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 23  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 24  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 25  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 26  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 27  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 28  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 29  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 30  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 31  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 32  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 33  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 34  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 35  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 36  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 37  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 38  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 39  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 40  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 41  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 42  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 43  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 44  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 45  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 46  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 47  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 48  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 49  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 50  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 51  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 52  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 53  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 54  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 55  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 56  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 57  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 58  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 59  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 60  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %%
trans_pathways = trans_pathways[trans_pathways.term_size < 500]
trans_pathways = trans_pathways[trans_pathways.term_size > 15]
trans_pathways
# Out:
#     source      native                                               name  \
# 3     KEGG  KEGG:05168                   Herpes simplex virus 1 infection
# 4     KEGG  KEGG:05022  Pathways of neurodegeneration - multiple diseases
# 5     KEGG  KEGG:04144                                        Endocytosis
# 6     KEGG  KEGG:05014                      Amyotrophic lateral sclerosis
# 7     KEGG  KEGG:05166            Human T-cell leukemia virus 1 infection
# ..     ...         ...                                                ...
# 237   KEGG  KEGG:00480                             Glutathione metabolism
# 238   KEGG  KEGG:00770                  Pantothenate and CoA biosynthesis
# 239   KEGG  KEGG:03420                         Nucleotide excision repair
# 240   KEGG  KEGG:04978                                 Mineral absorption
# 241   KEGG  KEGG:05340                           Primary immunodeficiency
#
#           p_value  significant  \
# 3    2.890048e-24         True
# 4    1.003099e-22         True
# 5    9.277320e-21         True
# 6    8.672610e-19         True
# 7    8.712541e-19         True
# ..            ...          ...
# 237  3.547639e-02         True
# 238  3.769693e-02         True
# 239  4.018691e-02         True
# 240  4.100770e-02         True
# 241  4.993706e-02         True
#
#                                            description  term_size  query_size  \
# 3                     Herpes simplex virus 1 infection        493       15521
# 4    Pathways of neurodegeneration - multiple diseases        475       15521
# 5                                          Endocytosis        252       15521
# 6                        Amyotrophic lateral sclerosis        363       15521
# 7              Human T-cell leukemia virus 1 infection        216       15521
# ..                                                 ...        ...         ...
# 237                             Glutathione metabolism         56       15521
# 238                  Pantothenate and CoA biosynthesis         21       15521
# 239                         Nucleotide excision repair         45       15521
# 240                                 Mineral absorption         59       15521
# 241                           Primary immunodeficiency         37       15521
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 3                  403                  26001   0.025965  0.817444  query_1
# 4                  387                  26001   0.024934  0.814737  query_1
# 5                  221                  26001   0.014239  0.876984  query_1
# 6                  299                  26001   0.019264  0.823691  query_1
# 7                  191                  26001   0.012306  0.884259  query_1
# ..                 ...                    ...        ...       ...      ...
# 237                 46                  26001   0.002964  0.821429  query_1
# 238                 20                  26001   0.001289  0.952381  query_1
# 239                 38                  26001   0.002448  0.844444  query_1
# 240                 48                  26001   0.003093  0.813559  query_1
# 241                 32                  26001   0.002062  0.864865  query_1
#
#           parents                                      intersections  \
# 3    [KEGG:00000]  [AKT1, AKT2, AKT3, ALYREF, APAF1, B2M, BAD, BA...
# 4    [KEGG:00000]  [ACTR10, ACTR1A, ADRM1, AGER, APAF1, APC, APC2...
# 5    [KEGG:00000]  [ACAP1, ACAP2, ACAP3, ACTR2, ACTR3, ACTR3B, AG...
# 6    [KEGG:00000]  [ACTB, ACTG1, ACTR10, ACTR1A, ADRM1, ALYREF, A...
# 7    [KEGG:00000]  [ADCY2, ADCY3, ADCY4, ADCY5, ADCY6, ADCY7, ADC...
# ..            ...                                                ...
# 237  [KEGG:00000]  [ANPEP, CHAC1, CHAC2, G6PD, GCLC, GCLM, GGCT, ...
# 238  [KEGG:00000]  [AASDHPPT, ALDH1B1, ALDH2, ALDH3A2, BCAT1, BCA...
# 239  [KEGG:00000]  [CCNH, CDK7, CUL4A, CUL4B, DDB1, DDB2, ERCC2, ...
# 240  [KEGG:00000]  [ATOX1, ATP1A1, ATP1A2, ATP1A3, ATP1A4, ATP1B1...
# 241  [KEGG:00000]  [ADA, AIRE, BLNK, BTK, CD19, CD3D, CD3E, CD4, ...
#
#                                              evidences
# 3    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 6    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# ..                                                 ...
# 237  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 238  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 239  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 240  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 241  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
#
# [239 rows x 16 columns]
