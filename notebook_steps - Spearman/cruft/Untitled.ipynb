# %%
import pandas as pd
import cptac

# %%
luad = cptac.Ovarian()

# %%
cnv = luad.get_CNV()

# %%
cnv
# Out:
# Name            A1BG    A1CF  A3GALT2  A4GALT   A4GNT    AAAS    AACS   AADAC  \
# Patient_ID
# 01OV002    -0.124800  0.0667   0.0813 -0.1562  0.0812 -0.0486 -0.1707 -0.8644
# 01OV007     0.074800  0.1364   0.0475 -0.2225  0.0560  0.1431  0.0493  0.2044
# 01OV008    -0.991900 -0.0039  -0.0181 -0.4348 -0.3921 -0.0007 -0.0307  0.3166
# 01OV010    -0.478500 -0.1239   0.8067 -0.2729  0.1658  0.0185 -0.1063  0.1658
# 01OV013    -0.083000  0.0195  -0.1612 -0.2163  0.3290 -0.1963 -0.2774  0.6529
# ...              ...     ...      ...     ...     ...     ...     ...     ...
# 26OV008     0.076300  0.1549  -0.1890 -0.8415 -0.3852  0.1170 -0.0030 -0.2320
# 26OV009     0.205669  0.2664  -0.2017 -0.3188  0.1733  0.1581  0.0964  0.2762
# 26OV010    -0.602800  0.0897  -0.4184  0.1302 -0.0063  0.6374 -0.4640  0.3072
# 26OV011     0.235100  0.2073   0.2433  0.5440  0.4907  0.0962 -0.3121  0.6694
# 26OV013    -1.226100  0.1406  -0.0810 -0.1041  0.3003  0.1720 -0.2225  0.7601
#
# ...
