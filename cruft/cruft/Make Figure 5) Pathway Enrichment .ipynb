# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/kegg_pathway_enrichment_df.csv')
df
# Out:
#    source      native                                             name  \
# 0    KEGG  KEGG:01200                                Carbon metabolism
# 1    KEGG  KEGG:04142                                         Lysosome
# 2    KEGG  KEGG:01200                                Carbon metabolism
# 3    KEGG  KEGG:00280       Valine, leucine and isoleucine degradation
# 4    KEGG  KEGG:01230                      Biosynthesis of amino acids
# 5    KEGG  KEGG:00520      Amino sugar and nucleotide sugar metabolism
# 6    KEGG  KEGG:01100                               Metabolic pathways
# 7    KEGG  KEGG:00240                            Pyrimidine metabolism
# 8    KEGG  KEGG:00250      Alanine, aspartate and glutamate metabolism
# 9    KEGG  KEGG:04146                                       Peroxisome
# 10   KEGG  KEGG:00670                        One carbon pool by folate
# 11   KEGG  KEGG:03030                                  DNA replication
# 12   KEGG  KEGG:00630          Glyoxylate and dicarboxylate metabolism
# 13   KEGG  KEGG:00051                  Fructose and mannose metabolism
# 14   KEGG  KEGG:00983                  Drug metabolism - other enzymes
# 15   KEGG  KEGG:01212                            Fatty acid metabolism
# 16   KEGG  KEGG:00010                     Glycolysis / Gluconeogenesis
# 17   KEGG  KEGG:00190                        Oxidative phosphorylation
# 18   KEGG  KEGG:04932                Non-alcoholic fatty liver disease
# 19   KEGG  KEGG:05415                          Diabetic cardiomyopathy
# 20   KEGG  KEGG:01230                      Biosynthesis of amino acids
# 21   KEGG  KEGG:01200                                Carbon metabolism
# 22   KEGG  KEGG:04714                                    Thermogenesis
# 23   KEGG  KEGG:05012                                Parkinson disease
# 24   KEGG  KEGG:05230              Central carbon metabolism in cancer
# 25   KEGG  KEGG:04723             Retrograde endocannabinoid signaling
# 26   KEGG  KEGG:03030                                  DNA replication
# 27   KEGG  KEGG:03013                                    RNA transport
# 28   KEGG  KEGG:04110                                       Cell cycle
# 29   KEGG  KEGG:03430                                  Mismatch repair
# 30   KEGG  KEGG:04668                            TNF signaling pathway
# 31   KEGG  KEGG:04120                   Ubiquitin mediated proteolysis
# 32   KEGG  KEGG:05215                                  Prostate cancer
# 33   KEGG  KEGG:03015                        mRNA surveillance pathway
# 34   KEGG  KEGG:03410                             Base excision repair
# 35   KEGG  KEGG:04218                              Cellular senescence
# 36   KEGG  KEGG:05160                                      Hepatitis C
# 37   KEGG  KEGG:01524                         Platinum drug resistance
# 38   KEGG  KEGG:05169                     Epstein-Barr virus infection
# 39   KEGG  KEGG:04657                          IL-17 signaling pathway
# 40   KEGG  KEGG:03030                                  DNA replication
# 41   KEGG  KEGG:04110                                       Cell cycle
# 42   KEGG  KEGG:00240                            Pyrimidine metabolism
# 43   KEGG  KEGG:03430                                  Mismatch repair
# 44   KEGG  KEGG:00970                      Aminoacyl-tRNA biosynthesis
# 45   KEGG  KEGG:04512                         ECM-receptor interaction
# 46   KEGG  KEGG:00524  Neomycin, kanamycin and gentamicin biosynthesis
# 47   KEGG  KEGG:04510                                   Focal adhesion
# 48   KEGG  KEGG:03030                                  DNA replication
#
#          p_value  significant  \
# 0   3.916650e-04         True
# 1   2.500731e-02         True
# 2   2.814710e-06         True
# 3   2.868780e-06         True
# 4   6.306264e-04         True
# 5   7.937249e-04         True
# 6   9.679728e-04         True
# 7   2.061673e-03         True
# 8   4.471885e-03         True
# 9   7.411569e-03         True
# 10  1.120690e-02         True
# 11  1.434649e-02         True
# 12  2.141505e-02         True
# 13  3.651759e-02         True
# 14  3.688353e-02         True
# 15  3.776499e-02         True
# 16  4.146599e-02         True
# 17  2.936398e-06         True
# 18  8.930266e-05         True
# 19  6.191766e-04         True
# 20  4.591013e-03         True
# 21  9.259101e-03         True
# 22  1.921947e-02         True
# 23  3.390272e-02         True
# 24  3.981622e-02         True
# 25  4.210772e-02         True
# 26  1.000261e-06         True
# 27  2.562220e-04         True
# 28  5.157535e-04         True
# 29  5.790799e-04         True
# 30  2.386110e-03         True
# 31  9.153988e-03         True
# 32  9.454902e-03         True
# 33  1.358389e-02         True
# 34  1.560221e-02         True
# 35  2.197929e-02         True
# 36  2.348392e-02         True
# 37  2.447293e-02         True
# 38  3.218569e-02         True
# 39  4.209657e-02         True
# 40  4.201497e-07         True
# 41  9.764510e-05         True
# 42  2.647426e-04         True
# 43  7.869298e-03         True
# 44  1.279506e-02         True
# 45  7.364376e-03         True
# 46  8.053350e-03         True
# 47  3.399317e-02         True
# 48  3.430394e-02         True
#
#                                         description  term_size  query_size  \
# 0                                 Carbon metabolism        110        2788
# 1                                          Lysosome        118        2176
# 2                                 Carbon metabolism        110        2218
# 3        Valine, leucine and isoleucine degradation         48        2099
# 4                       Biosynthesis of amino acids         72        2218
# 5       Amino sugar and nucleotide sugar metabolism         43        2208
# 6                                Metabolic pathways       1237        2151
# 7                             Pyrimidine metabolism         51        1074
# 8       Alanine, aspartate and glutamate metabolism         31        2100
# 9                                        Peroxisome         78        2178
# 10                        One carbon pool by folate         18         151
# 11                                  DNA replication         35        1659
# 12          Glyoxylate and dicarboxylate metabolism         29        1339
# 13                  Fructose and mannose metabolism         31        2267
# 14                  Drug metabolism - other enzymes         61         960
# 15                            Fatty acid metabolism         50        1978
# 16                     Glycolysis / Gluconeogenesis         62        2218
# 17                        Oxidative phosphorylation        115        1509
# 18                Non-alcoholic fatty liver disease        130         507
# 19                          Diabetic cardiomyopathy        182        3304
# 20                      Biosynthesis of amino acids         72        3395
# 21                                Carbon metabolism        110        3395
# 22                                    Thermogenesis        195        1523
# 23                                Parkinson disease        218        2112
# 24              Central carbon metabolism in cancer         64        3260
# 25             Retrograde endocannabinoid signaling        101        1509
# 26                                  DNA replication         35        2694
# 27                                    RNA transport        153        2119
# 28                                       Cell cycle        103        1607
# 29                                  Mismatch repair         21        1542
# 30                            TNF signaling pathway         92          92
# 31                   Ubiquitin mediated proteolysis        126        1356
# 32                                  Prostate cancer         80          11
# 33                        mRNA surveillance pathway         86        2115
# 34                             Base excision repair         29        5335
# 35                              Cellular senescence        135        2940
# 36                                      Hepatitis C        116          94
# 37                         Platinum drug resistance         65        4623
# 38                     Epstein-Barr virus infection        167         161
# 39                          IL-17 signaling pathway         70           4
# 40                                  DNA replication         35         701
# 41                                       Cell cycle        103         202
# 42                            Pyrimidine metabolism         51         804
# 43                                  Mismatch repair         21        1985
# 44                      Aminoacyl-tRNA biosynthesis         28         977
# 45                         ECM-receptor interaction         80         448
# 46  Neomycin, kanamycin and gentamicin biosynthesis          4         247
# 47                                   Focal adhesion        185         448
# 48                                  DNA replication         35         210
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                  48                  12487   0.017217  0.436364  query_1
# 1                  39                  12487   0.017923  0.330508  query_1
# 2                  46                  12487   0.020739  0.418182  query_1
# 3                  25                  12487   0.011910  0.520833  query_1
# 4                  30                  12487   0.013526  0.416667  query_1
# 5                  22                  12487   0.009964  0.511628  query_1
# 6                 318                  12487   0.147838  0.257074  query_1
# 7                  16                  12487   0.014898  0.313725  query_1
# 8                  17                  12487   0.008095  0.548387  query_1
# 9                  29                  12487   0.013315  0.371795  query_1
# 10                  4                  12487   0.026490  0.222222  query_1
# 11                 14                  12487   0.008439  0.400000  query_1
# 12                 11                  12487   0.008215  0.379310  query_1
# 13                 15                  12487   0.006617  0.483871  query_1
# 14                 16                  12487   0.016667  0.262295  query_1
# 15                 20                  12487   0.010111  0.400000  query_1
# 16                 24                  12487   0.010821  0.387097  query_1
# 17                 40                  12487   0.026508  0.347826  query_1
# 18                 21                  12487   0.041420  0.161538  query_1
# 19                 83                  12487   0.025121  0.456044  query_1
# 20                 37                  12487   0.010898  0.513889  query_1
# 21                 51                  12487   0.015022  0.463636  query_1
# 22                 48                  12487   0.031517  0.246154  query_1
# 23                 64                  12487   0.030303  0.293578  query_1
# 24                 32                  12487   0.009816  0.500000  query_1
# 25                 33                  12487   0.021869  0.326733  query_1
# 26                 24                  12487   0.008909  0.685714  query_1
# 27                 56                  12487   0.026428  0.366013  query_1
# 28                 35                  12487   0.021780  0.339806  query_1
# 29                 12                  12487   0.007782  0.571429  query_1
# 30                  7                  12487   0.076087  0.076087  query_1
# 31                 31                  12487   0.022861  0.246032  query_1
# 32                  3                  12487   0.272727  0.037500  query_1
# 33                 32                  12487   0.015130  0.372093  query_1
# 34                 25                  12487   0.004686  0.862069  query_1
# 35                 57                  12487   0.019388  0.422222  query_1
# 36                  7                  12487   0.074468  0.060345  query_1
# 37                 42                  12487   0.009085  0.646154  query_1
# 38                 10                  12487   0.062112  0.059880  query_1
# 39                  2                  12487   0.500000  0.028571  query_1
# 40                 14                  12487   0.019971  0.400000  query_1
# 41                 12                  12487   0.059406  0.116505  query_1
# 42                 15                  12487   0.018657  0.294118  query_1
# 43                 12                  12487   0.006045  0.571429  query_1
# 44                 12                  12487   0.012282  0.428571  query_1
# 45                 12                  12487   0.026786  0.150000  query_1
# 46                  3                  12487   0.012146  0.750000  query_1
# 47                 18                  12487   0.040179  0.097297  query_1
# 48                  5                  12487   0.023810  0.142857  query_1
#
#            parents                                      intersections  \
# 0   ['KEGG:00000']  ['AGXT', 'TALDO1', 'ESD', 'ACSS2', 'ME2', 'GPI...
# 1   ['KEGG:00000']  ['HEXA', 'CTSO', 'PLA2G15', 'GM2A', 'CTSS', 'G...
# 2   ['KEGG:00000']  ['GOT1', 'TALDO1', 'GLYCTK', 'PKM', 'PGK1', 'I...
# 3   ['KEGG:00000']  ['ACAA2', 'EHHADH', 'HADHB', 'HSD17B10', 'ALDH...
# 4   ['KEGG:00000']  ['GOT1', 'TALDO1', 'MTR', 'PKM', 'PGK1', 'ASNS...
# 5   ['KEGG:00000']  ['FPGT', 'CYB5R4', 'UXS1', 'NPL', 'HK2', 'GNE'...
# 6   ['KEGG:00000']  ['GOT1', 'TALDO1', 'IMPDH2', 'MTHFD1L', 'UPRT'...
# 7   ['KEGG:00000']  ['UPRT', 'CAD', 'TYMS', 'RRM2', 'DUT', 'ENTPD5...
# 8   ['KEGG:00000']  ['GOT1', 'CAD', 'ASNS', 'GLUL', 'FOLH1', 'NIT2...
# 9   ['KEGG:00000']  ['EHHADH', 'PRDX1', 'ECH1', 'XDH', 'SLC27A2', ...
# 10  ['KEGG:00000']               ['MTHFD1L', 'MTHFD2', 'TYMS', 'MTR']
# 11  ['KEGG:00000']  ['POLE', 'RFC1', 'RPA1', 'PCNA', 'POLA2', 'POL...
# 12  ['KEGG:00000']  ['GLYCTK', 'GLUL', 'ACAT2', 'SHMT2', 'GCSH', '...
# 13  ['KEGG:00000']  ['FPGT', 'HK2', 'HKDC1', 'TKFC', 'HK3', 'PMM1'...
# 14  ['KEGG:00000']  ['IMPDH2', 'GSTP1', 'IMPDH1', 'RRM2', 'CES2', ...
# 15  ['KEGG:00000']  ['ACAA2', 'EHHADH', 'HADHB', 'ELOVL5', 'MECR',...
# 16  ['KEGG:00000']  ['ALDH3A1', 'PKM', 'PGK1', 'AKR1A1', 'HK2', 'L...
# 17  ['KEGG:00000']  ['ATP6V0D1', 'UQCR10', 'NDUFS5', 'NDUFB9', 'ND...
# 18  ['KEGG:00000']  ['UQCR10', 'NDUFS5', 'NDUFB9', 'PIK3CA', 'JUN'...
# 19  ['KEGG:00000']  ['SLC2A1', 'UQCR10', 'NDUFS5', 'NDUFB9', 'PIK3...
# 20  ['KEGG:00000']  ['TKTL1', 'RPIA', 'PGAM1', 'ENO1', 'SDS', 'PGK...
# 21  ['KEGG:00000']  ['TKTL1', 'RPIA', 'PGAM1', 'ENO1', 'SDS', 'PDH...
# 22  ['KEGG:00000']  ['SMARCC2', 'UQCR10', 'NDUFS5', 'ARID1B', 'NDU...
# 23  ['KEGG:00000']  ['UQCR10', 'NDUFS5', 'NDUFB9', 'NDUFB10', 'SLC...
# 24  ['KEGG:00000']  ['SLC2A1', 'MYC', 'PIK3CA', 'PGAM1', 'PIK3R1',...
# 25  ['KEGG:00000']  ['NDUFS5', 'NDUFB9', 'GNG12', 'NDUFB10', 'NDUF...
# 26  ['KEGG:00000']  ['RFC5', 'RFC4', 'PRIM1', 'RFC2', 'MCM2', 'RFC...
# 27  ['KEGG:00000']  ['NUP153', 'EIF5', 'XPO5', 'EIF5B', 'STRAP', '...
# 28  ['KEGG:00000']  ['TP53', 'PRKDC', 'CHEK2', 'YWHAG', 'SKP2', 'T...
# 29  ['KEGG:00000']  ['RFC5', 'RFC4', 'MSH6', 'RFC2', 'RFC3', 'MSH2...
# 30  ['KEGG:00000']  ['NFKB1', 'MMP3', 'FADD', 'BAG4', 'RIPK1', 'RE...
# 31  ['KEGG:00000']  ['UBE2G1', 'UBE2M', 'UBA6', 'UBE4A', 'SKP2', '...
# 32  ['KEGG:00000']                          ['NFKB1', 'MMP3', 'TP53']
# 33  ['KEGG:00000']  ['PPP2R2A', 'GSPT1', 'RNMT', 'DDX19A', 'NCBP1'...
# 34  ['KEGG:00000']  ['UNG', 'PARP2', 'POLB', 'LIG3', 'FEN1', 'POLD...
# 35  ['KEGG:00000']  ['NFKB1', 'TP53', 'CHEK2', 'RELA', 'VDAC2', 'Z...
# 36  ['KEGG:00000']  ['NFKB1', 'TP53', 'FADD', 'PPP2R2A', 'RIPK1', ...
# 37  ['KEGG:00000']  ['TP53', 'FADD', 'TOP2A', 'MSH6', 'AKT2', 'MSH...
# 38  ['KEGG:00000']  ['NFKB1', 'TP53', 'FADD', 'RIPK1', 'RELA', 'MA...
# 39  ['KEGG:00000']                                  ['NFKB1', 'MMP3']
# 40  ['KEGG:00000']  ['MCM2', 'MCM7', 'MCM5', 'LIG1', 'MCM3', 'MCM4...
# 41  ['KEGG:00000']  ['MCM2', 'YWHAZ', 'CDK1', 'MCM7', 'CCNA2', 'MC...
# 42  ['KEGG:00000']  ['ENTPD3', 'RRM2', 'UMPS', 'TYMS', 'CAD', 'TK1...
# 43  ['KEGG:00000']  ['PMS2', 'LIG1', 'RFC2', 'RFC1', 'RFC4', 'PCNA...
# 44  ['KEGG:00000']  ['YARS2', 'SEPSECS', 'TARS2', 'NARS2', 'PARS2'...
# 45  ['KEGG:00000']  ['LAMB3', 'LAMC2', 'SDC1', 'ITGA5', 'ITGB6', '...
# 46  ['KEGG:00000']                              ['HK2', 'HK3', 'HK1']
# 47  ['KEGG:00000']  ['LAMB3', 'LAMC2', 'SRC', 'PDGFC', 'VAV3', 'ME...
# 48  ['KEGG:00000']         ['PCNA', 'MCM6', 'POLD1', 'SSBP1', 'FEN1']
#
#                                             evidences       Cancer
# 0   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        CCRCC
# 1   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        CCRCC
# 2   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 3   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 4   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 5   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 6   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 7   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 8   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 9   [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 10           [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG']]  Endometrial
# 11  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 12  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 13  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 14  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 15  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 16  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...  Endometrial
# 17  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 18  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 19  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 20  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 21  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 22  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 23  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 24  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 25  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...        HNSCC
# 26  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 27  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 28  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 29  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 30  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 31  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 32                     [['KEGG'], ['KEGG'], ['KEGG']]         LSCC
# 33  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 34  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 35  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 36  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 37  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 38  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LSCC
# 39                               [['KEGG'], ['KEGG']]         LSCC
# 40  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LUAD
# 41  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LUAD
# 42  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LUAD
# 43  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LUAD
# 44  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         LUAD
# 45  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         PDAC
# 46                     [['KEGG'], ['KEGG'], ['KEGG']]         PDAC
# 47  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         PDAC
# 48  [['KEGG'], ['KEGG'], ['KEGG'], ['KEGG'], ['KEG...         PDAC

# %%
g = sns.FacetGrid(data = df, col = 'Cancer', col_wrap = 1, sharey = False)
g.map_dataframe(sns.barplot, y = 'name', x = 'p_value')
# Out:
# C:\Users\nanel\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
