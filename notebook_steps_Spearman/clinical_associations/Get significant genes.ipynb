# %% [markdown]
# ## Getting the genes that have a significant P-value for each cancer's delta correlation
# ### Do we want to use all of the significant genes (approx. 5000 genes for each cancer) or just the most significant (i.e. lowest 50 p-values)?

# %%
import pandas as pd
import pcprutils as ut
import scipy.odr
import altair as alt

# %%
delta_correlation_df = pd.read_csv('../data/delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]

# %%
# Get all significant delta correlations

delta_corr_sig = delta_correlation_df.loc[delta_correlation_df['FDR'] < 0.05]
delta_corr_sig
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 5       AADAT          -0.263372  1.531939e-02  4.572896e-02  CCRCC
# 7       AAGAB           0.364999  7.633656e-04  3.646252e-03  CCRCC
# 8        AAK1           0.356932  6.347464e-14  1.385608e-12  CCRCC
# 11       AARS           0.415815  6.031667e-03  2.119475e-02  CCRCC
# ...       ...                ...           ...           ...    ...
# 50302   ZWINT           0.837582  2.770355e-08  1.722312e-07   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [21749 rows x 5 columns]

# %%
# Get all significant genes for each specific cancer

ccrcc_delta = delta_corr_sig.loc[delta_corr_sig['Cancer'] == 'CCRCC']
hnscc_delta = delta_corr_sig.loc[delta_corr_sig['Cancer'] == 'HNSCC']
endo_delta = delta_corr_sig.loc[delta_corr_sig['Cancer'] == 'Endometrial']
lscc_delta = delta_corr_sig.loc[delta_corr_sig['Cancer'] == 'LSCC']
luad_delta = delta_corr_sig.loc[delta_corr_sig['Cancer'] == 'LUAD']

# %%
hnscc_delta
# Out:
#            Gene  Delta_Correlation       P_Value           FDR Cancer
# 19247     AADAC          -0.495044  6.258443e-05  5.740776e-04  HNSCC
# 19250      AAK1           0.614117  1.000902e-11  3.887029e-10  HNSCC
# 19255     AARS2           0.565982  3.124882e-05  3.164216e-04  HNSCC
# 19256    AARSD1           0.450818  7.373637e-03  2.865766e-02  HNSCC
# 19258  AASDHPPT           0.689065  3.945785e-11  1.390700e-09  HNSCC
# ...         ...                ...           ...           ...    ...
# 29369    ZSWIM8           0.502199  4.125039e-03  1.822641e-02  HNSCC
# 29370      ZW10           0.514764  7.248112e-04  4.498890e-03  HNSCC
# 29372     ZWINT           0.925693  2.668810e-05  2.757498e-04  HNSCC
# 29373      ZXDC           0.503974  1.021347e-02  3.715855e-02  HNSCC
# 29374    ZYG11B          -0.499354  1.252112e-03  7.115341e-03  HNSCC
#
# [3044 rows x 5 columns]

# %%
sort_hnscc = hnscc_delta.sort_values(by=['FDR'])

# %%
hnscc_genes = sort_hnscc['Gene'].to_list()
hnscc_genes
# Out:
# ['MYO1B',
#  'STAT1',
#  'STAT2',
#  'SULF1',
#  'PTK7',
#  'GBP1',
#  'LAMC2',
#  'NSUN2',
#  'TYMP',
#  'TPX2',
#  'GBP5',
#  'KIF2C',
#  'DDX60',
#  'MYO5A',
#  'DDX58',
#  'PLOD2',
#  'UBE2L6',
#  'RTKN',
#  'KRT17',
#  'ITGB6',
#  'AFAP1L2',
#  'RBP1',
#  'ISG15',
#  'NFIA',
#  'TRIP13',
#  'ANLN',
#  'TNFRSF12A',
#  'BST2',
#  'APOL2',
#  'OASL',
#  'ABI3BP',
#  'HMGA2',
#  'ANKLE2',
#  'PARP12',
#  'PLEK2',
#  'HAAO',
#  'OAS2',
#  'ITGA3',
#  'PPFIA1',
#  'SP100',
#  'INHBA',
#  'XAF1',
#  'PLAU',
#  'DHX36',
#  'CDK6',
#  'LOXL2',
#  'MMP1',
#  'SRPK2',
#  'IGF2BP3',
#  'IFIT3',
#  'PLOD1',
#  'APPL1',
#  'KIF23',
#  'MMP14',
#  'POLR2H',
#  'RAB7A',
#  'TOP2A',
#  'TFRC',
#  'KYNU',
#  'UBE2C',
#  'IGF2BP2',
#  'TSPAN7',
#  'FBLIM1',
#  'LRRC15',
#  'SLC2A1',
#  'OCLN',
#  'IFI44',
#  'PBX1',
#  'MAMDC2',
#  'FAT1',
#  'SP110',
#  'USP18',
#  'PCM1',
#  'KDELC1',
#  'RRM2',
#  'MFAP4',
#  'SLC7A8',
#  'DENND4C',
#  'LUZP1',
#  'AURKB',
#  'HMGB3',
#  'LPIN1',
#  'APOBEC3G',
#  'AASS',
#  'EPS8',
#  'SFRP4',
#  'P3H2',
#  'FST',
#  'P4HA2',
#  'GBP4',
#  'CMTR1',
#  'MISP',
#  'PARP1',
#  'IDO1',
#  'DLGAP5',
#  'RNMT',
#  'TANC2',
#  'XPO5',
#  'OAS3',
#  'MX2',
#  'PRKAR2A',
#  'DIAPH2',
#  'LAMB3',
#  'IL4I1',
#  'MTAP',
#  'NMI',
#  'TDRP',
#  'CTHRC1',
#  'SLC3A2',
#  'SULF2',
#  'CKAP5',
#  'SERPINE1',
#  'MAOA',
#  'IGFBP5',
#  'CPA4',
#  'IRF9',
#  'IFIT2',
#  'NCS1',
#  'ACOT7',
#  'FLAD1',
#  'FBXO6',
#  'MT2A',
#  'WARS',
#  'CCDC25',
#  'NCAPH',
#  'GAS7',
#  'ACP5',
#  'PLA2G4A',
#  'XPO7',
#  'PPAT',
#  'FSCN1',
#  'HERC5',
#  'MYO10',
#  'SH3GLB1',
#  'SLC16A3',
#  'NFIX',
#  'CSNK2A2',
#  'TTF2',
#  'CTDSPL2',
#  'GNAI1',
#  'CTSV',
#  'GJA1',
#  'SLC16A7',
#  'IFIH1',
#  'IVNS1ABP',
#  'FKBP14',
#  'CIP2A',
#  'MYH14',
#  'DHX58',
#  'DNAJB2',
#  'IFIT1',
#  'MKI67',
#  'CPXM1',
#  'C14orf119',
#  'CENPF',
#  'PTPN12',
#  'RNF114',
#  'ANXA11',
#  'RSAD2',
#  'TAP2',
#  'STAU2',
#  'KPNA2',
#  'WDHD1',
#  'SLC9A9',
#  'RFC5',
#  'RFC4',
#  'PARP9',
#  'CXCL8',
#  'GDAP1',
#  'PML',
#  'RNF213',
#  'RASAL1',
#  'SLC38A2',
#  'TENM2',
#  'GSDME',
#  'P3H1',
#  'SSBP2',
#  'PCDH7',
#  'CHL1',
#  'SNCG',
#  'AKR1B10',
#  'LAP3',
#  'SPRR4',
#  'TBL1XR1',
#  'SLFN5',
#  'CAMSAP2',
#  'IFI35',
#  'CXCL13',
#  'CTPS1',
#  'AOX1',
#  'RIC8A',
#  'FLRT3',
#  'BASP1',
#  'STON2',
#  'SLC7A11',
#  'PCDH1',
#  'TNXB',
#  'PPME1',
#  'FAM120C',
#  'TXNL1',
#  'METTL7A',
#  'SIRPA',
#  'MSN',
#  'ALDOC',
#  'PLK1',
#  'TDG',
#  'NEMP1',
#  'LAMA3',
#  'CHAF1A',
#  'MAGEA4',
#  'XPC',
#  'SEC14L2',
#  'FBXO45',
#  'JAG1',
#  'EIF2AK2',
#  'SETMAR',
#  'APOBEC3B',
#  'UBASH3B',
#  'TNFSF10',
#  'PTPN2',
#  'PSTPIP2',
#  'EPSTI1',
#  'FAM172A',
#  'CDK1',
#  'SLC39A14',
#  'TRMT5',
#  'ADAM15',
#  'P4HA1',
#  'DUSP22',
#  'PRC1',
#  'TRIM22',
#  'NGLY1',
#  'GFRA1',
#  'ZNF280C',
#  'STON1',
#  'GAB1',
#  'DARS2',
#  'TAP1',
#  'IL36G',
#  'PLOD3',
#  'CCNA2',
#  'EPHX1',
#  'PSMB9',
#  'RPS4Y1',
#  'CUX1',
#  'PAK1',
#  'TCEA3',
#  'XPOT',
#  'CHEK2',
#  'PLAUR',
#  'FGD2',
#  'UBE3C',
#  'DSC1',
#  'RIN1',
#  'CDK2',
#  'KANK1',
#  'MMP12',
#  'MX1',
#  'ISG20',
#  'STOML2',
#  'AAK1',
#  'PBK',
#  'PSAT1',
#  'NKRF',
#  'HERC6',
#  'MICAL2',
#  'KRT16',
#  'BLVRB',
#  'CYBRD1',
#  'AIF1L',
#  'CEBPZ',
#  'GPD2',
#  'ITGB5',
#  'EFNB2',
#  'ZC3HAV1L',
#  'MSH6',
#  'TBC1D5',
#  'FGF2',
#  'HINT1',
#  'KNL1',
#  'C11orf54',
#  'DDI2',
#  'ZSCAN18',
#  'UHRF1',
#  'TMEM132A',
#  'MMP13',
#  'AASDHPPT',
#  'CEMIP2',
#  'HLA-B',
#  'DAB2IP',
#  'FKBP9',
#  'TAPBP',
#  'TRAF1',
#  'TMSB15B',
#  'AQP1',
#  'PODN',
#  'WDR48',
#  'RACGAP1',
#  'UBA6',
#  'OLFML2B',
#  'ALAD',
#  'IGF2BP1',
#  'ARHGEF12',
#  'BCAM',
#  'NOP2',
#  'PRTFDC1',
#  'TBL1X',
#  'TACC1',
#  'SFXN1',
#  'KIAA0930',
#  'TTC1',
#  'HLA-F',
#  'HLTF',
#  'GNG12',
#  'COBLL1',
#  'FADD',
#  'REXO2',
#  'THBS2',
#  'UBE4A',
#  'IFI30',
#  'ZFR',
#  'RSF1',
#  'CAB39L',
#  'MARCKS',
#  'SMS',
#  'COL5A2',
#  'NUP210',
#  'SMC2',
#  'NUP58',
#  'DCAF1',
#  'ZNF148',
#  'WDR1',
#  'PLPP3',
#  'COL17A1',
#  'HSPB8',
#  'PAIP1',
#  'TOMM22',
#  'LRP8',
#  'TK1',
#  'KIF11',
#  'PDE6D',
#  'IPO7',
#  'THBD',
#  'CA9',
#  'GEMIN5',
#  'NUMA1',
#  'RAP2B',
#  'SAAL1',
#  'CKS1B',
#  'NUB1',
#  'PIK3CA',
#  'DDX3Y',
#  'THOC5',
#  'LAMP3',
#  'FHL2',
#  'CMPK2',
#  'KCTD12',
#  'CGAS',
#  'IFIT5',
#  'NCEH1',
#  'KTN1',
#  'MPST',
#  'MAGI1',
#  'SLC4A2',
#  'FDFT1',
#  'NEBL',
#  'WBP11',
#  'BCCIP',
#  'RBSN',
#  'WDR43',
#  'VCPIP1',
#  'C3orf58',
#  'CASP4',
#  'PTGS2',
#  'PUS7',
#  'DDHD1',
#  'USP39',
#  'SLC5A6',
#  'ITGBL1',
#  'DCP1B',
#  'VAMP3',
#  'HTT',
#  'TIMP3',
#  'MATN2',
#  'ANK2',
#  'SENP3',
#  'UBXN7',
#  'CCNT1',
#  'WDR37',
#  'HEPHL1',
#  'C19orf66',
#  'OXCT1',
#  'KHDC1L',
#  'SPARC',
#  'DIAPH3',
#  'FAS',
#  'PHLDB2',
#  'SORBS2',
#  'RIF1',
#  'TFPI',
#  'BID',
#  'NOTCH2',
#  'CCNB1',
#  'UTRN',
#  'RPIA',
#  'TDRD7',
#  'DTX3L',
#  'PSMB10',
#  'PCTP',
#  'DNAJC13',
#  'APLP2',
#  'NMRK1',
#  'RTP4',
#  'RCN2',
#  'HERC4',
#  'RSBN1L',
#  'NDC80',
#  'CAPN7',
#  'FGD4',
#  'ZNFX1',
#  'P3H3',
#  'CMSS1',
#  'FTO',
#  'CKAP4',
#  'UACA',
#  'ESYT1',
#  'FAM89A',
#  'ECT2',
#  'S100A7A',
#  'STX3',
#  'HEBP2',
#  'ARHGAP10',
#  'TPD52L2',
#  'MMP11',
#  'COL11A1',
#  'GBP2',
#  'GSDMC',
#  'UPP1',
#  'NOL10',
#  'KRT75',
#  'KIF4A',
#  'CDH11',
#  'EPPK1',
#  'NISCH',
#  'SNX9',
#  'PADI3',
#  'MRC2',
#  'METTL16',
#  'SLC12A7',
#  'APOL3',
#  'GPT2',
#  'LMO7',
#  'AHSA1',
#  'NOLC1',
#  'ARHGEF10L',
#  'TRMT1',
#  'PLAC9',
#  'NMT1',
#  'NSD3',
#  'TP53',
#  'DUSP14',
#  'LGALSL',
#  'RBBP5',
#  'TMEM97',
#  'HSF1',
#  'FAM114A2',
#  'GPNMB',
#  'CDV3',
#  'NCAPG2',
#  'HNMT',
#  'CRYBG3',
#  'FBXL6',
#  'TRAP1',
#  'MT1E',
#  'SMYD2',
#  'DHRS9',
#  'XPR1',
#  'MYBBP1A',
#  'CEMIP',
#  'PI4K2A',
#  'PPP1R14C',
#  'EEF1AKMT4',
#  'SRA1',
#  'PHF3',
#  'P3H4',
#  'GINS4',
#  'CCDC50',
#  'NAB1',
#  'ATAD3A',
#  'NEK9',
#  'VPS26B',
#  'FAP',
#  'IGF1R',
#  'SCAF8',
#  'PRIM1',
#  'PHLDA2',
#  'HSP90AA1',
#  'NUP155',
#  'LCK',
#  'FAM168A',
#  'KIFC1',
#  'HSPBP1',
#  'INPP1',
#  'CCDC86',
#  'STK3',
#  'KIAA1191',
#  'GPCPD1',
#  'SWAP70',
#  'ATAD3B',
#  'BAZ1B',
#  'ACAD8',
#  'DCLK1',
#  'TAB2',
#  'KRT4',
#  'GNL1',
#  'FAM83A',
#  'PPM1L',
#  'NMD3',
#  'FAM50A',
#  'PLAA',
#  'C2CD5',
#  'PLSCR1',
#  'CCDC127',
#  'HSP90AB1',
#  'ZNF598',
#  'LPCAT1',
#  'SSSCA1',
#  'ANTXR1',
#  'TLR3',
#  'RRP12',
#  'SIAE',
#  'ST13',
#  'NLRX1',
#  'PSMB8',
#  'COL14A1',
#  'BPGM',
#  'EGFR',
#  'PRPSAP2',
#  'ZNHIT2',
#  'FKBP10',
#  'VCP',
#  'HAUS6',
#  'TNS4',
#  'ZBP1',
#  'PRKDC',
#  'KAT7',
#  'SGPP1',
#  'UBE2T',
#  'TXNIP',
#  'TP53BP2',
#  'ZC3HAV1',
#  'DLGAP4',
#  'SMARCC2',
#  'C5orf22',
#  'DVL2',
#  'RRAS2',
#  'STIP1',
#  'SCD5',
#  'NEPRO',
#  'LSG1',
#  'BCL7A',
#  'MNAT1',
#  'AURKA',
#  'GATAD2B',
#  'PNP',
#  'TLDC1',
#  'CEP55',
#  'BMP2K',
#  'TPBG',
#  'PTPRE',
#  'CAD',
#  'NUDC',
#  'DDX31',
#  'MORC2',
#  'SOX2',
#  'LRRC8E',
#  'CXCL10',
#  'ALDH5A1',
#  'NUP88',
#  'AK4',
#  'MAGEA3',
#  'DHX29',
#  'FADS2',
#  'NUCKS1',
#  'PDGFRL',
#  'BDH1',
#  'SH3BGRL',
#  'IFFO2',
#  'GLCE',
#  'IPO4',
#  'CHMP5',
#  'ADH4',
#  'ABCF2',
#  'CCDC88A',
#  'DNMT1',
#  'SLC38A1',
#  'GFPT2',
#  'TNFAIP3',
#  'GSTA4',
#  'FER',
#  'CHAF1B',
#  'PLPBP',
#  'ENAH',
#  'RASA1',
#  'SDS',
#  'MARK3',
#  'CRBN',
#  'ITIH5',
#  'C17orf75',
#  'ICAM1',
#  'CCAR2',
#  'ADGRL2',
#  'PRMT3',
#  'PCYOX1',
#  'PON3',
#  'LZIC',
#  'CROCC',
#  'SMCHD1',
#  'TKFC',
#  'PKMYT1',
#  'MSH2',
#  'DDHD2',
#  'DCUN1D1',
#  'XPO1',
#  'POM121',
#  'KIF7',
#  'RBM12B',
#  'GTF3C4',
#  'HAT1',
#  'RELB',
#  'HSPB1',
#  'DPT',
#  'HLA-C',
#  'REPIN1',
#  'DNMT3A',
#  'CEBPB',
#  'SERPINA5',
#  'RNF214',
#  'CRNN',
#  'STX6',
#  'S100A12',
#  'USP16',
#  'CXorf38',
#  'POGZ',
#  'NAB2',
#  'WDFY1',
#  'PRELP',
#  'STX8',
#  'ABCE1',
#  'HSPBAP1',
#  'NDRG1',
#  'ATG13',
#  'NAT10',
#  'POMK',
#  'ASNS',
#  'IL1RAP',
#  'TMX4',
#  'NFIB',
#  'PLIN1',
#  'MAP4K5',
#  'MMP10',
#  'YTHDF1',
#  'RNF14',
#  'PLEKHG3',
#  'NLRP10',
#  'ZNF384',
#  'RNASE7',
#  'LRIF1',
#  'PACSIN1',
#  'ATP2B4',
#  'PSME3',
#  'NEDD1',
#  'CXCL14',
#  'EGFL7',
#  'ITPK1',
#  'ESF1',
#  'ASF1A',
#  'TRAPPC8',
#  'OSBPL3',
#  'PRAG1',
#  'STK25',
#  'PROSER2',
#  'PRKCI',
#  'CPTP',
#  'SMARCA2',
#  'SSB',
#  'RAB5B',
#  'BIRC2',
#  'HSCB',
#  'SUPT16H',
#  'PAFAH1B1',
#  'GSTZ1',
#  'NDEL1',
#  'TNFRSF18',
#  'TNFRSF21',
#  'NUDCD1',
#  'RPP25',
#  'LPAR1',
#  'ISG20L2',
#  'TARBP1',
#  'YBX1',
#  'LRRC8A',
#  'TRMT6',
#  'SPHK1',
#  'UBE2F',
#  'STARD5',
#  'RAB34',
#  'GALT',
#  'DHRS11',
#  'CALHM6',
#  'YES1',
#  'LIPE',
#  'EEFSEC',
#  'IGFBP3',
#  'LGALS3',
#  'CHORDC1',
#  'SAMD9L',
#  'SH3KBP1',
#  'GLTP',
#  'CD8A',
#  'ARFRP1',
#  'KRT23',
#  'BUB1B',
#  'IL36RN',
#  'FDPS',
#  'MAP1B',
#  'WIZ',
#  'BOLA1',
#  'SLC25A5',
#  'DSCC1',
#  'TIA1',
#  'ACSL4',
#  'DCAF5',
#  'EFNB1',
#  'SNCA',
#  'IFT74',
#  'PLA2G4E',
#  'NDRG2',
#  'TFB2M',
#  'MXRA5',
#  'TCOF1',
#  'AP5Z1',
#  'SNX15',
#  'DARS',
#  'OGFR',
#  'RAVER2',
#  'LANCL2',
#  'KNSTRN',
#  'CLC',
#  'CKAP2',
#  'KIAA0391',
#  'NUDCD2',
#  'MB21D2',
#  'CARHSP1',
#  'RPUSD2',
#  'LIG4',
#  'RIOK1',
#  'HEATR5A',
#  'DCTPP1',
#  'DMXL1',
#  'IARS2',
#  'PSD3',
#  'TLR2',
#  'CHTF18',
#  'PHF2',
#  'PRMT6',
#  'TTPAL',
#  'MOB2',
#  'CLNS1A',
#  'PLEKHA1',
#  'RSPRY1',
#  'ASCC3',
#  'ENO1',
#  'EPM2AIP1',
#  'MTA1',
#  'TSC22D2',
#  'NDUFA4L2',
#  'ADAM17',
#  'PGAM1',
#  'SLC7A5',
#  'HACL1',
#  'AHR',
#  'ANKRD28',
#  'SQLE',
#  'NUBP1',
#  'PLD2',
#  'GZMH',
#  'KCNK1',
#  'EZH2',
#  'MSH3',
#  'SCARA5',
#  'PIK3CG',
#  'TUBB3',
#  'PTEN',
#  'RAB23',
#  'HARS2',
#  'MEFV',
#  'DBR1',
#  'CLCA4',
#  'DHX57',
#  'RETSAT',
#  'ARHGAP21',
#  'ELP3',
#  'CD4',
#  'PHIP',
#  'TBCE',
#  'ARID1B',
#  'ZHX2',
#  'MTPAP',
#  'SLC1A4',
#  'ATAD2',
#  'UQCRC2',
#  'DEK',
#  'NDUFA4',
#  'SPP1',
#  'ABLIM1',
#  'FANCI',
#  'OPA1',
#  'HMMR',
#  'CXCL12',
#  'ALPL',
#  'PITPNM1',
#  'C1QTNF5',
#  'OSBP',
#  'SEC24B',
#  'LRRC8D',
#  'ANP32B',
#  'COIL',
#  'CLEC2B',
#  'LSS',
#  'ARHGEF7',
#  'WDR55',
#  'CBLL1',
#  'PAK2',
#  'TTC39B',
#  'CD300A',
#  'ZBED1',
#  'PPP1R7',
#  'KIF16B',
#  'BRD3',
#  'DRG1',
#  'ITGAV',
#  'IPO9',
#  'DTL',
#  'FAM213A',
#  'ADIRF',
#  'RBPJ',
#  'FUK',
#  'VAC14',
#  'GTPBP4',
#  'RBM4',
#  'TFCP2',
#  'MMP28',
#  'XRN1',
#  'TRIM2',
#  'GSPT2',
#  'KARS',
#  'HSPH1',
#  'CHMP7',
#  'ACY1',
#  'DAGLB',
#  'FZD6',
#  'CD3EAP',
#  'UBE2S',
#  'LPCAT2',
#  'DEFB103A',
#  'NOTCH3',
#  'FABP6',
#  'GATM',
#  'ZNF622',
#  'OXSR1',
#  'URI1',
#  'POSTN',
#  'PLEKHA5',
#  'VPS36',
#  'FKBP4',
#  'C12orf75',
#  'ZMYM3',
#  'ATRX',
#  'MCM2',
#  'BRAT1',
#  'HEATR1',
#  'SIPA1',
#  'FANCD2',
#  'RTF1',
#  'RPRD1B',
#  'TUBB6',
#  'MSI1',
#  'UPF2',
#  'SMARCAD1',
#  'RBM26',
#  'ABCF1',
#  'PDHA1',
#  'TUSC1',
#  'SPATS2L',
#  'USP11',
#  'ATG9A',
#  'FAM207A',
#  'CALM1',
#  'GZMB',
#  'CBLC',
#  'ATP6V0D1',
#  'WIPI2',
#  'PADI1',
#  'CRKL',
#  'PICALM',
#  'SMAD4',
#  'SORT1',
#  'AGFG1',
#  'NDUFB1',
#  'TMEM185B',
#  'KNOP1',
#  'NF2',
#  'EIF1AY',
#  'CDKN2A',
#  'NUDT15',
#  'TRIM21',
#  'RXRB',
#  'CDC5L',
#  'CPSF7',
#  'CEACAM6',
#  'WASHC4',
#  'GPC1',
#  'TRIM24',
#  'ABHD16A',
#  'CBR3',
#  'LRRC57',
#  'ACBD6',
#  'TMEM63B',
#  'MCM6',
#  'AK6',
#  'SPAST',
#  'PLIN4',
#  'NUP133',
#  'YLPM1',
#  'SARM1',
#  'RRS1',
#  'FGFR1OP',
#  'RARRES2',
#  'PPP2CB',
#  'KIF14',
#  'WDR70',
#  'TWSG1',
#  'USP40',
#  'ADAR',
#  'GPAT4',
#  'CDAN1',
#  'CACYBP',
#  'SYPL1',
#  'SC5D',
#  'CBX8',
#  'POP1',
#  'PCYT1A',
#  'ATP6V1B2',
#  'TIPRL',
#  'BAZ1A',
#  'CT45A10',
#  'MYH15',
#  'ACAD9',
#  'C7orf25',
#  'PARG',
#  'ITGA11',
#  'TAGLN2',
#  'SEC61B',
#  'ARMC8',
#  'CDC42BPB',
#  'DOCK10',
#  'SNRPB',
#  'NCAPD2',
#  'CARD9',
#  'STAG2',
#  'MRM2',
#  'RAB30',
#  'DDX19B',
#  'SLIT3',
#  'KCTD21',
#  'SEMA4D',
#  'EMSY',
#  'BAK1',
#  'GALK2',
#  'ZWINT',
#  'CNBP',
#  'CNOT7',
#  'MBLAC2',
#  'DGKH',
#  'PMP2',
#  'LEMD2',
#  'VARS',
#  'DPH5',
#  'CD3G',
#  'UBE2Q1',
#  'ADGRE2',
#  'NUSAP1',
#  'IRF7',
#  'MST1R',
#  'CADM4',
#  'RNF115',
#  'TSPAN9',
#  'VANGL2',
#  'TRIP10',
#  ...]

# %%
import cptac
cptac.download('hnscc')
hnscc = cptac.Hnscc()

# %%
hnscc_clin = hnscc.get_clinical()
hnscc_clin
# Out:
# Name        Sample_Tumor_Normal  Cored_Sample            P16   age  \
# Patient_ID
# C3L-00977                 Tumor         False  Not Evaluated  56.0
# C3L-00987                 Tumor         False  Not Evaluated  61.0
# C3L-00994                 Tumor         False  Not Evaluated  50.0
# C3L-00995                 Tumor         False  Not Evaluated  56.0
# C3L-00997                 Tumor         False  Not Evaluated  47.0
# ...                         ...           ...            ...   ...
# C3N-04276.N              Normal         False            NaN   NaN
# C3N-04277.N              Normal         False            NaN   NaN
# C3N-04278.N              Normal         False            NaN   NaN
# C3N-04279.N              Normal         False            NaN   NaN
# C3N-04611.N              Normal         False            NaN   NaN
#
# Name                                            alcohol_consum  \
# Patient_ID
# C3L-00977                                 Lifelong non-drinker
# C3L-00987    Consumed alcohol in the past, but currently a ...
# C3L-00994    Alcohol consumption more than 2 drinks per day...
# C3L-00995    Alcohol consumption more than 2 drinks per day...
# C3L-00997                                 Lifelong non-drinker
# ...                                                        ...
# C3N-04276.N                                                NaN
# C3N-04277.N                                                NaN
# C3N-04278.N                                                NaN
# C3N-04279.N                                                NaN
# C3N-04611.N                                                NaN
#
# Name        clinic_staging_dist_metas  country  follow_up_days  \
# Patient_ID
# C3L-00977                         cM0   Russia           377.0
# C3L-00987                         cM0  Ukraine           429.0
# C3L-00994                         cM0  Ukraine           132.0
# C3L-00995                         cM0  Ukraine           -10.0
# C3L-00997                         cM0  Ukraine           442.0
# ...                               ...      ...             ...
# C3N-04276.N                       NaN      NaN             NaN
# C3N-04277.N                       NaN      NaN             NaN
# C3N-04278.N                       NaN      NaN             NaN
# C3N-04279.N                       NaN      NaN             NaN
# C3N-04611.N                       NaN      NaN             NaN
#
# Name        follow_up_is_contact follow_up_vital_status  ... smoke_age_start  \
# Patient_ID                                               ...
# C3L-00977                     No                 Living  ...             NaN
# C3L-00987                    Yes                 Living  ...              18
# C3L-00994                     No               Deceased  ...              16
# C3L-00995                     No               Deceased  ...              25
# C3L-00997                    Yes                 Living  ...              12
# ...                          ...                    ...  ...             ...
# C3N-04276.N                  NaN                    NaN  ...             NaN
# C3N-04277.N                  NaN                    NaN  ...             NaN
# C3N-04278.N                  NaN                    NaN  ...             NaN
# C3N-04279.N                  NaN                    NaN  ...             NaN
# C3N-04611.N                  NaN                    NaN  ...             NaN
#
# Name        smoke_age_stop                                    smoking_history  \
# Patient_ID
# C3L-00977              NaN             Current reformed smoker, years unknown
# C3L-00987              NaN  Current smoker: Includes daily and non-daily s...
# C3L-00994               50       Current reformed smoker within past 15 years
# C3L-00995               56        Current reformed smoker, more than 15 years
# C3L-00997               27        Current reformed smoker, more than 15 years
# ...                    ...                                                ...
# C3N-04276.N            NaN                                                NaN
# C3N-04277.N            NaN                                                NaN
# C3N-04278.N            NaN                                                NaN
# C3N-04279.N            NaN                                                NaN
# C3N-04611.N            NaN                                                NaN
#
# Name         smoking_inferred_binary  \
# Patient_ID
# C3L-00977            strong_evidence
# C3L-00987            strong_evidence
# C3L-00994            strong_evidence
# C3L-00995              weak_evidence
# C3L-00997            strong_evidence
# ...                              ...
# C3N-04276.N                      NaN
# C3N-04277.N                      NaN
# C3N-04278.N                      NaN
# C3N-04279.N                      NaN
# C3N-04611.N                      NaN
#
# Name                                       smoking_second_hand tumor_focality  \
# Patient_ID
# C3L-00977                                                  Yes       Unifocal
# C3L-00987                                                  Yes       Unifocal
# C3L-00994    Exposure to secondhand smoke history not avail...       Unifocal
# C3L-00995    Exposure to secondhand smoke history not avail...       Unifocal
# C3L-00997                                                  Yes       Unifocal
# ...                                                        ...            ...
# C3N-04276.N                                                NaN            NaN
# C3N-04277.N                                                NaN            NaN
# C3N-04278.N                                                NaN            NaN
# C3N-04279.N                                                NaN            NaN
# C3N-04611.N                                                NaN            NaN
#
# Name         tumor_necrosis tumor_site_curated tumor_site_original  \
# Patient_ID
# C3L-00977    Not identified        Oral cavity      Floor of mouth
# C3L-00987           Present        Oral cavity              Tongue
# C3L-00994           Present        Oral cavity              Tongue
# C3L-00995    Not identified        Oral cavity       Buccal mucosa
# C3L-00997           Present         Oropharynx          Oropharynx
# ...                     ...                ...                 ...
# C3N-04276.N             NaN                NaN                 NaN
# C3N-04277.N             NaN                NaN                 NaN
# C3N-04278.N             NaN                NaN                 NaN
# C3N-04279.N             NaN                NaN                 NaN
# C3N-04611.N             NaN                NaN                 NaN
#
# Name        tumor_size_cm
# Patient_ID
# C3L-00977             1.2
# C3L-00987             4.0
# C3L-00994             3.0
# C3L-00995             4.0
# C3L-00997             4.0
# ...                   ...
# C3N-04276.N           NaN
# C3N-04277.N           NaN
# C3N-04278.N           NaN
# C3N-04279.N           NaN
# C3N-04611.N           NaN
#
# [192 rows x 30 columns]

# %%
hnscc_delta
# Out:
#            Gene  Delta_Correlation       P_Value           FDR Cancer
# 19247     AADAC          -0.495044  6.258443e-05  5.740776e-04  HNSCC
# 19250      AAK1           0.614117  1.000902e-11  3.887029e-10  HNSCC
# 19255     AARS2           0.565982  3.124882e-05  3.164216e-04  HNSCC
# 19256    AARSD1           0.450818  7.373637e-03  2.865766e-02  HNSCC
# 19258  AASDHPPT           0.689065  3.945785e-11  1.390700e-09  HNSCC
# ...         ...                ...           ...           ...    ...
# 29369    ZSWIM8           0.502199  4.125039e-03  1.822641e-02  HNSCC
# 29370      ZW10           0.514764  7.248112e-04  4.498890e-03  HNSCC
# 29372     ZWINT           0.925693  2.668810e-05  2.757498e-04  HNSCC
# 29373      ZXDC           0.503974  1.021347e-02  3.715855e-02  HNSCC
# 29374    ZYG11B          -0.499354  1.252112e-03  7.115341e-03  HNSCC
#
# [3044 rows x 5 columns]

# %% [markdown]
# ## Calculate regression line for all patients for each tissue type for each gene

# %%
prot_trans = ut.load_prot_trans([
    "ccrcc",
    "endometrial",
    "hnscc",
    "lscc",
    "luad",
])
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 907 duplicated column headers. (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 27)
# cptac warning: Due to dropping the specified levels, dataframe now has 907 duplicated column headers. (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 41)
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 163)
# cptac warning: Due to dropping the specified levels, dataframe now has 858 duplicated column headers. (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 27)
# cptac warning: Due to dropping the specified levels, dataframe now has 858 duplicated column headers. (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 41)
# cptac warning: Due to dropping the specified levels, dataframe now has 745 duplicated column headers. (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 27)
# cptac warning: Due to dropping the specified levels, dataframe now has 745 duplicated column headers. (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pcprutils/__init__.py, line 41)

# %%
def get_regression(corr_df, prot_trans_df):
    
    sig_prot_trans = prot_trans_df[prot_trans_df["Gene"].isin(corr_df["Gene"])]
    
    def get_odr(df):
        
        def f(B, x):
            return B[0]*x + B[1]
        
        linear = scipy.odr.Model(f)
        data = scipy.odr.Data(df["Transcriptomics"], df["Proteomics"])
        odr = scipy.odr.ODR(data, linear, beta0=[1, 1])
        output = odr.run()
        
        return output.beta
    
    results = sig_prot_trans.\
    groupby(["Tissue", "Gene"]).\
    apply(get_odr).\
    reset_index(drop=False).\
    rename(columns={0: "beta"})
    
    mb = pd.DataFrame(results["beta"].tolist(), columns=["m", "b"])
    results = pd.concat([results, mb], axis=1).drop(columns=["beta"])
    
    return results

hnscc_results = get_regression(hnscc_delta, prot_trans["hnscc"])
luad_results = get_regression(luad_delta, prot_trans["luad"])
lscc_results = get_regression(lscc_delta, prot_trans["lscc"])
ccrcc_results = get_regression(ccrcc_delta, prot_trans["ccrcc"])
endo_results = get_regression(endo_delta, prot_trans["endometrial"])

# %%
def make_regplot(df):
    scatter = alt.Chart(df).mark_circle().encode(
        x="Transcriptomics",
        y="Proteomics",
        color="Tissue",
        tooltip=["Patient_ID"]
    )
    
    return scatter

def make_lineplot(df):
    line = alt.Chart(df).mark_line().encode(
        x='x',
        y='m(x)+b'
    )
    
    return line

# %%
#for gene in hnscc_results['Gene']:
gene = 'AADAC'

pr_tr_cancer = prot_trans['hnscc']
gene_df = pr_tr_cancer.loc[pr_tr_cancer['Gene'] == gene]
patient_scatter = make_regplot(gene_df)
    
gene_line = make_lineplot(hnscc_results.loc[hnscc_results['Gene'] == gene])
    
patient_scatter+gene_line
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/altair/vegalite/v4/schema/channels.py in to_dict(self, validate, ignore, context)
#      38             elif not (type_in_shorthand or type_defined_explicitly):
#      39                 if isinstance(context.get('data', None), pd.DataFrame):
# ---> 40                     raise ValueError("{} encoding field is specified without a type; "
#      41                                      "the type cannot be inferred because it does not "
#      42                                      "match any column in the data.".format(shorthand))
#
# ValueError: x encoding field is specified without a type; the type cannot be inferred because it does not match any column in the data.
# alt.LayerChart(...)

# %%
patient_scatter
# Out:
# alt.Chart(...)

# %%
hnscc_results
# Out:
#       Tissue      Gene         m          b
# 0     Normal     AADAC  0.599738  17.448712
# 1     Normal      AAK1 -0.004513  24.396185
# 2     Normal     AARS2  0.045875  23.694298
# 3     Normal    AARSD1  1.581359  10.203151
# 4     Normal  AASDHPPT  0.166157  23.169844
# ...      ...       ...       ...        ...
# 6083   Tumor    ZSWIM8  0.342667  20.922590
# 6084   Tumor      ZW10  0.313533  21.579339
# 6085   Tumor     ZWINT  0.992880   8.764980
# 6086   Tumor      ZXDC  2.057887  -2.979253
# 6087   Tumor    ZYG11B  0.442652  17.603829
#
# [6088 rows x 4 columns]
