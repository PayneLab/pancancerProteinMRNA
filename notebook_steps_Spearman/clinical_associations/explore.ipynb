# %% [markdown]
# # Adventure is out there!
#
# It looks like a lot of these are gene level tables, with all patients aggregated together. But we want to look at each patient individually.

# %%
import pcprutils as ut
import altair as alt

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## Load formatted proteomics and transcriptomics tables

# %%
tables = ut.load_prot_trans(["hnscc"])

# %%
for name, df in tables.items():
    print(f"{name}: {df.shape}")
# Out:
# hnscc: (1454346, 5)

# %% [markdown]
# ## Graphs

# %%
df = df.assign(Patient_ID=df["Patient_ID"].str.replace(".N", "", regex=False))

# %%
def make_regplot(pdf):
    scatter = alt.Chart(pdf).mark_circle().encode(
        x="Transcriptomics",
        y="Proteomics",
        color="Tissue",
        tooltip=["Gene"]
    )

    scatter = scatter + scatter.transform_regression(
        "Transcriptomics",
        "Proteomics"
    ).mark_line().transform_fold(
         ["regression line"], 
         as_=["regression", "y"]
    ).encode(alt.Color("regression:N"))

    chart = scatter.facet(
        columns=2,
        facet=alt.Facet("Tissue")
    ).resolve_scale(
        x="independent",
        y="independent",
    )

    return chart

# %%
norms = df[df["Tissue"] == "Normal"]["Patient_ID"].drop_duplicates(keep="first")

# %%
charts = []
for norm in norms[:10]:
    pdf = df[df["Patient_ID"] == norm]
    charts.append(make_regplot(pdf))
    
a = alt.vconcat(*charts)

# %%
a.save("test.html")

# %%
ndf = df[df["Patient_ID"].isin(norms)]

# %%
ndf
# Out:
#         Patient_ID   Gene  Proteomics  Tissue  Transcriptomics
# 2        C3L-00994   A1BG   28.348186   Tumor             5.14
# 3        C3L-00995   A1BG   28.004445   Tumor             5.69
# 4        C3L-00997   A1BG   27.735214   Tumor             4.54
# 5        C3L-00999   A1BG   27.949122   Tumor             4.89
# 7        C3L-01237   A1BG   28.216073   Tumor             5.42
# 8        C3L-02617   A1BG   27.452281   Tumor             4.26
# 9        C3L-02621   A1BG   27.701040   Tumor             6.21
# 10       C3L-02651   A1BG   27.616140   Tumor             4.97
# 11       C3L-03378   A1BG   27.756237   Tumor             4.82
# 17       C3N-00204   A1BG   27.827772   Tumor             7.49
# 21       C3N-00306   A1BG   27.659420   Tumor             5.49
# 22       C3N-00307   A1BG   27.598440   Tumor             5.67
# 23       C3N-00498   A1BG   27.550777   Tumor             5.04
# 24       C3N-00519   A1BG   28.158142   Tumor             5.53
# 32       C3N-01337   A1BG   27.340644   Tumor             6.22
# 33       C3N-01338   A1BG   27.318493   Tumor             5.23
# 35       C3N-01340   A1BG   27.626767   Tumor             6.41
# 37       C3N-01645   A1BG   27.248469   Tumor             6.24
# 39       C3N-01754   A1BG   27.442254   Tumor             6.11
# 1766695  C3N-03876   ZZZ3   20.464641  Normal            11.56
#
# [808979 rows x 5 columns]

# %%
cutoff = 15
# if cancer_name == 'Endometrial':
#     cutoff = 10

def get_corr(group):
    res = group.corr(method="spearman", min_periods=cutoff)
    return res.iloc[0, 1]

corr = ndf.\
groupby(["Patient_ID", "Tissue"]).\
apply(get_corr).\
to_frame().\
reset_index().\
pivot(index="Patient_ID", columns="Tissue", values=0)

corr = corr.assign(diff=corr["Tumor"] - corr["Normal"])

corr
# Out:
# Tissue        Normal     Tumor      diff
# Patient_ID
# C3L-00994   0.449391  0.465987  0.016597
# C3L-00995   0.435475  0.434951 -0.000524
# C3L-00997   0.434359  0.471041  0.036683
# C3L-00999   0.434085  0.434559  0.000474
# C3L-01237   0.453892  0.451955 -0.001937
# C3L-02617   0.429887  0.422181 -0.007706
# C3L-02621   0.436097  0.431910 -0.004187
# C3L-02651   0.427349  0.448294  0.020945
# C3L-03378   0.435145  0.452945  0.017800
# C3N-00204   0.452002  0.453287  0.001285
# C3N-00306   0.429075  0.421558 -0.007518
# C3N-00307   0.420045  0.403047 -0.016998
# C3N-00498   0.350507  0.431356  0.080848
# C3N-00519   0.430629  0.433626  0.002996
# C3N-01337   0.476015  0.484725  0.008710
# C3N-01338   0.449800  0.489189  0.039389
# C3N-01340   0.452107  0.464423  0.012316
# C3N-01645   0.442168  0.476514  0.034347
# C3N-01754   0.446690  0.487660  0.040970
# C3N-01756   0.444148  0.438663 -0.005485
# C3N-01943   0.457605  0.484441  0.026837
# C3N-01944   0.422548  0.458650  0.036102
# C3N-01946   0.455782  0.470271  0.014489
# C3N-01947   0.435168  0.456521  0.021352
# C3N-02279   0.442822  0.485275  0.042453
# C3N-02713   0.428086  0.447576  0.019490
# C3N-02714   0.451153  0.449446 -0.001707
# C3N-03027   0.438870  0.450932  0.012061
# C3N-03028   0.431468  0.476891  0.045423
# C3N-03045   0.446263  0.507144  0.060881
# C3N-03488   0.447684  0.454301  0.006617
# C3N-03490   0.421072  0.444282  0.023210
# C3N-03619   0.453036  0.467250  0.014214
# C3N-03620   0.434165  0.448994  0.014829
# C3N-03837   0.431853  0.480290  0.048437
# C3N-03841   0.429707  0.450991  0.021284
# C3N-03849   0.427337  0.488089  0.060752
# C3N-03876   0.423836  0.485396  0.061561
# C3N-03878   0.433891  0.435051  0.001159
# C3N-03888   0.444386  0.477453  0.033067
# C3N-03928   0.409965  0.457434  0.047469
# C3N-03933   0.406835  0.484439  0.077604

# %%
alt.Chart(corr).mark_boxplot().encode(
    y="diff"
).properties(
    width=100,
    height=500,
)
# Out:
# alt.Chart(...)
