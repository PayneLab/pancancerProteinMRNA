# %% [markdown]
# # Step 1: Import CPTAC Data and Define Correlation Functions

# %%
import cptac
import cptac.utils as ut
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import statistics as st
import load_data
import get_correlations

# %%
#Make docstrings for what is required
def get_single_gene_correlations(gene, cancer_type_list,type_dict,input_tissue_type = "tumor"):
    correlation_list = []
    type_list = []
    pval_list = []
    for cancer in cancer_type_list:
        correlation,pval,num_samples = get_correlations.correlation_list(cancer, [gene],tissue_type = input_tissue_type)
        if len(correlation) == 0:
            continue
        else:
            correlation_list.append(correlation[0])
            pval_list.append(pval[0][1])
            type_list.append(type_dict[cancer])
    return correlation_list, type_list, num_samples, pval_list

# %%
def make_df_with_genes(gene_list,cancer_list,name_dict,tissue_type):
    all_genes = []
    all_correlations = []
    all_cancer_types = []
    all_pvals = []
    for gene in gene_list:
        gene_corr_list,type_list,num_samples, pval_list = get_single_gene_correlations(gene,cancer_list,name_dict,tissue_type)
        gene_x,gene_y = get_x_y(gene_corr_list)
        all_genes.extend(gene_x)
        all_correlations.extend(gene_y)
        all_cancer_types.extend(type_list)
        all_pvals.extend(pval_list)
    df = pd.DataFrame(list(zip(all_genes,all_correlations,all_cancer_types, all_pvals)), columns =['Gene', 'Correlation','Cancer', 'p-val'])
    return(df)

# %%
def get_x_y(correlation_list):
    x = []
    y = []
    for item in correlation_list:
        x.append(item[0])
        y.append(item[1])
    return x,y

# %% [markdown]
# # Step 2: Define Desired Cancer Types

# %%
ccrcc = cptac.Ccrcc()
en = cptac.Endometrial()
luad = cptac.Luad()
hnscc  = cptac.Hnscc()
lscc = cptac.Lscc()
# Out:
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (<ipython-input-5-5c25f03e6d4a>, line 5)

# %%
cancer_list = [ccrcc,en,luad,hnscc,lscc]

# %%
type_dict = {ccrcc:"ccrcc",en:"endometrial",luad:"luad", hnscc:"hnscc",lscc:"lscc"}

# %% [markdown]
# # Step 3: Pick Genes and Make Dataframe

# %% [markdown]
# The genes shown here were picked from Bailey et al. found [here](https://pubmed.ncbi.nlm.nih.gov/29625053/)

# %%
cancer_genes = ['BRAF','FAT1','IDH1','TP53','KMT2D','KRAS','PIK3CA','PTEN','SPTA1']

# %%
tumor_df = make_df_with_genes(cancer_genes,cancer_list,type_dict,tissue_type = "tumor")
tumor_df['Tissue'] = ['Tumor'] * len(tumor_df)

# %%
tumor_df
# Out:
#       Gene  Correlation       Cancer         p-val Tissue
# 0     BRAF     0.546805        ccrcc  6.404490e-10  Tumor
# 1     BRAF     0.644945  endometrial  1.740190e-12  Tumor
# 2     BRAF     0.546703         luad  6.461032e-10  Tumor
# 3     BRAF     0.618639        hnscc  7.578852e-13  Tumor
# 4     BRAF    -0.059098         lscc  5.434862e-01  Tumor
# 5     FAT1     0.600361        ccrcc  4.138834e-12  Tumor
# 6     FAT1     0.859540  endometrial  7.399839e-29  Tumor
# 7     FAT1     0.753126         luad  2.311694e-21  Tumor
# 8     FAT1     0.813865        hnscc  5.556750e-27  Tumor
# 9     FAT1     0.838953         lscc  8.985484e-30  Tumor
# 10    IDH1     0.699513        ccrcc  1.885896e-17  Tumor
# 11    IDH1     0.922802  endometrial  2.675118e-40  Tumor
# 12    IDH1     0.736898         luad  4.446926e-20  Tumor
# 13    IDH1     0.844177        hnscc  9.646958e-31  Tumor
# 14    IDH1     0.792698         lscc  1.594770e-24  Tumor
# 15    TP53     0.096952  endometrial  3.832454e-01  Tumor
# 16    TP53     0.496929         luad  1.523660e-06  Tumor
# 17    TP53     0.742948        hnscc  2.981543e-18  Tumor
# 18    TP53     0.723227         lscc  9.640307e-19  Tumor
# 19   KMT2D     0.078602        ccrcc  4.143698e-01  Tumor
# 20   KMT2D     0.206689  endometrial  4.446940e-02  Tumor
# 21   KMT2D     0.343080         luad  2.433462e-04  Tumor
# 22   KMT2D     0.244149        hnscc  1.051409e-02  Tumor
# 23   KMT2D     0.240646         lscc  1.211582e-02  Tumor
# 24    KRAS     0.400604  endometrial  5.752369e-05  Tumor
# 25    KRAS     0.219640         luad  2.368358e-02  Tumor
# 26    KRAS     0.516669        hnscc  8.859633e-09  Tumor
# 27    KRAS     0.720933         lscc  1.395545e-18  Tumor
# 28  PIK3CA     0.521751        ccrcc  5.065631e-09  Tumor
# 29  PIK3CA     0.638375  endometrial  3.422092e-12  Tumor
# 30  PIK3CA     0.405897         luad  1.085663e-05  Tumor
# 31  PIK3CA     0.814412        hnscc  4.821807e-27  Tumor
# 32  PIK3CA     0.817814         lscc  3.444115e-27  Tumor
# 33    PTEN     0.497284        ccrcc  3.267175e-08  Tumor
# 34    PTEN     0.589048  endometrial  3.406507e-10  Tumor
# 35    PTEN     0.600418         luad  4.114600e-12  Tumor
# 36    PTEN     0.636979        hnscc  9.640723e-14  Tumor
# 37    PTEN     0.695318         lscc  6.855659e-17  Tumor
# 38   SPTA1     0.260784        ccrcc  5.929323e-03  Tumor
# 39   SPTA1    -0.107490  endometrial  2.998187e-01  Tumor
# 40   SPTA1    -0.082873         luad  3.893842e-01  Tumor
# 41   SPTA1     0.154798        hnscc  1.080085e-01  Tumor
# 42   SPTA1    -0.275174         lscc  4.306072e-03  Tumor

# %%
normal_df = make_df_with_genes(cancer_genes,cancer_list,type_dict,tissue_type = "normal")
normal_df['Tissue'] = ['Normal'] * len(normal_df)

# %%
normal_df
# Out:
#       Gene  Correlation Cancer         p-val  Tissue
# 0     BRAF     0.081654  ccrcc  4.861585e-01  Normal
# 1     BRAF     0.147973   luad  1.397435e-01  Normal
# 2     BRAF     0.173692  hnscc  2.713018e-01  Normal
# 3     BRAF    -0.037786   lscc  7.176714e-01  Normal
# 4     FAT1     0.409362  ccrcc  2.655076e-04  Normal
# 5     FAT1     0.373062   luad  1.219206e-04  Normal
# 6     FAT1     0.238513  hnscc  1.282240e-01  Normal
# 7     FAT1     0.483709   lscc  7.860562e-07  Normal
# 8     IDH1     0.741719  ccrcc  2.697707e-14  Normal
# 9     IDH1     0.692806   luad  1.001981e-15  Normal
# 10    IDH1     0.740893  hnscc  2.019960e-08  Normal
# 11    IDH1     0.634218   lscc  6.768440e-12  Normal
# 12    TP53    -0.193213   luad  9.447010e-02  Normal
# 13    TP53     0.149618  hnscc  3.699540e-01  Normal
# 14    TP53    -0.344411   lscc  6.760100e-04  Normal
# 15   KMT2D    -0.071417  ccrcc  5.426068e-01  Normal
# 16   KMT2D    -0.107127   luad  2.862975e-01  Normal
# 17   KMT2D     0.118734  hnscc  4.539083e-01  Normal
# 18   KMT2D    -0.034073   lscc  7.444075e-01  Normal
# 19    KRAS    -0.162044   luad  1.127935e-01  Normal
# 20    KRAS     0.234663  hnscc  1.346871e-01  Normal
# 21    KRAS     0.198606   lscc  5.499014e-02  Normal
# 22  PIK3CA     0.199898  ccrcc  8.552509e-02  Normal
# 23  PIK3CA     0.187812   luad  6.000407e-02  Normal
# 24  PIK3CA     0.028087  hnscc  8.598514e-01  Normal
# 25  PIK3CA     0.255913   lscc  1.278941e-02  Normal
# 26    PTEN     0.649130  ccrcc  2.995446e-10  Normal
# 27    PTEN     0.209110   luad  3.584929e-02  Normal
# 28    PTEN    -0.073318  hnscc  6.444848e-01  Normal
# 29    PTEN     0.054532   lscc  6.016573e-01  Normal
# 30   SPTA1    -0.155179  ccrcc  1.837206e-01  Normal
# 31   SPTA1     0.109024   luad  2.778005e-01  Normal
# 32   SPTA1     0.391600  hnscc  1.032935e-02  Normal
# 33   SPTA1     0.047282   lscc  6.508849e-01  Normal

# %%
# get delta correlation p-values
delta_corr_pvals_df = pd.read_csv('p_val.csv')
delta_corr_pvals_df
delta_corr_pvals_df
# Out:
#         Cancer      A1BG      A1CF       A2M         A2ML1    A4GALT  \
# 0        ccrcc  0.008435  0.001958  0.061198           NaN  0.347296
# 1  endometrial  0.824775       NaN  0.936116  3.499895e-02  0.264571
# 2          gbm  0.475921       NaN  0.953751           NaN       NaN
# 3         luad  0.778949       NaN  0.433724           NaN       NaN
# 4        hnscc  0.988560  0.446635  0.252807  6.755440e-02  0.118225
# 5         lscc  0.169387       NaN  0.610199  2.377650e-12  0.156933
#
#        AAAS          AACS     AADAC     AADAT  ...    ZSWIM9      ZW10  \
# 0  0.767248  1.477092e-01  0.081185  0.370717  ...       NaN  0.069946
# 1  0.030133  3.175433e-03       NaN  0.287843  ...  0.654079  0.781930
# 2  0.944833  2.692001e-01       NaN  0.995065  ...       NaN  0.428331
# 3  0.131262  7.607273e-12  0.065583  0.003088  ...       NaN  0.000012
# 4  0.011762  7.665152e-01  0.000098       NaN  ...       NaN  0.005881
# 5  0.030961  1.035001e-01  0.300931       NaN  ...  0.000682  0.000139
#
#          ZWILCH         ZWINT  ZXDA      ZXDC        ZYG11B       ZYX  \
# 0  1.166079e-01  2.703798e-01   NaN  0.065181  4.565249e-01  0.106062
# 1  7.278204e-03  2.185463e-03   NaN  0.359389  2.029671e-01  0.556780
# 2  4.868691e-04           NaN   NaN  0.752768  4.370716e-01  0.036739
# 3  5.299375e-16  2.143507e-05   NaN  0.574093  2.386150e-08  0.000360
# 4  3.638297e-01  8.984708e-06   NaN  0.001435  1.751749e-04  0.934953
# 5  6.967096e-08  6.784408e-12   NaN  0.005178  8.362345e-02  0.008578
#
#       ZZEF1      ZZZ3
# 0  0.327473  0.191946
# 1  0.236825  0.261292
# 2  0.512177  0.185044
# 3  0.000060  0.000002
# 4  0.090658  0.795908
# 5  0.011934  0.000571
#
# [6 rows x 14637 columns]

# %%
delta_corr_pvals_df[delta_corr_pvals_df.Cancer == 'luad'].reset_index()['BRAF'][0]
# Out:
# 0.0008911456607599553

# %%
combined_df = pd.merge(normal_df, tumor_df, how = 'outer')
combined_df['Significant Correlation'] = combined_df['p-val'] <= 0.05
delta_corr_pvals = []
for index, row in combined_df.iterrows():
    cancer = row['Cancer']
    gene = row['Gene']
    pval = delta_corr_pvals_df[delta_corr_pvals_df.Cancer == cancer].reset_index()[gene][0]
    delta_corr_pvals.append(pval)
combined_df['delta_corr_pval'] = delta_corr_pvals
combined_df['Significant Delta Correlation'] = combined_df['delta_corr_pval'] <= 0.05

# %%
combined_df
# Out:
#      Gene  Correlation       Cancer     p-val  Tissue  \
# 0    BRAF     0.081654        ccrcc  0.486158  Normal
# 1    BRAF     0.147973         luad  0.139744  Normal
# 2    BRAF     0.173692        hnscc  0.271302  Normal
# 3    BRAF    -0.037786         lscc  0.717671  Normal
# 4    FAT1     0.409362        ccrcc  0.000266  Normal
# ..    ...          ...          ...       ...     ...
# 72  SPTA1     0.260784        ccrcc  0.005929   Tumor
# 73  SPTA1    -0.107490  endometrial  0.299819   Tumor
# 74  SPTA1    -0.082873         luad  0.389384   Tumor
# 75  SPTA1     0.154798        hnscc  0.108009   Tumor
# 76  SPTA1    -0.275174         lscc  0.004306   Tumor
#
#     Significant Correlation  delta_corr_pval  Significant Delta Correlation
# 0                     False         0.000483                           True
# 1                     False         0.000891                           True
# 2                     False         0.003473                           True
# 3                     False         0.881426                          False
# 4                      True         0.089455                          False
# ..                      ...              ...                            ...
# 72                     True         0.005476                           True
# 73                    False         0.856207                          False
# 74                    False         0.168537                          False
# 75                    False         0.168930                          False
# 76                     True         0.021895                           True
#
# [77 rows x 8 columns]

# %% [markdown]
# # Step 4: Plot Data

# %%
g = sns.FacetGrid(combined_df, col ='Gene', height = 3, col_wrap = 3)

g.map_dataframe(sns.scatterplot, x = 'Tissue', y = 'Correlation', hue = 'Cancer', palette='tab10', size = 'Significant Correlation', size_order = [True, False])
g.map_dataframe(sns.lineplot, x = 'Tissue', y = 'Correlation', hue = 'Cancer', palette='tab10', style = 'Significant Delta Correlation', style_order = [True, False], label = '_Hidden')
g.set_axis_labels('Tissue', 'Correlation')
#g.add_legend()
g.set_titles('{col_name}')
current_handles, current_labels = plt.gca().get_legend_handles_labels()
del current_labels[9:15]
del current_handles[9:15]
plt.legend(current_handles, current_labels, bbox_to_anchor=(2.2, 2.2))
plt.savefig('Interesting_Cancer_Genes_Correlation_Change.png', bbox_inches='tight')

# %%
# change lines to represent statistical significance of change 
# also is original correlations statistically meaningful
