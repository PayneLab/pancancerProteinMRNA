# %%
import pandas as pd
import cptac
import scipy.stats as stats
import numpy as np
import statsmodels.stats.multitest as ssm
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
ccrcc = cptac.Ccrcc()
en = cptac.Endometrial()
luad = cptac.Luad()
lscc = cptac.Lscc()
hnscc = cptac.Hnscc()
# Out:
# Checking that hnscc index is up-to-date...
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (<ipython-input-2-7685cf93750a>, line 4)

# %%
cancer_list = [ccrcc, en, luad, lscc, hnscc]
cancer_names = ['ccrcc', 'en', 'luad', 'lscc', 'hnscc']

# %%
cancer_dfs = []
for cancer, name in zip(cancer_list, cancer_names):    
    trans_norm_df = cancer.get_transcriptomics(tissue_type = 'normal')
    if isinstance(trans_norm_df.columns, pd.MultiIndex):
        trans_norm_df = trans_norm_df.droplevel('Database_ID', axis = 1)
    trans_norm_df['patient_ID'] = trans_norm_df.index
    trans_norm_df = trans_norm_df.melt(id_vars = 'patient_ID', var_name = 'Gene', value_name = 'Transcriptomics')
    trans_norm_df['Tissue'] = ['normal'] * len(trans_norm_df)

    trans_tum_df = cancer.get_transcriptomics(tissue_type = 'tumor')
    if isinstance(trans_tum_df.columns, pd.MultiIndex):
        trans_tum_df = trans_norm_df.droplevel('Database_ID', axis = 1)
    trans_tum_df['patient_ID'] = trans_tum_df.index
    trans_tum_df = trans_tum_df.melt(id_vars = 'patient_ID', var_name = 'Gene', value_name = 'Transcriptomics')
    trans_tum_df['Tissue'] = ['tumor'] * len(trans_tum_df)
    trans_df = pd.concat([trans_norm_df, trans_tum_df])

    prot_norm_df = cancer.get_proteomics(tissue_type='normal')
    if isinstance(prot_norm_df.columns, pd.MultiIndex):
        prot_norm_df = prot_norm_df.droplevel('Database_ID', axis = 1)
    prot_norm_df['patient_ID'] = prot_norm_df.index
    prot_norm_df = prot_norm_df.melt(id_vars = 'patient_ID', var_name = 'Gene', value_name = 'Proteomics')
    prot_norm_df['Tissue'] = ['normal'] * len(prot_norm_df)

    prot_tum_df = cancer.get_proteomics(tissue_type='tumor')
    if isinstance(prot_tum_df.columns, pd.MultiIndex):
        prot_tum_df = prot_tum_df.droplevel('Database_ID', axis = 1)
    prot_tum_df['patient_ID'] = prot_tum_df.index
    prot_tum_df = prot_tum_df.melt(id_vars = 'patient_ID', var_name = 'Gene', value_name = 'Proteomics')
    prot_tum_df['Tissue'] = ['tumor'] * len(prot_tum_df)

    trans_df = pd.concat([trans_norm_df, trans_tum_df])
    prot_df = pd.concat([prot_norm_df, prot_tum_df])

    cancer_df = pd.merge(trans_df, prot_df, on = ['patient_ID', 'Gene', 'Tissue'])
    cancer_df = cancer_df.dropna()
    cancer_df['Cancer'] = [name] * len(cancer_df)
    cancer_dfs.append(cancer_df)
df = pd.concat(cancer_dfs)
df
# Out:
#           patient_ID  Gene  Transcriptomics  Tissue  Proteomics Cancer
# 0        C3L-00004.N  A1BG         0.859821  normal    0.291127  ccrcc
# 1        C3L-00010.N  A1BG         0.824992  normal   -0.579658  ccrcc
# 2        C3L-00011.N  A1BG         0.673249  normal   -0.096200  ccrcc
# 3        C3L-00026.N  A1BG         3.043751  normal   -0.209196  ccrcc
# 4        C3L-00079.N  A1BG         0.801038  normal   -0.395915  ccrcc
# ...              ...   ...              ...     ...         ...    ...
# 1766693    C3N-04275  ZZZ3        11.520000   tumor   18.577359  hnscc
# 1766695    C3N-04277  ZZZ3        11.510000   tumor   19.897997  hnscc
# 1766696    C3N-04278  ZZZ3        11.220000   tumor   19.898459  hnscc
# 1766697    C3N-04279  ZZZ3        11.330000   tumor   19.755773  hnscc
# 1766698    C3N-04280  ZZZ3        11.260000   tumor   19.515427  hnscc
#
# [8335133 rows x 6 columns]

# %%
RNA_transport_genes = []
file_name = 'data/kegg_rna_transport.txt'
with open(file_name) as file:
    for line in file:
        print(line)
        if 'RefSeq' in line:
            refseqs = re.search('RefSeq.*', line).group()
            refseqs = refseqs.split(';')[0]
            refseqs = refseqs.strip('RefSeq)')
            refseqs = refseqs.split(',')
            for gene in refseqs:
                gene = gene.strip()
                gene = gene.upper()
                if gene != '':
                    RNA_transport_genes.append(gene)
                    print(gene)
# Out:
# ID                   Definition
#
# ----------------------------------------------------------------------------------------------------
#
# hsa:100101267        K14316 nuclear pore complex protein Nup121 | (RefSeq) POM121C, POM121-2; POM121 transmembrane nucleo
#
# POM121C
# POM121-2
# hsa:10073            K13151 snurportin-1 | (RefSeq) SNUPN, KPNBL, RNUT1, Snurportin1; snurportin 1
#
# SNUPN
# KPNBL
# RNUT1
# SNURPORTIN1
# hsa:10189            K12881 THO complex subunit 4 | (RefSeq) ALYREF, ALY, ALY/REF, BEF, REF, THOC4; Aly/REF export factor
#
# ALYREF
# ALY
# ALY/REF
# BEF
# REF
# THOC4
# hsa:101954264        K14276 U1 spliceosomal RNA | (RefSeq) RNVU1-4, RNU1-102, RNU1-50, RNVU1-5, vU1.4, vU1.5; RNA, varian
#
# RNVU1-4
# RNU1-102
# RNU1-50
# RNVU1-5
# VU1.4
# VU1.5
# hsa:101954268        K14276 U1 spliceosomal RNA | (RefSeq) RNVU1-20, RNU1-110, vU1.20; RNA, variant U1 small nuclear 20
#
# RNVU1-20
# RNU1-110
# VU1.20
# hsa:101954271        K14280 U6 spliceosomal RNA | (RefSeq) RNU6-9, U6-9; RNA, U6 small nuclear 9
#
# RNU6-9
# U6-9
# hsa:101954273        K14276 U1 spliceosomal RNA | (RefSeq) RNVU1-1, RNU1-10P, RNU1-53, RNU1P10, RNVU1-10, U1.4, U1P14, vU
#
# RNVU1-1
# RNU1-10P
# RNU1-53
# RNU1P10
# RNVU1-10
# U1.4
# U1P14
# VU
# hsa:10209            K03113 translation initiation factor 1 | (RefSeq) EIF1, A121, EIF-1, EIF1A, ISO1, SUI1; eukaryotic t
#
# EIF1
# A121
# EIF-1
# EIF1A
# ISO1
# SUI1
# hsa:10248            K14527 ribonuclease P/MRP protein subunit RPP20 [EC:3.1.26.5] | (RefSeq) POP7, 0610037N12Rik, RPP2,
#
# POP7
# 0610037N12RIK
# RPP2
# hsa:10250            K13171 serine/arginine repetitive matrix protein 1 | (RefSeq) SRRM1, 160-KD, POP101, SRM160; serine
#
# SRRM1
# 160-KD
# POP101
# SRM160
# hsa:10284            K14324 histone deacetylase complex subunit SAP18 | (RefSeq) SAP18, 2HOR0202, SAP18P; Sin3A associate
#
# SAP18
# 2HOR0202
# SAP18P
# hsa:10289            K03113 translation initiation factor 1 | (RefSeq) EIF1B, GC20; eukaryotic translation initiation fac
#
# EIF1B
# GC20
# hsa:10419            K02516 type II protein arginine methyltransferase [EC:2.1.1.320] | (RefSeq) PRMT5, HRMT1L5, HSL7, IB
#
# PRMT5
# HRMT1L5
# HSL7
# IB
# hsa:10460            K14283 transforming acidic coiled-coil-containing protein 3 | (RefSeq) TACC3, ERIC-1, ERIC1, Tacc4,
#
# TACC3
# ERIC-1
# ERIC1
# TACC4
# hsa:10482            K14284 nuclear RNA export factor | (RefSeq) NXF1, MEX67, TAP; nuclear RNA export factor 1
#
# NXF1
# MEX67
# TAP
# hsa:10556            K03539 ribonuclease P/MRP protein subunit RPP1 [EC:3.1.26.5] | (RefSeq) RPP30, TSG15; ribonuclease P
#
# RPP30
# TSG15
# hsa:10557            K14523 ribonucleases P/MRP protein subunit RPP38 [EC:3.1.26.5] | (RefSeq) RPP38; ribonuclease P/MRP
#
# RPP38
# hsa:10605            K14322 polyadenylate-binding protein-interacting protein 1 | (RefSeq) PAIP1; poly(A) binding protein
#
# PAIP1
# hsa:10762            K14295 nuclear pore complex protein Nup50 | (RefSeq) NUP50, NPAP60, NPAP60L; nucleoporin 50
#
# NUP50
# NPAP60
# NPAP60L
# hsa:10775            K03538 ribonuclease P protein subunit POP4 [EC:3.1.26.5] | (RefSeq) POP4, RPP29; POP4 homolog, ribon
#
# POP4
# RPP29
# hsa:10799            K14530 ribonucleases P/MRP protein subunit RPP40 [EC:3.1.26.5] | (RefSeq) RPP40, RNASEP1, bA428J1.3;
#
# RPP40
# RNASEP1
# BA428J1.3
# hsa:10921            K14325 RNA-binding protein with serine-rich domain 1 | (RefSeq) RNPS1, E5.1; RNA binding protein wit
#
# RNPS1
# E5.1
# hsa:10940            K01164 ribonuclease P/MRP protein subunit POP1 [EC:3.1.26.5] | (RefSeq) POP1, ANXD2; POP1 homolog, r
#
# POP1
# ANXD2
# hsa:109617015        K14483 U3 small nucleolar RNA | (RefSeq) SNORD3E; small nucleolar RNA, C/D box 3E
#
# SNORD3E
# hsa:11097            K14321 nucleoporin-like protein 2 | (RefSeq) NUP42, CG1, NLP-1, NLP_1, NUPL2, hCG1; nucleoporin 42
#
# NUP42
# CG1
# NLP-1
# NLP_1
# NUPL2
# HCG1
# hsa:11102            K14529 ribonuclease P protein subunit RPP14 [EC:3.1.26.5] | (RefSeq) RPP14, P14; ribonuclease P/MRP
#
# RPP14
# P14
# hsa:11171            K13137 serine-threonine kinase receptor-associated protein | (RefSeq) STRAP, MAWD, PT-WD, UNRIP; ser
#
# STRAP
# MAWD
# PT-WD
# UNRIP
# hsa:11218            K13131 ATP-dependent RNA helicase DDX20 [EC:3.6.4.13] | (RefSeq) DDX20, DP103, GEMIN3; DEAD-box heli
#
# DDX20
# DP103
# GEMIN3
# hsa:11260            K14288 exportin-T | (RefSeq) XPOT, XPO3; exportin for tRNA
#
# XPOT
# XPO3
# hsa:11269            K18655 ATP-dependent RNA helicase DDX19/DBP5 [EC:3.6.4.13] | (RefSeq) DDX19B, DBP5, DDX19, RNAh; DEA
#
# DDX19B
# DBP5
# DDX19
# RNAH
# hsa:1207             K05019 chloride channel, nucleotide-sensitive, 1A | (RefSeq) CLNS1A, CLCI, CLNS1B, ICln; chloride nu
#
# CLNS1A
# CLCI
# CLNS1B
# ICLN
# hsa:129401           K14313 nuclear pore complex protein Nup53 | (RefSeq) NUP35, MP-44, MP44, NP44, NUP53; nucleoporin 35
#
# NUP35
# MP-44
# MP44
# NP44
# NUP53
# hsa:132430           K13126 polyadenylate-binding protein | (RefSeq) PABPC4L; poly(A) binding protein cytoplasmic 4 like
#
# PABPC4L
# hsa:138716           K14525 ribonucleases P/MRP protein subunit RPP25 [EC:3.1.26.5] | (RefSeq) RPP25L, C9orf23, bA296L22.
#
# RPP25L
# C9ORF23
# BA296L22.
# hsa:140886           K13126 polyadenylate-binding protein | (RefSeq) PABPC5, PABP5; poly(A) binding protein cytoplasmic 5
#
# PABPC5
# PABP5
# hsa:1915             K03231 elongation factor 1-alpha | (RefSeq) EEF1A1, CCS-3, CCS3, EE1A1, EEF-1, EEF1A, EF-Tu, EF1A, G
#
# EEF1A1
# CCS-3
# CCS3
# EE1A1
# EEF-1
# EEF1A
# EF-TU
# EF1A
# G
# hsa:1917             K03231 elongation factor 1-alpha | (RefSeq) EEF1A2, DEE33, EEF1AL, EF-1-alpha-2, EF1A, EIEE33, HS1,
#
# EEF1A2
# DEE33
# EEF1AL
# EF-1-ALPHA-2
# EF1A
# EIEE33
# HS1
# hsa:1964             K03236 translation initiation factor 1A | (RefSeq) EIF1AX, EIF1A, EIF1AP1, EIF4C, eIF-1A, eIF-4C; eu
#
# EIF1AX
# EIF1A
# EIF1AP1
# EIF4C
# EIF-1A
# EIF-4C
# hsa:1965             K03237 translation initiation factor 2 subunit 1 | (RefSeq) EIF2S1, EIF-2, EIF-2A, EIF-2alpha, EIF2,
#
# EIF2S1
# EIF-2
# EIF-2A
# EIF-2ALPHA
# EIF2
# hsa:1967             K03239 translation initiation factor eIF-2B subunit alpha | (RefSeq) EIF2B1, EIF2B, EIF2BA; eukaryot
#
# EIF2B1
# EIF2B
# EIF2BA
# hsa:1968             K03242 translation initiation factor 2 subunit 3 | (RefSeq) EIF2S3, EIF2, EIF2G, EIF2gamma, MEHMO, M
#
# EIF2S3
# EIF2
# EIF2G
# EIF2GAMMA
# MEHMO
# M
# hsa:1973             K03257 translation initiation factor 4A | (RefSeq) EIF4A1, DDX2A, EIF-4A, EIF4A, eIF-4A-I, eIF4A-I;
#
# EIF4A1
# DDX2A
# EIF-4A
# EIF4A
# EIF-4A-I
# EIF4A-I
# hsa:1974             K03257 translation initiation factor 4A | (RefSeq) EIF4A2, BM-010, DDX2B, EIF4A, EIF4F, eIF-4A-II, e
#
# EIF4A2
# BM-010
# DDX2B
# EIF4A
# EIF4F
# EIF-4A-II
# E
# hsa:1975             K03258 translation initiation factor 4B | (RefSeq) EIF4B, EIF-4B, PRO1843; eukaryotic translation in
#
# EIF4B
# EIF-4B
# PRO1843
# hsa:1977             K03259 translation initiation factor 4E | (RefSeq) EIF4E, AUTS19, CBP, EIF4E1, EIF4EL1, EIF4F, eIF-4
#
# EIF4E
# AUTS19
# CBP
# EIF4E1
# EIF4EL1
# EIF4F
# EIF-4
# hsa:1978             K07205 eukaryotic translation initiation factor 4E binding protein 1 | (RefSeq) EIF4EBP1, 4E-BP1, 4E
#
# EIF4EBP1
# 4E-BP1
# 4E
# hsa:1979             K18644 eukaryotic translation initiation factor 4E binding protein 2 | (RefSeq) EIF4EBP2, 4EBP2, PHA
#
# EIF4EBP2
# 4EBP2
# PHA
# hsa:1981             K03260 translation initiation factor 4G | (RefSeq) EIF4G1, EIF-4G1, EIF4F, EIF4G, EIF4GI, P220, PARK
#
# EIF4G1
# EIF-4G1
# EIF4F
# EIF4G
# EIF4GI
# P220
# PARK
# hsa:1982             K03260 translation initiation factor 4G | (RefSeq) EIF4G2, AAG1, DAP5, NAT1, P97; eukaryotic transla
#
# EIF4G2
# AAG1
# DAP5
# NAT1
# P97
# hsa:1983             K03262 translation initiation factor 5 | (RefSeq) EIF5, EIF-5, EIF-5A; eukaryotic translation initia
#
# EIF5
# EIF-5
# EIF-5A
# hsa:22794            K14323 protein CASC3 | (RefSeq) CASC3, BTZ, MLN51; CASC3 exon junction complex subunit
#
# CASC3
# BTZ
# MLN51
# hsa:22916            K12883 nuclear cap-binding protein subunit 2 | (RefSeq) NCBP2, CBC2, CBP20, NIP1, PIG55; nuclear cap
#
# NCBP2
# CBC2
# CBP20
# NIP1
# PIG55
# hsa:22985            K12875 apoptotic chromatin condensation inducer in the nucleus | (RefSeq) ACIN1, ACINUS, ACN, fSAP15
#
# ACIN1
# ACINUS
# ACN
# FSAP15
# hsa:23165            K14310 nuclear pore complex protein Nup205 | (RefSeq) NUP205, C7orf14, NPHS13; nucleoporin 205
#
# NUP205
# C7ORF14
# NPHS13
# hsa:23191            K05749 cytoplasmic FMR1 interacting protein | (RefSeq) CYFIP1, P140SRA-1, SHYC, SRA-1, SRA1; cytopla
#
# CYFIP1
# P140SRA-1
# SHYC
# SRA-1
# SRA1
# hsa:23225            K14314 nuclear pore complex protein Nup210 | (RefSeq) NUP210, GP210, POM210; nucleoporin 210
#
# NUP210
# GP210
# POM210
# hsa:23279            K14303 nuclear pore complex protein Nup160 | (RefSeq) NUP160, NPHS19; nucleoporin 160
#
# NUP160
# NPHS19
# hsa:2332             K15516 fragile X mental retardation protein | (RefSeq) FMR1, FMRP, FRAXA, POF, POF1; FMRP translatio
#
# FMR1
# FMRP
# FRAXA
# POF
# POF1
# hsa:23435            K23600 TAR DNA-binding protein 43 | (RefSeq) TARDBP, ALS10, TDP-43; TAR DNA binding protein
#
# TARDBP
# ALS10
# TDP-43
# hsa:23511            K14311 nuclear pore complex protein Nup188 | (RefSeq) NUP188, KIAA0169, SANDSTEF, hNup188; nucleopor
#
# NUP188
# KIAA0169
# SANDSTEF
# HNUP188
# hsa:23636            K14306 nuclear pore complex protein Nup62 | (RefSeq) NUP62, IBSN, SNDI, p62; nucleoporin 62
#
# NUP62
# IBSN
# SNDI
# P62
# hsa:2521             K13098 RNA-binding protein FUS | (RefSeq) FUS, ALS6, ETM4, FUS1, HNRNPP2, POMP75, TLS, altFUS; FUS R
#
# FUS
# ALS6
# ETM4
# FUS1
# HNRNPP2
# POMP75
# TLS
# ALTFU
# hsa:253314           K03259 translation initiation factor 4E | (RefSeq) EIF4E1B; eukaryotic translation initiation factor
#
# EIF4E1B
# hsa:25929            K13133 gem associated protein 5 | (RefSeq) GEMIN5, GEMIN-5; gem nuclear organelle associated protein
#
# GEMIN5
# GEMIN-5
# hsa:26019            K14327 regulator of nonsense transcripts 2 | (RefSeq) UPF2, HUPF2, RENT2, smg-3; UPF2 regulator of n
#
# UPF2
# HUPF2
# RENT2
# SMG-3
# hsa:26827            K14280 U6 spliceosomal RNA | (RefSeq) RNU6-1, RNU6, RNU6A, U6, U6-1; RNA, U6 small nuclear 1
#
# RNU6-1
# RNU6
# RNU6A
# U6
# U6-1
# hsa:26831            K14279 U5 spliceosomal RNA | (RefSeq) RNU5A-1, RNU5, RNU5A, RNU5C, U5A, U5B1; RNA, U5A small nuclear
#
# RNU5A-1
# RNU5
# RNU5A
# RNU5C
# U5A
# U5B1
# hsa:26834            K14278 U4 spliceosomal RNA | (RefSeq) RNU4-2, RNU4-1B, RNU4B1, RNU4C, U4A, U4b, U4c; RNA, U4 small n
#
# RNU4-2
# RNU4-1B
# RNU4B1
# RNU4C
# U4A
# U4B
# U4C
# hsa:26835            K14278 U4 spliceosomal RNA | (RefSeq) RNU4-1, RNU4A, RNU4B2, U4, U4BL; RNA, U4 small nuclear 1
#
# RNU4-1
# RNU4A
# RNU4B2
# U4
# U4BL
# hsa:26851            K14483 U3 small nucleolar RNA | (RefSeq) SNORD3B-1, RNU3A1, U3a, U3b1, U3b2; small nucleolar RNA, C/
#
# SNORD3B-1
# RNU3A1
# U3A
# U3B1
# U3B2
# hsa:26863            K14276 U1 spliceosomal RNA | (RefSeq) RNVU1-18, RNU1-25, RNU1-25P, RNU1-5, RNU1P1, RNU1P9, U1.15, U1
#
# RNVU1-18
# RNU1-25
# RNU1-25P
# RNU1-5
# RNU1P1
# RNU1P9
# U1.15
# U1
# hsa:26864            K14276 U1 spliceosomal RNA | (RefSeq) RNVU1-7, RNU1-26P, RNU1-6, RNU1-6P, RNU1-9, RNU1-9P, RNVU1-9,
#
# RNVU1-7
# RNU1-26P
# RNU1-6
# RNU1-6P
# RNU1-9
# RNU1-9P
# RNVU1-9
# hsa:26869            K14276 U1 spliceosomal RNA | (RefSeq) RNU1-3, HSD4, RNU1G3; RNA, U1 small nuclear 3
#
# RNU1-3
# HSD4
# RNU1G3
# hsa:26870            K14276 U1 spliceosomal RNA | (RefSeq) RNU1-2, RNU1C1, RNU1C2, U1C1, U1C21; RNA, U1 small nuclear 2
#
# RNU1-2
# RNU1C1
# RNU1C2
# U1C1
# U1C21
# hsa:26871            K14276 U1 spliceosomal RNA | (RefSeq) RNU1-1, HSD1, HU1-1, RNU1, RNU1A, RNU1A3, RNU1G4, Rnu1a1, U1,
#
# RNU1-1
# HSD1
# HU1-1
# RNU1
# RNU1A
# RNU1A3
# RNU1G4
# RNU1A1
# U1
# hsa:26986            K13126 polyadenylate-binding protein | (RefSeq) PABPC1, PAB1, PABP, PABP1, PABPC2, PABPL1; poly(A) b
#
# PABPC1
# PAB1
# PABP
# PABP1
# PABPC2
# PABPL1
# hsa:26999            K05749 cytoplasmic FMR1 interacting protein | (RefSeq) CYFIP2, DEE65, EIEE65, PIR121; cytoplasmic FM
#
# CYFIP2
# DEE65
# EIEE65
# PIR121
# hsa:2733             K18723 nucleoporin GLE1 | (RefSeq) GLE1, CAAHC, CAAHD, GLE1L, LCCS, LCCS1, hGLE1; GLE1 RNA export me
#
# GLE1
# CAAHC
# CAAHD
# GLE1L
# LCCS
# LCCS1
# HGLE1
# hsa:29107            K14285 NTF2-related export protein 1/2 | (RefSeq) NXT1, MTR2, P15; nuclear transport factor 2 like e
#
# NXT1
# MTR2
# P15
# hsa:340529           K13126 polyadenylate-binding protein | (RefSeq) PABPC1L2A, RBM32A; poly(A) binding protein cytoplasm
#
# PABPC1L2A
# RBM32A
# hsa:348995           K14305 nuclear pore complex protein Nup43 | (RefSeq) NUP43, bA350J20.1, p42; nucleoporin 43
#
# NUP43
# BA350J20.1
# P42
# hsa:3646             K03250 translation initiation factor 3 subunit E | (RefSeq) EIF3E, EIF3-P48, EIF3S6, INT6, eIF3-p46;
#
# EIF3E
# EIF3-P48
# EIF3S6
# INT6
# EIF3-P46
# hsa:3837             K14293 importin subunit beta-1 | (RefSeq) KPNB1, IMB1, IPO1, IPOB, Impnb, NTF97; karyopherin subunit
#
# KPNB1
# IMB1
# IPO1
# IPOB
# IMPNB
# NTF97
# hsa:387082           K12160 small ubiquitin-related modifier | (RefSeq) SUMO4, IDDM5, SMT3H4, SUMO-4, dJ281H8.4; small ub
#
# SUMO4
# IDDM5
# SMT3H4
# SUMO-4
# DJ281H8.4
# hsa:392517           K12883 nuclear cap-binding protein subunit 2 | (RefSeq) NCBP2L, dJ820B18.1; nuclear cap binding prot
#
# NCBP2L
# DJ820B18.1
# hsa:4116             K12877 protein mago nashi | (RefSeq) MAGOH, MAGOH1, MAGOHA; mago homolog, exon junction complex subu
#
# MAGOH
# MAGOH1
# MAGOHA
# hsa:4686             K12882 nuclear cap-binding protein subunit 1 | (RefSeq) NCBP1, CBP80, NCBP, Sto1; nuclear cap bindin
#
# NCBP1
# CBP80
# NCBP
# STO1
# hsa:4927             K14318 nuclear pore complex protein Nup88 | (RefSeq) NUP88, FADS4; nucleoporin 88
#
# NUP88
# FADS4
# hsa:4928             K14297 nuclear pore complex protein Nup98-Nup96 | (RefSeq) NUP98, ADIR2, NUP196, NUP96, Nup98-96; nu
#
# NUP98
# ADIR2
# NUP196
# NUP96
# NUP98-96
# hsa:5042             K13126 polyadenylate-binding protein | (RefSeq) PABPC3, PABP3, PABPL3, tPABP; poly(A) binding protei
#
# PABPC3
# PABP3
# PABPL3
# TPABP
# hsa:50628            K13132 gem associated protein 4 | (RefSeq) GEMIN4, HC56, HCAP1, HHRF-1, NEDMCR, p97; gem nuclear org
#
# GEMIN4
# HC56
# HCAP1
# HHRF-1
# NEDMCR
# P97
# hsa:51068            K07562 nonsense-mediated mRNA decay protein 3 | (RefSeq) NMD3, CGI-07; NMD3 ribosome export adaptor
#
# NMD3
# CGI-07
# hsa:51095            K00974 tRNA nucleotidyltransferase (CCA-adding enzyme) [EC:2.7.7.72 3.1.3.- 3.1.4.-] | (RefSeq) TRNT
#
# TRNT
# hsa:51367            K03537 ribonuclease P/MRP protein subunit POP5 [EC:3.1.26.5] | (RefSeq) POP5, HSPC004, RPP2, RPP20,
#
# POP5
# HSPC004
# RPP2
# RPP20
# hsa:51808            K14291 phosphorylated adapter RNA export protein | (RefSeq) PHAX, RNUXA; phosphorylated adaptor for
#
# PHAX
# RNUXA
# hsa:53371            K14308 nuclear pore complex protein Nup54 | (RefSeq) NUP54; nucleoporin 54
#
# NUP54
# hsa:5411             K13114 pinin | (RefSeq) PNN, DRS, DRSP, SDK3, memA; pinin, desmosome associated protein
#
# PNN
# DRS
# DRSP
# SDK3
# MEMA
# hsa:54913            K14525 ribonucleases P/MRP protein subunit RPP25 [EC:3.1.26.5] | (RefSeq) RPP25; ribonuclease P and
#
# RPP25
# hsa:54960            K13136 gem associated protein 8 | (RefSeq) GEMIN8, FAM51A1; gem nuclear organelle associated protein
#
# GEMIN8
# FAM51A1
# hsa:55110            K12877 protein mago nashi | (RefSeq) MAGOHB, MGN2, mago, magoh; mago homolog B, exon junction comple
#
# MAGOHB
# MGN2
# MAGO
# MAGOH
# hsa:55308            K18655 ATP-dependent RNA helicase DDX19/DBP5 [EC:3.6.4.13] | (RefSeq) DDX19A, DDX19-DDX19L, DDX19L;
#
# DDX19A
# DDX19-DDX19L
# DDX19L
# hsa:55520            K00784 ribonuclease Z [EC:3.1.26.11] | (RefSeq) ELAC1, D29; elaC ribonuclease Z 1
#
# ELAC1
# D29
# hsa:55706            K14315 nucleoporin NDC1 | (RefSeq) NDC1, NET3, TMEM48; NDC1 transmembrane nucleoporin
#
# NDC1
# NET3
# TMEM48
# hsa:55746            K14300 nuclear pore complex protein Nup133 | (RefSeq) NUP133, GAMOS8, NPHS18, hNUP133; nucleoporin 1
#
# NUP133
# GAMOS8
# NPHS18
# HNUP133
# hsa:55916            K14285 NTF2-related export protein 1/2 | (RefSeq) NXT2, P15-2; nuclear transport factor 2 like expor
#
# NXT2
# P15-2
# hsa:55998            K14284 nuclear RNA export factor | (RefSeq) NXF5; nuclear RNA export factor 5
#
# NXF5
# hsa:56000            K14284 nuclear RNA export factor | (RefSeq) NXF3; nuclear RNA export factor 3
#
# NXF3
# hsa:56001            K14284 nuclear RNA export factor | (RefSeq) NXF2, CT39, TAPL-2, TCP11X2; nuclear RNA export factor 2
#
# NXF2
# CT39
# TAPL-2
# TCP11X2
# hsa:57122            K14301 nuclear pore complex protein Nup107 | (RefSeq) NUP107, NPHS11, NUP84, ODG6, GAMOS7; nucleopor
#
# NUP107
# NPHS11
# NUP84
# ODG6
# GAMOS7
# hsa:57187            K12879 THO complex subunit 2 | (RefSeq) THOC2, CXorf3, MRX12, MRX35, THO2, dJ506G2.1, hTREX120; THO
#
# THOC2
# CXORF3
# MRX12
# MRX35
# THO2
# DJ506G2.1
# HTREX120
# hsa:57510            K14289 exportin-5 | (RefSeq) XPO5, exp5; exportin 5
#
# XPO5
# EXP5
# hsa:5901             K07936 GTP-binding nuclear protein Ran | (RefSeq) RAN, ARA24, Gsp1, TC4; RAN, member RAS oncogene fa
#
# RAN
# ARA24
# GSP1
# TC4
# hsa:5903             K12172 E3 SUMO-protein ligase RanBP2 [EC:2.3.2.-] | (RefSeq) RANBP2, ADANE, ANE1, IIAE3, NUP358, TRP
#
# RANBP2
# ADANE
# ANE1
# IIAE3
# NUP358
# TRP
# hsa:5905             K14319 Ran GTPase-activating protein 1 | (RefSeq) RANGAP1, Fug1, RANGAP, SD; Ran GTPase activating p
#
# RANGAP1
# FUG1
# RANGAP
# SD
# hsa:59343            K03345 sentrin-specific protease 2 (axin associating molecule) [EC:3.4.22.68] | (RefSeq) SENP2, AXAM
#
# SENP2
# AXAM
# hsa:5976             K14326 regulator of nonsense transcripts 1 [EC:3.6.4.-] | (RefSeq) UPF1, HUPF1, NORF1, RENT1, pNORF1
#
# UPF1
# HUPF1
# NORF1
# RENT1
# PNORF1
# hsa:60528            K00784 ribonuclease Z [EC:3.1.26.11] | (RefSeq) ELAC2, COXPD17, ELC2, HPC2; elaC ribonuclease Z 2
#
# ELAC2
# COXPD17
# ELC2
# HPC2
# hsa:6060             K14276 U1 spliceosomal RNA | (RefSeq) RNU1-4, HSD2, HSD5, HSD6, HSD7, RNU1, RNU1D2, RNU1E2, RNU1F1,
#
# RNU1-4
# HSD2
# HSD5
# HSD6
# HSD7
# RNU1
# RNU1D2
# RNU1E2
# RNU1F1
# hsa:6066             K14277 U2 spliceosomal RNA | (RefSeq) RNU2-1, RNU2, U2; RNA, U2 small nuclear 1
#
# RNU2-1
# RNU2
# U2
# hsa:6396             K14004 protein transport protein SEC13 | (RefSeq) SEC13, D3S1231E, SEC13L1, SEC13R, npp-20; SEC13 ho
#
# SEC13
# D3S1231E
# SEC13L1
# SEC13R
# NPP-20
# hsa:645974           K13126 polyadenylate-binding protein | (RefSeq) PABPC1L2B, RBM32B; poly(A) binding protein cytoplasm
#
# PABPC1L2B
# RBM32B
# hsa:65109            K14328 regulator of nonsense transcripts 3 | (RefSeq) UPF3B, HUPF3B, MRX62, MRX82, MRXS14, RENT3B, U
#
# UPF3B
# HUPF3B
# MRX62
# MRX82
# MRXS14
# RENT3B
# U
# hsa:65110            K14328 regulator of nonsense transcripts 3 | (RefSeq) UPF3A, HUPF3A, RENT3A, UPF3; UPF3A regulator o
#
# UPF3A
# HUPF3A
# RENT3A
# UPF3
# hsa:6606             K13129 survival motor neuron protein | (RefSeq) SMN1, BCD541, GEMIN1, SMA, SMA1, SMA2, SMA3, SMA4, S
#
# SMN1
# BCD541
# GEMIN1
# SMA
# SMA1
# SMA2
# SMA3
# SMA4
# S
# hsa:6607             K13129 survival motor neuron protein | (RefSeq) SMN2, BCD541, C-BCD541, GEMIN1, SMNC, TDRD16B; survi
#
# SMN2
# BCD541
# C-BCD541
# GEMIN1
# SMNC
# TDRD16B
# hsa:6612             K12160 small ubiquitin-related modifier | (RefSeq) SUMO3, SMT3A, SMT3H1, SUMO-3, Smt3B; small ubiqui
#
# SUMO3
# SMT3A
# SMT3H1
# SUMO-3
# SMT3B
# hsa:6613             K12160 small ubiquitin-related modifier | (RefSeq) SUMO2, HSMT3, SMT3B, SMT3H2, SUMO3, Smt3A; small
#
# SUMO2
# HSMT3
# SMT3B
# SMT3H2
# SUMO3
# SMT3A
# hsa:7175             K09291 nucleoprotein TPR | (RefSeq) TPR; translocated promoter region, nuclear basket protein
#
# TP
# hsa:728343           K14284 nuclear RNA export factor | (RefSeq) NXF2B, TCP11X2, bA353J17.1; nuclear RNA export factor 2B
#
# NXF2B
# TCP11X2
# BA353J17.1
# hsa:728689           K03252 translation initiation factor 3 subunit C | (RefSeq) EIF3CL; eukaryotic translation initiatio
#
# EIF3CL
# hsa:7329             K10577 ubiquitin-conjugating enzyme E2 I | (RefSeq) UBE2I, C358B7.1, P18, UBC9; ubiquitin conjugatin
#
# UBE2I
# C358B7.1
# P18
# UBC9
# hsa:7341             K12160 small ubiquitin-related modifier | (RefSeq) SUMO1, DAP1, GMP1, OFC10, PIC1, SENP2, SMT3, SMT3
#
# SUMO1
# DAP1
# GMP1
# OFC10
# PIC1
# SENP2
# SMT3
# SMT3
# hsa:7514             K14290 exportin-1 | (RefSeq) XPO1, CRM-1, CRM1, emb, exp1; exportin 1
#
# XPO1
# CRM-1
# CRM1
# EMB
# EXP1
# hsa:780851           K14483 U3 small nucleolar RNA | (RefSeq) SNORD3A, RNU3, U3; small nucleolar RNA, C/D box 3A
#
# SNORD3A
# RNU3
# U3
# hsa:780852           K14483 U3 small nucleolar RNA | (RefSeq) SNORD3B-2, U3-2B, U3b2; small nucleolar RNA, C/D box 3B-2
#
# SNORD3B-2
# U3-2B
# U3B2
# hsa:780853           K14483 U3 small nucleolar RNA | (RefSeq) SNORD3C, RNU3-3, U3-3; small nucleolar RNA, C/D box 3C
#
# SNORD3C
# RNU3-3
# U3-3
# hsa:79023            K14302 nuclear pore complex protein Nup37 | (RefSeq) NUP37, MCPH24, p37; nucleoporin 37
#
# NUP37
# MCPH24
# P37
# hsa:7919             K12812 ATP-dependent RNA helicase UAP56/SUB2 [EC:3.6.4.13] | (RefSeq) DDX39B, BAT1, D6S81E, UAP56; D
#
# DDX39B
# BAT1
# D6S81E
# UAP56
# hsa:79228            K13175 THO complex subunit 6 | (RefSeq) THOC6, WDR58, fSAP35; THO complex 6
#
# THOC6
# WDR58
# FSAP35
# hsa:79760            K13135 gem associated protein 7 | (RefSeq) GEMIN7, SIP3; gem nuclear organelle associated protein 7
#
# GEMIN7
# SIP3
# hsa:79833            K13134 gem associated protein 6 | (RefSeq) GEMIN6; gem nuclear organelle associated protein 6
#
# GEMIN6
# hsa:79897            K03540 ribonuclease P protein subunit RPR2 [EC:3.1.26.5] | (RefSeq) RPP21, C6orf135, CAT60; ribonucl
#
# RPP21
# C6ORF135
# CAT60
# hsa:79902            K14304 nuclear pore complex protein Nup85 | (RefSeq) NUP85, FROUNT, NPHS17, Nup75; nucleoporin 85
#
# NUP85
# FROUNT
# NPHS17
# NUP75
# hsa:80145            K13176 THO complex subunit 7 | (RefSeq) THOC7, NIF3L1BP1, fSAP24, hTREX30; THO complex 7
#
# THOC7
# NIF3L1BP1
# FSAP24
# HTREX30
# hsa:8021             K14317 nuclear pore complex protein Nup214 | (RefSeq) NUP214, CAIN, CAN, IIAE9; nucleoporin 214
#
# NUP214
# CAIN
# CAN
# IIAE9
# hsa:80336            K13126 polyadenylate-binding protein | (RefSeq) PABPC1L, C20orf119, EPAB, PABPC1L1, dJ1069P2.3; poly
#
# PABPC1L
# C20ORF119
# EPAB
# PABPC1L1
# DJ1069P2.3
# hsa:8086             K14320 aladin | (RefSeq) AAAS, AAA, AAASb, ADRACALA, ADRACALIN, ALADIN, GL003; aladin WD repeat nucl
#
# AAAS
# AAA
# AAASB
# ADRACALA
# ADRACALIN
# ALADIN
# GL003
# hsa:8087             K15516 fragile X mental retardation protein | (RefSeq) FXR1, FXR1P, MYOPMIL, MYORIBF; FMR1 autosomal
#
# FXR1
# FXR1P
# MYOPMIL
# MYORIBF
# hsa:81929            K14299 nucleoporin SEH1 | (RefSeq) SEH1L, SEC13L, SEH1A, SEH1B, Seh1; SEH1 like nucleoporin
#
# SEH1L
# SEC13L
# SEH1A
# SEH1B
# SEH1
# hsa:84305            K14294 partner of Y14 and mago | (RefSeq) PYM1, PYM, WIBG; PYM homolog 1, exon junction complex asso
#
# PYM1
# PYM
# WIBG
# hsa:84321            K12880 THO complex subunit 3 | (RefSeq) THOC3, THO3, hTREX45; THO complex 3
#
# THOC3
# THO3
# HTREX45
# hsa:8480             K14298 mRNA export factor | (RefSeq) RAE1, Gle2, MIG14, MRNP41, Mnrp41, dJ481F12.3, dJ800J21.1; ribo
#
# RAE1
# GLE2
# MIG14
# MRNP41
# MNRP41
# DJ481F12.3
# DJ800J21.1
# hsa:8487             K13130 gem associated protein 2 | (RefSeq) GEMIN2, SIP1, SIP1-delta; gem nuclear organelle associate
#
# GEMIN2
# SIP1
# SIP1-DELTA
# hsa:8563             K13174 THO complex subunit 5 | (RefSeq) THOC5, C22orf19, Fmip, PK1.3, fSAP79; THO complex 5
#
# THOC5
# C22ORF19
# FMIP
# PK1.3
# FSAP79
# hsa:8637             K18645 eukaryotic translation initiation factor 4E binding protein 3 | (RefSeq) EIF4EBP3, 4E-BP3, 4E
#
# EIF4EBP3
# 4E-BP3
# 4E
# hsa:8661             K03254 translation initiation factor 3 subunit A | (RefSeq) EIF3A, EIF3, EIF3S10, P167, TIF32, eIF3-
#
# EIF3A
# EIF3
# EIF3S10
# P167
# TIF32
# EIF3-
# hsa:8662             K03253 translation initiation factor 3 subunit B | (RefSeq) EIF3B, EIF3-ETA, EIF3-P110, EIF3-P116, E
#
# EIF3B
# EIF3-ETA
# EIF3-P110
# EIF3-P116
# E
# hsa:8663             K03252 translation initiation factor 3 subunit C | (RefSeq) EIF3C, EIF3CL, EIF3S8, eIF3-p110; eukary
#
# EIF3C
# EIF3CL
# EIF3S8
# EIF3-P110
# hsa:8664             K03251 translation initiation factor 3 subunit D | (RefSeq) EIF3D, EIF3S7, eIF3-p66, eIF3-zeta; euka
#
# EIF3D
# EIF3S7
# EIF3-P66
# EIF3-ZETA
# hsa:8665             K03249 translation initiation factor 3 subunit F | (RefSeq) EIF3F, EIF3S5, MRT67, eIF3-p47; eukaryot
#
# EIF3F
# EIF3S5
# MRT67
# EIF3-P47
# hsa:8666             K03248 translation initiation factor 3 subunit G | (RefSeq) EIF3G, EIF3-P42, EIF3S4, eIF3-delta, eIF
#
# EIF3G
# EIF3-P42
# EIF3S4
# EIF3-DELTA
# EIF
# hsa:8667             K03247 translation initiation factor 3 subunit H | (RefSeq) EIF3H, EIF3S3, eIF3-gamma, eIF3-p40; euk
#
# EIF3H
# EIF3S3
# EIF3-GAMMA
# EIF3-P40
# hsa:8668             K03246 translation initiation factor 3 subunit I | (RefSeq) EIF3I, EIF3S2, PRO2242, TRIP-1, TRIP1, e
#
# EIF3I
# EIF3S2
# PRO2242
# TRIP-1
# TRIP1
# E
# hsa:8669             K03245 translation initiation factor 3 subunit J | (RefSeq) EIF3J, EIF3S1, eIF3-alpha, eIF3-p35; euk
#
# EIF3J
# EIF3S1
# EIF3-ALPHA
# EIF3-P35
# hsa:8672             K03260 translation initiation factor 4G | (RefSeq) EIF4G3, eIF-4G_3, eIF4G_3, eIF4GII; eukaryotic tr
#
# EIF4G3
# EIF-4G_3
# EIF4G_3
# EIF4GII
# hsa:8761             K13126 polyadenylate-binding protein | (RefSeq) PABPC4, APP-1, APP1, PABP4, iPABP; poly(A) binding p
#
# PABPC4
# APP-1
# APP1
# PABP4
# IPABP
# hsa:8890             K03680 translation initiation factor eIF-2B subunit delta | (RefSeq) EIF2B4, EIF-2B, EIF2B, EIF2Bdel
#
# EIF2B4
# EIF-2B
# EIF2B
# EIF2BDEL
# hsa:8891             K03241 translation initiation factor eIF-2B subunit gamma | (RefSeq) EIF2B3, EIF-2B, EIF2Bgamma; euk
#
# EIF2B3
# EIF-2B
# EIF2BGAMMA
# hsa:8892             K03754 translation initiation factor eIF-2B subunit beta | (RefSeq) EIF2B2, EIF-2Bbeta, EIF2B; eukar
#
# EIF2B2
# EIF-2BBETA
# EIF2B
# hsa:8893             K03240 translation initiation factor eIF-2B subunit epsilon | (RefSeq) EIF2B5, CACH, CLE, EIF-2B, EI
#
# EIF2B5
# CACH
# CLE
# EIF-2B
# EI
# hsa:8894             K03238 translation initiation factor 2 subunit 2 | (RefSeq) EIF2S2, EIF2, EIF2B, EIF2beta, PPP1R67,
#
# EIF2S2
# EIF2
# EIF2B
# EIF2BETA
# PPP1R67
# hsa:9086             K03236 translation initiation factor 1A | (RefSeq) EIF1AY, eIF-4C; eukaryotic translation initiation
#
# EIF1AY
# EIF-4C
# hsa:91181            K14314 nuclear pore complex protein Nup210 | (RefSeq) NUP210L; nucleoporin 210 like
#
# NUP210L
# hsa:94026            K14316 nuclear pore complex protein Nup121 | (RefSeq) POM121L2, POM121-L, POM121L; POM121 transmembr
#
# POM121L2
# POM121-L
# POM121L
# hsa:9470             K03259 translation initiation factor 4E | (RefSeq) EIF4E2, 4E-LP, 4EHP, EIF4EL3, IF4e, h4EHP; eukary
#
# EIF4E2
# 4E-LP
# 4EHP
# EIF4EL3
# IF4E
# H4EHP
# hsa:9513             K15516 fragile X mental retardation protein | (RefSeq) FXR2, FMR1L2, FXR2P; FMR1 autosomal homolog 2
#
# FXR2
# FMR1L2
# FXR2P
# hsa:9631             K14312 nuclear pore complex protein Nup155 | (RefSeq) NUP155, ATFB15, N155; nucleoporin 155
#
# NUP155
# ATFB15
# N155
# hsa:9669             K03243 translation initiation factor 5B | (RefSeq) EIF5B, IF2; eukaryotic translation initiation fac
#
# EIF5B
# IF2
# hsa:96764            K14292 trimethylguanosine synthase [EC:2.1.1.-] | (RefSeq) TGS1, NCOA6IP, PIMT, PIPMT; trimethylguan
#
# TGS1
# NCOA6IP
# PIMT
# PIPMT
# hsa:9688             K14309 nuclear pore complex protein Nup93 | (RefSeq) NUP93, NIC96; nucleoporin 93
#
# NUP93
# NIC96
# hsa:9775             K13025 ATP-dependent RNA helicase [EC:3.6.4.13] | (RefSeq) EIF4A3, DDX48, Fal1, MUK34, NMP265, NUK34
#
# EIF4A3
# DDX48
# FAL1
# MUK34
# NMP265
# NUK34
# hsa:9818             K14307 nucleoporin p58/p45 | (RefSeq) NUP58, NUP45, NUPL1, PRO2463; nucleoporin 58
#
# NUP58
# NUP45
# NUPL1
# PRO2463
# hsa:9883             K14316 nuclear pore complex protein Nup121 | (RefSeq) POM121, P145, POM121A; POM121 transmembrane nu
#
# POM121
# P145
# POM121A
# hsa:9939             K12876 RNA-binding protein 8A | (RefSeq) RBM8A, BOV-1A, BOV-1B, BOV-1C, C1DELq21.1, DEL1q21.1, MDS01
#
# RBM8A
# BOV-1A
# BOV-1B
# BOV-1C
# C1DELQ21.1
# DEL1Q21.1
# MDS01
# hsa:9972             K14296 nuclear pore complex protein Nup153 | (RefSeq) NUP153, HNUP153, N153; nucleoporin 153
#
# NUP153
# HNUP153
# N153
# hsa:9984             K12878 THO complex subunit 1 | (RefSeq) THOC1, HPR1, P84, P84N5; THO complex 1
# THOC1
# HPR1
# P84
# P84N5

# %%
luad_mutations = cptac.utils.get_frequently_mutated(luad)
luad_mutations.sort_values('Unique_Samples_Mut', ascending = False)
# Out:
# Name       Gene  Unique_Samples_Mut  Missense_Mut  Truncation_Mut
# 94         TP53            0.536364      0.400000        0.145455
# 31         EGFR            0.345455      0.345455        0.000000
# 54        MUC16            0.336364      0.300000        0.072727
# 96          TTN            0.318182      0.281818        0.081818
# 81         RYR2            0.318182      0.272727        0.081818
# ..          ...                 ...           ...             ...
# 92        TENM1            0.109091      0.100000        0.009091
# 73    POM121L12            0.109091      0.109091        0.000000
# 20       COL3A1            0.109091      0.090909        0.027273
# 76        PXDNL            0.109091      0.109091        0.000000
# 29        DNAH9            0.109091      0.100000        0.018182
#
# [106 rows x 4 columns]

# %%
cptac.version()
# Out:
# '0.8.8'

# %%
pd.show_versions()
# Out:
# C:\Users\nanel\anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# INSTALLED VERSIONS
# ------------------
# commit           : f2c8480af2f25efdbd803218b9d87980f416563e
# python           : 3.8.3.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.2.3
# numpy            : 1.18.5
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.1.1
# setuptools       : 49.2.0.post20200714
# Cython           : 0.29.21
# pytest           : 5.4.3
# hypothesis       : None
# sphinx           : 3.1.2
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.9
# lxml.etree       : 4.5.2
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.16.1
# pandas_datareader: None
# bs4              : 4.9.1
# bottleneck       : 1.3.2
# fsspec           : 0.7.4
# fastparquet      : None
# gcsfs            : None
# matplotlib       : 3.2.2
# numexpr          : 2.7.1
# odfpy            : None
# openpyxl         : 3.0.4
# pandas_gbq       : None
# pyarrow          : 3.0.0
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.5.0
# sqlalchemy       : 1.3.18
# tables           : 3.6.1
# tabulate         : 0.8.7
# xarray           : None
# xlrd             : 1.2.0
# xlwt             : 1.3.0
# numba            : 0.50.1
