# %%
import cptac
import numpy as np
import pandas as pd
from gprofiler import GProfiler
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# cptac warning: Your version of cptac (0.8.8) is out-of-date. Latest is 0.9.0. Please run 'pip install --upgrade cptac' to update it. (<ipython-input-1-1cd1c7874502>, line 1)

# %%
permutation_df = pd.read_csv('data/full_10k_permutation_corrected.csv')
correlation_df = pd.read_csv('data/corr_diff.csv')
regression_df = pd.read_csv('data/regressions_data.csv')

# %%
permutation_df = pd.melt(permutation_df, id_vars='Cancer', var_name = 'Gene', value_name = 'perm_pval')

# %%
correlation_df = correlation_df.melt(id_vars='Cancer', var_name='Gene', value_name='delta_corr')

# %%
regression_df = regression_df.rename(columns={'gene': 'Gene', 'cancer': 'Cancer'})
regression_df = regression_df[['Cancer', 'Gene', 'interaction_coeff', 'interaction_pval']]

# %%
df = pd.merge(permutation_df, correlation_df, how = 'outer')
df = pd.merge(df, regression_df, how = 'outer')

# %%
background_genes = list(pd.unique(df.Gene))
len(background_genes)
# Out:
# 13669

# %%
rows = []
for gene in pd.unique(df.Gene):
    row = {}
    gene_df = df[df.Gene == gene]
    gene_df = gene_df[gene_df.perm_pval <= 0.05]
    if len(gene_df) > 2:
        row['Gene'] = gene
        row['perm_pval'] = np.mean(gene_df.perm_pval)
        row['delta_corr'] = np.mean(gene_df.delta_corr)
        row['interaction_coeff'] = np.mean(gene_df.interaction_coeff)
        row['interaction_pval'] = np.mean(gene_df.interaction_pval)
        row['abs_interaction_coeff'] = abs(np.mean(gene_df.interaction_coeff))
        rows.append(row)
sig_perm_df = pd.DataFrame(rows)
sig_perm_df
# Out:
#          Gene  perm_pval  delta_corr  interaction_coeff  interaction_pval  \
# 0        AAAS   0.029511    0.383641           0.478558          0.310070
# 1       AAGAB   0.000010    0.513239           0.744205          0.099849
# 2        AAK1   0.000017    0.539893           0.468512          0.058654
# 3        AAMP   0.007805    0.422332           0.834418          0.051275
# 4        AARS   0.007671    0.443220           0.588859          0.273249
# ...       ...        ...         ...                ...               ...
# 3803  ZSCAN18   0.009996    0.461501           0.204678          0.498252
# 3804     ZW10   0.001301    0.481355           0.596254          0.095312
# 3805   ZWILCH   0.000030    0.775549           1.843545          0.101584
# 3806    ZWINT   0.001874    0.854401           0.988399          0.001941
# 3807   ZYG11B   0.006057    0.161963           0.526668          0.069729
#
#       abs_interaction_coeff
# 0                  0.478558
# 1                  0.744205
# 2                  0.468512
# 3                  0.834418
# 4                  0.588859
# ...                     ...
# 3803               0.204678
# 3804               0.596254
# 3805               1.843545
# 3806               0.988399
# 3807               0.526668
#
# [3808 rows x 6 columns]

# %%
rows = []
for gene in pd.unique(df.Gene):
    row = {}
    gene_df = df[df.Gene == gene]
    gene_df = gene_df[gene_df.interaction_pval <= 0.05]
    if len(gene_df) > 2:
        row['Gene'] = gene
        row['perm_pval'] = np.mean(gene_df.perm_pval)
        row['delta_corr'] = np.mean(gene_df.delta_corr)
        row['interaction_coeff'] = np.mean(gene_df.interaction_coeff)
        row['interaction_pval'] = np.mean(gene_df.interaction_pval)
        row['abs_interaction_coeff'] = abs(np.mean(gene_df.interaction_coeff))
        rows.append(row)
sig_regression_df = pd.DataFrame(rows)
sig_regression_df
# Out:
#           Gene     perm_pval  delta_corr  interaction_coeff  interaction_pval  \
# 0         AAK1  2.187208e-09    0.539893           0.453549          0.005085
# 1        AARS2  1.575518e-01    0.399337           0.719068          0.015352
# 2     AASDHPPT  4.554894e-09    0.569367           0.850032          0.001351
# 3         AASS  9.059842e-08    0.516246           1.079797          0.015262
# 4       ABCB10  2.677682e-02    0.345190           1.149501          0.013915
# ...        ...           ...         ...                ...               ...
# 1364    ZNF638  2.620840e-04    0.647382           1.012607          0.002426
# 1365    ZNF687  5.961230e-04    0.622238           0.797145          0.014088
# 1366     ZNFX1  6.527134e-02    0.420009           0.388419          0.005495
# 1367    ZNHIT2  5.211000e-05    0.664401           0.756881          0.000306
# 1368     ZWINT  1.874433e-03    0.854401           0.988399          0.001941
#
#       abs_interaction_coeff
# 0                  0.453549
# 1                  0.719068
# 2                  0.850032
# 3                  1.079797
# 4                  1.149501
# ...                     ...
# 1364               1.012607
# 1365               0.797145
# 1366               0.388419
# 1367               0.756881
# 1368               0.988399
#
# [1369 rows x 6 columns]

# %%
gp = GProfiler(return_dataframe=True)

# %%
sig_perm_unranked = pd.unique(sig_perm_df.Gene)
sig_perm_df = sig_perm_df.sort_values(by = 'abs_interaction_coeff', ascending = False)
sig_perm_slope = pd.unique(sig_perm_df.Gene)
sig_perm_upregulated = sig_perm_df[sig_perm_df.interaction_coeff >= 0]
sig_perm_upregulated_unranked = pd.unique(sig_perm_upregulated.Gene)
sig_perm_upregulated = sig_perm_upregulated.sort_values(by = 'interaction_coeff', ascending = False)
sig_perm_upregulated = pd.unique(sig_perm_upregulated.Gene)
sig_perm_downregulated = sig_perm_df[sig_perm_df.interaction_coeff <= 0]
sig_perm_downregulated_unranked = pd.unique(sig_perm_downregulated.Gene)
sig_perm_downregulated = sig_perm_downregulated.sort_values(by = 'interaction_coeff')
sig_perm_downregulated = pd.unique(sig_perm_downregulated.Gene)

# %%
sig_perm_unranked = gp.profile(organism='hsapiens', query = list(sig_perm_unranked), no_iea=True,
                       ordered=False, no_evidences=False, background= background_genes, sources = ['GO:BP'])

# %%
sig_perm_slope = gp.profile(organism='hsapiens', query = list(sig_perm_slope), no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])

# %%
sig_perm_upregulated_unranked = gp.profile(organism='hsapiens', query = list(sig_perm_upregulated_unranked), no_iea=True,
                       ordered=False, no_evidences=False, background= background_genes, sources = ['GO:BP'])

# %%
sig_perm_upregulated = gp.profile(organism='hsapiens', query = list(sig_perm_upregulated), no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])

# %%
sig_perm_downregulated_unranked = gp.profile(organism='hsapiens', query = list(sig_perm_downregulated_unranked), no_iea=True,
                       ordered=False, no_evidences=False, background= background_genes, sources = ['GO:BP'])

# %%
sig_perm_downregulated = gp.profile(organism='hsapiens', query = list(sig_perm_downregulated), no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])

# %%
sig_regression_unranked = pd.unique(sig_regression_df.Gene)
sig_regression_df = sig_regression_df.sort_values(by = 'abs_interaction_coeff', ascending = False)
sig_regression_slope = pd.unique(sig_regression_df.Gene)
sig_regression_upregulated = sig_regression_df[sig_regression_df.interaction_coeff >= 0]
sig_regression_upregulated_unranked = pd.unique(sig_regression_upregulated.Gene)
sig_regression_upregulated = sig_regression_upregulated.sort_values(by = 'interaction_coeff', ascending = False)
sig_regression_upregulated = pd.unique(sig_regression_upregulated.Gene)
sig_regression_downregulated = sig_regression_df[sig_regression_df.interaction_coeff <= 0]
sig_regression_downregulated_unranked = pd.unique(sig_regression_downregulated.Gene)
sig_regression_downregulated = sig_regression_downregulated.sort_values(by = 'interaction_coeff')
sig_regression_downregulated = pd.unique(sig_regression_downregulated.Gene)

# %%
sig_regression_unranked = gp.profile(organism='hsapiens', query = list(sig_regression_unranked), no_iea=True,
                       ordered=False, no_evidences=False, background= background_genes, sources = ['GO'])

# %%
sig_regression_slope = gp.profile(organism='hsapiens', query = list(sig_regression_slope), no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO'])

# %%
sig_regression_upregulated_unranked = gp.profile(organism='hsapiens', query = list(sig_regression_upregulated_unranked), no_iea=True,
                       ordered=False, no_evidences=False, background= background_genes, sources = ['GO'])

# %%
sig_regression_upregulated = gp.profile(organism='hsapiens', query = list(sig_regression_upregulated), no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO'])

# %%
sig_regression_downregulated_unranked = gp.profile(organism='hsapiens', query = list(sig_regression_downregulated_unranked), no_iea=True,
                       ordered=False, no_evidences=False, background= background_genes, sources = ['GO'])

# %%
sig_regression_downregulated = gp.profile(organism='hsapiens', query = list(sig_regression_downregulated), no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['KEGG'])

# %%
sig_perm_unranked['Analysis'] = ['perm_unranked'] * len(sig_perm_unranked)
sig_perm_slope['Analysis'] = ['perm_slope'] * len(sig_perm_slope)
sig_perm_upregulated_unranked['Analysis'] = ['perm_upregulated_unranked'] * len(sig_perm_upregulated_unranked)
sig_perm_upregulated['Analysis'] = ['perm_upregulated'] * len(sig_perm_upregulated)
sig_perm_downregulated_unranked['Analysis'] = ['perm_downregulated_unranked'] * len(sig_perm_downregulated_unranked)
sig_perm_downregulated['Analysis'] = ['perm_downregulated'] * len(sig_perm_downregulated)

# %%
sig_regression_unranked['Analysis'] = ['regression_unranked'] * len(sig_regression_unranked)
sig_regression_slope['Analysis'] = ['regression_slope'] * len(sig_regression_slope)
sig_regression_upregulated_unranked['Analysis'] = ['regression_upregulated_unranked'] * len(sig_regression_upregulated_unranked)
sig_regression_upregulated['Analysis'] = ['regression_upregulated'] * len(sig_regression_upregulated)
sig_regression_downregulated_unranked['Analysis'] = ['regression_downregulated_unranked'] * len(sig_regression_downregulated_unranked)
sig_regression_downregulated['Analysis'] = ['regression_downregulated'] * len(sig_regression_downregulated)

# %%
upregulated_pathways = [sig_perm_unranked, sig_perm_slope,sig_perm_upregulated_unranked,sig_perm_upregulated,sig_regression_unranked,sig_regression_slope,
                       sig_regression_upregulated_unranked,sig_regression_upregulated]

# %%
upregulated_pathways_df = pd.concat(upregulated_pathways)
upregulated_pathways_df
# Out:
#    source      native                                               name  \
# 0   GO:CC  GO:0005737                                          cytoplasm
# 1   GO:CC  GO:0005829                                            cytosol
# 2   GO:MF  GO:0003824                                 catalytic activity
# 3   GO:CC  GO:0005622                 intracellular anatomical structure
# 4   GO:CC  GO:0043227                         membrane-bounded organelle
# ..    ...         ...                                                ...
# 25  GO:BP  GO:0009451                                   RNA modification
# 26  GO:BP  GO:1902850  microtubule cytoskeleton organization involved...
# 27  GO:CC  GO:0005759                               mitochondrial matrix
# 28  GO:BP  GO:0051987  positive regulation of attachment of spindle m...
# 29  GO:BP  GO:0000281                                mitotic cytokinesis
#
#          p_value  significant  \
# 0   2.054960e-50         True
# 1   2.736190e-40         True
# 2   3.665954e-36         True
# 3   1.610549e-33         True
# 4   2.493146e-21         True
# ..           ...          ...
# 25  1.825347e-02         True
# 26  2.257544e-02         True
# 27  3.047388e-02         True
# 28  3.557296e-02         True
# 29  4.708426e-02         True
#
#                                           description  term_size  query_size  \
# 0   "All of the contents of a cell excluding the p...       8617        3746
# 1   "The part of the cytoplasm that does not conta...       4425        3746
# 2   "Catalysis of a biochemical reaction at physio...       4198        3746
# 3   "A component of a cell contained within (but n...      10798        3746
# 4   "Organized structure of distinctive morphology...       9273        3746
# ..                                                ...        ...         ...
# 25  "The covalent alteration of one or more nucleo...        131         695
# 26  "Any microtubule cytoskeleton organization tha...        127         308
# 27  "The gel-like material, with considerable fine...        400         451
# 28  "Any process that activates or increases the f...          6         203
# 29  "A cell cycle process that results in the divi...         65         962
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                2763                  13575   0.737587  0.320645  query_1
# 1                1568                  13575   0.418580  0.354350  query_1
# 2                1484                  13575   0.396156  0.353502  query_1
# 3                3242                  13575   0.865456  0.300241  query_1
# 4                2810                  13575   0.750133  0.303030  query_1
# ..                ...                    ...        ...       ...      ...
# 25                 24                  13575   0.034532  0.183206  query_1
# 26                 15                  13575   0.048701  0.118110  query_1
# 27                 35                  13575   0.077605  0.087500  query_1
# 28                  4                  13575   0.019704  0.666667  query_1
# 29                 18                  13575   0.018711  0.276923  query_1
#
#                                              parents  \
# 0                           [GO:0005622, GO:0110165]
# 1                           [GO:0005737, GO:0110165]
# 2                                       [GO:0003674]
# 3                                       [GO:0110165]
# 4                                       [GO:0043226]
# ..                                               ...
# 25                          [GO:0016070, GO:0043412]
# 26                          [GO:0000226, GO:1903047]
# 27              [GO:0005739, GO:0043233, GO:0070013]
# 28  [GO:0008608, GO:0051984, GO:0051988, GO:0090068]
# 29                          [GO:0061640, GO:1903047]
#
#                                         intersections  \
# 0   [AAAS, AAGAB, AAK1, AAMP, AARS2, AASDHPPT, AAS...
# 1   [AAAS, AAGAB, AAK1, AAMP, AASDHPPT, AASS, ABCB...
# 2   [AAK1, AARS2, AASDHPPT, AASS, ABAT, ABCA3, ABC...
# 3   [AAAS, AAGAB, AAK1, AAMP, AARS2, AASDHPPT, AAS...
# 4   [AAAS, AAGAB, AAK1, AARS2, AASDHPPT, AASS, ABA...
# ..                                                ...
# 25  [TFB2M, TFB1M, TRMT5, NSUN2, TRIT1, MRM1, TRMT...
# 26  [PLK1, BCCIP, RACGAP1, KIFC1, CCNB1, TPX2, PRC...
# 27  [TFB2M, TFB1M, LRPPRC, SUPV3L1, NDUFAF7, TRMT5...
# 28                       [CCNB1, AURKB, HNRNPU, RCC2]
# 29  [CKAP2, PLK1, ECT2, RACGAP1, ANLN, KIF23, RASA...
#
#                                             evidences                Analysis
# 0   [[IDA], [IDA], [ISS, IBA, TAS], [IDA, IBA], [I...           perm_unranked
# 1   [[IDA], [IDA], [TAS], [IDA, IBA], [IDA, TAS], ...           perm_unranked
# 2   [[ISS, IBA, TAS], [IMP, IBA], [IDA, IBA, TAS],...           perm_unranked
# 3   [[IDA, HDA, IBA, TAS], [IDA], [ISS, IBA, TAS],...           perm_unranked
# 4   [[IDA, HDA, IBA, TAS], [IDA], [ISS], [IDA, IBA...           perm_unranked
# ..                                                ...                     ...
# 25  [[IBA], [IBA, TAS], [IMP, IBA], [IDA, IBA, TAS...  regression_upregulated
# 26  [[IDA], [IMP], [IDA], [IMP, IBA], [IMP], [IDA,...  regression_upregulated
# 27  [[IDA, IBA, TAS], [IDA, IBA, TAS], [IDA], [IDA...  regression_upregulated
# 28                  [[IMP], [IDA], [IMP, IBA], [IMP]]  regression_upregulated
# 29  [[IGI], [IDA], [IMP, IBA], [IDA, IMP], [IDA, I...  regression_upregulated
#
# [610 rows x 17 columns]

# %%
upregulated_pathways_df['p_value'] = -np.log10(upregulated_pathways_df['p_value'])

# %%
plt.figure(figsize=(5,10))
g = sns.barplot(data = upregulated_pathways_df,
               x = 'p_value', y = 'name', hue = 'Analysis')
g.legend(loc='center right', bbox_to_anchor=(1.8, .5))
plt.xlabel('-log10 p-value')
# Out:
# Text(0.5, 0, '-log10 p-value')

# %%
num_upregulated_analyses = len(pd.unique(upregulated_pathways_df.Analysis))

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-32-0891b765a168>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
upregulated_pathways = []
upregulated_analyses = []
for pathway in pd.unique(upregulated_pathways_df.name):
    pathway_df = upregulated_pathways_df[upregulated_pathways_df.name == pathway]
    analyses = set(pathway_df.Analysis)
    if analyses not in upregulated_analyses:
        upregulated_analyses.append(analyses)
        upregulated_pathways.append({pathway})
    else:
        i = upregulated_analyses.index(analyses)
        upregulated_pathways[i].add(pathway)
upregulated_pathways_df = pd.DataFrame({'Analyses':upregulated_analyses, 'Pathways': upregulated_pathways})
upregulated_pathways_df['Pathway_Frequency'] = [len(a) / num_upregulated_analyses for a in upregulated_pathways_df.Analyses]
upregulated_pathways_df = upregulated_pathways_df.sort_values(by = 'Pathway_Frequency', ascending = False)
upregulated_pathways_df
# Out:
#                                                                                                                                                                     Analyses  \
# 8   {regression_upregulated_unranked, perm_upregulated, perm_slope, perm_upregulated_unranked, regression_unranked, regression_upregulated, perm_unranked, regression_slope}
# 16  {regression_upregulated_unranked, perm_upregulated, perm_slope, perm_upregulated_unranked, regression_upregulated, perm_unranked, regression_slope}
# 1   {regression_upregulated_unranked, perm_upregulated, perm_slope, perm_upregulated_unranked, regression_unranked, perm_unranked, regression_slope}
# 14  {perm_upregulated, perm_slope, perm_upregulated_unranked, regression_upregulated, perm_unranked, regression_slope}
# 4   {regression_upregulated_unranked, perm_upregulated, perm_slope, perm_upregulated_unranked, regression_unranked, perm_unranked}
# 23  {perm_upregulated, perm_slope, perm_upregulated_unranked, regression_upregulated, regression_slope}
# 22  {regression_upregulated_unranked, perm_upregulated, perm_slope, regression_upregulated, regression_slope}
# 5   {regression_upregulated_unranked, perm_upregulated, perm_slope, perm_upregulated_unranked, perm_unranked}
# 7   {perm_upregulated, perm_slope, perm_upregulated_unranked, regression_upregulated, perm_unranked}
# 9   {perm_upregulated, perm_slope, perm_upregulated_unranked, regression_unranked, perm_unranked}
# 10  {regression_upregulated_unranked, perm_upregulated_unranked, regression_unranked, perm_unranked, regression_slope}
# 21  {perm_slope, perm_upregulated, regression_slope, regression_upregulated}
# 19  {regression_upregulated_unranked, perm_unranked, regression_slope, regression_unranked}
# 18  {perm_slope, perm_unranked, perm_upregulated, regression_upregulated}
# 0   {regression_upregulated_unranked, perm_unranked, perm_upregulated_unranked, regression_unranked}
# 2   {perm_slope, perm_unranked, perm_upregulated, perm_upregulated_unranked}
# 24  {perm_slope, perm_upregulated, perm_upregulated_unranked}
# 17  {perm_slope, perm_unranked, perm_upregulated_unranked}
# 11  {perm_unranked, perm_upregulated, perm_upregulated_unranked}
# 3   {perm_unranked, perm_upregulated_unranked, regression_unranked}
# 13  {regression_upregulated_unranked, perm_unranked, perm_upregulated_unranked}
# 25  {perm_slope, regression_slope, regression_upregulated}
# 12  {perm_unranked, regression_unranked}
# 20  {perm_slope, perm_upregulated}
# 6   {perm_unranked, perm_upregulated_unranked}
# 31  {regression_slope, regression_upregulated}
# 30  {regression_slope, regression_unranked}
# 29  {regression_unranked}
# 15  {perm_unranked}
# 28  {perm_upregulated}
# 27  {perm_upregulated_unranked}
# 26  {perm_slope}
# 32  {regression_slope}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Pathways  \
# 8   {cadherin binding, cell adhesion molecule binding}
# 16  {mitotic cell cycle, mitotic nuclear division}
# 1   {cytosol}
# 14  {mitochondrial RNA metabolic process, mitotic cell cycle process}
# 4   {small molecule metabolic process}
# 23  {sister chromatid segregation, transferase activity, transferring one-carbon groups, organelle fission}
# 22  {mitotic sister chromatid segregation}
# 5   {RNA binding}
# 7   {mitochondrial matrix}
# 9   {small molecule catabolic process}
# 10  {extracellular exosome}
# 21  {spindle organization, nuclear chromosome segregation, spindle assembly, nuclear division, S-adenosylmethionine-dependent methyltransferase activity, mitotic spindle assembly, methyltransferase activity, chromosome segregation, RNA modification, regulation of attachment of spindle microtubules to kinetochore}
# 19  {anchoring junction}
# 18  {mitotic cytokinesis}
# 0   {extracellular vesicle, ion binding, extracellular organelle, response to stress, identical protein binding, intracellular anatomical structure, catalytic activity, cytoplasm, membrane-bounded organelle}
# 2   {carboxylic acid catabolic process, aminoacyl-tRNA ligase activity, negative regulation of viral genome replication, membrane-enclosed lumen, tRNA binding, tRNA metabolic process, helicase activity, intracellular organelle lumen, organelle lumen, tRNA aminoacylation, cell cycle process, tRNA aminoacylation for protein translation, protein folding, organonitrogen compound biosynthetic process, nucleobase-containing small molecule metabolic process, mitochondrion, organic acid catabolic process, amino acid activation, response to type I interferon, nucleobase metabolic process, nucleobase biosynthetic process, ligase activity, forming carbon-oxygen bonds}
# 24  {catalytic activity, acting on RNA, chromosomal region, nucleoside monophosphate metabolic process, chromosome organization, DNA strand elongation involved in DNA replication, catalytic activity, acting on a tRNA}
# 17  {cell cycle}
# 11  {type I interferon signaling pathway, nuclear lumen, ligase activity, cellular response to type I interferon, regulation of viral genome replication, nucleoside phosphate biosynthetic process, nucleotide metabolic process, cellular response to DNA damage stimulus, nucleotide biosynthetic process}
# 3   {cellular_component, molecular_function, response to stimulus, biological_process}
# ...
# 30  {focal adhesion, cell-substrate junction}
# 29  {cell-cell junction, cytoskeleton organization, extracellular space, cell junction, monosaccharide metabolic process, extracellular region}
# 15  {protein-containing complex binding, organelle organization, regulation of phosphorus metabolic process, response to oxidative stress, cell leading edge, monocarboxylic acid metabolic process, cellular response to oxidative stress, oxidoreductase activity, enzyme regulator activity}
# 28  {nucleobase-containing small molecule interconversion, ribonucleoside monophosphate metabolic process, RNA methylation, DNA duplex unwinding, tRNA processing, nuclear chromosome}
# 27  {positive regulation of molecular function, fatty acid catabolic process, adenyl nucleotide binding, purine ribonucleoside triphosphate binding, purine ribonucleotide binding, purine-containing compound metabolic process, catalytic activity, acting on a protein, protein metabolic process, ATPase activity, kinase activity, ribonucleotide binding, midbody, pyrimidine-containing compound biosynthetic process, organonitrogen compound catabolic process, cellular aromatic compound metabolic process, nucleoside metabolic process, cellular nitrogen compound metabolic process, heterocycle metabolic process}
# 26  {purine nucleobase metabolic process}
# 32  {mitochondrion organization, cadherin binding involved in cell-cell adhesion}
#
#     Pathway_Frequency
# 8   1.000
# 16  0.875
# 1   0.875
# 14  0.750
# 4   0.750
# 23  0.625
# 22  0.625
# 5   0.625
# 7   0.625
# 9   0.625
# 10  0.625
# 21  0.500
# 19  0.500
# 18  0.500
# 0   0.500
# 2   0.500
# 24  0.375
# 17  0.375
# 11  0.375
# 3   0.375
# 13  0.375
# 25  0.375
# 12  0.250
# 20  0.250
# 6   0.250
# 31  0.250
# 30  0.250
# 29  0.125
# 15  0.125
# 28  0.125
# 27  0.125
# 26  0.125
# 32  0.125

# %%
rows = []
for index, row in upregulated_pathways_df.iterrows():
    pathways = row.Pathways
    for pathway in pathways:
        new_row = dict()
        new_row['Pathway'] = pathway
        new_row['Frequency'] = row.Pathway_Frequency
        rows.append(new_row)
upregulated_pathways_df = pd.DataFrame(rows)
upregulated_pathways_df
# Out:
#                                              Pathway  Frequency
# 0    cadherin binding                                 1.000
# 1    cell adhesion molecule binding                   1.000
# 2    mitotic cell cycle                               0.875
# 3    mitotic nuclear division                         0.875
# 4    cytosol                                          0.875
# ..       ...                                            ...
# 234  cellular nitrogen compound metabolic process     0.125
# 235  heterocycle metabolic process                    0.125
# 236  purine nucleobase metabolic process              0.125
# 237  mitochondrion organization                       0.125
# 238  cadherin binding involved in cell-cell adhesion  0.125
#
# [239 rows x 2 columns]

# %%
axes = sns.barplot(data = upregulated_pathways_df, y = 'Pathway', x = 'Frequency')

# %%
downregulated_pathways = [sig_perm_unranked, sig_perm_slope,sig_perm_downregulated_unranked,sig_perm_downregulated,sig_regression_unranked,sig_regression_slope,
                       sig_regression_downregulated_unranked,sig_regression_downregulated]
downregulated_pathways_df = pd.concat(downregulated_pathways)
num_downregulated_analyses = len(pd.unique(downregulated_pathways_df.Analysis))

# %%
downregulated_pathways = []
downregulated_analyses = []
for pathway in pd.unique(downregulated_pathways_df.name):
    pathway_df = downregulated_pathways_df[downregulated_pathways_df.name == pathway]
    analyses = set(pathway_df.Analysis)
    if analyses not in downregulated_analyses:
        downregulated_analyses.append(analyses)
        downregulated_pathways.append({pathway})
    else:
        i = downregulated_analyses.index(analyses)
        downregulated_pathways[i].add(pathway)
downregulated_pathways_df = pd.DataFrame({'Analyses':downregulated_analyses, 'Pathways': downregulated_pathways})
downregulated_pathways_df['Pathway_Frequency'] = [len(a) / num_downregulated_analyses for a in downregulated_pathways_df.Analyses]
downregulated_pathways_df = downregulated_pathways_df.sort_values(by = 'Pathway_Frequency', ascending = False)
downregulated_pathways_df
# Out:
#                                                                                                                                       Analyses  \
# 5   {regression_downregulated_unranked, regression_unranked, perm_unranked, perm_downregulated, perm_downregulated_unranked, regression_slope}
# 6   {regression_downregulated_unranked, regression_unranked, perm_unranked, perm_downregulated, perm_downregulated_unranked}
# 7   {perm_unranked, perm_downregulated_unranked, regression_downregulated_unranked, regression_unranked}
# 1   {perm_slope, perm_unranked, regression_slope, regression_unranked}
# 12  {regression_downregulated_unranked, perm_downregulated_unranked, regression_unranked}
# 3   {perm_slope, perm_unranked, regression_unranked}
# 8   {perm_slope, perm_unranked, regression_slope}
# 9   {perm_unranked, regression_slope, regression_unranked}
# 0   {perm_unranked, regression_unranked}
# 18  {regression_slope, regression_unranked}
# 15  {perm_downregulated, perm_downregulated_unranked}
# 14  {perm_downregulated_unranked, regression_unranked}
# 11  {perm_slope, regression_slope}
# 2   {perm_slope, perm_unranked}
# 13  {perm_downregulated_unranked}
# 10  {perm_slope}
# 4   {perm_unranked}
# 16  {perm_downregulated}
# 17  {regression_unranked}
# 19  {regression_slope}
# 20  {regression_downregulated_unranked}
# 21  {regression_downregulated}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Pathways  \
# 5   {extracellular exosome}
# 6   {extracellular vesicle, extracellular organelle}
# 7   {vesicle}
# 1   {cytosol, cadherin binding, cell adhesion molecule binding}
# 12  {extracellular region, extracellular space}
# 3   {small molecule catabolic process, small molecule metabolic process}
# 8   {mitotic cell cycle, mitochondrial RNA metabolic process, mitotic nuclear division, mitotic cell cycle process}
# 9   {anchoring junction}
# 0   {regulation of cellular component organization, ion binding, molecular_function, biological_process, response to stress, identical protein binding, intracellular anatomical structure, catalytic activity, cytoplasm, membrane-bounded organelle, cellular_component, response to stimulus}
# 18  {focal adhesion, cell-substrate junction}
# 15  {actin binding}
# 14  {cytoskeleton organization}
# 11  {mitotic spindle organization, mitotic sister chromatid segregation, spindle organization, sister chromatid segregation, transferase activity, transferring one-carbon groups, nuclear chromosome segregation, spindle assembly, nuclear division, organelle fission, S-adenosylmethionine-dependent methyltransferase activity, mitotic spindle assembly, methyltransferase activity, chromosome segregation, RNA modification, regulation of attachment of spindle microtubules to kinetochore}
# 2   {carboxylic acid catabolic process, mitochondrial matrix, aminoacyl-tRNA ligase activity, negative regulation of viral genome replication, membrane-enclosed lumen, cell cycle, tRNA binding, tRNA metabolic process, RNA binding, helicase activity, intracellular organelle lumen, organelle lumen, tRNA aminoacylation, cell cycle process, tRNA aminoacylation for protein translation, protein folding, organonitrogen compound biosynthetic process, nucleobase-containing small molecule metabolic process, mitochondrion, organic acid catabolic process, amino acid activation, response to type I interferon, mitotic cytokinesis, nucleobase metabolic process, nucleobase biosynthetic process, ligase activity, forming carbon-oxygen bonds}
# 13  {nervous system development, multicellular organismal process, supramolecular fiber organization, cell periphery}
# ...
# 16  {vacuole}
# 17  {monosaccharide metabolic process, cell-cell junction, cell junction}
# 19  {microtubule cytoskeleton organization involved in mitosis, mitochondrion organization, regulation of chromosome segregation, spindle, attachment of spindle microtubules to kinetochore, mitotic spindle, cadherin binding involved in cell-cell adhesion, positive regulation of attachment of spindle microtubules to kinetochore, spindle midzone}
# 20  {actin filament-based process}
# 21  {Phagosome, Arrhythmogenic right ventricular cardiomyopathy, Cholesterol metabolism, Amino sugar and nucleotide sugar metabolism, Malaria, Glycolysis / Gluconeogenesis, Viral myocarditis}
#
#     Pathway_Frequency
# 5   0.750
# 6   0.625
# 7   0.500
# 1   0.500
# 12  0.375
# 3   0.375
# 8   0.375
# 9   0.375
# 0   0.250
# 18  0.250
# 15  0.250
# 14  0.250
# 11  0.250
# 2   0.250
# 13  0.125
# 10  0.125
# 4   0.125
# 16  0.125
# 17  0.125
# 19  0.125
# 20  0.125
# 21  0.125
