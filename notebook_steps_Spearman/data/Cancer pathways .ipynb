# %%
import pandas as pd
from gprofiler import GProfiler
gp = GProfiler(return_dataframe=True)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')

all_profiles = []
for cancer in pd.unique(delta_correlation_df.Cancer):
    cancer_df = delta_correlation_df[delta_correlation_df.Cancer == cancer]
    background_genes  = list(pd.unique(cancer_df.Gene))
    cancer_df = cancer_df[cancer_df.FDR < 0.05]
    sig_genes  = list(pd.unique(cancer_df.Gene))
    
    cancer_profile = gp.profile(organism='hsapiens', query = sig_genes, no_iea=True, sources = ["KEGG"],
                       ordered=True, no_evidences=False, background= background_genes)
    all_profiles.append(cancer_profile)

# %%
all_profiles[4].head(30)
# Out:
#    source      native                                         name  \
# 0    KEGG  KEGG:02010                             ABC transporters
# 1    KEGG  KEGG:00071                       Fatty acid degradation
# 2    KEGG  KEGG:01212                        Fatty acid metabolism
# 3    KEGG  KEGG:01100                           Metabolic pathways
# 4    KEGG  KEGG:00280   Valine, leucine and isoleucine degradation
# 5    KEGG  KEGG:00620                          Pyruvate metabolism
# 6    KEGG  KEGG:00640                        Propanoate metabolism
# 7    KEGG  KEGG:00010                 Glycolysis / Gluconeogenesis
# 8    KEGG  KEGG:04146                                   Peroxisome
# 9    KEGG  KEGG:00410                      beta-Alanine metabolism
# 10   KEGG  KEGG:00061                      Fatty acid biosynthesis
# 11   KEGG  KEGG:01523                        Antifolate resistance
# 12   KEGG  KEGG:03320                       PPAR signaling pathway
# 13   KEGG  KEGG:00650                         Butanoate metabolism
# 14   KEGG  KEGG:00561                      Glycerolipid metabolism
# 15   KEGG  KEGG:00910                          Nitrogen metabolism
# 16   KEGG  KEGG:00250  Alanine, aspartate and glutamate metabolism
# 17   KEGG  KEGG:00510                        N-Glycan biosynthesis
# 18   KEGG  KEGG:00380                        Tryptophan metabolism
# 19   KEGG  KEGG:00340                         Histidine metabolism
# 20   KEGG  KEGG:00740                        Riboflavin metabolism
# 21   KEGG  KEGG:00230                            Purine metabolism
# 22   KEGG  KEGG:00730                          Thiamine metabolism
# 23   KEGG  KEGG:01200                            Carbon metabolism
# 24   KEGG  KEGG:01240                    Biosynthesis of cofactors
# 25   KEGG  KEGG:00630      Glyoxylate and dicarboxylate metabolism
# 26   KEGG  KEGG:01230                  Biosynthesis of amino acids
# 27   KEGG  KEGG:00513       Various types of N-glycan biosynthesis
# 28   KEGG  KEGG:00330              Arginine and proline metabolism
# 29   KEGG  KEGG:04144                                  Endocytosis
#
#          p_value  significant                                  description  \
# 0   9.460157e-28         True                             ABC transporters
# 1   1.086039e-18         True                       Fatty acid degradation
# 2   1.042540e-13         True                        Fatty acid metabolism
# 3   1.671366e-12         True                           Metabolic pathways
# 4   1.432813e-10         True   Valine, leucine and isoleucine degradation
# 5   1.997418e-09         True                          Pyruvate metabolism
# 6   5.298915e-08         True                        Propanoate metabolism
# 7   2.867268e-07         True                 Glycolysis / Gluconeogenesis
# 8   2.941857e-06         True                                   Peroxisome
# 9   1.404711e-05         True                      beta-Alanine metabolism
# 10  3.815052e-05         True                      Fatty acid biosynthesis
# 11  7.914571e-05         True                        Antifolate resistance
# 12  3.830131e-04         True                       PPAR signaling pathway
# 13  4.337596e-04         True                         Butanoate metabolism
# 14  8.738533e-04         True                      Glycerolipid metabolism
# 15  9.217487e-04         True                          Nitrogen metabolism
# 16  1.840000e-03         True  Alanine, aspartate and glutamate metabolism
# 17  2.191826e-03         True                        N-Glycan biosynthesis
# 18  2.506320e-03         True                        Tryptophan metabolism
# 19  3.150069e-03         True                         Histidine metabolism
# 20  3.182906e-03         True                        Riboflavin metabolism
# 21  3.267413e-03         True                            Purine metabolism
# 22  3.447401e-03         True                          Thiamine metabolism
# 23  7.141887e-03         True                            Carbon metabolism
# 24  1.264159e-02         True                    Biosynthesis of cofactors
# 25  1.587864e-02         True      Glyoxylate and dicarboxylate metabolism
# 26  2.046842e-02         True                  Biosynthesis of amino acids
# 27  3.024416e-02         True       Various types of N-glycan biosynthesis
# 28  3.586965e-02         True              Arginine and proline metabolism
# 29  4.863054e-02         True                                  Endocytosis
#
#     term_size  query_size  intersection_size  effective_domain_size  \
# 0          29          27                 15                   9998
# 1          36         222                 19                   9998
# 2          45          85                 13                   9998
# 3        1041         253                 86                   9998
# 4          47         222                 14                   9998
# 5          38         222                 13                   9998
# 6          30          89                  8                   9998
# 7          54         225                 13                   9998
# 8          64          85                  9                   9998
# 9          24         292                  9                   9998
# 10         13          85                  5                   9998
# 11         21          23                  4                   9998
# 12         49          85                  7                   9998
# 13         20          86                  5                   9998
# 14         39         222                  9                   9998
# 15         13         698                  8                   9998
# 16         26        2157                 20                   9998
# 17         39         233                  8                   9998
# 18         31         293                  8                   9998
# 19         17         431                  7                   9998
# 20          8          79                  3                   9998
# 21         90         187                 11                   9998
# 22         11         242                  5                   9998
# 23        102         225                 11                   9998
# 24        113         242                 13                   9998
# 25         24          88                  4                   9998
# 26         63         540                 13                   9998
# 27         30         231                  6                   9998
# 28         38         347                  8                   9998
# 29        205         421                 23                   9998
#
#     precision    recall    query       parents  \
# 0    0.555556  0.517241  query_1  [KEGG:00000]
# 1    0.085586  0.527778  query_1  [KEGG:00000]
# 2    0.152941  0.288889  query_1  [KEGG:00000]
# 3    0.339921  0.082613  query_1  [KEGG:00000]
# 4    0.063063  0.297872  query_1  [KEGG:00000]
# 5    0.058559  0.342105  query_1  [KEGG:00000]
# 6    0.089888  0.266667  query_1  [KEGG:00000]
# 7    0.057778  0.240741  query_1  [KEGG:00000]
# 8    0.105882  0.140625  query_1  [KEGG:00000]
# 9    0.030822  0.375000  query_1  [KEGG:00000]
# 10   0.058824  0.384615  query_1  [KEGG:00000]
# 11   0.173913  0.190476  query_1  [KEGG:00000]
# 12   0.082353  0.142857  query_1  [KEGG:00000]
# 13   0.058140  0.250000  query_1  [KEGG:00000]
# 14   0.040541  0.230769  query_1  [KEGG:00000]
# 15   0.011461  0.615385  query_1  [KEGG:00000]
# 16   0.009272  0.769231  query_1  [KEGG:00000]
# 17   0.034335  0.205128  query_1  [KEGG:00000]
# 18   0.027304  0.258065  query_1  [KEGG:00000]
# 19   0.016241  0.411765  query_1  [KEGG:00000]
# 20   0.037975  0.375000  query_1  [KEGG:00000]
# 21   0.058824  0.122222  query_1  [KEGG:00000]
# 22   0.020661  0.454545  query_1  [KEGG:00000]
# 23   0.048889  0.107843  query_1  [KEGG:00000]
# 24   0.053719  0.115044  query_1  [KEGG:00000]
# 25   0.045455  0.166667  query_1  [KEGG:00000]
# 26   0.024074  0.206349  query_1  [KEGG:00000]
# 27   0.025974  0.200000  query_1  [KEGG:00000]
# 28   0.023055  0.210526  query_1  [KEGG:00000]
# 29   0.054632  0.112195  query_1  [KEGG:00000]
#
#                                         intersections  \
# 0   [ABCA1, ABCA12, ABCA3, ABCB10, ABCB6, ABCB7, A...
# 1   [ACAA2, ACADL, ACADM, ACADS, ACADSB, ACADVL, A...
# 2   [ACAA2, ACACA, ACADL, ACADM, ACADS, ACADSB, AC...
# 3   [AACS, AADAT, AASS, ABAT, ACAA2, ACACA, ACAD8,...
# 4   [AACS, ABAT, ACAA2, ACAD8, ACADM, ACADS, ACADS...
# 5   [ACACA, ACAT1, ACSS1, ACSS2, ACYP2, ADH1B, ADH...
# 6   [ABAT, ACACA, ACADS, ACAT1, ACOX3, ACSS1, ACSS...
# 7   [ACSS1, ACSS2, ADH1B, ADH1C, ADH5, ADH7, ALDH1...
# 8   [ABCD1, ABCD3, ABCD4, ACOT8, ACOX2, ACOX3, ACS...
# 9   [ABAT, ACADS, ACOX3, ALDH1B1, ALDH2, ALDH3A2, ...
# 10                [ACACA, ACSF3, ACSL3, ACSL4, ACSL5]
# 11                       [ABCC2, ABCC3, ABCC4, ABCC5]
# 12  [ACADL, ACADM, ACOX2, ACOX3, ACSL3, ACSL4, ACSL5]
# 13                  [AACS, ABAT, ACADS, ACAT1, ACSM3]
# 14  [AGK, AGPAT3, AGPAT4, AGPAT5, AKR1B10, ALDH1B1...
# 15        [CA12, CA13, CA2, CA3, CA4, CA5B, CA8, CA9]
# 16  [ABAT, ADSL, ADSS, ALDH5A1, ASL, ASNS, ASPA, A...
# 17  [ALG1, ALG11, ALG12, ALG14, ALG2, ALG3, ALG5, ...
# 18  [AADAT, ACAT1, ALDH1B1, ALDH2, ALDH3A2, ALDH7A...
# 19  [ALDH1B1, ALDH2, ALDH3A2, ALDH7A1, AMDHD1, AOC...
# 20                                 [ACP1, ACP2, ACP5]
# 21  [ADA, ADCY9, ADK, ADSL, ADSS, AK1, AK2, AK3, A...
# 22                        [ACP1, AK1, AK2, AK4, ALPL]
# 23  [ACADS, ACAT1, ACO1, ACOX3, ACSS1, ACSS2, ADH5...
# 24  [ADSL, ADSS, AK1, AK2, AK3, AK4, AK6, AK9, ALA...
# 25                        [ACAT1, ACO1, ACSS1, ACSS2]
# 26  [ACO1, ACY1, ALDH18A1, ALDOA, ALDOB, ALDOC, AR...
# 27            [ALG1, ALG11, ALG12, ALG14, ALG2, ALG3]
# 28  [ALDH18A1, ALDH1B1, ALDH2, ALDH3A2, ALDH7A1, A...
# 29  [ACAP2, ACAP3, ACTR3B, AGAP2, AGAP3, AP2A1, AP...
#
#                                             evidences
# 0   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 6   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 9   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 10           [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 11                   [[KEGG], [KEGG], [KEGG], [KEGG]]
# 12  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 13           [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 14  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 15  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 16  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 17  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 18  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 19  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 20                           [[KEGG], [KEGG], [KEGG]]
# 21  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 22           [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 23  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 24  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 25                   [[KEGG], [KEGG], [KEGG], [KEGG]]
# 26  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 27   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 28  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 29  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...

# %%
sps = ['ABC transporters',
 'Fatty acid degradation',
 'Metabolic pathways',
 'Fatty acid metabolism',
 'Pyruvate metabolism',
 'Valine, leucine and isoleucine degradation',
 'Butanoate metabolism',
 'Glycolysis / Gluconeogenesis',
 'Lysosome',
 'Peroxisome',
 'Biosynthesis of unsaturated fatty acids',
 'Thiamine metabolism',
 'Purine metabolism',
 'Glyoxylate and dicarboxylate metabolism',
 'Tyrosine metabolism',
 'Carbon metabolism',
 'Various types of N-glycan biosynthesis',
 'Lysine degradation',
 'Chemical carcinogenesis',
 'Arginine biosynthesis',
 'Cysteine and methionine metabolism',
 'Proteasome',
 'Drug metabolism - cytochrome P450',
 'Arginine and proline metabolism',
 'Synthesis and degradation of ketone bodies',
 'Citrate cycle (TCA cycle)',
 'Pantothenate and CoA biosynthesis',
 'Oxidative phosphorylation',
 'Fructose and mannose metabolism',
 'Biosynthesis of amino acids',
 'DNA replication',
 'D-Glutamine and D-glutamate metabolism',
 'Phenylalanine metabolism',
 'Translation Factors',
 'Mitochondrial LC-Fatty Acid Beta-Oxidation',
 'Fatty Acid Beta Oxidation',
 'Fatty Acid Biosynthesis',
 'Nuclear Receptors in Lipid Metabolism and Toxicity',
 'Fatty Acid Omega Oxidation',
 'Fluoroacetic acid toxicity',
 'Statin Pathway',
 'Pregnane X Receptor pathway',
'Integrated Cancer Pathway',
 'G Protein Signaling Pathways',
 'Cytoplasmic Ribosomal Proteins',
 'Mitochondrial complex I assembly model OXPHOS system',
 'Nanoparticle triggered autophagic cell death',
 'Nanomaterial induced apoptosis',
 'Composition of Lipid Particles']

rcd = ['Antifolate resistance',
 'Autophagy - other',
 'Platinum drug resistance',
 'Complement and coagulation cascades',
 'Cholesterol metabolism',
 'p53 signaling pathway',
 'Ferroptosis',
 'Apoptosis',
 'Platelet activation',
 'Apoptosis Modulation and Signaling',
'Statin Pathway',
'Apoptosis - multiple species',
'G Protein Signaling Pathways']

ang = ['Glycerolipid metabolism',
 'Vasopressin-regulated water reabsorption',
 'Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate',
 'Hematopoietic cell lineage',
'Prostaglandin Synthesis and Regulation',
 'Complement and Coagulation Cascades',
'G Protein Signaling Pathways']

rim = ['PPAR signaling pathway',
 'Endocytosis',
 'Alanine, aspartate and glutamate metabolism',
 'Nitrogen metabolism',
 'Adipocytokine signaling pathway',
 'Cell cycle',
 'Glutathione metabolism',
 'Protein digestion and absorption',
 'Phospholipase D signaling pathway',
 'Folate biosynthesis',
 'Longevity regulating pathway',
 'RNA degradation',
 'Thermogenesis',
 'Longevity regulating pathway - multiple species',
 'Complement Activation',
 'Photodynamic therapy-induced NFE2L2 (NRF2) survival signaling',
'DNA replication',
'Statin Pathway'
'Irinotecan Pathway'
'G Protein Signaling Pathways']

iam = ['Tryptophan metabolism',
 'Fatty acid biosynthesis',
 'N-Glycan biosynthesis',
 'Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate',
 'Inositol phosphate metabolism',
 'Adherens junction',
 'Glycosphingolipid biosynthesis - lacto and neolacto series',
 'Glycosphingolipid biosynthesis - globo and isoglobo series',
 'Regulation of actin cytoskeleton'
'G Protein Signaling Pathways']

grs = ['Apoptosis - multiple species',
 'Inositol phosphate metabolism',
 'Endocrine resistance'
'G Protein Signaling Pathways']

# %%
d = {'sps': pd.Series(sps), 'rcd': pd.Series(rcd), 'ang' : pd.Series(ang), 'rim' : pd.Series(rim), 'iam' : pd.Series(iam), 'grs': pd.Series(grs)}

# %%
df = pd.DataFrame(data=d)

# %%
llist=[[],[],[],[],[]]
for cancer in range(5):
    for num, i in enumerate(all_profiles[cancer].description):
        if i in sps:
            llist[cancer].append('sps')
        elif i in rcd:
            llist[cancer].append('rcd')
        elif i in ang:
            llist[cancer].append('ang')
        elif i in rim:
            llist[cancer].append('rim')
        elif i in iam:
            llist[cancer].append('iam')
        elif i in grs:
            llist[cancer].append('grs')

# %%
for n in range(5):
    ld = {'Pathways' : pd.Series(llist[n])}
    ldf = pd.DataFrame(data=llist[n])
    ldf = ldf.rename(columns={0: "Pathways"})
    sns.countplot(x ='Pathways',data=ldf, order= ['sps', 'rcd', 'ang', 'rim', 'iam','grs'])
    plt.show()
