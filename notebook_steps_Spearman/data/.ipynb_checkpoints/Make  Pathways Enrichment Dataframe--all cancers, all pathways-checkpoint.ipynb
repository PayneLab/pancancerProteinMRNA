# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
sig_delta_corr = delta_correlation_df[delta_correlation_df.FDR < 0.05]
num_genes = pd.DataFrame(sig_delta_corr.groupby('Gene').size())
sig_genes = num_genes[num_genes[0] >=3].index
sig_delta_corr = sig_delta_corr[sig_delta_corr.Gene.isin(sig_genes)]
sig_delta_corr = sig_delta_corr.groupby('Gene').mean()
sig_delta_corr['Delta_Correlation'] = abs(sig_delta_corr.Delta_Correlation)
sig_delta_corr = sig_delta_corr.sort_values('Delta_Correlation', ascending = False)
sig_delta_corr.reset_index(inplace = True)
genes = list(sig_delta_corr.Gene)
pathway_enrichment = gp.profile(organism='hsapiens', query = genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes)
#pathway_enrichment.to_csv('combinded_GO_pathway_enrichment_df.csv', index = False)

# %%
pathway_enrichment
# Out:
#     source             native                                        name  \
# 0      HPA        HPA:0600222  tonsil; squamous epithelial cells[≥Medium]
# 1      HPA        HPA:0310431     lymph node; germinal center cells[≥Low]
# 2      HPA        HPA:0610832  urinary bladder; urothelial cells[≥Medium]
# 3      HPA        HPA:0170051        endometrium 2; glandular cells[≥Low]
# 4      HPA        HPA:0470682            skin 2; epidermal cells[≥Medium]
# ..     ...                ...                                         ...
# 395   REAC  REAC:R-HSA-453279        Mitotic G1 phase and G1/S transition
# 396  CORUM          CORUM:353             DNA ligase IV-condensin complex
# 397     HP         HP:0006721                Acute lymphoblastic leukemia
# 398   REAC  REAC:R-HSA-446107               Type I hemidesmosome assembly
# 399    HPA        HPA:0210053       fallopian tube; glandular cells[High]
#
#           p_value  significant  \
# 0    7.849803e-20         True
# 1    1.837034e-18         True
# 2    3.859159e-16         True
# 3    7.165793e-16         True
# 4    1.545091e-15         True
# ..            ...          ...
# 395  4.913412e-02         True
# 396  4.925396e-02         True
# 397  4.960672e-02         True
# 398  4.963203e-02         True
# 399  4.987656e-02         True
#
#                                            description  term_size  query_size  \
# 0           tonsil; squamous epithelial cells[≥Medium]       4331        2457
# 1              lymph node; germinal center cells[≥Low]       4412        3096
# 2           urinary bladder; urothelial cells[≥Medium]       5175        2467
# 3                 endometrium 2; glandular cells[≥Low]       5764        3317
# 4                     skin 2; epidermal cells[≥Medium]       4196        2440
# ..                                                 ...        ...         ...
# 395               Mitotic G1 phase and G1/S transition        132         548
# 396                    DNA ligase IV-condensin complex          3         169
# 397  A form of acute leukemia characterized by exce...         27         146
# 398                      Type I hemidesmosome assembly         11        2990
# 399              fallopian tube; glandular cells[High]       1549        1990
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 0                 1178                  12415   0.479446  0.271993  query_1
# 1                 1466                  12415   0.473514  0.332276  query_1
# 2                 1361                  12415   0.551682  0.262995  query_1
# 3                 1983                  12415   0.597829  0.344032  query_1
# 4                 1127                  12415   0.461885  0.268589  query_1
# ..                 ...                    ...        ...       ...      ...
# 395                 18                  12415   0.032847  0.136364  query_1
# 396                  2                  12415   0.011834  0.666667  query_1
# 397                  5                  12415   0.034247  0.185185  query_1
# 398                  9                  12415   0.003010  0.818182  query_1
# 399                336                  12415   0.168844  0.216914  query_1
#
#                  parents                                      intersections  \
# 0          [HPA:0600221]  [PRC1, NECTIN4, NCAPG2, FLAD1, CIP2A, DHX36, S...
# 1          [HPA:0310000]  [IGF2BP3, PRC1, NCAPG2, FLAD1, CIP2A, DHX36, S...
# 2          [HPA:0610831]  [PRC1, NECTIN4, NCAPG2, FLAD1, CIP2A, DHX36, S...
# 3          [HPA:0170000]  [PRC1, NECTIN4, NCAPG2, FLAD1, CIP2A, DHX36, S...
# 4          [HPA:0470681]  [PRC1, NECTIN4, NCAPG2, FLAD1, CIP2A, DHX36, S...
# ..                   ...                                                ...
# 395   [REAC:R-HSA-69278]  [CDKN2A, TYMS, PPP2R2A, CDK1, CCNA2, PCNA, TK1...
# 396      [CORUM:0000000]                                       [SMC2, SMC4]
# 397         [HP:0002488]                 [CDKN2A, TRIP13, TP53, NSUN2, BLM]
# 398  [REAC:R-HSA-446728]  [LAMC2, LAMB3, COL17A1, ITGB4, KRT5, ITGA6, DS...
# 399        [HPA:0210052]  [CIP2A, DHX36, GATAD2B, XPR1, ANXA1, PGK1, SMA...
#
#                                              evidences
# 0    [[Enhanced], [Enhanced], [Approved], [Approved...
# 1    [[Enhanced], [Enhanced], [Approved], [Approved...
# 2    [[Enhanced], [Enhanced], [Approved], [Approved...
# 3    [[Enhanced], [Enhanced], [Approved], [Approved...
# 4    [[Enhanced], [Enhanced], [Approved], [Approved...
# ..                                                 ...
# 395  [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 396                                 [[CORUM], [CORUM]]
# 397                     [[HP], [HP], [HP], [HP], [HP]]
# 398  [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 399  [[Approved], [Approved], [Approved], [Supporte...
#
# [400 rows x 16 columns]

# %%
pd.unique(pathway_enrichment.source)
# Out:
# array(['HPA', 'GO:BP', 'REAC', 'MIRNA', 'WP', 'KEGG', 'GO:CC', 'CORUM',
#        'GO:MF', 'HP'], dtype=object)
