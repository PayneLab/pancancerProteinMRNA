# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
sig_delta_corr = delta_correlation_df[delta_correlation_df.FDR < 0.05]
num_genes = pd.DataFrame(sig_delta_corr.groupby('Gene').size())
sig_genes = num_genes[num_genes[0] >=3].index
sig_delta_corr = sig_delta_corr[sig_delta_corr.Gene.isin(sig_genes)]
sig_delta_corr = sig_delta_corr.groupby('Gene').mean()
sig_delta_corr['Delta_Correlation'] = abs(sig_delta_corr.Delta_Correlation)
sig_delta_corr = sig_delta_corr.sort_values('Delta_Correlation', ascending = False)
sig_delta_corr.reset_index(inplace = True)
genes = list(sig_delta_corr.Gene)
pathway_enrichment = gp.profile(organism='hsapiens', query = genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['GO:BP'])
pathway_enrichment.to_csv('combinded_GO_pathway_enrichment_df.csv', index = False)

# %%
pathway_enrichment
# Out:
#    source      native                                               name  \
# 0   GO:BP  GO:0000278                                 mitotic cell cycle
# 1   GO:BP  GO:1903047                         mitotic cell cycle process
# 2   GO:BP  GO:0022402                                 cell cycle process
# 3   GO:BP  GO:0000280                                   nuclear division
# 4   GO:BP  GO:0140014                           mitotic nuclear division
# 5   GO:BP  GO:0048285                                  organelle fission
# 6   GO:BP  GO:0051276                            chromosome organization
# 7   GO:BP  GO:0007049                                         cell cycle
# 8   GO:BP  GO:0007052                       mitotic spindle organization
# 9   GO:BP  GO:0000070               mitotic sister chromatid segregation
# 10  GO:BP  GO:1902850  microtubule cytoskeleton organization involved...
# 11  GO:BP  GO:0000819                       sister chromatid segregation
# 12  GO:BP  GO:0007051                               spindle organization
# 13  GO:BP  GO:0098813                     nuclear chromosome segregation
# 14  GO:BP  GO:0006271  DNA strand elongation involved in DNA replication
# 15  GO:BP  GO:0033260                            nuclear DNA replication
# 16  GO:BP  GO:0044786                         cell cycle DNA replication
# 17  GO:BP  GO:0044282                   small molecule catabolic process
# 18  GO:BP  GO:0007093            mitotic cell cycle checkpoint signaling
# 19  GO:BP  GO:0007059                             chromosome segregation
# 20  GO:BP  GO:0044772                mitotic cell cycle phase transition
# 21  GO:BP  GO:0006259                              DNA metabolic process
# 22  GO:BP  GO:0044770                        cell cycle phase transition
# 23  GO:BP  GO:0022616                              DNA strand elongation
# 24  GO:BP  GO:0051255                           spindle midzone assembly
# 25  GO:BP  GO:0016054                     organic acid catabolic process
# 26  GO:BP  GO:0000075                    cell cycle checkpoint signaling
# 27  GO:BP  GO:0006281                                         DNA repair
# 28  GO:BP  GO:0006974           cellular response to DNA damage stimulus
# 29  GO:BP  GO:0046395                  carboxylic acid catabolic process
# 30  GO:BP  GO:0000226              microtubule cytoskeleton organization
# 31  GO:BP  GO:0051983               regulation of chromosome segregation
# 32  GO:BP  GO:0033045         regulation of sister chromatid segregation
# 33  GO:BP  GO:0030261                            chromosome condensation
# 34  GO:BP  GO:0051256                   mitotic spindle midzone assembly
#
#          p_value  significant  \
# 0   3.184596e-11         True
# 1   7.713240e-10         True
# 2   3.415768e-07         True
# 3   1.178064e-06         True
# 4   1.281807e-06         True
# 5   1.965113e-06         True
# 6   2.382411e-06         True
# 7   3.735888e-06         True
# 8   4.953801e-06         True
# 9   6.801727e-06         True
# 10  1.798965e-05         True
# 11  3.435814e-05         True
# 12  4.567180e-05         True
# 13  5.347682e-05         True
# 14  7.935868e-05         True
# 15  1.128125e-04         True
# 16  1.351358e-04         True
# 17  2.515204e-04         True
# 18  5.229969e-04         True
# 19  5.437873e-04         True
# 20  6.281192e-04         True
# 21  9.050599e-04         True
# 22  2.136659e-03         True
# 23  2.982973e-03         True
# 24  4.514355e-03         True
# 25  6.565041e-03         True
# 26  8.178743e-03         True
# 27  8.526453e-03         True
# 28  8.675581e-03         True
# 29  2.261347e-02         True
# 30  2.359950e-02         True
# 31  3.146842e-02         True
# 32  3.438399e-02         True
# 33  3.666414e-02         True
# 34  4.456287e-02         True
#
#                                           description  term_size  query_size  \
# 0   "Progression through the phases of the mitotic...        792         220
# 1   "A process that is part of the mitotic cell cy...        702         916
# 2   "The cellular process that ensures successive ...        969         916
# 3   "The division of a cell nucleus into two nucle...        316         109
# 4   "A mitotic cell cycle process comprising the s...        269          93
# 5   "The creation of two or more organelles by div...        355         112
# 6   "A process that is carried out at the cellular...        823         109
# 7   "The progression of biochemical and morphologi...       1143         981
# 8   "A process that is carried out at the cellular...        172         216
# 9   "The cell cycle process in which replicated ho...        142         807
# 10  "Any microtubule cytoskeleton organization tha...        183         216
# 11  "The cell cycle process in which sister chroma...        164         874
# 12  "A process that is carried out at the cellular...        213         216
# 13  "The process in which genetic material, in the...        192         109
# 14  "The process in which an existing DNA strand i...         18        1570
# 15  "The DNA-dependent DNA replication that occurs...         56         585
# 16  "The DNA-dependent DNA replication that takes ...         57         886
# 17  "The chemical reactions and pathways resulting...        326        3659
# 18  "A signaling process that ensures accurate chr...        122         257
# 19  "The process in which genetic material, in the...        231         109
# 20  "The cell cycle process by which a cell commit...        418         281
# 21  "Any cellular metabolic process involving deox...        639         551
# 22  "The cell cycle process by which a cell commit...        473         257
# 23  "The DNA metabolic process in which an existin...         23        1836
# 24  "The cell cycle process in which aggregation, ...          8         349
# 25  "The chemical reactions and pathways resulting...        211        3659
# 26  "A signaling process that controls cell cycle ...        146         257
# 27  "The process of restoring DNA after damage. Ge...        399         611
# 28  "Any process that results in a change in state...        628         598
# 29  "The chemical reactions and pathways resulting...        196        3659
# 30  "A process that is carried out at the cellular...        491          95
# 31  "Any process that modulates the frequency, rat...         67         257
# 32  "Any process that modulates the frequency, rat...         55         257
# 33  "The progressive compaction of dispersed inter...         33         282
# 34  "The cell cycle process in which the aggregati...          6         349
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                  57                  12415   0.259091  0.071970  query_1
# 1                 128                  12415   0.139738  0.182336  query_1
# 2                 159                  12415   0.173581  0.164087  query_1
# 3                  22                  12415   0.201835  0.069620  query_1
# 4                  18                  12415   0.193548  0.066914  query_1
# 5                  23                  12415   0.205357  0.064789  query_1
# 6                  33                  12415   0.302752  0.040097  query_1
# 7                 187                  12415   0.190622  0.163605  query_1
# 8                  20                  12415   0.092593  0.116279  query_1
# 9                  37                  12415   0.045849  0.260563  query_1
# 10                 20                  12415   0.092593  0.109290  query_1
# 11                 41                  12415   0.046911  0.250000  query_1
# 12                 21                  12415   0.097222  0.098592  query_1
# 13                 16                  12415   0.146789  0.083333  query_1
# 14                 14                  12415   0.008917  0.777778  query_1
# 15                 17                  12415   0.029060  0.303571  query_1
# 16                 21                  12415   0.023702  0.368421  query_1
# 17                160                  12415   0.043728  0.490798  query_1
# 18                 17                  12415   0.066148  0.139344  query_1
# 19                 16                  12415   0.146789  0.069264  query_1
# 20                 35                  12415   0.124555  0.083732  query_1
# 21                 72                  12415   0.130672  0.112676  query_1
# 22                 35                  12415   0.136187  0.073996  query_1
# 23                 16                  12415   0.008715  0.695652  query_1
# 24                  6                  12415   0.017192  0.750000  query_1
# 25                106                  12415   0.028970  0.502370  query_1
# 26                 17                  12415   0.066148  0.116438  query_1
# 27                 53                  12415   0.086743  0.132832  query_1
# 28                 71                  12415   0.118729  0.113057  query_1
# 29                 98                  12415   0.026783  0.500000  query_1
# 30                 18                  12415   0.189474  0.036660  query_1
# 31                 11                  12415   0.042802  0.164179  query_1
# 32                 10                  12415   0.038911  0.181818  query_1
# 33                 10                  12415   0.035461  0.303030  query_1
# 34                  5                  12415   0.014327  0.833333  query_1
#
#                                              parents  \
# 0                                       [GO:0007049]
# 1                           [GO:0000278, GO:0022402]
# 2                           [GO:0007049, GO:0009987]
# 3                                       [GO:0048285]
# 4                           [GO:0000280, GO:1903047]
# 5                                       [GO:0006996]
# 6                                       [GO:0006996]
# 7                                       [GO:0009987]
# 8                           [GO:0007051, GO:1902850]
# 9               [GO:0000819, GO:0140014, GO:1903047]
# 10                          [GO:0000226, GO:1903047]
# 11                          [GO:0051276, GO:0098813]
# 12                          [GO:0000226, GO:0022402]
# 13                          [GO:0007059, GO:0022402]
# 14                          [GO:0006261, GO:0022616]
# 15                                      [GO:0044786]
# 16                          [GO:0006261, GO:0022402]
# 17                          [GO:0009056, GO:0044281]
# 18              [GO:0000075, GO:0045930, GO:1903047]
# 19                                      [GO:0009987]
# 20                          [GO:0044770, GO:1903047]
# 21                          [GO:0044260, GO:0090304]
# 22                                      [GO:0022402]
# 23                                      [GO:0006259]
# 24  [GO:0007017, GO:0022402, GO:0022607, GO:0051225]
# 25  [GO:0006082, GO:0044248, GO:0044282, GO:1901575]
# 26                          [GO:0035556, GO:1901988]
# 27                          [GO:0006259, GO:0006974]
# 28                                      [GO:0033554]
# 29                          [GO:0016054, GO:0019752]
# 30                          [GO:0007010, GO:0007017]
# 31                          [GO:0007059, GO:0050794]
# 32  [GO:0000819, GO:0010564, GO:0033044, GO:0051983]
# 33                                      [GO:0006323]
# 34  [GO:0000022, GO:0051255, GO:0090307, GO:1903047]
#
#                                         intersections  \
# 0   [ZWINT, PRC1, NCAPG2, CDKN2A, KIF2C, TRIP13, P...
# 1   [ZWINT, PRC1, NCAPG2, CDKN2A, KIF2C, TRIP13, N...
# 2   [ZWINT, PRC1, NCAPG2, CDKN2A, KIF2C, TRIP13, N...
# 3   [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, K...
# 4   [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, K...
# 5   [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, K...
# 6   [ZWINT, PRC1, NCAPG2, DHX36, CDKN2A, NSD3, KIF...
# 7   [ZWINT, PRC1, NCAPG2, CDKN2A, KIF2C, TRIP13, P...
# 8   [ZWINT, PRC1, KIF2C, KIF11, TPX2, INCENP, DYNC...
# 9   [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, D...
# 10  [ZWINT, PRC1, KIF2C, KIF11, TPX2, INCENP, DYNC...
# 11  [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, D...
# 12  [ZWINT, PRC1, KIF2C, KIF11, TPX2, INCENP, DYNC...
# 13  [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, I...
# 14  [GINS2, PCNA, GINS3, GINS1, MCM4, GINS4, RFC4,...
# 15  [BLM, PCNA, MCM5, CHTF18, GINS3, RFC5, WRN, RF...
# 16  [BLM, PCNA, MCM5, CHTF18, GINS3, RFC5, WRN, RF...
# 17  [PGK1, ACAD10, XDH, ENTPD5, KHK, MECR, SDS, AP...
# 18  [ZWINT, TRIP13, CHEK1, DYNC1LI1, CENPF, TP53, ...
# 19  [ZWINT, PRC1, NCAPG2, KIF2C, TRIP13, NCAPD3, I...
# 20  [ZWINT, CDKN2A, TRIP13, TYMS, TPX2, CHEK1, ANX...
# 21  [UBE2T, DHX36, CDKN2A, TRIP13, TYMS, USP7, CHE...
# 22  [ZWINT, CDKN2A, TRIP13, TYMS, TPX2, CHEK1, ANX...
# 23  [GINS2, PCNA, GINS3, GINS1, MCM4, GINS4, RFC4,...
# 24       [PRC1, INCENP, AURKB, KIF23, RACGAP1, KIF4A]
# 25  [ACAD10, MECR, SDS, ARG2, EHHADH, LPIN1, LONP2...
# 26  [ZWINT, TRIP13, CHEK1, DYNC1LI1, CENPF, TP53, ...
# 27  [UBE2T, TRIP13, USP7, CHEK1, HSF1, TP53, WDR70...
# 28  [UBE2T, CDKN2A, TRIP13, USP7, CHEK1, USP16, GN...
# 29  [ACAD10, MECR, SDS, ARG2, EHHADH, LPIN1, LONP2...
# 30  [ZWINT, PRC1, KIF2C, KIF11, TPX2, CHEK1, INCEN...
# 31  [ZWINT, KIF2C, TRIP13, DYNC1LI1, CENPF, DLGAP5...
# 32  [ZWINT, TRIP13, DYNC1LI1, CENPF, DLGAP5, MAD2L...
# 33  [NCAPG2, NCAPD3, INCENP, SMC2, CDK1, NCAPG, SM...
# 34               [PRC1, AURKB, KIF23, RACGAP1, KIF4A]
#
#                                             evidences
# 0   [[IDA, IBA, TAS], [IBA, TAS], [IBA, TAS], [IDA...
# 1   [[IDA, IBA, TAS], [IBA, TAS], [IBA, TAS], [IDA...
# 2   [[IDA, IBA, TAS], [IDA, IBA, TAS], [IBA, TAS],...
# 3   [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 4   [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 5   [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 6   [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IDA, IMP...
# 7   [[IDA, IBA, TAS], [IDA, IBA, TAS], [IBA, TAS],...
# 8   [[TAS], [IBA, TAS], [TAS], [IDA, IMP, IBA, TAS...
# 9   [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 10  [[TAS], [IBA, TAS], [TAS], [IDA, IMP, IBA, TAS...
# 11  [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 12  [[TAS], [IBA, TAS], [TAS], [IDA, IMP, IBA, TAS...
# 13  [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 14  [[TAS], [IBA], [TAS], [IBA, TAS], [IBA], [TAS]...
# 15  [[TAS], [ISS, TAS], [IBA], [TAS], [IBA], [TAS]...
# 16  [[TAS], [ISS, TAS], [IBA], [TAS], [IBA], [TAS]...
# 17  [[TAS], [TAS], [IDA], [TAS], [TAS], [TAS], [ID...
# 18  [[IDA], [IMP], [IMP], [IMP], [NAS], [IMP, TAS]...
# 19  [[IDA, IBA], [IBA, TAS], [IBA, TAS], [IMP], [I...
# 20  [[IDA], [IDA, IMP, ISO, TAS], [IMP], [TAS], [T...
# 21  [[IMP, TAS], [IMP], [IMP, ISO], [ISS, IBA], [I...
# 22  [[IDA], [IDA, IMP, ISO, TAS], [IMP, IBA], [TAS...
# 23  [[TAS], [IBA], [TAS], [IBA, TAS], [IBA], [TAS]...
# 24  [[IBA], [IBA], [IMP, TAS], [IMP, IBA], [IDA], ...
# 25  [[TAS], [TAS], [IDA, IBA, TAS], [IBA], [IDA, I...
# 26  [[IDA], [IMP, IBA], [IDA, IMP], [IMP], [NAS], ...
# 27  [[IMP, TAS], [ISS], [IMP, TAS], [IDA, IMP], [I...
# 28  [[IMP, IBA, TAS], [IDA, ISO], [ISS], [IMP, TAS...
# 29  [[TAS], [TAS], [IDA, IBA, TAS], [IBA], [IDA, I...
# 30  [[TAS], [IBA, TAS], [IDA, IMP, TAS], [IDA, IMP...
# 31  [[IDA], [IMP], [IMP], [IMP], [NAS], [NAS], [ID...
# 32  [[IDA], [IMP], [IMP], [NAS], [NAS], [IDA, IMP,...
# 33  [[TAS], [IDA, IMP, IBA, TAS], [IBA], [IDA, TAS...
# 34      [[IBA], [IMP, TAS], [IMP, IBA], [IDA], [IMP]]
