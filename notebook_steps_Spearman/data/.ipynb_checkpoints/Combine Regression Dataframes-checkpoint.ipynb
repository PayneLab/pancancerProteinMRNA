# %%
import pandas as pd
import glob

# %%
files = glob.glob('Scripts_to_make_regression_dataframes/*regressions.csv')
files
# Out:
# ['Scripts_to_make_regression_dataframes\\CCRCC_regressions.csv',
#  'Scripts_to_make_regression_dataframes\\Endometrial_regressions.csv',
#  'Scripts_to_make_regression_dataframes\\HNSCC_regressions.csv',
#  'Scripts_to_make_regression_dataframes\\LSCC_regressions.csv',
#  'Scripts_to_make_regression_dataframes\\LUAD_regressions.csv',
#  'Scripts_to_make_regression_dataframes\\PDAC_regressions.csv']

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
regression_df = pd.concat(dfs)
regression_df.to_csv('regression_df.csv', index = False)
regression_df
# Out:
#          Gene  interaction_coeff  condition_coeff  transcript_coeff  \
# 0        A1BG          -0.399310         0.683426          0.377849
# 1        A1CF           0.009264        -0.282587          0.073218
# 2         A2M          -0.001738         1.059763          0.001776
# 3      A4GALT          -0.069014         1.186499          0.074956
# 4        AAAS          -0.005048         0.253459          0.008609
# ...       ...                ...              ...               ...
# 10928    ZXDC           0.211513        -1.518100         -0.762300
# 10929  ZYG11B          -0.302709         3.604961          0.385818
# 10930     ZYX          -0.112959         1.407814          0.356106
# 10931   ZZEF1          -0.013929         0.233128          0.135443
# 10932    ZZZ3           0.012028        -0.537942         -0.140017
#
#        intercept  interaction_pval  condition_pval  transcript_pval  \
# 0      -0.462140          0.004893        0.000044     6.114431e-03
# 1      -0.563416          0.249574        0.001941     2.664112e-22
# 2      -0.899006          0.025257        0.000041     1.024242e-02
# 3      -0.824329          0.597891        0.419827     4.397210e-01
# 4      -0.148476          0.490634        0.038262     2.000865e-01
# ...          ...               ...             ...              ...
# 10928  25.599212          0.946348        0.964870     8.013962e-01
# 10929  16.176521          0.302508        0.291332     1.614768e-01
# 10930  24.383164          0.442878        0.369781     1.082073e-02
# 10931  22.760766          0.916577        0.887268     2.640039e-01
# 10932  21.722427          0.974614        0.901142     6.893205e-01
#
#        intercept_pval  interaction_FDR  condition_FDR  intercept_FDR Cancer
# 0        1.735687e-03         0.030269       0.000267   5.284138e-03  CCRCC
# 1        3.148530e-11         0.483928       0.007715   3.375975e-10  CCRCC
# 2        1.455183e-05         0.102154       0.000248   6.862382e-05  CCRCC
# 3        4.279663e-01         0.787282       0.572700   5.581218e-01  CCRCC
# 4        1.786438e-01         0.712627       0.094165   2.857311e-01  CCRCC
# ...               ...              ...            ...            ...    ...
# 10928    4.451743e-01         0.976633       0.984317   4.588998e-01   PDAC
# 10929    1.225991e-06         0.608560       0.598847   1.716011e-06   PDAC
# 10930    1.892405e-36         0.721709       0.669121   1.204288e-35   PDAC
# 10931    2.416000e-32         0.968207       0.959289   1.255425e-31   PDAC
# 10932    4.545059e-07         0.988213       0.964104   6.516869e-07   PDAC
#
# [65036 rows x 13 columns]
