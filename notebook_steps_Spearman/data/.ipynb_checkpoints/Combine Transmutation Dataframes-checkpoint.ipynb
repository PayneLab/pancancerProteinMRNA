# %%
import pandas as pd
import glob
import statsmodels.stats.multitest as ssm

# %%
files = glob.glob('Scripts_to_make_transmutation_effects_dataframes/*effects.csv')
files
# Out:
# ['Scripts_to_make_transmutation_effects_dataframes\\CCRCC_PBRM1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\CCRCC_SETD2_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\CCRCC_TTN_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_ARID1A_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_CTCF_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_CTNNB1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_KMT2B_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_KRAS_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_PIK3CA_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_PIK3R1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_PTEN_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_TP53_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\Endometrial_ZFHX3_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_CDKN2A_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_DMD_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_FAT1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_KMT2D_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_MUC16_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_MUC4_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_NOTCH1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_PLEC_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\HNSCC_TTN_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_CSMD3_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_DNAH5_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_KMT2D_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_LRP1B_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_MUC16_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_RYR2_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_SYNE1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_TTN_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_XIRP2_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LSCC_ZFHX4_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_COL11A1_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_EGFR_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_FAT3_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_KRAS_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_LRP1B_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_MUC16_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_RYR2_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_TP53_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_TTN_transmutation_effects.csv',
#  'Scripts_to_make_transmutation_effects_dataframes\\LUAD_ZFHX4_transmutation_effects.csv']

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
transmutation_df = pd.concat(dfs)
dfs = []
for cancer in pd.unique(transmutation_df.Cancer):
    df = transmutation_df[transmutation_df.Cancer == cancer]
    df['FDR'] = ssm.fdrcorrection(df['P_Value'])[1]
    dfs.append(df)
transmutation_df = pd.concat(dfs)
transmutation_df = transmutation_df[transmutation_df.Cancer != 'PDAC']
transmutation_df.to_csv('transmutation_df.csv', index = False)
transmutation_df
# Out:
# <ipython-input-3-f81a8a838a6b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FDR'] = ssm.fdrcorrection(df['P_Value'])[1]
#         Gene  Delta_Correlation   P_Value       FDR Cancer Mutated_Gene
# 0       A1BG           0.194142  0.346092  0.934467  CCRCC        PBRM1
# 1       A1CF          -0.050287  0.166994  0.927123  CCRCC        PBRM1
# 2        A2M           0.027150  0.893202  0.993176  CCRCC        PBRM1
# 3       AAAS          -0.069457  0.725130  0.980069  CCRCC        PBRM1
# 4       AACS          -0.133106  0.359595  0.936438  CCRCC        PBRM1
# ...      ...                ...       ...       ...    ...          ...
# 9386    ZXDC           0.153748  0.525218  0.957828   LUAD        ZFHX4
# 9387  ZYG11B          -0.115236  0.484129  0.950108   LUAD        ZFHX4
# 9388     ZYX          -0.075521  0.728263  0.980100   LUAD        ZFHX4
# 9389   ZZEF1           0.029538  0.776407  0.983019   LUAD        ZFHX4
# 9390    ZZZ3          -0.064619  0.773380  0.982950   LUAD        ZFHX4
#
# [376444 rows x 6 columns]
