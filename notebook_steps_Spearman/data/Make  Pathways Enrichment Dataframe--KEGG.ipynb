# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
pathway_enrichments = []
for cancer in pd.unique(delta_correlation_df.Cancer):
    cancer_df = delta_correlation_df[delta_correlation_df.Cancer == cancer]
    sig_cancer_df = cancer_df[cancer_df.FDR < 0.05]
    sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
    sig_cancer_df = sig_cancer_df.sort_values('Delta_Correlation', ascending = False)
    sig_genes = list(sig_cancer_df.Gene)
    pathway_enrichment = gp.profile(organism='hsapiens', query = sig_genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['KEGG'])
    pathway_enrichment['Cancer'] = [cancer] * len(pathway_enrichment)
    pathway_enrichments.append(pathway_enrichment)
pathway_enrichments = pd.concat(pathway_enrichments)
pathway_enrichments.to_csv('kegg_pathway_enrichment_df.csv', index = False)
pathway_enrichments
# Out:
# <ipython-input-5-ac98142a4dc5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-ac98142a4dc5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-ac98142a4dc5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-ac98142a4dc5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
# <ipython-input-5-ac98142a4dc5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_cancer_df['Delta_Correlation'] = abs(sig_cancer_df.Delta_Correlation)
#    source      native                                         name  \
# 0    KEGG  KEGG:01200                            Carbon metabolism
# 1    KEGG  KEGG:00020                    Citrate cycle (TCA cycle)
# 2    KEGG  KEGG:00640                        Propanoate metabolism
# 3    KEGG  KEGG:00280   Valine, leucine and isoleucine degradation
# 4    KEGG  KEGG:00010                 Glycolysis / Gluconeogenesis
# 5    KEGG  KEGG:00620                          Pyruvate metabolism
# 6    KEGG  KEGG:01100                           Metabolic pathways
# 0    KEGG  KEGG:00280   Valine, leucine and isoleucine degradation
# 1    KEGG  KEGG:01230                  Biosynthesis of amino acids
# 2    KEGG  KEGG:00240                        Pyrimidine metabolism
# 3    KEGG  KEGG:01200                            Carbon metabolism
# 4    KEGG  KEGG:00520  Amino sugar and nucleotide sugar metabolism
# 5    KEGG  KEGG:03030                              DNA replication
# 6    KEGG  KEGG:01100                           Metabolic pathways
# 7    KEGG  KEGG:00071                       Fatty acid degradation
# 8    KEGG  KEGG:01212                        Fatty acid metabolism
# 9    KEGG  KEGG:00010                 Glycolysis / Gluconeogenesis
# 0    KEGG  KEGG:00190                    Oxidative phosphorylation
# 1    KEGG  KEGG:04932            Non-alcoholic fatty liver disease
# 2    KEGG  KEGG:05164                                  Influenza A
# 3    KEGG  KEGG:05169                 Epstein-Barr virus infection
# 4    KEGG  KEGG:05166      Human T-cell leukemia virus 1 infection
# 5    KEGG  KEGG:05012                            Parkinson disease
# 6    KEGG  KEGG:05415                      Diabetic cardiomyopathy
# 7    KEGG  KEGG:05222                       Small cell lung cancer
# 8    KEGG  KEGG:05162                                      Measles
# 9    KEGG  KEGG:00740                        Riboflavin metabolism
# 0    KEGG  KEGG:03030                              DNA replication
# 1    KEGG  KEGG:03013                                RNA transport
# 2    KEGG  KEGG:04110                                   Cell cycle
# 3    KEGG  KEGG:03430                              Mismatch repair
# 4    KEGG  KEGG:04218                          Cellular senescence
# 5    KEGG  KEGG:04668                        TNF signaling pathway
# 6    KEGG  KEGG:05418       Fluid shear stress and atherosclerosis
# 7    KEGG  KEGG:03015                    mRNA surveillance pathway
# 8    KEGG  KEGG:04120               Ubiquitin mediated proteolysis
# 9    KEGG  KEGG:05215                              Prostate cancer
# 10   KEGG  KEGG:01230                  Biosynthesis of amino acids
# 0    KEGG  KEGG:03030                              DNA replication
# 1    KEGG  KEGG:00240                        Pyrimidine metabolism
# 2    KEGG  KEGG:04110                                   Cell cycle
# 3    KEGG  KEGG:03430                              Mismatch repair
#
#          p_value  significant                                  description  \
# 0   7.742099e-12         True                            Carbon metabolism
# 1   3.657811e-06         True                    Citrate cycle (TCA cycle)
# 2   6.753259e-05         True                        Propanoate metabolism
# 3   8.346592e-05         True   Valine, leucine and isoleucine degradation
# 4   2.626106e-04         True                 Glycolysis / Gluconeogenesis
# 5   5.037111e-03         True                          Pyruvate metabolism
# 6   1.308542e-02         True                           Metabolic pathways
# 0   1.458228e-05         True   Valine, leucine and isoleucine degradation
# 1   1.683188e-03         True                  Biosynthesis of amino acids
# 2   1.737214e-03         True                        Pyrimidine metabolism
# 3   2.430846e-03         True                            Carbon metabolism
# 4   2.914948e-03         True  Amino sugar and nucleotide sugar metabolism
# 5   2.983885e-03         True                              DNA replication
# 6   3.723209e-03         True                           Metabolic pathways
# 7   7.674003e-03         True                       Fatty acid degradation
# 8   2.724018e-02         True                        Fatty acid metabolism
# 9   4.092035e-02         True                 Glycolysis / Gluconeogenesis
# 0   6.786354e-05         True                    Oxidative phosphorylation
# 1   2.001503e-04         True            Non-alcoholic fatty liver disease
# 2   2.729539e-04         True                                  Influenza A
# 3   4.912953e-04         True                 Epstein-Barr virus infection
# 4   3.360897e-03         True      Human T-cell leukemia virus 1 infection
# 5   6.205116e-03         True                            Parkinson disease
# 6   9.096204e-03         True                      Diabetic cardiomyopathy
# 7   1.001584e-02         True                       Small cell lung cancer
# 8   1.177905e-02         True                                      Measles
# 9   4.458225e-02         True                        Riboflavin metabolism
# 0   6.944638e-07         True                              DNA replication
# 1   1.433569e-04         True                                RNA transport
# 2   2.753033e-04         True                                   Cell cycle
# 3   1.385443e-03         True                              Mismatch repair
# 4   6.532288e-03         True                          Cellular senescence
# 5   1.096488e-02         True                        TNF signaling pathway
# 6   1.553291e-02         True       Fluid shear stress and atherosclerosis
# 7   1.567801e-02         True                    mRNA surveillance pathway
# 8   2.491178e-02         True               Ubiquitin mediated proteolysis
# 9   2.519501e-02         True                              Prostate cancer
# 10  3.988601e-02         True                  Biosynthesis of amino acids
# 0   6.899369e-07         True                              DNA replication
# 1   9.145781e-05         True                        Pyrimidine metabolism
# 2   1.009008e-04         True                                   Cell cycle
# 3   1.526516e-03         True                              Mismatch repair
#
#     term_size  query_size  intersection_size  effective_domain_size  \
# 0         110        3288                 69                  12415
# 1          29        3066                 22                  12415
# 2          34        3266                 23                  12415
# 3          48        3266                 29                  12415
# 4          62        3142                 35                  12415
# 5          45        3142                 25                  12415
# 6        1227        3316                459                  12415
# 0          48        1748                 22                  12415
# 1          72         690                 15                  12415
# 2          51        1312                 18                  12415
# 3         110        1606                 32                  12415
# 4          43        1656                 18                  12415
# 5          35        1644                 15                  12415
# 6        1227        1775                266                  12415
# 7          40        1272                 14                  12415
# 8          50        1322                 16                  12415
# 9          62         698                 12                  12415
# 0         115        1419                 36                  12415
# 1         129        1419                 38                  12415
# 2         131        2556                 61                  12415
# 3         167        2548                 68                  12415
# 4         181        2548                 70                  12415
# 5         218        1419                 50                  12415
# 6         181        2912                 72                  12415
# 7          82        1144                 21                  12415
# 8         105        2556                 48                  12415
# 9           8        1172                  5                  12415
# 0          35        2636                 24                  12415
# 1         151        2799                 69                  12415
# 2         103         605                 20                  12415
# 3          21        1369                 11                  12415
# 4         135        2018                 45                  12415
# 5          92         157                  8                  12415
# 6         118         171                  9                  12415
# 7          84        3159                 42                  12415
# 8         125        2564                 47                  12415
# 9          79          15                  3                  12415
# 10         72         285                  8                  12415
# 0          35         863                 15                  12415
# 1          51        1068                 18                  12415
# 2         103         102                  9                  12415
# 3          21        2012                 13                  12415
#
#     precision    recall    query       parents  \
# 0    0.020985  0.627273  query_1  [KEGG:00000]
# 1    0.007175  0.758621  query_1  [KEGG:00000]
# 2    0.007042  0.676471  query_1  [KEGG:00000]
# 3    0.008879  0.604167  query_1  [KEGG:00000]
# 4    0.011139  0.564516  query_1  [KEGG:00000]
# 5    0.007957  0.555556  query_1  [KEGG:00000]
# 6    0.138420  0.374083  query_1  [KEGG:00000]
# 0    0.012586  0.458333  query_1  [KEGG:00000]
# 1    0.021739  0.208333  query_1  [KEGG:00000]
# 2    0.013720  0.352941  query_1  [KEGG:00000]
# 3    0.019925  0.290909  query_1  [KEGG:00000]
# 4    0.010870  0.418605  query_1  [KEGG:00000]
# 5    0.009124  0.428571  query_1  [KEGG:00000]
# 6    0.149859  0.216789  query_1  [KEGG:00000]
# 7    0.011006  0.350000  query_1  [KEGG:00000]
# 8    0.012103  0.320000  query_1  [KEGG:00000]
# 9    0.017192  0.193548  query_1  [KEGG:00000]
# 0    0.025370  0.313043  query_1  [KEGG:00000]
# 1    0.026779  0.294574  query_1  [KEGG:00000]
# 2    0.023865  0.465649  query_1  [KEGG:00000]
# 3    0.026688  0.407186  query_1  [KEGG:00000]
# 4    0.027473  0.386740  query_1  [KEGG:00000]
# 5    0.035236  0.229358  query_1  [KEGG:00000]
# 6    0.024725  0.397790  query_1  [KEGG:00000]
# 7    0.018357  0.256098  query_1  [KEGG:00000]
# 8    0.018779  0.457143  query_1  [KEGG:00000]
# 9    0.004266  0.625000  query_1  [KEGG:00000]
# 0    0.009105  0.685714  query_1  [KEGG:00000]
# 1    0.024652  0.456954  query_1  [KEGG:00000]
# 2    0.033058  0.194175  query_1  [KEGG:00000]
# 3    0.008035  0.523810  query_1  [KEGG:00000]
# 4    0.022299  0.333333  query_1  [KEGG:00000]
# 5    0.050955  0.086957  query_1  [KEGG:00000]
# 6    0.052632  0.076271  query_1  [KEGG:00000]
# 7    0.013295  0.500000  query_1  [KEGG:00000]
# 8    0.018331  0.376000  query_1  [KEGG:00000]
# 9    0.200000  0.037975  query_1  [KEGG:00000]
# 10   0.028070  0.111111  query_1  [KEGG:00000]
# 0    0.017381  0.428571  query_1  [KEGG:00000]
# 1    0.016854  0.352941  query_1  [KEGG:00000]
# 2    0.088235  0.087379  query_1  [KEGG:00000]
# 3    0.006461  0.619048  query_1  [KEGG:00000]
#
#                                         intersections  \
# 0   [AGXT, HK2, ENO2, PGAM2, HIBCH, ESD, ME2, SDS,...
# 1   [PCK2, SUCLG1, PCK1, IDH3B, PDHB, SUCLA2, OGDH...
# 2   [LDHAL6A, ABAT, HIBCH, DBT, SUCLG1, ACSS2, ALD...
# 3   [IVD, ACAA1, ABAT, HIBCH, HMGCL, DBT, ALDH6A1,...
# 4   [HK2, LDHAL6A, ENO2, PCK2, PGAM2, ALDOB, GPI, ...
# 5   [LDHAL6A, PCK2, ME2, ACSS2, LDHC, ADH6, LDHD, ...
# 6   [AGXT, IDO1, PLA2G7, PCYT1A, NDUFC1, CA9, CYP1...
# 0   [EHHADH, ACAA2, HADHB, BCAT2, ACSF3, ACAD8, AL...
# 1   [TALDO1, MTR, PGK1, PKM, GOT1, GLUL, SDS, ASS1...
# 2   [TYMS, CAD, NME1, RRM2, UCK2, ENTPD5, DUT, UPR...
# 3   [TALDO1, ACSS1, IDNK, PGK1, PKM, HKDC1, GOT1, ...
# 4   [CYB5R4, HKDC1, HK2, GNE, NPL, UXS1, GNPNAT1, ...
# 5   [POLE, RFC1, POLD3, MCM6, RPA1, MCM5, PCNA, PO...
# 6   [TALDO1, IMPDH2, ACSS1, IMPDH1, EHHADH, NSD3, ...
# 7   [EHHADH, ACAA2, HADHB, ECI1, ALDH3A2, ACOX3, A...
# 8   [EHHADH, ACAA2, HADHB, MECR, SCD, ACSF3, ACOX3...
# 9   [ACSS1, ALDH3A1, PGK1, PKM, HKDC1, ALDH3B1, LD...
# 0   [ATP6V0D1, NDUFS5, NDUFB1, NDUFB4, NDUFB10, ND...
# 1   [NDUFS5, NDUFB1, JUN, NDUFB4, NDUFB10, NDUFB9,...
# 2   [FADD, SLC25A5, CXCL10, RSAD2, CDK6, PIK3CA, H...
# 3   [FADD, ISG15, MYC, CXCL10, TP53, CDK6, JUN, PI...
# 4   [SLC2A1, CDKN2A, SLC25A5, CCNB2, MYC, TP53, PT...
# 5   [SLC25A5, NDUFS5, TP53, ATF6, NDUFB1, NDUFB4, ...
# 6   [SLC2A1, SLC25A5, NDUFS5, PTEN, NDUFB1, PDHA1,...
# 7   [RXRB, MYC, BIRC2, TP53, COL4A6, LAMC2, CDK6, ...
# 8   [FADD, TP53, CDK6, JUN, PIK3CA, CSNK2A2, PIK3R...
# 9                     [FLAD1, ACP5, BLVRB, RFK, ACP1]
# 0   [RFC4, RFC5, PRIM1, RFC2, RFC3, MCM5, MCM6, SS...
# 1   [NUP153, XPO5, EIF5, EIF5B, GEMIN2, STRAP, XPO...
# 2   [TP53, CHEK2, PRKDC, SKP2, YWHAG, YWHAZ, YWHAQ...
# 3   [RFC4, RFC5, RFC2, MSH6, RFC3, MSH2, SSBP1, PC...
# 4   [TP53, NFKB1, CHEK2, CALML3, VDAC2, CCNB2, CCN...
# 5   [MMP3, NFKB1, RIPK1, TNFRSF1A, BAG4, FADD, ICA...
# 6   [TP53, NFKB1, TNFRSF1A, KEAP1, SDC1, CALML3, I...
# 7   [GSPT1, RNMT, PPP2R2A, DDX19A, EIF4A3, PAPOLG,...
# 8   [KEAP1, UBE2G1, SKP2, UBE2M, UBA6, UBE2F, UBE4...
# 9                                 [MMP3, TP53, NFKB1]
# 10  [PGK1, PSAT1, MAT1A, IDH3A, PYCR3, PYCR1, ALDO...
# 0   [MCM2, MCM7, LIG1, MCM5, MCM3, PRIM1, MCM4, FE...
# 1   [ENTPD3, RRM2, TYMS, UMPS, CAD, TK1, ENTPD5, D...
# 2   [MCM2, CDK1, YWHAZ, MCM7, CHEK1, CCNA2, CCNB1,...
# 3   [PMS2, LIG1, RFC2, RFC4, MSH6, RFC5, RFC1, PCN...
#
#                                             evidences       Cancer
# 0   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 6   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        CCRCC
# 0   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 6   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 9   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...  Endometrial
# 0   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 6   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...        HNSCC
# 9            [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]        HNSCC
# 0   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 4   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 5   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 6   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 7   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 8   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 9                            [[KEGG], [KEGG], [KEGG]]         LSCC
# 10  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LSCC
# 0   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LUAD
# 1   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LUAD
# 2   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LUAD
# 3   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...         LUAD
