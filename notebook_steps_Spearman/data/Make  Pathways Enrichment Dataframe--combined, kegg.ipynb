# %%
import pandas as pd
from gprofiler import GProfiler

# %%
delta_correlation_df = pd.read_csv('delta_correlation_df.csv')
delta_correlation_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 50303    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 50304  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 50305     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 50306   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 50307    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]

# %%
background_genes = list(pd.unique(delta_correlation_df.Gene))

# %%
gp = GProfiler(return_dataframe=True)

# %%
sig_delta_corr = delta_correlation_df[delta_correlation_df.FDR < 0.05]
num_genes = pd.DataFrame(sig_delta_corr.groupby('Gene').size())
sig_genes = num_genes[num_genes[0] >=3].index
sig_delta_corr = sig_delta_corr[sig_delta_corr.Gene.isin(sig_genes)]
sig_delta_corr = sig_delta_corr.groupby('Gene').mean()
sig_delta_corr['Delta_Correlation'] = abs(sig_delta_corr.Delta_Correlation)
sig_delta_corr = sig_delta_corr.sort_values('Delta_Correlation', ascending = False)
sig_delta_corr.reset_index(inplace = True)
genes = list(sig_delta_corr.Gene)
pathway_enrichment = gp.profile(organism='hsapiens', query = genes, no_iea=True,
                       ordered=True, no_evidences=False, background= background_genes, sources = ['KEGG'])
pathway_enrichment.to_csv('combinded_kegg_pathway_enrichment_df.csv', index = False)

# %%
pathway_enrichment
# Out:
#   source      native                                        name  \
# 0   KEGG  KEGG:00280  Valine, leucine and isoleucine degradation
# 1   KEGG  KEGG:03030                             DNA replication
# 2   KEGG  KEGG:03430                             Mismatch repair
# 3   KEGG  KEGG:00240                       Pyrimidine metabolism
# 4   KEGG  KEGG:04110                                  Cell cycle
# 5   KEGG  KEGG:01200                           Carbon metabolism
# 6   KEGG  KEGG:05164                                 Influenza A
# 7   KEGG  KEGG:04115                       p53 signaling pathway
#
#         p_value  significant                                 description  \
# 0  4.317141e-07         True  Valine, leucine and isoleucine degradation
# 1  7.801888e-06         True                             DNA replication
# 2  8.865737e-05         True                             Mismatch repair
# 3  3.179117e-04         True                       Pyrimidine metabolism
# 4  1.320747e-03         True                                  Cell cycle
# 5  1.562638e-03         True                           Carbon metabolism
# 6  2.087796e-02         True                                 Influenza A
# 7  2.219830e-02         True                       p53 signaling pathway
#
#    term_size  query_size  intersection_size  effective_domain_size  precision  \
# 0         48        3644                 34                  12415   0.009330
# 1         35        1570                 18                  12415   0.011465
# 2         21        1288                 12                  12415   0.009317
# 3         51        3314                 32                  12415   0.009656
# 4        103         913                 24                  12415   0.026287
# 5        110        3639                 56                  12415   0.015389
# 6        131        3383                 68                  12415   0.020101
# 7         59        1100                 17                  12415   0.015455
#
#      recall    query       parents  \
# 0  0.708333  query_1  [KEGG:00000]
# 1  0.514286  query_1  [KEGG:00000]
# 2  0.571429  query_1  [KEGG:00000]
# 3  0.627451  query_1  [KEGG:00000]
# 4  0.233010  query_1  [KEGG:00000]
# 5  0.509091  query_1  [KEGG:00000]
# 6  0.519084  query_1  [KEGG:00000]
# 7  0.288136  query_1  [KEGG:00000]
#
#                                        intersections  \
# 0  [EHHADH, HADHB, ACSF3, IL4I1, BCAT1, AACS, ACA...
# 1  [PCNA, MCM5, RFC5, RFC1, PRIM1, MCM2, MCM4, RF...
# 2  [PCNA, PMS2, RFC5, RFC1, RFC4, MSH6, POLD3, MS...
# 3  [TYMS, CAD, ENTPD5, TK1, RRM2, UPRT, DTYMK, DC...
# 4  [CDKN2A, CHEK1, TP53, CDK1, MAD2L1, CCNA2, PCN...
# 5  [PGK1, TALDO1, MDH2, SDS, PGAM1, RPIA, SHMT2, ...
# 6  [FADD, TMPRSS4, RELA, JAK1, ICAM1, EP300, XPO1...
# 7  [CDKN2A, CHEK1, TP53, CDK1, SERPINB5, CCNB1, R...
#
#                                            evidences
# 0  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 1  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 6  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
#   source      native                                        name  \
# 0   KEGG  KEGG:00280  Valine, leucine and isoleucine degradation
# 1   KEGG  KEGG:03030                             DNA replication
# 2   KEGG  KEGG:03430                             Mismatch repair
# 3   KEGG  KEGG:00240                       Pyrimidine metabolism
# 4   KEGG  KEGG:04110                                  Cell cycle
# 5   KEGG  KEGG:01200                           Carbon metabolism
# 6   KEGG  KEGG:05164                                 Influenza A
# 7   KEGG  KEGG:04115                       p53 signaling pathway
#
#         p_value  significant                                 description  \
# 0  4.317141e-07         True  Valine, leucine and isoleucine degradation
# 1  7.801888e-06         True                             DNA replication
# 2  8.865737e-05         True                             Mismatch repair
# 3  3.179117e-04         True                       Pyrimidine metabolism
# 4  1.320747e-03         True                                  Cell cycle
# 5  1.562638e-03         True                           Carbon metabolism
# 6  2.087796e-02         True                                 Influenza A
# 7  2.219830e-02         True                       p53 signaling pathway
#
#    term_size  query_size  intersection_size  effective_domain_size  precision  \
# 0         48        3644                 34                  12415   0.009330
# 1         35        1570                 18                  12415   0.011465
# 2         21        1288                 12                  12415   0.009317
# 3         51        3314                 32                  12415   0.009656
# 4        103         913                 24                  12415   0.026287
# 5        110        3639                 56                  12415   0.015389
# 6        131        3383                 68                  12415   0.020101
# 7         59        1100                 17                  12415   0.015455
#
#      recall    query       parents  \
# 0  0.708333  query_1  [KEGG:00000]
# 1  0.514286  query_1  [KEGG:00000]
# 2  0.571429  query_1  [KEGG:00000]
# 3  0.627451  query_1  [KEGG:00000]
# 4  0.233010  query_1  [KEGG:00000]
# 5  0.509091  query_1  [KEGG:00000]
# 6  0.519084  query_1  [KEGG:00000]
# 7  0.288136  query_1  [KEGG:00000]
#
#                                        intersections  \
# 0  [EHHADH, HADHB, ACSF3, IL4I1, BCAT1, AACS, ACA...
# 1  [PCNA, MCM5, RFC5, RFC1, PRIM1, MCM2, MCM4, RF...
# 2  [PCNA, PMS2, RFC5, RFC1, RFC4, MSH6, POLD3, MS...
# 3  [TYMS, CAD, ENTPD5, TK1, RRM2, UPRT, DTYMK, DC...
# 4  [CDKN2A, CHEK1, TP53, CDK1, MAD2L1, CCNA2, PCN...
# 5  [PGK1, TALDO1, MDH2, SDS, PGAM1, RPIA, SHMT2, ...
# 6  [FADD, TMPRSS4, RELA, JAK1, ICAM1, EP300, XPO1...
# 7  [CDKN2A, CHEK1, TP53, CDK1, SERPINB5, CCNB1, R...
#
#                                            evidences
# 0  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 1  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 6  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
#   source      native                                        name  \
# 0   KEGG  KEGG:00280  Valine, leucine and isoleucine degradation
# 1   KEGG  KEGG:03030                             DNA replication
# 2   KEGG  KEGG:03430                             Mismatch repair
# 3   KEGG  KEGG:00240                       Pyrimidine metabolism
# 4   KEGG  KEGG:04110                                  Cell cycle
# 5   KEGG  KEGG:01200                           Carbon metabolism
# 6   KEGG  KEGG:05164                                 Influenza A
# 7   KEGG  KEGG:04115                       p53 signaling pathway
#
#         p_value  significant                                 description  \
# 0  4.317141e-07         True  Valine, leucine and isoleucine degradation
# 1  7.801888e-06         True                             DNA replication
# 2  8.865737e-05         True                             Mismatch repair
# 3  3.179117e-04         True                       Pyrimidine metabolism
# 4  1.320747e-03         True                                  Cell cycle
# 5  1.562638e-03         True                           Carbon metabolism
# 6  2.087796e-02         True                                 Influenza A
# 7  2.219830e-02         True                       p53 signaling pathway
#
#    term_size  query_size  intersection_size  effective_domain_size  precision  \
# 0         48        3644                 34                  12415   0.009330
# 1         35        1570                 18                  12415   0.011465
# 2         21        1288                 12                  12415   0.009317
# 3         51        3314                 32                  12415   0.009656
# 4        103         913                 24                  12415   0.026287
# 5        110        3639                 56                  12415   0.015389
# 6        131        3383                 68                  12415   0.020101
# 7         59        1100                 17                  12415   0.015455
#
#      recall    query       parents  \
# 0  0.708333  query_1  [KEGG:00000]
# 1  0.514286  query_1  [KEGG:00000]
# 2  0.571429  query_1  [KEGG:00000]
# 3  0.627451  query_1  [KEGG:00000]
# 4  0.233010  query_1  [KEGG:00000]
# 5  0.509091  query_1  [KEGG:00000]
# 6  0.519084  query_1  [KEGG:00000]
# 7  0.288136  query_1  [KEGG:00000]
#
#                                        intersections  \
# 0  [EHHADH, HADHB, ACSF3, IL4I1, BCAT1, AACS, ACA...
# 1  [PCNA, MCM5, RFC5, RFC1, PRIM1, MCM2, MCM4, RF...
# 2  [PCNA, PMS2, RFC5, RFC1, RFC4, MSH6, POLD3, MS...
# 3  [TYMS, CAD, ENTPD5, TK1, RRM2, UPRT, DTYMK, DC...
# 4  [CDKN2A, CHEK1, TP53, CDK1, MAD2L1, CCNA2, PCN...
# 5  [PGK1, TALDO1, MDH2, SDS, PGAM1, RPIA, SHMT2, ...
# 6  [FADD, TMPRSS4, RELA, JAK1, ICAM1, EP300, XPO1...
# 7  [CDKN2A, CHEK1, TP53, CDK1, SERPINB5, CCNB1, R...
#
#                                            evidences
# 0  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 1  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 3  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 4  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 5  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 6  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 7  [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
