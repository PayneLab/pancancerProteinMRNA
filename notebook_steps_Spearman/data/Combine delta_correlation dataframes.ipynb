# %%
import pandas as pd
import glob

# %%
files = glob.glob('Scripts_to_Make_Cancer_Delta_Corr_and_P_Value_Dataframe/*_delta_corr_pval_df.csv')
files
# Out:
# ['Scripts_to_Make_Cancer_Delta_Corr_and_P_Value_Dataframe\\CCRCC_delta_corr_pval_df.csv',
#  'Scripts_to_Make_Cancer_Delta_Corr_and_P_Value_Dataframe\\Endometrial_delta_corr_pval_df.csv',
#  'Scripts_to_Make_Cancer_Delta_Corr_and_P_Value_Dataframe\\HNSCC_delta_corr_pval_df.csv',
#  'Scripts_to_Make_Cancer_Delta_Corr_and_P_Value_Dataframe\\LSCC_delta_corr_pval_df.csv',
#  'Scripts_to_Make_Cancer_Delta_Corr_and_P_Value_Dataframe\\LUAD_delta_corr_pval_df.csv']

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
delta_corr_df = pd.concat(dfs)
delta_corr_df = delta_corr_df[delta_corr_df.Cancer != 'PDAC']
delta_corr_df.to_csv('delta_correlation_df.csv', index = False)
delta_corr_df
# Out:
#          Gene  Delta_Correlation       P_Value           FDR Cancer
# 0        A1BG          -0.268533  5.703182e-02  1.320375e-01  CCRCC
# 1        A1CF           0.192038  1.063340e-04  6.401858e-04  CCRCC
# 2         A2M          -0.191619  1.277644e-01  2.439276e-01  CCRCC
# 3        AAAS           0.019654  8.963138e-01  9.409267e-01  CCRCC
# 4        AACS          -0.169937  6.007042e-02  1.375402e-01  CCRCC
# ...       ...                ...           ...           ...    ...
# 10054    ZXDC           0.073854  6.395306e-01  6.962162e-01   LUAD
# 10055  ZYG11B           0.734569  1.583743e-10  1.504331e-09   LUAD
# 10056     ZYX           0.440861  2.253307e-06  9.499585e-06   LUAD
# 10057   ZZEF1           0.422001  3.731185e-11  3.889196e-10   LUAD
# 10058    ZZZ3           0.717501  2.955080e-06  1.215796e-05   LUAD
#
# [50308 rows x 5 columns]
